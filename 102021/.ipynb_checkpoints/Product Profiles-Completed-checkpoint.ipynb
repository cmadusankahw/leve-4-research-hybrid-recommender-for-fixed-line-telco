# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %% [markdown]
# ### Columns - common
# - Product_ID - product code
# - Base_Type (BB/VOICE/PEOTV)
# - Pricing_Type (PAID/FREE)
# - Package_Type (ADSL/Fibre/4G/Telephone/PeoTV)
# - VAS (YES/NO) - value added service
# - Title
# - Description
# - Included_Packages - packages shipped with a product
# - Price (Rs.) - totl cost, downpayment or first installment
# - Monthly_Rental (Rs.)
# - Subscription_Type (SINGLE_PLAY/DOUBLE_PLAY/TRIPLE_PLAY)
# - Minimum_Subscription_Period (years)
# - Recidence_Type (Home/Office)
# - Tax_Status (INCLUDED/EXCLUDED)
# - Conditions - list of conditions for package
# - **Available_Regions** - list of available regions: MSAN or related level
# - **Dependent_Packages** (other products it depends on)

# %% [markdown]
# ### Columns- BB
# - BB_Data_standard (GB) - Standard data for a Time-based package
# - BB_Data_Free (GB) - Free data for a Time-based package
# - BB_Data_Anytime (GB) - data for anytime package
# - BB_Data_Unlimited (GB) - data for unlimited package
# - BB_Connection_Type (Time-based/Anytime/Unlimited)
# - BB_Connection_Speed (Download Speed/ Upload Speed)

# %% [markdown]
# ### Columns- VOICE
# - VOICE_Home_SLT_Instrument_Rental (Rs.) - Home Telephone rental (with SLT provided telephone)
# - VOICE_Home_Customer_Instrument_Rental (Rs.) - Home Telephone rental (with Customer provided telephone)
# - VOICE_Charge_Active_Hours (SLT-STL, SLT-Other) (Rs.) - Voice calls charges for Active hours
# - VOICE_Charge_Leisure_Hours (SLT-STL, SLT-Other) (Rs.) - Voice calls charges for Leisure hours
# - VOICE_Free_Minutes - Free voice call minutes given per package
# - VOICE_Telehelth_Insurance_Benefits (Rs.) - Awarded Benefit at fullfilment for SLT Telehealth Insurance packages
# - VOICE_Tele_Life_Insurance_Benefits (Rs.) - Awarded Benefit at fullfilment for SLT Tele Life Insurance packages

# %% [markdown]
# ### Columns- PEOTV
# - PEOTV_No_of_Channels - No of channels in a PEO TV package

# %%
# product catalog
product_catalog = pd.read_csv("data/product_catalog/Product_Profile_CSv.csv")

# %%
business_rules = pd.read_csv("data/product_catalog/business_rules.csv")

# %%
peo_packages_df = pd.read_csv("data/product_catalog/PeoTV_Package_Channel_Map_Transposed.csv")

# %%
bss_info_df = pd.read_csv("data/product_catalog/Product_Info_BSS_All.csv")
packages_info_df = pd.read_csv("data/product_catalog/Packages_Info.csv")

# %% [markdown]
# ## Merging Actual Product Information Datasets

# %% [markdown]
# ### VAS Info dataset for merging

# %%
bss_info_df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
packages_info_df
# Out:
#      Unnamed: 0                      Package  Rental Package_Type  \
# 0             0                         KASP   132.0        Other
# 1             1  BB_SLT Film Hall Portal VOD     NaN           BB
# 2             2  V_E-channeling Subscription     NaN        Voice
# 3             3              V_Detailed Bill     0.0        Voice
# 4             4    P_Megaline New Connection     0.0        Other
# ..          ...                          ...     ...          ...
# 136         136           V_Absentee service     0.0        Voice
# 137         137        V_Abbreviated Dialing     0.0        Voice
# 138         138    V_Call Transfer Three way     0.0        Voice
# 139         139            V_Call Forwarding     0.0        Voice
# 140         140               V_Call Waiting     0.0        Voice
#
#     Product_Type MEDIUM                  TARIFF_NAME  \
# 0            NaN    NaN                          NaN
# 1            NaN    NaN  BB SLT Film Hall VOD_Charge
# 2            NaN    NaN   V_E-Channeling Reservation
# 3            NaN    NaN                          NaN
# 4       Megaline    NaN                          NaN
# ..           ...    ...                          ...
# 136          NaN    NaN                          NaN
# 137          NaN    NaN                          NaN
# 138          NaN    NaN                          NaN
# 139          NaN    NaN                          NaN
# 140          NaN    NaN                          NaN
#
#                      TARIFF_DESC is_VAS is_Promotion is_Subscription  \
# 0                            NaN    YES           NO              NO
# 1    BB SLT Film Hall VOD_Charge     NO           NO              NO
# 2     V_E-Channeling Reservation    YES           NO              NO
# 3                            NaN    YES           NO              NO
# 4                            NaN     NO           NO             YES
# ..                           ...    ...          ...             ...
# 136                          NaN     NO           NO              NO
# 137                          NaN     NO           NO              NO
# 138                          NaN     NO           NO              NO
# 139                          NaN     NO           NO              NO
# 140                          NaN     NO           NO              NO
#
#     FREE_or_PAID
# 0           PAID
# 1           PAID
# 2           PAID
# 3           PAID
# 4           PAID
# ..           ...
# 136         FREE
# 137         FREE
# 138         FREE
# 139         FREE
# 140         FREE
#
# [141 rows x 12 columns]

# %%
product_catalog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 42 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Product_ID                             242 non-null    object
#  1   Base_Type                              242 non-null    object
#  2   Pricing_Type                           155 non-null    object
#  3   Package_Type                           155 non-null    object
#  4   VAS                                    159 non-null    object
#  5   Title                                  155 non-null    object
#  6   Description                            66 non-null     object
#  7   BB_Data_Standard                       43 non-null     float64
#  8   BB_Data_Free                           44 non-null     object
#  9   BB_Data_Anytime                        33 non-null     float64
#  10  BB_Data_Unlimited                      11 non-null     object
#  11  BB_Connection_Type                     87 non-null     object
#  12  BB_Connection_Speed                    97 non-null     object
#  13  Included_Packages                      11 non-null     object
#  14  Price                                  147 non-null    object
#  15  Monthly_Rental                         133 non-null    object
#  16  VOICE_Home_SLT_Instrument_Rental       11 non-null     float64
#  17  VOICE_Home_Customer_Instrument_Rental  11 non-null     float64
#  18  VOICE_Charge_Active_Hours              16 non-null     object
#  19  VOICE_Charge_Leisure_Hours             16 non-null     object
#  20  VOICE_Free_Minutes                     11 non-null     object
#  21  VOICE_Telehelth_Insurance_Benefits     3 non-null      float64
#  22  VOICE_Tele_Life_Insurance_Benefits     8 non-null      float64
#  23  PEOTV_No_of_Channels                   8 non-null      float64
#  24  PEOTV_Foreign_Channels                 8 non-null      float64
#  25  PEOTV_Local_Channels                   8 non-null      float64
#  26  PEOTV_Movie_Channels                   8 non-null      float64
#  27  PEOTV_Kids_Channels                    8 non-null      float64
#  28  PEOTV_Religious_Channels               8 non-null      float64
#  29  PEOTV_Tamil_Channels                   8 non-null      float64
#  30  PEOTV_Educational_Channels             8 non-null      float64
#  31  PEOTV_Music_Channels                   8 non-null      float64
#  32  PEOTV_Sports_Channels                  8 non-null      float64
#  33  PEOTV_News_Channels                    8 non-null      float64
#  34  PEOTV_HD_Pack                          22 non-null     object
#  35  Subscription_Type                      155 non-null    object
#  36  Minimum_Subscription_Period            19 non-null     float64
#  37  Recidence_Type                         154 non-null    object
#  38  Tax_Status                             151 non-null    object
#  39  Conditions                             151 non-null    object
#  40  Available_Regions                      0 non-null      float64
#  41  Dependent_Packages                     1 non-null      object
# dtypes: float64(19), object(23)
# memory usage: 79.5+ KB

# %%
bss_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT_ID       29 non-null     int64
#  1   PRODUCT_NAME     29 non-null     object
#  2   MEDIUM           23 non-null     object
#  3   CATEGORY         23 non-null     object
#  4   Monthly_Rental   13 non-null     float64
#  5   BILLING_CENTRE   29 non-null     object
#  6   ACCOUNT_MANAGER  28 non-null     object
#  7   TARIFF_ID        29 non-null     int64
#  8   TARIFF_NAME      29 non-null     object
#  9   TARIFF_DESC      29 non-null     object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.4+ KB

# %%
def update_vas_ype(vas):
    if not isinstance(vas, float):
        if "Voice" in vas:
            return "VOICE"
        if "Other" in vas:
            return "OTHER"
        if "PeoTV" in vas:
            return "PEOTV"
        else:
            return vas

# %%
vas_all_df["VAS_Type"] = vas_all_df["VAS_Type"].apply(lambda x: update_vas_ype(x))

# %%
vas_all_df["VAS_Type"].unique()
# Out:
# array(['OTHER', 'VOICE', 'FREE', 'BB', 'PEOTV'], dtype=object)

# %%
vas_all_df.rename(columns={"VAS":"Product_ID","VAS_Type":"Base_Type","Rental":"Monthly_Rental","One_Time_Charge":"Price"},inplace=True)

# %%
vas_all_df["Product_ID"].unique()
# Out:
# array(['C_Sisu Connect', 'P-Plus4_Tele Life', 'V-Basic4_TeleLife',
#        'V-Basic2_TeleLife', 'P-Basic4_Tele Life', 'C-Basic1_Tele Life',
#        'V-Plus4_TeleLife', 'P-Basic2_Tele Life', 'P_Sisu Connect',
#        'V_E-channeling Subscription', 'V_Detailed Bill',
#        'P_Incoming Call Memory', 'P_Call Forwarding by time',
#        'P_CLI presentation in call waiting', 'P_Call park',
#        'P_Anonymous call barring', 'P_Call back on busy',
#        'P_Outgoing Call Memory', 'P_Call Forwarding Offline',
#        'P_Call holding', 'P_Call Transfer Three way',
#        'P_Incoming Call Transfer', 'P_Megaline New Connection',
#        'P_Additional features -Double VAS Bundle',
#        'V_One-Time Detailed Bill', 'P-Plus1_Tele Life',
#        'BB_SLT Film Hall Service', 'V_Call Forwarding - On Busy',
#        'AB_Additional Distance', 'V_Call Forwarding - No Answer',
#        'V_Short Message Service', 'V_Cordeless Phone - Installment',
#        'V_Referral offer Discount', 'V_Basic Phone', 'V_Sisu Connect',
#        'V_Miscellaneous Service', 'V_Voice Startup Fee',
#        'AB_Referral offer Discount', 'V-Plus1_TeleLife',
#        'E_Referral offer Discount', 'V_Double VAS Bundle',
#        'AB_Citylink Loyalty Rewards', 'AB_Relocation', 'OTT_SLT PeoTV Go',
#        'V_E-channeling Registration', 'M_Activation Charge',
#        'AB_Megaline Startup', 'V_Call Forwarding - Immediate',
#        'V_Call Barring - Outgoing', 'V_Call Barring', 'AB_Rental Free',
#        'V_Telehealth', 'V_Railway Registration', 'V_Triple VAS Bundle',
#        'V_Caller Line Identification', 'V_Hotline-Immediate',
#        'P_Removal of Int & Parallel Ext', 'P_One-Time Detailed Bill',
#        'DQ_Contact Details', 'P_IDD', 'P_SLT CLI', 'P_Megaline',
#        'BB_Detailed Reports ', 'P-Basic1_Tele Life',
#        'AB_Fiber Access Bearer', 'V_Selective call acceptance',
#        'V_Caller name sending',
#        'V_Caller name identificationPresentation',
#        'V_Password call barring (secret code)',
#        'Package Rental Through ADSL', 'V_Call forwarding selective',
#        'V_Complete call on no response', 'V_Do not disturb service',
#        'V_Selective call waiting', 'V_Selective call rejection',
#        'V_Secretary service', 'V_Call holding',
#        'V_Call Forwarding by time', 'V_Call back on busy',
#        'V_CLI presentation in call waiting', 'V_Call park',
#        'V_Call Forwarding Offline', 'V_Basic Phone Installment',
#        'V_Incoming Call Transfer', 'V_Incoming Call Memory',
#        'V_Anonymous call barring', 'V_Outgoing Call Memory',
#        'V_Call Forwarding', 'V_Abbreviated Dialing', 'V_Absentee service',
#        'V_Call Transfer Three way', 'E_Video on Demand', 'V_Installment',
#        'V_Single VAS Bundle', 'AB_Service Vacation', 'V_SLT CLI',
#        'V_DQ Contact Details', 'AB_Parallel line Installation', 'V_IDD',
#        'E_PeoTV Initiation', 'V_Hotline-Time Delayed',
#        'V_Call Forwarding-No Answer', 'V_Call Forwarding-On Busy',
#        'V_Call Forwarding-Immediate', 'V_Hotline Service',
#        'V_Call Waiting', 'E_PeoTV_Package Transfer', 'E_TSTV',
#        'AB_Megaline', 'PeoTVGo_Channel Package',
#        'BB_PeoTVGO Revenue code', 'PEO TV GO_OTT_A-la carte channels',
#        'E_SLT PeoTV Service', 'AB_Copper Access Bearer',
#        'BB_Personal Storage', 'BB_SLT BroadBand Service',
#        'AB_WireLess Access', 'V_SLT Voice Service', 'BB_PeoTVGO',
#        'BB_Messenger Bundle', 'BB_ Entertainment Unlimited',
#        'V-Basic1_TeleLife', 'BB_YouTube Bundle', 'Edu Lite', 'Meet Lite',
#        'Meet Max', 'BB Personal Storage', 'BB_Report Subscription Charge'],
#       dtype=object)

# %%
vas_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product_ID      128 non-null    object
#  1   Monthly_Rental  25 non-null     float64
#  2   Price           3 non-null      float64
#  3   Base_Type       128 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 4.1+ KB

# %% [markdown]
# ### Products from BSS merging

# %%
products_bss_df = pd.read_csv("data/product_catalog/Product_info_from_BSS.csv")

# %%
products_bss_df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
def update_cat(cat):
    if not isinstance(cat, float):
        if "Single Play-Voice" in cat:
            return "SINGLE_PLAY"
        if "Triple Play" in cat:
            return "TRIPLE_PLAY"
        if "Double Play" in cat:
            return "DOUBLE_PLAY"

# %%
products_bss_df["CATEGORY"] = products_bss_df["CATEGORY"].apply(lambda x: update_cat(x))

# %%
products_bss_df.drop(["PRODUCT_ID.hash","TARIFF_ID.hash","CATEGORY_DETAILS"],axis=1,inplace=True)

# %%
products_bss_df.rename(columns={"PRODUCT_NAME":"Product_ID","CATEGORY":"Subscription_Type","MEDIUM":"Transfer_Medium"}, inplace=True)

# %%
products_bss_df["Product_ID"].unique()
# Out:
# array([nan, 'V-Plus4_TeleLife', 'V_E-channeling Subscription',
#        'V-Basic2_TeleLife', 'V-Basic4_TeleLife', 'V-Basic1_TeleLife',
#        'V_Sisu Connect', 'V_Telehealth', 'V-Plus1_TeleLife',
#        'V_E-channeling Registration', 'BB_ Entertainment Unlimited',
#        'OTT_SLT PeoTV Go', 'AB_WireLess Access',
#        'BB_SLT Film Hall Service', 'BB_Detailed Reports ',
#        'AB_Fiber Access Bearer', 'BB_PeoTVGO', 'BB_Extra GB',
#        'BB_SLT BroadBand Service', 'BB_Personal Storage',
#        'E_SLT PeoTV Service', 'V_SLT Voice Service',
#        'AB_Copper Access Bearer'], dtype=object)

# %%
products_bss_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product_ID         22 non-null     object
#  1   Transfer_Medium    19 non-null     object
#  2   Subscription_Type  17 non-null     object
#  3   TARIFF_NAME        22 non-null     object
#  4   TARIFF_DESC        22 non-null     object
#  5   Monthly_Rental     10 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 1.2+ KB

# %% [markdown]
# ### Meging DF to product catalog

# %%
final_product_catalog = pd.concat([product_catalog,vas_all_df,products_bss_df], axis=0, ignore_index=True)

# %%
final_product_catalog.drop_duplicates(["Product_ID"],inplace=True,keep="last")

# %%
final_product_catalog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 0 to 392
# Data columns (total 45 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Product_ID                             263 non-null    object
#  1   Base_Type                              241 non-null    object
#  2   Pricing_Type                           134 non-null    object
#  3   Package_Type                           134 non-null    object
#  4   VAS                                    134 non-null    object
#  5   Title                                  134 non-null    object
#  6   Description                            47 non-null     object
#  7   BB_Data_Standard                       43 non-null     float64
#  8   BB_Data_Free                           43 non-null     object
#  9   BB_Data_Anytime                        32 non-null     float64
#  10  BB_Data_Unlimited                      11 non-null     object
#  11  BB_Connection_Type                     86 non-null     object
#  12  BB_Connection_Speed                    89 non-null     object
#  13  Included_Packages                      3 non-null      object
#  14  Price                                  133 non-null    object
#  15  Monthly_Rental                         141 non-null    object
#  16  VOICE_Home_SLT_Instrument_Rental       3 non-null      float64
#  17  VOICE_Home_Customer_Instrument_Rental  3 non-null      float64
#  18  VOICE_Charge_Active_Hours              6 non-null      object
#  19  VOICE_Charge_Leisure_Hours             6 non-null      object
#  20  VOICE_Free_Minutes                     3 non-null      object
#  21  VOICE_Telehelth_Insurance_Benefits     0 non-null      float64
#  22  VOICE_Tele_Life_Insurance_Benefits     3 non-null      float64
#  23  PEOTV_No_of_Channels                   8 non-null      float64
#  24  PEOTV_Foreign_Channels                 8 non-null      float64
#  25  PEOTV_Local_Channels                   8 non-null      float64
#  26  PEOTV_Movie_Channels                   8 non-null      float64
#  27  PEOTV_Kids_Channels                    8 non-null      float64
#  28  PEOTV_Religious_Channels               8 non-null      float64
#  29  PEOTV_Tamil_Channels                   8 non-null      float64
#  30  PEOTV_Educational_Channels             8 non-null      float64
#  31  PEOTV_Music_Channels                   8 non-null      float64
#  32  PEOTV_Sports_Channels                  8 non-null      float64
#  33  PEOTV_News_Channels                    8 non-null      float64
#  34  PEOTV_HD_Pack                          22 non-null     object
#  35  Subscription_Type                      151 non-null    object
#  36  Minimum_Subscription_Period            6 non-null      float64
#  37  Recidence_Type                         134 non-null    object
#  38  Tax_Status                             131 non-null    object
#  39  Conditions                             131 non-null    object
#  40  Available_Regions                      0 non-null      float64
#  41  Dependent_Packages                     0 non-null      object
#  42  Transfer_Medium                        19 non-null     object
#  43  TARIFF_NAME                            22 non-null     object
#  44  TARIFF_DESC                            22 non-null     object
# dtypes: float64(19), object(26)
# memory usage: 94.9+ KB

# %% [markdown]
# ### Mark VAS Services

# %%
original_list = final_product_catalog["Product_ID"].unique()

# %%
# other products list
vas_list_df = pd.read_csv("data/product_catalog/VAS_Names_Only_List.csv")
vas_list = vas_list_df["VAS"].unique()

# %%
matches = list(set(original_list).intersection(set(vas_list)))
matches
# Out:
# ['PeoTVGo_Channel Package',
#  'V_Sisu Connect',
#  'V_Call Forwarding - No Answer',
#  'P-Plus1_Tele Life',
#  'V_E-channeling Subscription',
#  'V_Hotline-Immediate',
#  'E_Referral offer Discount',
#  'P_IDD',
#  'V_Hotline Service',
#  'P_Call back on busy',
#  'V_Password call barring (secret code)',
#  'V_Railway Registration',
#  'V-Basic2_TeleLife',
#  'Meet Lite',
#  'V-Basic4_TeleLife',
#  'BB_Detailed Reports ',
#  'P_Call Forwarding Offline',
#  'V_SLT CLI',
#  'V_Single VAS Bundle',
#  'P_Incoming Call Transfer',
#  'V_Call Forwarding by time',
#  'V_Call Waiting',
#  'P_Call holding',
#  'BB_PeoTVGO Revenue code',
#  'V_Basic Phone Installment',
#  'P_Megaline New Connection',
#  'V_Double VAS Bundle',
#  'V_Call holding',
#  'M_Activation Charge',
#  'BB_YouTube Bundle',
#  'BB_SLT Film Hall Service',
#  'P_Call Forwarding by time',
#  'BB_Report Subscription Charge',
#  'OTT_SLT PeoTV Go',
#  'V_Call park',
#  'BB Personal Storage',
#  'V_Incoming Call Memory',
#  'P_CLI presentation in call waiting',
#  'BB_PeoTVGO',
#  'V_Call back on busy',
#  'V_SLT Voice Service',
#  'P-Basic1_Tele Life',
#  'PEO TV GO_OTT_A-la carte channels',
#  'P_Outgoing Call Memory',
#  'V_Short Message Service',
#  'V_One-Time Detailed Bill',
#  'Package Rental Through ADSL',
#  'P_One-Time Detailed Bill',
#  'V_Anonymous call barring',
#  'V_Call forwarding selective',
#  'BB_SLT BroadBand Service',
#  'V_IDD',
#  'V_Caller name sending',
#  'P_Call Transfer Three way',
#  'P_Incoming Call Memory',
#  'V_Call Forwarding - On Busy',
#  'V_Installment',
#  'AB_Citylink Loyalty Rewards',
#  'V-Plus4_TeleLife',
#  'V_Absentee service',
#  'AB_Service Vacation',
#  'V_Call Barring - Outgoing',
#  'V_DQ Contact Details',
#  'V_Call Transfer Three way',
#  'P_Anonymous call barring',
#  'E_PeoTV Initiation',
#  'V_Hotline-Time Delayed',
#  'AB_Megaline',
#  'P_Call park',
#  'AB_Additional Distance',
#  'E_TSTV',
#  'AB_Megaline Startup',
#  'Meet Max',
#  'E_SLT PeoTV Service',
#  'DQ_Contact Details',
#  'V_Abbreviated Dialing',
#  'V_Referral offer Discount',
#  'BB_Personal Storage',
#  'V_Do not disturb service',
#  'V_Voice Startup Fee',
#  'V-Plus1_TeleLife',
#  'V_Telehealth',
#  'Edu Lite',
#  'V_Miscellaneous Service',
#  'C-Basic1_Tele Life',
#  'V_Call Forwarding-On Busy',
#  'P_Megaline',
#  'P-Basic4_Tele Life',
#  'V_Call Barring',
#  'P_Removal of Int & Parallel Ext',
#  'V_Caller name identificationPresentation',
#  'V_Call Forwarding',
#  'P_SLT CLI',
#  'AB_Fiber Access Bearer',
#  'V_Selective call waiting',
#  'V_Secretary service',
#  'V_CLI presentation in call waiting',
#  'P-Basic2_Tele Life',
#  'V_Selective call rejection',
#  'V-Basic1_TeleLife',
#  'V_Selective call acceptance',
#  'V_Incoming Call Transfer',
#  'AB_WireLess Access',
#  'AB_Rental Free',
#  'P_Additional features -Double VAS Bundle',
#  'AB_Parallel line Installation',
#  'AB_Copper Access Bearer',
#  'P_Sisu Connect',
#  'V_Cordeless Phone - Installment',
#  'V_Triple VAS Bundle',
#  'BB_Messenger Bundle',
#  'V_Detailed Bill',
#  'V_Complete call on no response',
#  'E_PeoTV_Package Transfer',
#  'V_Call Forwarding Offline',
#  'AB_Referral offer Discount',
#  'V_Call Forwarding-Immediate',
#  'V_E-channeling Registration',
#  'C_Sisu Connect',
#  'V_Caller Line Identification',
#  'V_Call Forwarding-No Answer',
#  'V_Call Forwarding - Immediate',
#  'BB_ Entertainment Unlimited',
#  'E_Video on Demand',
#  'V_Outgoing Call Memory',
#  'V_Basic Phone',
#  'AB_Relocation',
#  'P-Plus4_Tele Life']

# %%
def mark_vas(pid, vas):
    if not isinstance(pid, float):
        for v in matches:
            if v in pid:
                return "YES"
        return vas

# %%
final_product_catalog["VAS"] = final_product_catalog.apply(lambda x: mark_vas(x["Product_ID"], x["VAS"]), axis=1)

# %%
final_product_catalog.reset_index(inplace=True)

# %%
final_product_catalog.drop(["index"],axis=1,inplace=True)

# %%
final_product_catalog["VAS"].value_counts()
# Out:
# YES    151
# NO     111
# Name: VAS, dtype: int64

# %% [markdown]
# ## ToDo
# - Monthly rental/ One Time Purchase details for VAS
# - Most available locations for VAS/ Peo TV Packages

# %% [markdown]
# ## Merging Business Rules

# %%
business_rules.columns = ["description","LTE","Megaline","FTTH"]

# %%
business_rules = business_rules.iloc[2:,:]

# %%
business_rules.dropna(how='all', inplace=True)
# Out:
# <ipython-input-50-72796c5fb044>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   business_rules.dropna(how='all', inplace=True)

# %%
business_rules.fillna(method='ffill', inplace=True)
# Out:
# /home/chiran/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# #### Filling Sub Type in Business rules

# %%
business_rules
# Out:
#             description                                                LTE  \
# 2               BB only                                          Available
# 4               BB only                                          Available
# 5              PEO only                 Peo Tv go-Least recommended option
# 7              PEO only                 Peo Tv go-Least recommended option
# 8      Package Transfer  · LTE to Mega –No such product but can be reco...
# 10     Package Transfer  · LTE to Fiber- No such product but can be rec...
# 13  Multiple Voice, Peo                                      Not Available
# 14    Commitment period                                      Not Available
# 16    Commitment period                                      Not Available
# 17             Distance                                      Not Available
# 19             Distance                                      Not Available
# 22       Special points      BB package starts from Rs.740/= worth package
# 24       Special points      BB package starts from Rs.740/= worth package
# 26       Special points      BB package starts from Rs.740/= worth package
# 30       Special points      BB package starts from Rs.740/= worth package
# 32       Special points      BB package starts from Rs.740/= worth package
# 34       Special points      BB package starts from Rs.740/= worth package
#
#                                              Megaline  \
# 2                                         Voice+BB or
# 4                               Triple play available
# 5                                        Voice+PEO or
# 7                               Triple play available
# 8                 · Mega to Fiber highly recommended.
# 10  · Mega to LTE - No such product & not recommended
# 13                                      Not Available
# 14                             · One year commitment.
# 16  · Cannot do the location changes until the per...
# 17  · Up to 500 m Free of charge  Charged Rs.2400 ...
# 19                     · Maximum distance up to 750 m
# 22                     · For triple play- Router FOC.
# 24                       · For Voice+Peo- Router FOC.
# 26           · For Voice+BB- charging for the router.
# 30                       · Early Termination charged.
# 32                         · BB starts from Web lite.
# 34                      · Peo starts from Peo silver.
#
#                                                  FTTH
# 2                                         Voice+BB or
# 4                               Triple play available
# 5                                        Voice+PEO or
# 7                               Triple play available
# 8   · FTTH to Mega or FTTH to LTE- cannot be migra...
# 10  · FTTH to Mega or FTTH to LTE- cannot be migra...
# 13                                          Available
# 14                             · One year commitment.
# 16  · Cannot do the location changes until the per...
# 17  · Up to 500 m Free of charge charged Rs.2400 p...
# 19                     · Maximum distance up to 750 m
# 22                  · BB package starts from Web Pal.
# 24          · Peo starts from Rs.890/= worth package.
# 26                       · Early Termination charged.
# 30                       · Early Termination charged.
# 32                       · Early Termination charged.
# 34                       · Early Termination charged.

# %%
final_product_catalog
# Out:
#                    Product_ID Base_Type Pricing_Type Package_Type  VAS  \
# 0         BB_Higher_Education        BB         PAID         ADSL   NO
# 1                 BB_Web_Lite        BB         PAID         ADSL   NO
# 2                   BB_Entree        BB         PAID         ADSL   NO
# 3           BB_Web_Starter_4G        BB         PAID           4G   NO
# 4         BB_Web_Starter_ADSL        BB         PAID         ADSL   NO
# ..                        ...       ...          ...          ...  ...
# 259  BB_SLT BroadBand Service       NaN          NaN          NaN  YES
# 260       BB_Personal Storage       NaN          NaN          NaN  YES
# 261       E_SLT PeoTV Service       NaN          NaN          NaN  YES
# 262       V_SLT Voice Service       NaN          NaN          NaN  YES
# 263   AB_Copper Access Bearer       NaN          NaN          NaN  YES
#
#                 Title Description  BB_Data_Standard BB_Data_Free  \
# 0    HIGHER EDUCATION         NaN               4.0            6
# 1            WEB LITE         NaN               6.0            9
# 2              ENTREE         NaN               NaN          NaN
# 3      WEB STARTER 4G         NaN              11.0           17
# 4    WEB STARTER ADSL         NaN              11.0           17
# ..                ...         ...               ...          ...
# 259               NaN         NaN               NaN          NaN
# 260               NaN         NaN               NaN          NaN
# 261               NaN         NaN               NaN          NaN
# 262               NaN         NaN               NaN          NaN
# 263               NaN         NaN               NaN          NaN
#
#      BB_Data_Anytime  ...         Subscription_Type  \
# 0                NaN  ...  DOUBLE_PLAY, TRIPLE_PLAY
# 1                NaN  ...  DOUBLE_PLAY, TRIPLE_PLAY
# 2                7.0  ...  DOUBLE_PLAY, TRIPLE_PLAY
# 3                NaN  ...  DOUBLE_PLAY, TRIPLE_PLAY
# 4                NaN  ...  DOUBLE_PLAY, TRIPLE_PLAY
# ..               ...  ...                       ...
# 259              NaN  ...               DOUBLE_PLAY
# 260              NaN  ...               DOUBLE_PLAY
# 261              NaN  ...                      None
# 262              NaN  ...                      None
# 263              NaN  ...                      None
#
#     Minimum_Subscription_Period Recidence_Type Tax_Status  \
# 0                           NaN           Home   EXCLUDED
# 1                           NaN           Home   EXCLUDED
# 2                           NaN           Home   EXCLUDED
# 3                           NaN           Home   EXCLUDED
# 4                           NaN           Home   EXCLUDED
# ..                          ...            ...        ...
# 259                         NaN            NaN        NaN
# 260                         NaN            NaN        NaN
# 261                         NaN            NaN        NaN
# 262                         NaN            NaN        NaN
# 263                         NaN            NaN        NaN
#
#                                             Conditions Available_Regions  \
# 0    Speeds may vary depending on the line distance...               NaN
# 1    Speeds may vary depending on the line distance...               NaN
# 2    Speeds may vary depending on the line distance...               NaN
# 3    Download and upload speed will be reduced to 6...               NaN
# 4    Speeds may vary depending on the line distance...               NaN
# ..                                                 ...               ...
# 259                                                NaN               NaN
# 260                                                NaN               NaN
# 261                                                NaN               NaN
# 262                                                NaN               NaN
# 263                                                NaN               NaN
#
#      Dependent_Packages  Transfer_Medium  \
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# ..                  ...              ...
# 259                 NaN               MC
# 260                 NaN               MC
# 261                 NaN              NaN
# 262                 NaN              NaN
# 263                 NaN              NaN
#
#                               TARIFF_NAME                     TARIFF_DESC
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ..                                    ...                             ...
# 259                                Entree                          Entrée
# 260                     BB Storage_Charge               BB Storage_Charge
# 261                         Cu_Peo Silver                   Cu_Peo Silver
# 262  z Sales End_Add. Line with SLT Phone  Additional Line with SLT Phone
# 263               AB_Copper Access Bearer         AB_Copper Access Bearer
#
# [264 rows x 45 columns]

# %%
final_product_catalog.to_csv("data/product_catalog/Product_Profile_Finalised.csv")
