# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly import tools
from plotly.subplots import make_subplots
import plotly.offline as py
import seaborn as sns
from ast import literal_eval
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

# %%
user_profile = pd.read_csv("data/user_profile/prepared/User_Profile_Clustered_with_categorical.csv")
user_profile.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1,inplace=True)

# %%
user_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3307 entries, 0 to 3306
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   event_source.hash            3307 non-null   object
#  1   ONNET_OUTGOING_Categorical   3307 non-null   object
#  2   ONNET_OUTGOING_Scaled        3307 non-null   float64
#  3   ONNET_OUTGOING_Outlier       3307 non-null   object
#  4   ONNET_INCOMING_Categorical   3307 non-null   object
#  5   ONNET_INCOMING_Scaled        3307 non-null   float64
#  6   ONNET_INCOMING_Outlier       3307 non-null   object
#  7   OFFNET_OUTGOING_Categorical  3307 non-null   object
#  8   OFFNET_OUTGOING_Scaled       3307 non-null   float64
#  9   OFFNET_OUTGOING_Outlier      3307 non-null   object
#  10  OFFNET_INCOMING_Categorical  3307 non-null   object
#  11  OFFNET_INCOMING_Scaled       3307 non-null   float64
#  12  OFFNET_INCOMING_Outlier      3191 non-null   object
#  13  IDD_INCOMING_Categorical     3307 non-null   object
#  14  IDD_INCOMING_Scaled          3307 non-null   float64
#  15  IDD_INCOMING_Outlier         3307 non-null   object
#  16  IDD_OUTGOING_Categorical     3307 non-null   object
#  17  IDD_OUTGOING_Scaled          3307 non-null   float64
#  18  IDD_OUTGOING_Outlier         3307 non-null   object
#  19  Peo_TV_Package               3307 non-null   object
#  20  PEO_TV_Categorical           3307 non-null   object
#  21  PEO_TV_Scaled                3307 non-null   float64
#  22  BB_Categorical               3307 non-null   object
#  23  BB_Scaled                    3307 non-null   float64
#  24  Location_Identifier          3307 non-null   object
#  25  ONNET_Overall_Categorical    3307 non-null   object
#  26  OFFNET_Overall_Categorical   3307 non-null   object
#  27  IDD_Overall_Categorical      3307 non-null   object
#  28  VOICE_Categorical            3307 non-null   object
#  29  Play_Type                    3307 non-null   object
#  30  Play_Usage                   3307 non-null   object
#  31  Voice_Packages               3307 non-null   object
#  32  Other_Packages               3307 non-null   object
#  33  Household_Types              3307 non-null   object
#  34  Having_Insurance             3307 non-null   object
#  35  Cluster                      3307 non-null   int64
# dtypes: float64(8), int64(1), object(27)
# memory usage: 930.2+ KB

# %%
# clusters
cluster_0 = user_profile[(user_profile["Cluster"]==0)]
cluster_1 = user_profile[(user_profile["Cluster"]==1)]
cluster_2 = user_profile[(user_profile["Cluster"]==2)]

# %%
out_cols = ["ONNET_OUTGOING_Outlier","ONNET_INCOMING_Outlier","OFFNET_OUTGOING_Outlier","OFFNET_INCOMING_Outlier","IDD_INCOMING_Outlier","IDD_OUTGOING_Outlier"]
scaled_cols=["ONNET_OUTGOING_Scaled","ONNET_INCOMING_Scaled","OFFNET_OUTGOING_Scaled","OFFNET_INCOMING_Scaled","IDD_INCOMING_Scaled","IDD_OUTGOING_Scaled"]

# %%
ax = sns.kdeplot(user_profile[scaled_cols[0]][(user_profile[out_cols[0]] == 'NO') ], color="Red", shade = True)
ax = sns.kdeplot(user_profile[scaled_cols[0]][(user_profile[out_cols[0]] == 'YES') ], ax =ax, color="Blue", shade= True)
ax.legend(["Not Outlier","Outlier"],loc='upper right')
ax.set_ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
ax = sns.kdeplot(user_profile[scaled_cols[1]][(user_profile[out_cols[1]] == 'NO') ], color="Red", shade = True)
ax = sns.kdeplot(user_profile[scaled_cols[1]][(user_profile[out_cols[1]] == 'YES') ], ax =ax, color="Blue", shade= True)
ax.legend(["Not Outlier","Outlier"],loc='upper right')
ax.set_ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
ax = sns.kdeplot(user_profile[scaled_cols[2]][(user_profile[out_cols[2]] == 'NO') ], color="Red", shade = True)
ax = sns.kdeplot(user_profile[scaled_cols[2]][(user_profile[out_cols[2]] == 'YES') ], ax =ax, color="Blue", shade= True)
ax.legend(["Not Outlier","Outlier"],loc='upper right')
ax.set_ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
ax = sns.kdeplot(user_profile[scaled_cols[3]][(user_profile[out_cols[3]] == 'NO') ], color="Red", shade = True)
ax = sns.kdeplot(user_profile[scaled_cols[3]][(user_profile[out_cols[3]] == 'YES') ], ax =ax, color="Blue", shade= True)
ax.legend(["Not Outlier","Outlier"],loc='upper right')
ax.set_ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
ax = sns.kdeplot(user_profile[scaled_cols[4]][(user_profile[out_cols[4]] == 'NO') ], color="Red", shade = True)
ax = sns.kdeplot(user_profile[scaled_cols[4]][(user_profile[out_cols[4]] == 'YES') ], ax =ax, color="Blue", shade= True)
ax.legend(["Not Outlier","Outlier"],loc='upper right')
ax.set_ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
ax = sns.kdeplot(user_profile[scaled_cols[5]][(user_profile[out_cols[5]] == 'NO') ], color="Red", shade = True)
ax = sns.kdeplot(user_profile[scaled_cols[5]][(user_profile[out_cols[5]] == 'YES') ], ax =ax, color="Blue", shade= True)
ax.legend(["Not Outlier","Outlier"],loc='upper right')
ax.set_ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# ## ToDO
# - get otliers only by threshold
# - analyze correlations with other features
# - analyze relationships with other features
