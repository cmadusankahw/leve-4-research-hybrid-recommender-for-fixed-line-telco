# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly import tools
from plotly.subplots import make_subplots
import plotly.offline as py
import seaborn as sns
from ast import literal_eval
from collections import Counter

# %%
user_profile = pd.read_csv("data/user_profile/prepared/User_Profile_Clustered_with_categorical.csv")
user_profile.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                 event_source.hash  \
# 0           0             0  00221451f705ebe26051158bb14f567a
# 1           1             1  002fb47f60400713c854b0f69ff78c0a
# 2           2             2  00567a4a3c474aca1ce5cd6570648932
# 3           3             3  00724ae2470df1ed0fe919800d02517d
# 4           4             4  007400db8afa996e788d23986739f3db
#
#   ONNET_OUTGOING_Categorical  ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier  \
# 0                        LOW               0.009321                     NO
# 1                        LOW               0.051339                     NO
# 2                        LOW               0.002404                     NO
# 3                        LOW               0.003140                     NO
# 4                        LOW               0.025755                     NO
#
#   ONNET_INCOMING_Categorical  ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 0                        LOW               0.017514                     NO
# 1                        LOW               0.056319                     NO
# 2                        LOW               0.001374                     NO
# 3                        LOW               0.002747                     NO
# 4                        LOW               0.017857                     NO
#
#   OFFNET_OUTGOING_Categorical  ...  OFFNET_Overall_Categorical  \
# 0                         LOW  ...                         LOW
# 1                         LOW  ...                         LOW
# 2                         LOW  ...                         LOW
# 3                         LOW  ...                         LOW
# 4                         LOW  ...                         LOW
#
#   IDD_Overall_Categorical VOICE_Categorical    Play_Type  \
# 0                      NO               LOW  SINGLE_PLAY
# 1                     LOW               LOW  SINGLE_PLAY
# 2                      NO               LOW  TRIPLE_PLAY
# 3                      NO               LOW  DOUBLE_PLAY
# 4                     LOW               LOW  SINGLE_PLAY
#
#                                 Play_Usage Voice_Packages  Other_Packages  \
# 0          ['VOICE_LOW', 'BB_NO', 'TV_NO']             NO              NO
# 1          ['VOICE_LOW', 'BB_NO', 'TV_NO']             NO              NO
# 2  ['VOICE_LOW', 'BB_MEDIUM', 'TV_MEDIUM']             NO              NO
# 3         ['VOICE_LOW', 'BB_LOW', 'TV_NO']             NO              NO
# 4          ['VOICE_LOW', 'BB_NO', 'TV_NO']             NO              NO
#
#   Household_Types Having_Insurance  Cluster
# 0              NO               NO        0
# 1              NO               NO        0
# 2              NO               NO        1
# 3              NO               NO        2
# 4              NO               NO        0
#
# [5 rows x 38 columns]

# %%
user_profile.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1,inplace=True)

# %% [markdown]
# ### Cluster Counts

# %%
user_profile["Cluster"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Cluster'>

# %% [markdown]
# # Cluster analysis - Cluster 0

# %%
cluster_0 = user_profile[(user_profile["Cluster"]==0)]

# %%
cluster_0.describe()
# Out:
#        ONNET_OUTGOING_Scaled  ONNET_INCOMING_Scaled  OFFNET_OUTGOING_Scaled  \
# count            1721.000000            1721.000000             1721.000000
# mean                0.090396               0.089406                0.102266
# std                 0.103823               0.105735                0.118160
# min                 0.001202               0.000000                0.000000
# 25%                 0.013834               0.012191                0.015993
# 50%                 0.049696               0.047390                0.065640
# 75%                 0.137976               0.133585                0.145310
# max                 1.000000               1.000000                1.000000
#
#        OFFNET_INCOMING_Scaled  IDD_INCOMING_Scaled  IDD_OUTGOING_Scaled  \
# count             1721.000000          1721.000000          1721.000000
# mean                 0.101678             0.037603             0.014981
# std                  0.102458             0.114038             0.066942
# min                  0.000000             0.000000             0.000000
# 25%                  0.019370             0.000000             0.000000
# 50%                  0.077136             0.000000             0.000000
# 75%                  0.156561             0.014423             0.000000
# max                  0.948718             0.884615             0.826923
#
#        PEO_TV_Scaled    BB_Scaled  Cluster
# count    1721.000000  1721.000000   1721.0
# mean        0.006112     0.003899      0.0
# std         0.038001     0.028817      0.0
# min         0.000000     0.000000      0.0
# 25%         0.000000     0.000000      0.0
# 50%         0.000000     0.000000      0.0
# 75%         0.000000     0.000000      0.0
# max         0.425000     0.487847      0.0

# %%
cluster_0.iloc[:,:34].boxplot(figsize=(15,10),rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Usage of randomly selected users

# %%
cluster_0.iloc[:,[2,5,8,11,14,17,21,23]].sample(n=10).plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
cluster_0.iloc[:,[2,5,8,11,14,17,21,23]].plot.kde(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cluster_0.iloc[:,:34].hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'ONNET_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'ONNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'OFFNET_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'OFFNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'PEO_TV_Scaled'}>,
#         <AxesSubplot:title={'center':'BB_Scaled'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### Subscription Type and Usage

# %%
cluster_0["Play_Type"].value_counts()
# Out:
# SINGLE_PLAY    1663
# TRIPLE_PLAY      58
# Name: Play_Type, dtype: int64

# %%
cluster_0["Play_Usage"].value_counts()
# Out:
# ['VOICE_LOW', 'BB_NO', 'TV_NO']            1118
# ['VOICE_MEDIUM', 'BB_NO', 'TV_NO']          480
# ['VOICE_HIGH', 'BB_NO', 'TV_NO']             65
# ['VOICE_LOW', 'BB_LOW', 'TV_LOW']            46
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_LOW']          4
# ['VOICE_LOW', 'BB_LOW', 'TV_MEDIUM']          3
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_LOW']          3
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_MEDIUM']       1
# ['VOICE_HIGH', 'BB_LOW', 'TV_LOW']            1
# Name: Play_Usage, dtype: int64

# %%
ax =cluster_0["Play_Usage"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Voice Calls Usage

# %%
cluster_0["VOICE_Categorical"].value_counts()
# Out:
# LOW       1170
# MEDIUM     485
# HIGH        66
# Name: VOICE_Categorical, dtype: int64

# %%
cluster_0["VOICE_Categorical"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%',colors = ['pink', 'yellow','green'] )
# Out:
# <AxesSubplot:ylabel='VOICE_Categorical'>

# %%
count_dict = dict(cluster_0["Voice_Packages"].value_counts())
all_products = []
for x,y in count_dict.items():
    if x != "NO":
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
    else:
        for i in range(y):
            all_products.append(x)
all_voice_products_dict = Counter(all_products)
all_voice_products_dict
# Out:
# Counter({'NO': 1582,
#          'V_Installment': 13,
#          'V_Call Transfer Three way': 66,
#          'V_Absentee service': 61,
#          'V_Abbreviated Dialing': 60,
#          'V_Call Forwarding': 69,
#          'V_Call Waiting': 59,
#          'V_Call Forwarding-Immediate': 57,
#          'V_Call Forwarding-On Busy': 58,
#          'V_Call Forwarding-No Answer': 58,
#          'V_IDD': 47,
#          'V_Hotline Service': 24,
#          'E_PeoTV_Package Transfer': 3,
#          'V_DQ Contact Details': 48,
#          'V_Basic Phone Installment': 3,
#          'V_Cordeless Phone - Installment': 3,
#          'V_SLT CLI': 31,
#          'V_SLT Voice Service': 22,
#          'V_Single VAS Bundle': 30,
#          'V_Caller Line Identification': 10,
#          'V_Call Forwarding Offline': 36,
#          'V_Outgoing Call Memory': 35,
#          'V_Hotline-Immediate': 12,
#          'V_Hotline-Time Delayed': 13,
#          'V_Call holding': 34,
#          'V_Call Forwarding by time': 33,
#          'V_Incoming Call Memory': 35,
#          'V-Plus1_TeleLife': 1,
#          'V_Miscellaneous Service': 1,
#          'V_Call park': 21,
#          'V_Call back on busy': 21,
#          'V_Anonymous call barring': 21,
#          'V_Incoming Call Transfer': 26,
#          'V_CLI presentation in call waiting': 21,
#          'V_Double VAS Bundle': 2,
#          'V_Caller name sending': 2,
#          'V_Call forwarding selective': 2,
#          'V_Caller name identificationPresentation': 2,
#          'V_Do not disturb service': 2,
#          'V_Password call barring (secret code)': 2,
#          'V_Secretary service': 2,
#          'V_Selective call acceptance': 2,
#          'V_Selective call rejection': 2,
#          'V_Selective call waiting': 2,
#          'V_Complete call on no response': 2,
#          'V_Triple VAS Bundle': 1,
#          'V_Railway Registration': 1,
#          'V_E-channeling Registration': 1,
#          'V_Short Message Service': 3,
#          'V_Call Forwarding - Immediate': 3,
#          'V_Call Barring - Outgoing': 2,
#          'V_Sisu Connect': 1,
#          'V_Call Forwarding - No Answer': 2,
#          'V_Call Forwarding - On Busy': 2,
#          'V_One-Time Detailed Bill': 1})

# %%
avp_without_no = all_voice_products_dict
avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(20,10))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### IDD Usage

# %%
cluster_0["IDD_Overall_Categorical"].value_counts()
# Out:
# NO        1054
# LOW        592
# MEDIUM      38
# HIGH        37
# Name: IDD_Overall_Categorical, dtype: int64

# %%
cluster_0["IDD_Overall_Categorical"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%',colors = ['red', 'pink','yellow','green'] )
# Out:
# <AxesSubplot:ylabel='IDD_Overall_Categorical'>

# %% [markdown]
# ### PeoTV Usage

# %%
cluster_0["PEO_TV_Categorical"].value_counts()
# Out:
# NO        1663
# LOW         54
# MEDIUM       4
# Name: PEO_TV_Categorical, dtype: int64

# %% [markdown]
# #### PeoTV Usage among Triple Play users in Cluster 0

# %%
cluster_0_peo = cluster_0[(cluster_0["Play_Type"] == "TRIPLE_PLAY")]
cluster_0_peo["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%',colors = ['pink','yellow','green'])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %%
ax =cluster_0_peo["Peo_TV_Package"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### BroadBand Internet Usage

# %%
cluster_0["BB_Categorical"].value_counts()
# Out:
# NO        1663
# LOW         55
# MEDIUM       3
# Name: BB_Categorical, dtype: int64

# %% [markdown]
# #### BB Usage for triple Play users in Cluster 0

# %%
cluster_0_bb = cluster_0[(cluster_0["Play_Type"] == "TRIPLE_PLAY")]
cluster_0_bb["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%',colors = ['pink','yellow','green'])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# ### User Location

# %%
ax =cluster_0["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %%
cluster_0["Location_Identifier"].value_counts()
# Out:
# MSAG5200-ISLND-PHG-NODE500241      242
# MSAG5200-ISLMV-GDM-NODE482491      209
# MSAG5200-ISLMT-AVR-NODE467161      152
# MSAG5200PH-AKG-NODE431631          115
# MSAG5200-ISLIDH-KGW-NODE6194491    107
# C300MNW-MEE-NODE18887751            98
# MSAG5200-ISLSI-DWS-NODE520721       95
# MSAG5200-ISLBZ-NODE435881           90
# MSAG5200BG-NODE431391               85
# UA5000(IPMB)SL-NODE385341           77
# C300MKI-NODE10668164                54
# MSAG5200-ISLPC-AGT-NODE480031       46
# MSAG5200-ISLMH-POL-NODE491451       45
# C300MIDH-IDJ-NODE11065541           31
# MSAG5200-ISLWKN-SWP-NODE473481      21
# MSAG5200-ISLVA-NKM-NODE481961       18
# MSAG5200-ISLMX-NODE5391821          15
# MSAG5200MGE-NODE428381              15
# C300MVH-NODE9874041                 14
# ZXDSL9806H-ISLKL-PRC-NODE482361     13
# MSAG5200-ISLMB-PSL-NODE482261       13
# MSAG5200-ISLMLT-VMD-NODE4145091     12
# C300MTP-NODE8700911                 12
# MSAG5200-ISLHZ-BRL-NODE471911       11
# ZXDSL9806H-ISLAG-PNP-NODE529761      9
# MSAG5200-ISLWY-MDB-NODE506221        9
# C300MHT-NE-NODE8152461               8
# MSAG5200-ISLGE-NODE5577981           8
# MSAG5200-ISLNL-HGW-NODE491281        7
# MSAG5200-ISLHC-NAP-NODE478721        7
# UA5000(IPMB)IM-NODE391531            7
# C300MHE-DMD-NODE15221561             7
# MSAG5200-ISLHK-OCC-NODE506561        7
# MSAG5200-ISLJA-PKV-NODE460421        6
# MSAG5200-ISLTBL-NODE5577771          6
# MSAG5200-ISLWI-NWT-NODE485201        6
# ZXDSL9806H-ISLKE-NRP-NODE495731      5
# MSAG5200PK-NODE438641                5
# MSAG5200HPG-NODE432141               5
# C300MPDT-NODE13379431                5
# MSAG5200-ISLTBT-TLJ-NODE487241       5
# MSAG5200-ISLHNT-NODE423851           4
# MA5603TAD-SRV-NODE10224991           4
# MSAG5200-ISLWM-NODE432881            3
# MSAG5200-ISLPK-PNU-NODE6136021       3
# MSAG5200-ISLHO-NODE524692            2
# MSAG5200-ISLPRN-NODE427901           2
# MSAG5200WLI-NODE422581               1
# Name: Location_Identifier, dtype: int64

# %% [markdown]
# #### User locations of Triply play customers

# %%
ax =cluster_0_peo["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Socio-economic factors

# %%
cluster_0["Household_Types"].value_counts()
# Out:
# NO                          1684
# ['Family_Member_Abroad']      37
# Name: Household_Types, dtype: int64

# %%
cluster_0["Household_Types"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","pink"])
# Out:
# <AxesSubplot:ylabel='Household_Types'>

# %%
cluster_0["Having_Insurance"].value_counts()
# Out:
# NO     1720
# YES       1
# Name: Having_Insurance, dtype: int64

# %% [markdown]
# ## Cluster 0 - Findings

# %% [markdown]
# - Subscription: Signle Play (But having 60 Triple Play customers as well?)
# - Subscription Usage:
#   - Voice: low Usage | **68% L** | **28% M* | **4% H**
#   - BB (Overall): Very low usage | **3% Low** | **97% NO**
#   - BB (Usage among Triple Play cusomers): Very Low | **95% L** | **5% M**
#   - PeoTV (Overall): Very low usage | **3% L** | **97% NO**
#   - PeoTV (Usage among Triple Play cusomers): Very Low | **96.7% L** | **3.3% M**
#   - Triple Play Users have **very low** use of BB and PeoTV (Maybe thats why they are in this cluster?)
# - IDD Usage: Low | **61% NO** | **34% LOW**
# - Mostly Used Voice package - V_Call Forwarding (4%)
# - Mostly used PeoTV package (among Triple Play users) - Peo Silver (83%)
# - Locations - **MSAG5200** | MSAG5200-ISLND-PHG-NODE500241 (14%), MSAG5200-ISLMV-GDM-NODE482491(12%),
# - Household : Mostly No information found **97%** |  some households have family members abroad **2%**
# - Only 1 User having Insurrance Coverage. This cannot be commented as we only have 2 users for whole dataset having an insurrance

# %% [markdown]
# # Cluster analysis - Cluster 1

# %%
cluster_1 = user_profile[(user_profile["Cluster"]==1)]

# %%
cluster_1.describe()
# Out:
#        ONNET_OUTGOING_Scaled  ONNET_INCOMING_Scaled  OFFNET_OUTGOING_Scaled  \
# count             561.000000             561.000000              561.000000
# mean                0.101772               0.098437                0.106371
# std                 0.091440               0.093265                0.101327
# min                 0.001202               0.000000                0.000000
# 25%                 0.027522               0.020948                0.026810
# 50%                 0.079548               0.063874                0.078493
# 75%                 0.152914               0.157795                0.157452
# max                 0.521929               0.540865                0.667092
#
#        OFFNET_INCOMING_Scaled  IDD_INCOMING_Scaled  IDD_OUTGOING_Scaled  \
# count              561.000000           561.000000           561.000000
# mean                 0.114133             0.037010             0.017400
# std                  0.093224             0.111117             0.080858
# min                  0.000000             0.000000             0.000000
# 25%                  0.036270             0.000000             0.000000
# 50%                  0.101526             0.000000             0.000000
# 75%                  0.166331             0.012821             0.000000
# max                  0.712569             0.807692             0.833333
#
#        PEO_TV_Scaled   BB_Scaled  Cluster
# count     561.000000  561.000000    561.0
# mean        0.747861    0.406445      1.0
# std         0.188249    0.251168      0.0
# min         0.093750    0.005208      1.0
# 25%         0.618750    0.201389      1.0
# 50%         0.775000    0.364583      1.0
# 75%         0.918750    0.578125      1.0
# max         0.975000    1.000000      1.0

# %%
cluster_1.iloc[:,:34].boxplot(figsize=(15,10),rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Usage among selected sample of users

# %%
cluster_1.iloc[:,[2,5,8,11,14,17,21,23]].sample(n=10).plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
cluster_1.iloc[:,[2,5,8,11,14,17,21,23]].plot.kde(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cluster_1.iloc[:,:34].hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'ONNET_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'ONNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'OFFNET_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'OFFNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'PEO_TV_Scaled'}>,
#         <AxesSubplot:title={'center':'BB_Scaled'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### Subscription Type and Usage

# %%
cluster_1["Play_Type"].value_counts()
# Out:
# TRIPLE_PLAY    561
# Name: Play_Type, dtype: int64

# %%
cluster_1["Play_Usage"].value_counts()
# Out:
# ['VOICE_LOW', 'BB_LOW', 'TV_HIGH']            95
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_HIGH']         81
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_HIGH']      70
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_HIGH']         63
# ['VOICE_LOW', 'BB_LOW', 'TV_MEDIUM']          60
# ['VOICE_LOW', 'BB_HIGH', 'TV_HIGH']           38
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_MEDIUM']       30
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_HIGH']        27
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_MEDIUM']       24
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_MEDIUM']    18
# ['VOICE_LOW', 'BB_HIGH', 'TV_MEDIUM']         17
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_MEDIUM']      10
# ['VOICE_HIGH', 'BB_LOW', 'TV_HIGH']            6
# ['VOICE_LOW', 'BB_HIGH', 'TV_LOW']             5
# ['VOICE_HIGH', 'BB_MEDIUM', 'TV_HIGH']         3
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_LOW']        3
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_LOW']           3
# ['VOICE_HIGH', 'BB_HIGH', 'TV_HIGH']           2
# ['VOICE_HIGH', 'BB_LOW', 'TV_MEDIUM']          2
# ['VOICE_HIGH', 'BB_HIGH', 'TV_LOW']            2
# ['VOICE_HIGH', 'BB_MEDIUM', 'TV_MEDIUM']       1
# ['VOICE_LOW', 'BB_LOW', 'TV_LOW']              1
# Name: Play_Usage, dtype: int64

# %%
ax =cluster_1["Play_Usage"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Voice Calls Usage

# %%
cluster_1["VOICE_Categorical"].value_counts()
# Out:
# LOW       324
# MEDIUM    221
# HIGH       16
# Name: VOICE_Categorical, dtype: int64

# %%
cluster_1["VOICE_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='VOICE_Categorical'>

# %%
count_dict = dict(cluster_1["Voice_Packages"].value_counts())
all_products = []
for x,y in count_dict.items():
    if x != "NO":
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
    else:
        for i in range(y):
            all_products.append(x)
all_voice_products_dict = Counter(all_products)
all_voice_products_dict
# Out:
# Counter({'NO': 500,
#          'V_Basic Phone Installment': 6,
#          'V_Absentee service': 29,
#          'V_Abbreviated Dialing': 28,
#          'V_Call Transfer Three way': 35,
#          'V_Call Forwarding': 35,
#          'V_Call Waiting': 28,
#          'V_Call Forwarding-Immediate': 29,
#          'V_Call Forwarding-On Busy': 29,
#          'V_Call Forwarding-No Answer': 29,
#          'V_Cordeless Phone - Installment': 4,
#          'V_Hotline Service': 19,
#          'V_Hotline-Time Delayed': 14,
#          'V_IDD': 8,
#          'V_DQ Contact Details': 7,
#          'V_Hotline-Immediate': 7,
#          'V_Call holding': 15,
#          'V_Incoming Call Memory': 15,
#          'V_Outgoing Call Memory': 15,
#          'V_Incoming Call Transfer': 14,
#          'V_Call Forwarding by time': 15,
#          'V_SLT Voice Service': 2,
#          'V_SLT CLI': 5,
#          'V_Single VAS Bundle': 2,
#          'V_Caller Line Identification': 2,
#          'V_Call Forwarding Offline': 15,
#          'V_Short Message Service': 2,
#          'V_Installment': 1,
#          'V_Railway Registration': 1,
#          'V_Triple VAS Bundle': 1,
#          'V_Call back on busy': 12,
#          'V_CLI presentation in call waiting': 12,
#          'V_Anonymous call barring': 11,
#          'V_Call park': 12,
#          'V_Selective call acceptance': 1,
#          'V_Call forwarding selective': 1,
#          'V_Selective call waiting': 1,
#          'V_Caller name sending': 1,
#          'V_Do not disturb service': 1,
#          'V_Selective call rejection': 1,
#          'V_Secretary service': 1,
#          'V_Password call barring (secret code)': 1,
#          'V_Caller name identificationPresentation': 1,
#          'V_Complete call on no response': 1,
#          'V_Referral offer Discount': 1})

# %%
avp_without_no = all_voice_products_dict
avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(20,10))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### IDD Usage

# %%
cluster_1["IDD_Overall_Categorical"].value_counts()
# Out:
# NO        333
# LOW       204
# HIGH       15
# MEDIUM      9
# Name: IDD_Overall_Categorical, dtype: int64

# %%
cluster_1["IDD_Overall_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='IDD_Overall_Categorical'>

# %% [markdown]
# ### PeoTV Usage

# %%
cluster_1["PEO_TV_Categorical"].value_counts()
# Out:
# HIGH      385
# MEDIUM    162
# LOW        14
# Name: PEO_TV_Categorical, dtype: int64

# %%
cluster_1["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["green","yellow","pink"])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %%
ax =cluster_1["Peo_TV_Package"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### BroadBand Internet Usage

# %%
cluster_1["BB_Categorical"].value_counts()
# Out:
# LOW       257
# MEDIUM    203
# HIGH      101
# Name: BB_Categorical, dtype: int64

# %%
cluster_1["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# ### User Location

# %%
ax =cluster_1["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %%
cluster_1["Location_Identifier"].value_counts()
# Out:
# MSAG5200-ISLMT-AVR-NODE467161      80
# MSAG5200PH-AKG-NODE431631          65
# MSAG5200BG-NODE431391              49
# MSAG5200-ISLMV-GDM-NODE482491      45
# UA5000(IPMB)SL-NODE385341          43
# MSAG5200-ISLND-PHG-NODE500241      38
# MSAG5200-ISLIDH-KGW-NODE6194491    32
# MSAG5200-ISLMH-POL-NODE491451      28
# C300MNW-MEE-NODE18887751           25
# MSAG5200-ISLBZ-NODE435881          20
# C300MIDH-IDJ-NODE11065541          19
# MSAG5200-ISLPC-AGT-NODE480031      19
# C300MKI-NODE10668164               10
# MSAG5200-ISLHNT-NODE423851          8
# MSAG5200HPG-NODE432141              7
# MSAG5200-ISLMLT-VMD-NODE4145091     6
# ZXDSL9806H-ISLKE-NRP-NODE495731     5
# MSAG5200-ISLHK-OCC-NODE506561       5
# MSAG5200-ISLHC-NAP-NODE478721       5
# C300MHT-NE-NODE8152461              5
# C300MTP-NODE8700911                 4
# UA5000(IPMB)IM-NODE391531           4
# MSAG5200-ISLWI-NWT-NODE485201       4
# MSAG5200-ISLWY-MDB-NODE506221       4
# MSAG5200PK-NODE438641               4
# MSAG5200-ISLWKN-SWP-NODE473481      3
# MSAG5200-ISLPK-PNU-NODE6136021      3
# MSAG5200-ISLVA-NKM-NODE481961       3
# MSAG5200-ISLTBL-NODE5577771         2
# ZXDSL9806H-ISLAG-PNP-NODE529761     2
# MSAG5200-ISLMB-PSL-NODE482261       2
# MSAG5200-ISLGE-NODE5577981          2
# MSAG5200-ISLNL-HGW-NODE491281       2
# MSAG5200MGE-NODE428381              1
# MSAG5200-ISLSI-DWS-NODE520721       1
# C300MPDT-NODE13379431               1
# MSAG5200-ISLHZ-BRL-NODE471911       1
# ZXDSL9806H-ISLKL-PRC-NODE482361     1
# MSAG5200-ISLJA-PKV-NODE460421       1
# MA5603TAD-SRV-NODE10224991          1
# C300MVH-NODE9874041                 1
# Name: Location_Identifier, dtype: int64

# %% [markdown]
# ### Socio-economic factors

# %%
cluster_1["Household_Types"].value_counts()
# Out:
# ['Kids']                                                       301
# NO                                                             140
# ['Kids', 'Professional_or_Student']                             62
# ['Professional_or_Student']                                     33
# ['Senior_Citizen', 'Kids']                                       8
# ['Kids', 'Family_Member_Abroad']                                 8
# ['Kids', 'Professional_or_Student', 'Family_Member_Abroad']      3
# ['Senior_Citizen', 'Kids', 'Professional_or_Student']            2
# ['Family_Member_Abroad']                                         2
# ['Senior_Citizen', 'Kids', 'Family_Member_Abroad']               1
# ['Professional_or_Student', 'Family_Member_Abroad']              1
# Name: Household_Types, dtype: int64

# %%
ax = cluster_1["Household_Types"].value_counts().plot(kind='bar', figsize=(10,6))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()
    
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %%
cluster_1["Having_Insurance"].value_counts()
# Out:
# NO    561
# Name: Having_Insurance, dtype: int64

# %% [markdown]
# ## Cluster 1 - Findings

# %% [markdown]
# - Subscription: Triple Play
# - Subscription Usage:
#   - Peo TV **High** usage | **H 67%** | **M 28%** | **L 5%**
#   - BB **Medium** usage | **H 18%** | **M 36%** | **L 45%**
#   - VOICE **Low** usage | **H 3%** | **M 39%** | **L 57%**
# - IDD Usage: Very low  | **No usage 59%** | **Low Usage 36%**
# - Mostly used Voice package - **V_Call Transfer Three way** and **V_Call Forwarding** (4%)
# - Mostly used PeoTV package - Peo_Silver (68%)
# - Household : Mostly Kids and senior citizens(55%), Some probability of having Working Professional or Students (17%)
# - Location : Mostly in MSAN: MSAG5200 - 65%
# - No Insurrance Coverage

# %% [markdown]
# # Cluster analysis - Cluster 2

# %%
cluster_2 = user_profile[(user_profile["Cluster"]==2)]

# %%
cluster_2.describe()
# Out:
#        ONNET_OUTGOING_Scaled  ONNET_INCOMING_Scaled  OFFNET_OUTGOING_Scaled  \
# count            1025.000000            1025.000000             1025.000000
# mean                0.100434               0.098378                0.104891
# std                 0.104874               0.106129                0.113736
# min                 0.001202               0.000000                0.000000
# 25%                 0.019304               0.015968                0.020801
# 50%                 0.063825               0.061985                0.068779
# 75%                 0.156937               0.151957                0.147346
# max                 0.795894               0.742788                0.705357
#
#        OFFNET_INCOMING_Scaled  IDD_INCOMING_Scaled  IDD_OUTGOING_Scaled  \
# count             1025.000000          1025.000000          1025.000000
# mean                 0.102195             0.036332             0.013907
# std                  0.094631             0.104220             0.061302
# min                  0.000000             0.000000             0.000000
# 25%                  0.026213             0.000000             0.000000
# 50%                  0.081019             0.000000             0.000000
# 75%                  0.149088             0.014423             0.000000
# max                  0.640453             0.884615             0.785256
#
#        PEO_TV_Scaled    BB_Scaled  Cluster
# count    1025.000000  1025.000000   1025.0
# mean        0.245049     0.197636      2.0
# std         0.338322     0.260511      0.0
# min         0.000000     0.000000      2.0
# 25%         0.000000     0.000000      2.0
# 50%         0.000000     0.081597      2.0
# 75%         0.575000     0.307292      2.0
# max         0.950000     1.000000      2.0

# %%
cluster_2.iloc[:,:34].boxplot(figsize=(15,10),rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Usage among sample of users

# %%
cluster_2.iloc[:,[2,5,8,11,14,17,21,23]].sample(n=10).plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
cluster_2.iloc[:,[2,5,8,11,14,17,21,23]].plot.kde(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cluster_2.iloc[:,:34].hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'ONNET_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'ONNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'OFFNET_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'OFFNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'PEO_TV_Scaled'}>,
#         <AxesSubplot:title={'center':'BB_Scaled'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### Subscription Type and Usage

# %%
cluster_2["Play_Type"].value_counts()
# Out:
# DOUBLE_PLAY    1025
# Name: Play_Type, dtype: int64

# %%
cluster_2["Play_Usage"].value_counts()
# Out:
# ['VOICE_LOW', 'BB_LOW', 'TV_NO']          242
# ['VOICE_LOW', 'BB_NO', 'TV_HIGH']         131
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_NO']       122
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_NO']       101
# ['VOICE_LOW', 'BB_NO', 'TV_MEDIUM']        80
# ['VOICE_MEDIUM', 'BB_NO', 'TV_HIGH']       76
# ['VOICE_LOW', 'BB_HIGH', 'TV_NO']          66
# ['VOICE_MEDIUM', 'BB_NO', 'TV_MEDIUM']     52
# ['VOICE_LOW', 'BB_NO', 'TV_LOW']           42
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_NO']     38
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_NO']       25
# ['VOICE_HIGH', 'BB_LOW', 'TV_NO']          16
# ['VOICE_MEDIUM', 'BB_NO', 'TV_LOW']        13
# ['VOICE_HIGH', 'BB_MEDIUM', 'TV_NO']        7
# ['VOICE_HIGH', 'BB_NO', 'TV_HIGH']          4
# ['VOICE_HIGH', 'BB_HIGH', 'TV_NO']          4
# ['VOICE_HIGH', 'BB_NO', 'TV_MEDIUM']        3
# ['VOICE_HIGH', 'BB_NO', 'TV_LOW']           3
# Name: Play_Usage, dtype: int64

# %%
ax =cluster_2["Play_Usage"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Double Play categories

# %%
tv_users = cluster_2[(cluster_2["BB_Categorical"] == "NO") & (cluster_2["PEO_TV_Categorical"] != "NO")]["event_source.hash"].count()
bb_users = cluster_2[(cluster_2["BB_Categorical"] != "NO") & (cluster_2["PEO_TV_Categorical"] == "NO")]["event_source.hash"].count()
new_dict= {"Double Play(Voice+BB)": bb_users, "Double Play(Voice+|PeoTV)": tv_users}
print(new_dict)

fig,ax = plt.subplots(figsize=(7,7))
ax.bar(*zip(*new_dict.items()))
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/1025:.0%}', (x + width/2, y + height*1.02), ha='center')
plt.show()
# Out:
# {'Double Play(Voice+BB)': 621, 'Double Play(Voice+|PeoTV)': 404}

# %% [markdown]
# ### Voice Calls Usage

# %%
cluster_2["VOICE_Categorical"].value_counts()
# Out:
# LOW       662
# MEDIUM    326
# HIGH       37
# Name: VOICE_Categorical, dtype: int64

# %%
cluster_2["VOICE_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='VOICE_Categorical'>

# %%
count_dict = dict(cluster_2["Voice_Packages"].value_counts())
all_products = []
for x,y in count_dict.items():
    if x != "NO":
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
    else:
        for i in range(y):
            all_products.append(x)
all_voice_products_dict = Counter(all_products)
all_voice_products_dict
# Out:
# Counter({'NO': 925,
#          'V_Absentee service': 51,
#          'V_Abbreviated Dialing': 51,
#          'V_Call Transfer Three way': 58,
#          'V_Call Forwarding': 61,
#          'V_Call Waiting': 52,
#          'V_Call Forwarding-Immediate': 51,
#          'V_Call Forwarding-On Busy': 51,
#          'V_Call Forwarding-No Answer': 52,
#          'V_Basic Phone Installment': 5,
#          'V_IDD': 24,
#          'V_Installment': 2,
#          'V_DQ Contact Details': 22,
#          'V_Cordeless Phone - Installment': 3,
#          'V_SLT CLI': 15,
#          'V_Hotline Service': 24,
#          'V_Hotline-Time Delayed': 17,
#          'V_Secretary service': 1,
#          'V_Call park': 15,
#          'V_Selective call rejection': 1,
#          'V_Selective call waiting': 1,
#          'V_Incoming Call Memory': 25,
#          'V_CLI presentation in call waiting': 15,
#          'V_Do not disturb service': 1,
#          'V_Call back on busy': 15,
#          'V_Complete call on no response': 1,
#          'V_Call Forwarding Offline': 27,
#          'V_Call forwarding selective': 1,
#          'V_Password call barring (secret code)': 1,
#          'V_Anonymous call barring': 15,
#          'V_Call holding': 24,
#          'V_Caller name identificationPresentation': 1,
#          'V_Incoming Call Transfer': 23,
#          'V_Caller name sending': 1,
#          'V_Selective call acceptance': 1,
#          'V_Call Forwarding by time': 24,
#          'V_Outgoing Call Memory': 25,
#          'V_Voice Startup Fee': 1,
#          'V_Double VAS Bundle': 7,
#          'V_SLT Voice Service': 5,
#          'V_Single VAS Bundle': 5,
#          'V_Referral offer Discount': 1,
#          'V_Hotline-Immediate': 10,
#          'V_E-channeling Registration': 1,
#          'V_Basic Phone': 1,
#          'V_Call Forwarding - Immediate': 1,
#          'V_Caller Line Identification': 3,
#          'V_Triple VAS Bundle': 1,
#          'V_Call Barring - Outgoing': 1,
#          'V_Call Barring': 1,
#          'E_PeoTV_Package Transfer': 1,
#          'V_Detailed Bill': 1,
#          'V_Short Message Service': 1,
#          'V_Telehealth': 1,
#          'V_Call Forwarding - No Answer': 1,
#          'V_Call Forwarding - On Busy': 1})

# %%
avp_without_no = all_voice_products_dict
avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(20,10))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### IDD Usage

# %%
cluster_2["IDD_Overall_Categorical"].value_counts()
# Out:
# NO        625
# LOW       352
# MEDIUM     35
# HIGH       13
# Name: IDD_Overall_Categorical, dtype: int64

# %%
cluster_2["IDD_Overall_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='IDD_Overall_Categorical'>

# %% [markdown]
# ### PeoTV Usage

# %%
cluster_2["PEO_TV_Categorical"].value_counts()
# Out:
# NO        621
# HIGH      211
# MEDIUM    135
# LOW        58
# Name: PEO_TV_Categorical, dtype: int64

# %% [markdown]
# #### Usage among All users in cluster

# %%
cluster_2["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","green","yellow","pink"])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %% [markdown]
# #### Usage among VOICE + PeoTV Users

# %%
cluster_2_peo = cluster_2[(cluster_2["BB_Categorical"] == "NO") & (cluster_2["PEO_TV_Categorical"] != "NO")]
cluster_2_peo["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["green","yellow","pink"])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %%
ax =cluster_2_peo["Peo_TV_Package"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### BroadBand Internet Usage

# %%
cluster_2["BB_Categorical"].value_counts()
# Out:
# NO        404
# LOW       380
# MEDIUM    146
# HIGH       95
# Name: BB_Categorical, dtype: int64

# %% [markdown]
# #### Usage among All users in cluster

# %%
cluster_2["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# #### Usage among Voice + BB Users

# %%
cluster_2_bb = cluster_2[(cluster_2["BB_Categorical"] != "NO") & (cluster_2["PEO_TV_Categorical"] == "NO")]
cluster_2_bb["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# ### User Location

# %%
ax =cluster_2["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %%
cluster_2["Location_Identifier"].value_counts()
# Out:
# MSAG5200PH-AKG-NODE431631          91
# MSAG5200-ISLMT-AVR-NODE467161      91
# MSAG5200BG-NODE431391              85
# MSAG5200-ISLND-PHG-NODE500241      82
# MSAG5200-ISLMV-GDM-NODE482491      75
# C300MNW-MEE-NODE18887751           60
# UA5000(IPMB)SL-NODE385341          57
# MSAG5200-ISLMLT-VMD-NODE4145091    51
# MSAG5200-ISLPC-AGT-NODE480031      51
# MSAG5200-ISLBZ-NODE435881          47
# MSAG5200-ISLIDH-KGW-NODE6194491    47
# MSAG5200-ISLMH-POL-NODE491451      34
# MSAG5200-ISLVA-NKM-NODE481961      33
# C300MKI-NODE10668164               23
# MSAG5200-ISLJA-PKV-NODE460421      12
# MSAG5200-ISLSI-DWS-NODE520721      11
# C300MIDH-IDJ-NODE11065541          11
# MSAG5200-ISLWI-NWT-NODE485201      11
# ZXDSL9806H-ISLKE-NRP-NODE495731    10
# MSAG5200-ISLWKN-SWP-NODE473481      9
# ZXDSL9806H-ISLAG-PNP-NODE529761     8
# MSAG5200-ISLPRN-NODE427901          8
# MSAG5200-ISLGE-NODE5577981          7
# MSAG5200HPG-NODE432141              7
# MSAG5200-ISLNL-HGW-NODE491281       7
# MSAG5200-ISLTBL-NODE5577771         7
# C300MHT-NE-NODE8152461              7
# UA5000(IPMB)IM-NODE391531           6
# C300MPDT-NODE13379431               6
# MSAG5200-ISLHZ-BRL-NODE471911       6
# ZXDSL9806H-ISLKL-PRC-NODE482361     6
# MSAG5200-ISLTBT-TLJ-NODE487241      5
# C300MTP-NODE8700911                 5
# MSAG5200-ISLHNT-NODE423851          5
# MSAG5200-ISLMX-NODE5391821          5
# C300MHE-DMD-NODE15221561            5
# MSAG5200-ISLHK-OCC-NODE506561       5
# MSAG5200MGE-NODE428381              4
# MSAG5200-ISLHC-NAP-NODE478721       4
# MSAG5200-ISLMB-PSL-NODE482261       4
# MSAG5200PK-NODE438641               3
# MSAG5200-ISLHO-NODE524692           3
# MSAG5200-ISLWY-MDB-NODE506221       3
# MSAG5200-ISLWM-NODE432881           2
# MA5603TAD-SRV-NODE10224991          2
# C300MVH-NODE9874041                 2
# MSAG5200-ISLKI-KRB-NODE479411       1
# MSAG5200-ISLPK-PNU-NODE6136021      1
# Name: Location_Identifier, dtype: int64

# %% [markdown]
# #### User locations of Voice + BB customers

# %%
ax =cluster_2_bb["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# #### User locations of Voice + peoTV customers

# %%
ax =cluster_2_peo["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Socio-economic factors

# %%
cluster_2["Household_Types"].value_counts()
# Out:
# NO                                                     709
# ['Kids']                                               205
# ['Professional_or_Student']                             94
# ['Family_Member_Abroad']                                10
# ['Senior_Citizen', 'Kids']                               4
# ['Kids', 'Family_Member_Abroad']                         2
# ['Professional_or_Student', 'Family_Member_Abroad']      1
# Name: Household_Types, dtype: int64

# %%
ax = cluster_2["Household_Types"].value_counts().plot(kind='bar', figsize=(10,6))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()
    
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %%
cluster_2["Having_Insurance"].value_counts()
# Out:
# NO     1024
# YES       1
# Name: Having_Insurance, dtype: int64

# %% [markdown]
# ## Cluster 2 - Findings

# %% [markdown]
# - Subscription: Double Play (Voice + BB, Voice + PeoTV)
# - Subscripotion Types:
#   - Voice + BB Highest | **61%**
#   - Voice + PeoTV Lowest | **39%**
# - Subscription Usage:
#   - Voice: **Low** | **64% L** | **31% M** | **3.6% H**
#   - BB (Among Voice+BB Users): Low usage | **61% L** | **23% M** | **15% H**
#   - PeoTV (Among Voice+peoTV Users): High usage | **52% H** | **33% M** | **14% L**
# - IDD Usage: Very Low | **61% NO** | **34% LOW**
# - Mostly Used Voice package - V_Call Forwarding (4%)
# - Mostly used PeoTV Package (Among Voice + PeoTV Subscribers) - Peo_Sliver (64%)
# - Household : Mostly No information found **69%** | some have kids **20%** | some have professions or students **9**
# - Location: Motly in MSAN : MSAG5200 (67%)
#   - All Users - MSAG5200PH-AKG-NODE431631 (9%)
#   - Voice + BB Users - MSAG5200PH-AKG-NODE431631 (8%)
#   - Voice + PeoTV Users - MSAG5200-ISLMT-AVR-NODE467161 (11%)
# - Only 1 User having Insurrance Coverage. This cannot be commented as we only have 2 users for whole dataset having an insurrance
