# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
bb_usage_info = pd.read_csv("data/BB-Usage-Information.csv")  

bb_usage_info
# Out:
#       Event_Source                 Event_Source.hash       Upload  \
# 0        VA2053035  6ff8125723953fdecaa253d2cb98b8fa   2479835042
# 1        BG2286138  93ace21ebf00ad04343ff61293cec667   1864315334
# 2        BZ2270133  2ada0ac0b4bafccb83447afd2e003804    413588193
# 3       IDH2073131  6c3134cf9691e170e9d1c011b0f19fdf   1012518853
# 4        MT2050369  b7e298db3ba9498507c6c971b88ab990    926361088
# ...            ...                               ...          ...
# 16785    KI2911444  64c4801b8e54f160cb55485ea4749b53  23669941591
# 16786    IM2287049  4a9c1740f2139c820db9e20f67488ff1   1166127281
# 16787    MH2227363  31a7c210ea5cf7d79fc4ffca84c70613    618513100
# 16788    MT2050369  b7e298db3ba9498507c6c971b88ab990   1454432998
# 16789   MLT2291078  69afa8f1a1e707183f88a905c647ab1b    631714217
#
#            Download  Duration  year-month RTOM_CODE LOCATION_CODE  \
# 0       17257396464   2505813      201910      R-VA   VA-NKM-NODE
# 1        8461159743   1326514      201910      R-RN       BG-NODE
# 2        4289102246     96033      201910     R-MRG       BZ-NODE
# 3       14796542338   2681718      201910     R-KON  IDH-KGW-NODE
# 4       20905123491   1666741      201910      R-MT   MT-AVR-NODE
# ...             ...       ...         ...       ...           ...
# 16785  169473000000   2650134      202005      R-KI       KI-NODE
# 16786   14184721881    631664      202008      R-GL       IM-NODE
# 16787    8530589182    353262      202005      R-MH   MH-POL-NODE
# 16788   27510692517   1661209      202005      R-MT   MT-AVR-NODE
# 16789   26455546135   2423427      202008     R-MLT  MLT-VMD-NODE
#
#                MSAN  EQUP_ID  EQUP_INDEX        PSTN  \
# 0      MSAG5200-ISL    48196           1  0242053035
# 1          MSAG5200    43139           1  0452286138
# 2      MSAG5200-ISL    43588           1  0552270133
# 3      MSAG5200-ISL   619449           1  0112073131
# 4      MSAG5200-ISL    46716           1  0662050369
# ...             ...      ...         ...         ...
# 16785         C300M  1066816           4  0112911444
# 16786  UA5000(IPMB)    39153           1  0912287049
# 16787  MSAG5200-ISL    49145           1  0412227363
# 16788  MSAG5200-ISL    46716           1  0662050369
# 16789  MSAG5200-ISL   414509           1  0212291078
#
#                               PSTN.hash
# 0      9231c080ea1108c7eeede0f449becb59
# 1      7e3969e2fb0fa148d817d3569b3eab3f
# 2      f1415c386cab3355a5356c556fe9d0e1
# 3      517b461d5b8e09f1c3547218cc2e4947
# 4      7fa3296ae71b6d2bb2ff46f97218940d
# ...                                 ...
# 16785  0b9c67d21fa2883687695482de31d631
# 16786  46960b77dad950ddae76dd53bd7848cd
# 16787  4dd51155385e44fdf8d82be5630963f8
# 16788  7fa3296ae71b6d2bb2ff46f97218940d
# 16789  cc66aaac252bb6f6cdde8df430e622f5
#
# [16790 rows x 13 columns]

# %%
# Handle null values
# Drop unnecessary cols
# Pivot by monthYear
# Usage rating Upload/Downlad/Duration - bucketizing/ add rating cols
# location grouping/bucketizing (consider 4 location cols)
# User profile dim table
# visualize and analyze data

# %%
bb_usage_info = bb_usage_info.drop_duplicates(["PSTN.hash","year-month"], keep="last")

bb_usage_info.shape
# Out:
# (13043, 13)

# %%
bb_usage_info = bb_usage_info.drop(['Event_Source','PSTN'], axis=1)

# %%
bb_usage_info.head()
# Out:
#                   Event_Source.hash      Upload     Download  Duration  \
# 0  6ff8125723953fdecaa253d2cb98b8fa  2479835042  17257396464   2505813
# 1  93ace21ebf00ad04343ff61293cec667  1864315334   8461159743   1326514
# 2  2ada0ac0b4bafccb83447afd2e003804   413588193   4289102246     96033
# 3  6c3134cf9691e170e9d1c011b0f19fdf  1012518853  14796542338   2681718
# 4  b7e298db3ba9498507c6c971b88ab990   926361088  20905123491   1666741
#
#    year-month RTOM_CODE LOCATION_CODE          MSAN  EQUP_ID  EQUP_INDEX  \
# 0      201910      R-VA   VA-NKM-NODE  MSAG5200-ISL    48196           1
# 1      201910      R-RN       BG-NODE      MSAG5200    43139           1
# 2      201910     R-MRG       BZ-NODE  MSAG5200-ISL    43588           1
# 3      201910     R-KON  IDH-KGW-NODE  MSAG5200-ISL   619449           1
# 4      201910      R-MT   MT-AVR-NODE  MSAG5200-ISL    46716           1
#
#                           PSTN.hash
# 0  9231c080ea1108c7eeede0f449becb59
# 1  7e3969e2fb0fa148d817d3569b3eab3f
# 2  f1415c386cab3355a5356c556fe9d0e1
# 3  517b461d5b8e09f1c3547218cc2e4947
# 4  7fa3296ae71b6d2bb2ff46f97218940d

# %%
bb_usage_info['Duration'].fillna(0)
bb_usage_info['Upload'].fillna(0)
bb_usage_info['Download'].fillna(0)
# Out:
# 0         17257396464
# 1          8461159743
# 2          4289102246
# 3         14796542338
# 4         20905123491
#              ...
# 16785    169473000000
# 16786     14184721881
# 16787      8530589182
# 16788     27510692517
# 16789     26455546135
# Name: Download, Length: 13043, dtype: int64

# %%
bb_usage_info.isnull().sum(axis=0)
# Out:
# Event_Source.hash    0
# Upload               0
# Download             0
# Duration             0
# year-month           0
# RTOM_CODE            0
# LOCATION_CODE        0
# MSAN                 0
# EQUP_ID              0
# EQUP_INDEX           0
# PSTN.hash            0
# dtype: int64

# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Usage Ranking
#
# - 1. Pivot by year-month
# - 2. Bin by Upload/Download/Duration
# - 3. Usage Rank
# - 4. Labling usage

# %%
bb_usage = bb_usage_info[['PSTN.hash','Upload','Download','Duration','year-month']]
bb_usage['Usage'] = bb_usage.loc[:,['Upload','Download']].sum(axis=1)
bb_usage = bb_usage.drop(['Upload','Download'], axis=1)
bb_usage
# Out:
# <ipython-input-9-b69c0b867eab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_usage['Usage'] = bb_usage.loc[:,['Upload','Download']].sum(axis=1)
#                               PSTN.hash  Duration  year-month         Usage
# 0      9231c080ea1108c7eeede0f449becb59   2505813      201910   19737231506
# 1      7e3969e2fb0fa148d817d3569b3eab3f   1326514      201910   10325475077
# 2      f1415c386cab3355a5356c556fe9d0e1     96033      201910    4702690439
# 3      517b461d5b8e09f1c3547218cc2e4947   2681718      201910   15809061191
# 4      7fa3296ae71b6d2bb2ff46f97218940d   1666741      201910   21831484579
# ...                                 ...       ...         ...           ...
# 16785  0b9c67d21fa2883687695482de31d631   2650134      202005  193142941591
# 16786  46960b77dad950ddae76dd53bd7848cd    631664      202008   15350849162
# 16787  4dd51155385e44fdf8d82be5630963f8    353262      202005    9149102282
# 16788  7fa3296ae71b6d2bb2ff46f97218940d   1661209      202005   28965125515
# 16789  cc66aaac252bb6f6cdde8df430e622f5   2423427      202008   27087260352
#
# [13043 rows x 4 columns]

# %%
pivot_bb_usage_info = pd.pivot_table(bb_usage,index=['PSTN.hash'],columns=['year-month'], aggfunc=np.sum, fill_value=0)
pivot_bb_usage_info
# Out:
#                                  Duration                                      \
# year-month                         201908   201910   201911   201912   202001
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  2277937  1256652   795222  1417310  2176277
# 00724ae2470df1ed0fe919800d02517d        0        0        0        0        0
# 00a8c3e3baed0557c31ab9b68a086ed2   699711  1153572   374914   511928  1194567
# 00cc5a820586ce291c0fa4c2a99a4816        0        0        0        0   157239
# 00d1f690ec4af27702febbd0db6942c2   713219   663171   558688   377493   570854
# ...                                   ...      ...      ...      ...      ...
# feca6cdb74a4a95dec4fe88f3fb2f938        0        0        0        0        0
# ff1093d5ef61bf46f8c88e9b7614e311   681240   791191   872112   938131   666153
# ff45fdfb4b6dac191aba17a281181d39  2292467  2332487  2276132  2523725  2548082
# ffb2ec238eba276f65157693ed329c7f        0        0        0   140358  2056665
# ffd697d66cc01c8897ce3e37d693673a  1405744        0        0        0        0
#
#                                                                                \
# year-month                         202002   202003   202004   202005   202006
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  2212790  2030474  1725246  2133617  1777555
# 00724ae2470df1ed0fe919800d02517d        0        0        0        0        0
# 00a8c3e3baed0557c31ab9b68a086ed2   493510   431098   552825   421133  1049049
# 00cc5a820586ce291c0fa4c2a99a4816   548360        0        0  1119319   966783
# 00d1f690ec4af27702febbd0db6942c2   545675   697625   520233   350390   222968
# ...                                   ...      ...      ...      ...      ...
# feca6cdb74a4a95dec4fe88f3fb2f938        0        0        0        0        0
# ff1093d5ef61bf46f8c88e9b7614e311   693108  1223891  1615199  1541898   813031
# ff45fdfb4b6dac191aba17a281181d39  2422885  2645146  2558089  2545852  2542633
# ffb2ec238eba276f65157693ed329c7f  1820231  2413915  2272529  2597092  2555086
# ffd697d66cc01c8897ce3e37d693673a        0        0        0        0        0
#
#                                   ...        Usage                            \
# year-month                        ...       201911       201912       202001
# PSTN.hash                         ...
# 00567a4a3c474aca1ce5cd6570648932  ...  11764247072  27618734644  33279185555
# 00724ae2470df1ed0fe919800d02517d  ...            0            0            0
# 00a8c3e3baed0557c31ab9b68a086ed2  ...  13435042644  10508792092  17492553338
# 00cc5a820586ce291c0fa4c2a99a4816  ...            0            0      5498326
# 00d1f690ec4af27702febbd0db6942c2  ...   7795652629   7632107196   8961346005
# ...                               ...          ...          ...          ...
# feca6cdb74a4a95dec4fe88f3fb2f938  ...            0            0            0
# ff1093d5ef61bf46f8c88e9b7614e311  ...  10917038375  15030006772  10187461833
# ff45fdfb4b6dac191aba17a281181d39  ...  21145367276  24093109565  21815269999
# ffb2ec238eba276f65157693ed329c7f  ...            0   1329073213  57067166125
# ffd697d66cc01c8897ce3e37d693673a  ...            0            0            0
#
#                                                                          \
# year-month                             202002       202003       202004
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  36946597062  28860391201  37042221978
# 00724ae2470df1ed0fe919800d02517d            0            0            0
# 00a8c3e3baed0557c31ab9b68a086ed2  12583099729  15043376719  12242977343
# 00cc5a820586ce291c0fa4c2a99a4816    466553446            0            0
# 00d1f690ec4af27702febbd0db6942c2   8920192587   9256717275   9942677985
# ...                                       ...          ...          ...
# feca6cdb74a4a95dec4fe88f3fb2f938            0            0            0
# ff1093d5ef61bf46f8c88e9b7614e311  15969021804  36102576759  38960566940
# ff45fdfb4b6dac191aba17a281181d39  62009852907  15310178039     79844405
# ffb2ec238eba276f65157693ed329c7f  30448045515  37105632895  53587037923
# ffd697d66cc01c8897ce3e37d693673a            0            0            0
#
#                                                                          \
# year-month                             202005       202006       202007
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  28569658912  23665016296  34679735150
# 00724ae2470df1ed0fe919800d02517d            0            0            0
# 00a8c3e3baed0557c31ab9b68a086ed2  11913781294  10473258735  12740584970
# 00cc5a820586ce291c0fa4c2a99a4816   4262102209   1337888512   2060643618
# 00d1f690ec4af27702febbd0db6942c2   8421748563   8968497023   8231107555
# ...                                       ...          ...          ...
# feca6cdb74a4a95dec4fe88f3fb2f938            0            0  12000151549
# ff1093d5ef61bf46f8c88e9b7614e311  30736946619  10703406784  14345497745
# ff45fdfb4b6dac191aba17a281181d39   1433535592  28492231202  18422981099
# ffb2ec238eba276f65157693ed329c7f  61060854787  32526861024  48837017695
# ffd697d66cc01c8897ce3e37d693673a            0            0            0
#
#
# year-month                             202008
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  18426445302
# 00724ae2470df1ed0fe919800d02517d   9968594629
# 00a8c3e3baed0557c31ab9b68a086ed2   7354630340
# 00cc5a820586ce291c0fa4c2a99a4816  12134620309
# 00d1f690ec4af27702febbd0db6942c2   8412970065
# ...                                       ...
# feca6cdb74a4a95dec4fe88f3fb2f938  10358924286
# ff1093d5ef61bf46f8c88e9b7614e311  12314535636
# ff45fdfb4b6dac191aba17a281181d39  13053784719
# ffb2ec238eba276f65157693ed329c7f  14880625561
# ffd697d66cc01c8897ce3e37d693673a            0
#
# [1306 rows x 24 columns]

# %%
pivot_bb_usage_info.columns
# Out:
# MultiIndex([('Duration', 201908),
#             ('Duration', 201910),
#             ('Duration', 201911),
#             ('Duration', 201912),
#             ('Duration', 202001),
#             ('Duration', 202002),
#             ('Duration', 202003),
#             ('Duration', 202004),
#             ('Duration', 202005),
#             ('Duration', 202006),
#             ('Duration', 202007),
#             ('Duration', 202008),
#             (   'Usage', 201908),
#             (   'Usage', 201910),
#             (   'Usage', 201911),
#             (   'Usage', 201912),
#             (   'Usage', 202001),
#             (   'Usage', 202002),
#             (   'Usage', 202003),
#             (   'Usage', 202004),
#             (   'Usage', 202005),
#             (   'Usage', 202006),
#             (   'Usage', 202007),
#             (   'Usage', 202008)],
#            names=[None, 'year-month'])

# %%
bb_usage.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#             Duration    year-month               Usage
# count    13043.00000   13043.00000         13043.00000
# mean   1521226.50564  201974.09438   22678527038.04807
# std     870908.53424      44.13513   28481239994.13892
# min        120.00000  201908.00000             0.00000
# 25%     739867.00000  201912.00000    6834388399.50000
# 50%    1518326.00000  202003.00000   13811012030.00000
# 75%    2427392.00000  202006.00000   27456020350.00000
# max    2709612.00000  202008.00000  537118249202.00000

# %%
# binning usage
usage_bins = [0, 7057561283.25, 14188526279.5,28226707481.75, 537118249202.0]
for col in pivot_bb_usage_info['Usage'].columns:
    pivot_bb_usage_info['Usage'][col] = np.searchsorted(usage_bins, pivot_bb_usage_info['Usage'][col].values)
pivot_bb_usage_info['Usage']
# Out:
# <ipython-input-13-11a9924446b9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_bb_usage_info['Usage'][col] = np.searchsorted(usage_bins, pivot_bb_usage_info['Usage'][col].values)
# year-month                        201908  201910  201911  201912  202001  \
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932       4       3       2       3       4
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 00a8c3e3baed0557c31ab9b68a086ed2       2       2       2       2       3
# 00cc5a820586ce291c0fa4c2a99a4816       0       0       0       0       1
# 00d1f690ec4af27702febbd0db6942c2       2       2       2       2       2
# ...                                  ...     ...     ...     ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938       0       0       0       0       0
# ff1093d5ef61bf46f8c88e9b7614e311       2       2       2       3       2
# ff45fdfb4b6dac191aba17a281181d39       3       4       3       3       3
# ffb2ec238eba276f65157693ed329c7f       0       0       0       1       4
# ffd697d66cc01c8897ce3e37d693673a       1       0       0       0       0
#
# year-month                        202002  202003  202004  202005  202006  \
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932       4       4       4       4       3
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 00a8c3e3baed0557c31ab9b68a086ed2       2       3       2       2       2
# 00cc5a820586ce291c0fa4c2a99a4816       1       0       0       1       1
# 00d1f690ec4af27702febbd0db6942c2       2       2       2       2       2
# ...                                  ...     ...     ...     ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938       0       0       0       0       0
# ff1093d5ef61bf46f8c88e9b7614e311       3       4       4       4       2
# ff45fdfb4b6dac191aba17a281181d39       4       3       1       1       4
# ffb2ec238eba276f65157693ed329c7f       4       4       4       4       4
# ffd697d66cc01c8897ce3e37d693673a       0       0       0       0       0
#
# year-month                        202007  202008
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932       4       3
# 00724ae2470df1ed0fe919800d02517d       0       2
# 00a8c3e3baed0557c31ab9b68a086ed2       2       2
# 00cc5a820586ce291c0fa4c2a99a4816       1       2
# 00d1f690ec4af27702febbd0db6942c2       2       2
# ...                                  ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938       2       2
# ff1093d5ef61bf46f8c88e9b7614e311       3       2
# ff45fdfb4b6dac191aba17a281181d39       3       2
# ffb2ec238eba276f65157693ed329c7f       4       3
# ffd697d66cc01c8897ce3e37d693673a       0       0
#
# [1306 rows x 12 columns]

# %%
# binning duration
duration_bins = [0, 745381.25, 1522064.0, 2438034.0,2709612.0]
for col in pivot_bb_usage_info['Duration'].columns:
    pivot_bb_usage_info['Duration'][col] = np.searchsorted(duration_bins, pivot_bb_usage_info['Duration'][col].values)
pivot_bb_usage_info['Duration']
# Out:
# <ipython-input-14-e9ec739a43e9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_bb_usage_info['Duration'][col] = np.searchsorted(duration_bins, pivot_bb_usage_info['Duration'][col].values)
# year-month                        201908  201910  201911  201912  202001  \
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932       3       2       2       2       3
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 00a8c3e3baed0557c31ab9b68a086ed2       1       2       1       1       2
# 00cc5a820586ce291c0fa4c2a99a4816       0       0       0       0       1
# 00d1f690ec4af27702febbd0db6942c2       1       1       1       1       1
# ...                                  ...     ...     ...     ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938       0       0       0       0       0
# ff1093d5ef61bf46f8c88e9b7614e311       1       2       2       2       1
# ff45fdfb4b6dac191aba17a281181d39       3       3       3       4       4
# ffb2ec238eba276f65157693ed329c7f       0       0       0       1       3
# ffd697d66cc01c8897ce3e37d693673a       2       0       0       0       0
#
# year-month                        202002  202003  202004  202005  202006  \
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932       3       3       3       3       3
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 00a8c3e3baed0557c31ab9b68a086ed2       1       1       1       1       2
# 00cc5a820586ce291c0fa4c2a99a4816       1       0       0       2       2
# 00d1f690ec4af27702febbd0db6942c2       1       1       1       1       1
# ...                                  ...     ...     ...     ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938       0       0       0       0       0
# ff1093d5ef61bf46f8c88e9b7614e311       1       2       3       3       2
# ff45fdfb4b6dac191aba17a281181d39       3       4       4       4       4
# ffb2ec238eba276f65157693ed329c7f       3       3       3       4       4
# ffd697d66cc01c8897ce3e37d693673a       0       0       0       0       0
#
# year-month                        202007  202008
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932       3       2
# 00724ae2470df1ed0fe919800d02517d       0       3
# 00a8c3e3baed0557c31ab9b68a086ed2       1       1
# 00cc5a820586ce291c0fa4c2a99a4816       2       3
# 00d1f690ec4af27702febbd0db6942c2       1       1
# ...                                  ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938       2       2
# ff1093d5ef61bf46f8c88e9b7614e311       1       1
# ff45fdfb4b6dac191aba17a281181d39       3       3
# ffb2ec238eba276f65157693ed329c7f       4       4
# ffd697d66cc01c8897ce3e37d693673a       0       0
#
# [1306 rows x 12 columns]

# %%
pivot_bb_usage_info
# Out:
#                                  Duration                                     \
# year-month                         201908 201910 201911 201912 202001 202002
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932        3      2      2      2      3      3
# 00724ae2470df1ed0fe919800d02517d        0      0      0      0      0      0
# 00a8c3e3baed0557c31ab9b68a086ed2        1      2      1      1      2      1
# 00cc5a820586ce291c0fa4c2a99a4816        0      0      0      0      1      1
# 00d1f690ec4af27702febbd0db6942c2        1      1      1      1      1      1
# ...                                   ...    ...    ...    ...    ...    ...
# feca6cdb74a4a95dec4fe88f3fb2f938        0      0      0      0      0      0
# ff1093d5ef61bf46f8c88e9b7614e311        1      2      2      2      1      1
# ff45fdfb4b6dac191aba17a281181d39        3      3      3      4      4      3
# ffb2ec238eba276f65157693ed329c7f        0      0      0      1      3      3
# ffd697d66cc01c8897ce3e37d693673a        2      0      0      0      0      0
#
#                                                               ...  Usage  \
# year-month                       202003 202004 202005 202006  ... 201911
# PSTN.hash                                                     ...
# 00567a4a3c474aca1ce5cd6570648932      3      3      3      3  ...      2
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0  ...      0
# 00a8c3e3baed0557c31ab9b68a086ed2      1      1      1      2  ...      2
# 00cc5a820586ce291c0fa4c2a99a4816      0      0      2      2  ...      0
# 00d1f690ec4af27702febbd0db6942c2      1      1      1      1  ...      2
# ...                                 ...    ...    ...    ...  ...    ...
# feca6cdb74a4a95dec4fe88f3fb2f938      0      0      0      0  ...      0
# ff1093d5ef61bf46f8c88e9b7614e311      2      3      3      2  ...      2
# ff45fdfb4b6dac191aba17a281181d39      4      4      4      4  ...      3
# ffb2ec238eba276f65157693ed329c7f      3      3      4      4  ...      0
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0  ...      0
#
#                                                                             \
# year-month                       201912 202001 202002 202003 202004 202005
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932      3      4      4      4      4      4
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0      0
# 00a8c3e3baed0557c31ab9b68a086ed2      2      3      2      3      2      2
# 00cc5a820586ce291c0fa4c2a99a4816      0      1      1      0      0      1
# 00d1f690ec4af27702febbd0db6942c2      2      2      2      2      2      2
# ...                                 ...    ...    ...    ...    ...    ...
# feca6cdb74a4a95dec4fe88f3fb2f938      0      0      0      0      0      0
# ff1093d5ef61bf46f8c88e9b7614e311      3      2      3      4      4      4
# ff45fdfb4b6dac191aba17a281181d39      3      3      4      3      1      1
# ffb2ec238eba276f65157693ed329c7f      1      4      4      4      4      4
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0      0      0
#
#
# year-month                       202006 202007 202008
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932      3      4      3
# 00724ae2470df1ed0fe919800d02517d      0      0      2
# 00a8c3e3baed0557c31ab9b68a086ed2      2      2      2
# 00cc5a820586ce291c0fa4c2a99a4816      1      1      2
# 00d1f690ec4af27702febbd0db6942c2      2      2      2
# ...                                 ...    ...    ...
# feca6cdb74a4a95dec4fe88f3fb2f938      0      2      2
# ff1093d5ef61bf46f8c88e9b7614e311      2      3      2
# ff45fdfb4b6dac191aba17a281181d39      4      3      2
# ffb2ec238eba276f65157693ed329c7f      4      4      3
# ffd697d66cc01c8897ce3e37d693673a      0      0      0
#
# [1306 rows x 24 columns]

# %%
year_month_list = pivot_bb_usage_info['Usage'].columns

# %%
# multplying bins to get usage rating
for col in year_month_list:
    pivot_bb_usage_info[col] = pivot_bb_usage_info['Usage'][col]  * pivot_bb_usage_info['Duration'][col]

# %% [markdown]
# ## ToDO
# - find a different approach other than product

# %% [markdown]
# ### Usage ratings for year-month

# %%
pivot_bb_usage_info = pivot_bb_usage_info.drop(['Usage','Duration'], axis=1)
pivot_bb_usage_info
# Out:
#                                  201908 201910 201911 201912 202001 202002  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932     12      6      4      6     12     12
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0      0
# 00a8c3e3baed0557c31ab9b68a086ed2      2      4      2      2      6      2
# 00cc5a820586ce291c0fa4c2a99a4816      0      0      0      0      1      1
# 00d1f690ec4af27702febbd0db6942c2      2      2      2      2      2      2
# ...                                 ...    ...    ...    ...    ...    ...
# feca6cdb74a4a95dec4fe88f3fb2f938      0      0      0      0      0      0
# ff1093d5ef61bf46f8c88e9b7614e311      2      4      4      6      2      3
# ff45fdfb4b6dac191aba17a281181d39      9     12      9     12     12     12
# ffb2ec238eba276f65157693ed329c7f      0      0      0      1     12     12
# ffd697d66cc01c8897ce3e37d693673a      2      0      0      0      0      0
#
#                                  202003 202004 202005 202006 202007 202008
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932     12     12     12      9     12      6
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0      6
# 00a8c3e3baed0557c31ab9b68a086ed2      3      2      2      4      2      2
# 00cc5a820586ce291c0fa4c2a99a4816      0      0      2      2      2      6
# 00d1f690ec4af27702febbd0db6942c2      2      2      2      2      2      2
# ...                                 ...    ...    ...    ...    ...    ...
# feca6cdb74a4a95dec4fe88f3fb2f938      0      0      0      0      4      4
# ff1093d5ef61bf46f8c88e9b7614e311      8     12     12      4      3      2
# ff45fdfb4b6dac191aba17a281181d39     12      4      4     16      9      6
# ffb2ec238eba276f65157693ed329c7f     12     12     16     16     16     12
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0      0      0
#
# [1306 rows x 12 columns]

# %%
# scaling usage rating
scaler = MinMaxScaler()
for col in year_month_list:
    pivot_bb_usage_info[col] = scaler.fit_transform(pivot_bb_usage_info[col].values.reshape(-1,1))

# %%
sns.heatmap(pivot_bb_usage_info[year_month_list].sample(n=10), annot=True)
# Out:
# <AxesSubplot:xlabel='None-year-month', ylabel='PSTN.hash'>

# %%
ax = sns.boxplot(data=pivot_bb_usage_info[[int(x) for x in year_month_list]], orient="h", palette="Set2")
ax
# Out:
# <AxesSubplot:>

# %%
pivot_bb_usage_info['Usage_Rating_Scaled'] = pivot_bb_usage_info[year_month_list].sum(axis=1)/len(year_month_list)
pivot_bb_usage_info
# Out:
#                                     201908 201910  201911  201912  202001  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  1.000000  0.375  0.2500  0.3750  0.7500
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000  0.0000  0.0000  0.0000
# 00a8c3e3baed0557c31ab9b68a086ed2  0.166667  0.250  0.1250  0.1250  0.3750
# 00cc5a820586ce291c0fa4c2a99a4816  0.000000  0.000  0.0000  0.0000  0.0625
# 00d1f690ec4af27702febbd0db6942c2  0.166667  0.125  0.1250  0.1250  0.1250
# ...                                    ...    ...     ...     ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.000000  0.000  0.0000  0.0000  0.0000
# ff1093d5ef61bf46f8c88e9b7614e311  0.166667  0.250  0.2500  0.3750  0.1250
# ff45fdfb4b6dac191aba17a281181d39  0.750000  0.750  0.5625  0.7500  0.7500
# ffb2ec238eba276f65157693ed329c7f  0.000000  0.000  0.0000  0.0625  0.7500
# ffd697d66cc01c8897ce3e37d693673a  0.166667  0.000  0.0000  0.0000  0.0000
#
#                                   202002  202003 202004 202005  202006  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  0.7500  0.7500  0.750  0.750  0.5625
# 00724ae2470df1ed0fe919800d02517d  0.0000  0.0000  0.000  0.000  0.0000
# 00a8c3e3baed0557c31ab9b68a086ed2  0.1250  0.1875  0.125  0.125  0.2500
# 00cc5a820586ce291c0fa4c2a99a4816  0.0625  0.0000  0.000  0.125  0.1250
# 00d1f690ec4af27702febbd0db6942c2  0.1250  0.1250  0.125  0.125  0.1250
# ...                                  ...     ...    ...    ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.0000  0.0000  0.000  0.000  0.0000
# ff1093d5ef61bf46f8c88e9b7614e311  0.1875  0.5000  0.750  0.750  0.2500
# ff45fdfb4b6dac191aba17a281181d39  0.7500  0.7500  0.250  0.250  1.0000
# ffb2ec238eba276f65157693ed329c7f  0.7500  0.7500  0.750  1.000  1.0000
# ffd697d66cc01c8897ce3e37d693673a  0.0000  0.0000  0.000  0.000  0.0000
#
#                                   202007 202008 Usage_Rating_Scaled
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  0.7500  0.375            0.619792
# 00724ae2470df1ed0fe919800d02517d  0.0000  0.375            0.031250
# 00a8c3e3baed0557c31ab9b68a086ed2  0.1250  0.125            0.175347
# 00cc5a820586ce291c0fa4c2a99a4816  0.1250  0.375            0.072917
# 00d1f690ec4af27702febbd0db6942c2  0.1250  0.125            0.128472
# ...                                  ...    ...                 ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.2500  0.250            0.041667
# ff1093d5ef61bf46f8c88e9b7614e311  0.1875  0.125            0.326389
# ff45fdfb4b6dac191aba17a281181d39  0.5625  0.375            0.625000
# ffb2ec238eba276f65157693ed329c7f  1.0000  0.750            0.567708
# ffd697d66cc01c8897ce3e37d693673a  0.0000  0.000            0.013889
#
# [1306 rows x 13 columns]

# %%
pivot_bb_usage_info.describe()
# Out:
#                  201908       201910       201911       201912       202001  \
# year-month
# count       1306.000000  1306.000000  1306.000000  1306.000000  1306.000000
# mean           0.328931     0.310825     0.299914     0.327910     0.346861
# std            0.323410     0.295865     0.281419     0.303084     0.315020
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.083333     0.062500     0.062500     0.062500     0.062500
# 50%            0.250000     0.250000     0.250000     0.250000     0.250000
# 75%            0.500000     0.500000     0.500000     0.500000     0.562500
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  202002       202003       202004       202005       202006  \
# year-month
# count       1306.000000  1306.000000  1306.000000  1306.000000  1306.000000
# mean           0.322741     0.363419     0.376388     0.374856     0.376627
# std            0.291014     0.323282     0.328423     0.320893     0.315067
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.062500     0.062500     0.062500     0.062500     0.125000
# 50%            0.250000     0.250000     0.250000     0.250000     0.250000
# 75%            0.500000     0.562500     0.750000     0.562500     0.562500
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  202007       202008 Usage_Rating_Scaled
# year-month
# count       1306.000000  1306.000000         1306.000000
# mean           0.390027     0.391702            0.350850
# std            0.317071     0.315250            0.262686
# min            0.000000     0.000000            0.005208
# 25%            0.125000     0.125000            0.127170
# 50%            0.250000     0.312500            0.281250
# 75%            0.562500     0.750000            0.531250
# max            1.000000     1.000000            1.000000

# %%
# labling usage bins
bins = [0, 0.33, 0.66,1]
labels = ['LOW','MEDIUM','HIGH']
pivot_bb_usage_info['Usage_Rating_Categorical'] = pd.cut(pivot_bb_usage_info['Usage_Rating_Scaled'], bins=bins, labels=labels)
pivot_bb_usage_info
# Out:
#                                     201908 201910  201911  201912  202001  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  1.000000  0.375  0.2500  0.3750  0.7500
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000  0.0000  0.0000  0.0000
# 00a8c3e3baed0557c31ab9b68a086ed2  0.166667  0.250  0.1250  0.1250  0.3750
# 00cc5a820586ce291c0fa4c2a99a4816  0.000000  0.000  0.0000  0.0000  0.0625
# 00d1f690ec4af27702febbd0db6942c2  0.166667  0.125  0.1250  0.1250  0.1250
# ...                                    ...    ...     ...     ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.000000  0.000  0.0000  0.0000  0.0000
# ff1093d5ef61bf46f8c88e9b7614e311  0.166667  0.250  0.2500  0.3750  0.1250
# ff45fdfb4b6dac191aba17a281181d39  0.750000  0.750  0.5625  0.7500  0.7500
# ffb2ec238eba276f65157693ed329c7f  0.000000  0.000  0.0000  0.0625  0.7500
# ffd697d66cc01c8897ce3e37d693673a  0.166667  0.000  0.0000  0.0000  0.0000
#
#                                   202002  202003 202004 202005  202006  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  0.7500  0.7500  0.750  0.750  0.5625
# 00724ae2470df1ed0fe919800d02517d  0.0000  0.0000  0.000  0.000  0.0000
# 00a8c3e3baed0557c31ab9b68a086ed2  0.1250  0.1875  0.125  0.125  0.2500
# 00cc5a820586ce291c0fa4c2a99a4816  0.0625  0.0000  0.000  0.125  0.1250
# 00d1f690ec4af27702febbd0db6942c2  0.1250  0.1250  0.125  0.125  0.1250
# ...                                  ...     ...    ...    ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.0000  0.0000  0.000  0.000  0.0000
# ff1093d5ef61bf46f8c88e9b7614e311  0.1875  0.5000  0.750  0.750  0.2500
# ff45fdfb4b6dac191aba17a281181d39  0.7500  0.7500  0.250  0.250  1.0000
# ffb2ec238eba276f65157693ed329c7f  0.7500  0.7500  0.750  1.000  1.0000
# ffd697d66cc01c8897ce3e37d693673a  0.0000  0.0000  0.000  0.000  0.0000
#
#                                   202007 202008 Usage_Rating_Scaled  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  0.7500  0.375            0.619792
# 00724ae2470df1ed0fe919800d02517d  0.0000  0.375            0.031250
# 00a8c3e3baed0557c31ab9b68a086ed2  0.1250  0.125            0.175347
# 00cc5a820586ce291c0fa4c2a99a4816  0.1250  0.375            0.072917
# 00d1f690ec4af27702febbd0db6942c2  0.1250  0.125            0.128472
# ...                                  ...    ...                 ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.2500  0.250            0.041667
# ff1093d5ef61bf46f8c88e9b7614e311  0.1875  0.125            0.326389
# ff45fdfb4b6dac191aba17a281181d39  0.5625  0.375            0.625000
# ffb2ec238eba276f65157693ed329c7f  1.0000  0.750            0.567708
# ffd697d66cc01c8897ce3e37d693673a  0.0000  0.000            0.013889
#
#                                  Usage_Rating_Categorical
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932                   MEDIUM
# 00724ae2470df1ed0fe919800d02517d                      LOW
# 00a8c3e3baed0557c31ab9b68a086ed2                      LOW
# 00cc5a820586ce291c0fa4c2a99a4816                      LOW
# 00d1f690ec4af27702febbd0db6942c2                      LOW
# ...                                                   ...
# feca6cdb74a4a95dec4fe88f3fb2f938                      LOW
# ff1093d5ef61bf46f8c88e9b7614e311                      LOW
# ff45fdfb4b6dac191aba17a281181d39                   MEDIUM
# ffb2ec238eba276f65157693ed329c7f                   MEDIUM
# ffd697d66cc01c8897ce3e37d693673a                      LOW
#
# [1306 rows x 14 columns]

# %%
# adding category "NO" 
pivot_bb_usage_info['Usage_Rating_Categorical'] = pivot_bb_usage_info['Usage_Rating_Categorical'].cat.add_categories("NO")
pivot_bb_usage_info.loc[pivot_bb_usage_info['Usage_Rating_Scaled'] == 0.0, 'Usage_Rating_Categorical'] = "NO"
pivot_bb_usage_info[(pivot_bb_usage_info['Usage_Rating_Scaled'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [(201908, ), (201910, ), (201911, ), (201912, ), (202001, ), (202002, ), (202003, ), (202004, ), (202005, ), (202006, ), (202007, ), (202008, ), (Usage_Rating_Scaled, ), (Usage_Rating_Categorical, )]
# Index: []

# %% [markdown]
# ### Fina Result: Usage Ratings

# %%
pivot_bb_usage_info
# Out:
#                                     201908 201910  201911  201912  202001  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  1.000000  0.375  0.2500  0.3750  0.7500
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000  0.0000  0.0000  0.0000
# 00a8c3e3baed0557c31ab9b68a086ed2  0.166667  0.250  0.1250  0.1250  0.3750
# 00cc5a820586ce291c0fa4c2a99a4816  0.000000  0.000  0.0000  0.0000  0.0625
# 00d1f690ec4af27702febbd0db6942c2  0.166667  0.125  0.1250  0.1250  0.1250
# ...                                    ...    ...     ...     ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.000000  0.000  0.0000  0.0000  0.0000
# ff1093d5ef61bf46f8c88e9b7614e311  0.166667  0.250  0.2500  0.3750  0.1250
# ff45fdfb4b6dac191aba17a281181d39  0.750000  0.750  0.5625  0.7500  0.7500
# ffb2ec238eba276f65157693ed329c7f  0.000000  0.000  0.0000  0.0625  0.7500
# ffd697d66cc01c8897ce3e37d693673a  0.166667  0.000  0.0000  0.0000  0.0000
#
#                                   202002  202003 202004 202005  202006  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  0.7500  0.7500  0.750  0.750  0.5625
# 00724ae2470df1ed0fe919800d02517d  0.0000  0.0000  0.000  0.000  0.0000
# 00a8c3e3baed0557c31ab9b68a086ed2  0.1250  0.1875  0.125  0.125  0.2500
# 00cc5a820586ce291c0fa4c2a99a4816  0.0625  0.0000  0.000  0.125  0.1250
# 00d1f690ec4af27702febbd0db6942c2  0.1250  0.1250  0.125  0.125  0.1250
# ...                                  ...     ...    ...    ...     ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.0000  0.0000  0.000  0.000  0.0000
# ff1093d5ef61bf46f8c88e9b7614e311  0.1875  0.5000  0.750  0.750  0.2500
# ff45fdfb4b6dac191aba17a281181d39  0.7500  0.7500  0.250  0.250  1.0000
# ffb2ec238eba276f65157693ed329c7f  0.7500  0.7500  0.750  1.000  1.0000
# ffd697d66cc01c8897ce3e37d693673a  0.0000  0.0000  0.000  0.000  0.0000
#
#                                   202007 202008 Usage_Rating_Scaled  \
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932  0.7500  0.375            0.619792
# 00724ae2470df1ed0fe919800d02517d  0.0000  0.375            0.031250
# 00a8c3e3baed0557c31ab9b68a086ed2  0.1250  0.125            0.175347
# 00cc5a820586ce291c0fa4c2a99a4816  0.1250  0.375            0.072917
# 00d1f690ec4af27702febbd0db6942c2  0.1250  0.125            0.128472
# ...                                  ...    ...                 ...
# feca6cdb74a4a95dec4fe88f3fb2f938  0.2500  0.250            0.041667
# ff1093d5ef61bf46f8c88e9b7614e311  0.1875  0.125            0.326389
# ff45fdfb4b6dac191aba17a281181d39  0.5625  0.375            0.625000
# ffb2ec238eba276f65157693ed329c7f  1.0000  0.750            0.567708
# ffd697d66cc01c8897ce3e37d693673a  0.0000  0.000            0.013889
#
#                                  Usage_Rating_Categorical
# year-month
# PSTN.hash
# 00567a4a3c474aca1ce5cd6570648932                   MEDIUM
# 00724ae2470df1ed0fe919800d02517d                      LOW
# 00a8c3e3baed0557c31ab9b68a086ed2                      LOW
# 00cc5a820586ce291c0fa4c2a99a4816                      LOW
# 00d1f690ec4af27702febbd0db6942c2                      LOW
# ...                                                   ...
# feca6cdb74a4a95dec4fe88f3fb2f938                      LOW
# ff1093d5ef61bf46f8c88e9b7614e311                      LOW
# ff45fdfb4b6dac191aba17a281181d39                   MEDIUM
# ffb2ec238eba276f65157693ed329c7f                   MEDIUM
# ffd697d66cc01c8897ce3e37d693673a                      LOW
#
# [1306 rows x 14 columns]

# %%
pivot_bb_usage_info.to_csv("data/user_profile/BB_Usage_Categorical.csv")

# %% [markdown]
# # Phase 2

# %% [markdown]
# ## Binnig by Location
#
# - 1. group by location columns
# - 2. Bin by location and get counts

# %%
# bucketing by location
bb_location_info = bb_usage_info
bb_location_info['Location_Identifier'] = bb_location_info['MSAN'].astype(str)+ bb_location_info['LOCATION_CODE'].astype(str) +bb_location_info['EQUP_ID'].astype(str) +bb_location_info['EQUP_INDEX'].astype(str)
bb_location_info
# Out:
#                       Event_Source.hash       Upload      Download  Duration  \
# 0      6ff8125723953fdecaa253d2cb98b8fa   2479835042   17257396464   2505813
# 1      93ace21ebf00ad04343ff61293cec667   1864315334    8461159743   1326514
# 2      2ada0ac0b4bafccb83447afd2e003804    413588193    4289102246     96033
# 3      6c3134cf9691e170e9d1c011b0f19fdf   1012518853   14796542338   2681718
# 4      b7e298db3ba9498507c6c971b88ab990    926361088   20905123491   1666741
# ...                                 ...          ...           ...       ...
# 16785  64c4801b8e54f160cb55485ea4749b53  23669941591  169473000000   2650134
# 16786  4a9c1740f2139c820db9e20f67488ff1   1166127281   14184721881    631664
# 16787  31a7c210ea5cf7d79fc4ffca84c70613    618513100    8530589182    353262
# 16788  b7e298db3ba9498507c6c971b88ab990   1454432998   27510692517   1661209
# 16789  69afa8f1a1e707183f88a905c647ab1b    631714217   26455546135   2423427
#
#        year-month RTOM_CODE LOCATION_CODE          MSAN  EQUP_ID  EQUP_INDEX  \
# 0          201910      R-VA   VA-NKM-NODE  MSAG5200-ISL    48196           1
# 1          201910      R-RN       BG-NODE      MSAG5200    43139           1
# 2          201910     R-MRG       BZ-NODE  MSAG5200-ISL    43588           1
# 3          201910     R-KON  IDH-KGW-NODE  MSAG5200-ISL   619449           1
# 4          201910      R-MT   MT-AVR-NODE  MSAG5200-ISL    46716           1
# ...           ...       ...           ...           ...      ...         ...
# 16785      202005      R-KI       KI-NODE         C300M  1066816           4
# 16786      202008      R-GL       IM-NODE  UA5000(IPMB)    39153           1
# 16787      202005      R-MH   MH-POL-NODE  MSAG5200-ISL    49145           1
# 16788      202005      R-MT   MT-AVR-NODE  MSAG5200-ISL    46716           1
# 16789      202008     R-MLT  MLT-VMD-NODE  MSAG5200-ISL   414509           1
#
#                               PSTN.hash              Location_Identifier
# 0      9231c080ea1108c7eeede0f449becb59    MSAG5200-ISLVA-NKM-NODE481961
# 1      7e3969e2fb0fa148d817d3569b3eab3f            MSAG5200BG-NODE431391
# 2      f1415c386cab3355a5356c556fe9d0e1        MSAG5200-ISLBZ-NODE435881
# 3      517b461d5b8e09f1c3547218cc2e4947  MSAG5200-ISLIDH-KGW-NODE6194491
# 4      7fa3296ae71b6d2bb2ff46f97218940d    MSAG5200-ISLMT-AVR-NODE467161
# ...                                 ...                              ...
# 16785  0b9c67d21fa2883687695482de31d631             C300MKI-NODE10668164
# 16786  46960b77dad950ddae76dd53bd7848cd        UA5000(IPMB)IM-NODE391531
# 16787  4dd51155385e44fdf8d82be5630963f8    MSAG5200-ISLMH-POL-NODE491451
# 16788  7fa3296ae71b6d2bb2ff46f97218940d    MSAG5200-ISLMT-AVR-NODE467161
# 16789  cc66aaac252bb6f6cdde8df430e622f5  MSAG5200-ISLMLT-VMD-NODE4145091
#
# [13043 rows x 12 columns]

# %%
bb_location_info = bb_location_info.drop_duplicates("PSTN.hash", keep="last")
bb_location_info.shape
# Out:
# (1306, 12)

# %%
user_location = bb_location_info[['PSTN.hash','Location_Identifier']]
user_location
# Out:
#                               PSTN.hash              Location_Identifier
# 1038   603cefb461111f70653b606298757799        MSAG5200PH-AKG-NODE431631
# 3104   0ac56d0bbc79038c4ad883305638512f    MSAG5200-ISLMV-GDM-NODE482491
# 3131   03c567a2c97746f2545c0f9b8285827c   MSAG5200-ISLTBT-TLJ-NODE487241
# 3505   f6ec80f8701edf2f87c851996aa07ef1            MSAG5200BG-NODE431391
# 3655   923b8b0fdb0af84e50f1ba089c78c38d        MSAG5200PH-AKG-NODE431631
# ...                                 ...                              ...
# 16785  0b9c67d21fa2883687695482de31d631             C300MKI-NODE10668164
# 16786  46960b77dad950ddae76dd53bd7848cd        UA5000(IPMB)IM-NODE391531
# 16787  4dd51155385e44fdf8d82be5630963f8    MSAG5200-ISLMH-POL-NODE491451
# 16788  7fa3296ae71b6d2bb2ff46f97218940d    MSAG5200-ISLMT-AVR-NODE467161
# 16789  cc66aaac252bb6f6cdde8df430e622f5  MSAG5200-ISLMLT-VMD-NODE4145091
#
# [1306 rows x 2 columns]

# %%
user_location.to_csv("data/user_profile/BB_USAGE_Locations_of_Users.csv")

# %%
bb_location_info["User_Count"] = 1
bb_gropued_by_locations = bb_location_info.groupby(['Location_Identifier'], axis=0,as_index=False).sum()
bb_gropued_by_locations = bb_gropued_by_locations[['Location_Identifier','User_Count']]
# Out:
# <ipython-input-34-28461a8251ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_location_info["User_Count"] = 1

# %%
bb_gropued_by_locations
# Out:
#                 Location_Identifier  User_Count
# 0          C300MHE-DMD-NODE15221561           3
# 1            C300MHT-NE-NODE8152461          10
# 2         C300MIDH-IDJ-NODE11065541          23
# 3              C300MKI-NODE10668164          25
# 4          C300MNW-MEE-NODE18887751          73
# 5             C300MPDT-NODE13379431           3
# 6               C300MTP-NODE8700911           9
# 7               C300MVH-NODE9874041           3
# 8        MA5603TAD-SRV-NODE10224991           2
# 9         MSAG5200-ISLBZ-NODE435881          44
# 10       MSAG5200-ISLGE-NODE5577981           8
# 11    MSAG5200-ISLHC-NAP-NODE478721           8
# 12    MSAG5200-ISLHK-OCC-NODE506561           9
# 13       MSAG5200-ISLHNT-NODE423851          10
# 14        MSAG5200-ISLHO-NODE524692           2
# 15    MSAG5200-ISLHZ-BRL-NODE471911           8
# 16  MSAG5200-ISLIDH-KGW-NODE6194491          59
# 17    MSAG5200-ISLJA-PKV-NODE460421          13
# 18    MSAG5200-ISLMB-PSL-NODE482261           7
# 19    MSAG5200-ISLMH-POL-NODE491451          48
# 20  MSAG5200-ISLMLT-VMD-NODE4145091          58
# 21    MSAG5200-ISLMT-AVR-NODE467161         140
# 22    MSAG5200-ISLMV-GDM-NODE482491         105
# 23       MSAG5200-ISLMX-NODE5391821           3
# 24    MSAG5200-ISLND-PHG-NODE500241          94
# 25    MSAG5200-ISLNL-HGW-NODE491281           8
# 26    MSAG5200-ISLPC-AGT-NODE480031          51
# 27   MSAG5200-ISLPK-PNU-NODE6136021           3
# 28       MSAG5200-ISLPRN-NODE427901          10
# 29    MSAG5200-ISLSI-DWS-NODE520721          16
# 30      MSAG5200-ISLTBL-NODE5577771           5
# 31   MSAG5200-ISLTBT-TLJ-NODE487241           4
# 32    MSAG5200-ISLVA-NKM-NODE481961          42
# 33    MSAG5200-ISLWI-NWT-NODE485201          10
# 34   MSAG5200-ISLWKN-SWP-NODE473481          12
# 35        MSAG5200-ISLWM-NODE432881           3
# 36    MSAG5200-ISLWY-MDB-NODE506221           7
# 37            MSAG5200BG-NODE431391          95
# 38           MSAG5200HPG-NODE432141           9
# 39           MSAG5200MGE-NODE428381           3
# 40        MSAG5200PH-AKG-NODE431631         130
# 41            MSAG5200PK-NODE438641           5
# 42        UA5000(IPMB)IM-NODE391531           6
# 43        UA5000(IPMB)SL-NODE385341          94
# 44  ZXDSL9806H-ISLAG-PNP-NODE529761           8
# 45  ZXDSL9806H-ISLKE-NRP-NODE495731          11
# 46  ZXDSL9806H-ISLKL-PRC-NODE482361           7

# %%
bb_gropued_by_locations.to_csv("data/user_profile/BB_Users_by_location.csv")
