# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
voice_usage_info = pd.read_csv("data/VOICE_INCOMING_CALL_USAGE_IDD.csv")

voice_usage_info.shape
# Out:
# (5131, 10)

# %%
voice_usage_info
# Out:
#       event_source                 event_source.hash  call_count  \
# 0        672221677  b99957e9215d70ac90b5819e405827f7           2
# 1        242228729  61242a1f704099c655f84ef4fc0af8fd           9
# 2        672221677  b99957e9215d70ac90b5819e405827f7           2
# 3        242228729  61242a1f704099c655f84ef4fc0af8fd           2
# 4        672221677  b99957e9215d70ac90b5819e405827f7           6
# ...            ...                               ...         ...
# 5126     112727670  a0723957ebd80e956172f8424d6d530f           5
# 5127     112727670  a0723957ebd80e956172f8424d6d530f           3
# 5128     112727670  a0723957ebd80e956172f8424d6d530f           6
# 5129     112727670  a0723957ebd80e956172f8424d6d530f           4
# 5130     112727670  a0723957ebd80e956172f8424d6d530f           2
#
#       duration (seconds)      ym rtom_code location_code            msan  \
# 0                    458  202002      R-KL   KL-PRC-NODE  ZXDSL9806H-ISL
# 1                   4440  201912      R-VA   VA-NKM-NODE    MSAG5200-ISL
# 2                     56  202005      R-KL   KL-PRC-NODE  ZXDSL9806H-ISL
# 3                    736  201911      R-VA   VA-NKM-NODE    MSAG5200-ISL
# 4                   1001  201912      R-KL   KL-PRC-NODE  ZXDSL9806H-ISL
# ...                  ...     ...       ...           ...             ...
# 5126               11352  202001      R-RM   MV-GDM-NODE    MSAG5200-ISL
# 5127                7142  202008      R-RM   MV-GDM-NODE    MSAG5200-ISL
# 5128                7328  202002      R-RM   MV-GDM-NODE    MSAG5200-ISL
# 5129               11493  202004      R-RM   MV-GDM-NODE    MSAG5200-ISL
# 5130                8091  202007      R-RM   MV-GDM-NODE    MSAG5200-ISL
#
#       equp_id  equp_index
# 0       48236           1
# 1       48196           1
# 2       48236           1
# 3       48196           1
# 4       48236           1
# ...       ...         ...
# 5126    48249           1
# 5127    48249           1
# 5128    48249           1
# 5129    48249           1
# 5130    48249           1
#
# [5131 rows x 10 columns]

# %%
# ToDo 
# Handle null values
# Drop unnecessary cols
# Pivot by monthYear
# Usage rating Call Count/Duration - bucketizing/ add rating cols
# location grouping/bucketizing (consider 4 location cols)
# User profile dim table
# visualize and analyze data

# %%
voice_usage_info = voice_usage_info.drop_duplicates(["event_source","ym"], keep="last")

voice_usage_info.shape
# Out:
# (5131, 10)

# %%
voice_usage_info = voice_usage_info.drop(['event_source.hash'], axis=1)
voice_usage_info.rename(columns={'duration (seconds)': 'duration','ym':'year-month'}, inplace=True)
voice_usage_info
# Out:
#       event_source  call_count  duration  year-month rtom_code location_code  \
# 0        672221677           2       458      202002      R-KL   KL-PRC-NODE
# 1        242228729           9      4440      201912      R-VA   VA-NKM-NODE
# 2        672221677           2        56      202005      R-KL   KL-PRC-NODE
# 3        242228729           2       736      201911      R-VA   VA-NKM-NODE
# 4        672221677           6      1001      201912      R-KL   KL-PRC-NODE
# ...            ...         ...       ...         ...       ...           ...
# 5126     112727670           5     11352      202001      R-RM   MV-GDM-NODE
# 5127     112727670           3      7142      202008      R-RM   MV-GDM-NODE
# 5128     112727670           6      7328      202002      R-RM   MV-GDM-NODE
# 5129     112727670           4     11493      202004      R-RM   MV-GDM-NODE
# 5130     112727670           2      8091      202007      R-RM   MV-GDM-NODE
#
#                 msan  equp_id  equp_index
# 0     ZXDSL9806H-ISL    48236           1
# 1       MSAG5200-ISL    48196           1
# 2     ZXDSL9806H-ISL    48236           1
# 3       MSAG5200-ISL    48196           1
# 4     ZXDSL9806H-ISL    48236           1
# ...              ...      ...         ...
# 5126    MSAG5200-ISL    48249           1
# 5127    MSAG5200-ISL    48249           1
# 5128    MSAG5200-ISL    48249           1
# 5129    MSAG5200-ISL    48249           1
# 5130    MSAG5200-ISL    48249           1
#
# [5131 rows x 9 columns]

# %%
voice_usage_info['duration'].fillna(0)
voice_usage_info['call_count'].fillna(0)
# Out:
# 0       2
# 1       9
# 2       2
# 3       2
# 4       6
#        ..
# 5126    5
# 5127    3
# 5128    6
# 5129    4
# 5130    2
# Name: call_count, Length: 5131, dtype: int64

# %%
voice_usage_info.isnull().sum(axis=0)
# Out:
# event_source     0
# call_count       0
# duration         0
# year-month       0
# rtom_code        0
# location_code    0
# msan             0
# equp_id          0
# equp_index       0
# dtype: int64

# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Usage Ranking
#
# - 1. Pivot by year-month
# - 2. Bin by Upload/Download/Duration
# - 3. Usage Rank
# - 4. Labling usage

# %%
voice_usage = voice_usage_info[['event_source','call_count','duration','year-month']]
voice_usage
# Out:
#       event_source  call_count  duration  year-month
# 0        672221677           2       458      202002
# 1        242228729           9      4440      201912
# 2        672221677           2        56      202005
# 3        242228729           2       736      201911
# 4        672221677           6      1001      201912
# ...            ...         ...       ...         ...
# 5126     112727670           5     11352      202001
# 5127     112727670           3      7142      202008
# 5128     112727670           6      7328      202002
# 5129     112727670           4     11493      202004
# 5130     112727670           2      8091      202007
#
# [5131 rows x 4 columns]

# %%
pivot_voice_usage_info = pd.pivot_table(voice_usage,index=['event_source'],columns=['year-month'], aggfunc=np.sum, fill_value=0)
pivot_voice_usage_info
# Out:
#              call_count                                                   \
# year-month       201908 201909 201910 201911 201912 202001 202002 202003
# event_source
# 112053643             0      3      0      0      0      0      0      0
# 112055691             2      1     16      5      7      5     11      5
# 112055692             0      0      1      0      0      0      1      0
# 112055693             1      0      0      0      0      1      2      0
# 112058059             0      1      0      0      0      0      0      0
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# 912255127             0      0      0      0      2      0      0      0
# 912286091             3      0      0      0      0      0      0      0
# 912286158             0      0      0      1      0      0      0      0
# 912286560             1      1      1      0      0      1      0      0
# 912286838             0      0      0      0      0      0      2      0
#
#                             ... duration                                     \
# year-month   202004 202005  ...   201911 201912 202001 202002 202003 202004
# event_source                ...
# 112053643         0      0  ...        0      0      0      0      0      0
# 112055691         0      0  ...     1039   1593    947   2344    659      0
# 112055692         0      0  ...        0      0      0    352      0      0
# 112055693         0      0  ...        0      0    126    246      0      0
# 112058059         0      0  ...        0      0      0      0      0      0
# ...             ...    ...  ...      ...    ...    ...    ...    ...    ...
# 912255127         0      0  ...        0     93      0      0      0      0
# 912286091         0      0  ...        0      0      0      0      0      0
# 912286158         0      0  ...      147      0      0      0      0      0
# 912286560         1      0  ...        0      0    427      0      0    280
# 912286838         0      0  ...        0      0      0     30      0      0
#
#
# year-month   202005 202006 202007 202008
# event_source
# 112053643         0      0      0      0
# 112055691         0     49    267      0
# 112055692         0      0      0    232
# 112055693         0      0      0      0
# 112058059         0      0      0      0
# ...             ...    ...    ...    ...
# 912255127         0      0      0      0
# 912286091         0      0      0      0
# 912286158         0      0     98      0
# 912286560         0      0      0      0
# 912286838         0      0      0      0
#
# [1197 rows x 26 columns]

# %%
pivot_voice_usage_info.columns
# Out:
# MultiIndex([('call_count', 201908),
#             ('call_count', 201909),
#             ('call_count', 201910),
#             ('call_count', 201911),
#             ('call_count', 201912),
#             ('call_count', 202001),
#             ('call_count', 202002),
#             ('call_count', 202003),
#             ('call_count', 202004),
#             ('call_count', 202005),
#             ('call_count', 202006),
#             ('call_count', 202007),
#             ('call_count', 202008),
#             (  'duration', 201908),
#             (  'duration', 201909),
#             (  'duration', 201910),
#             (  'duration', 201911),
#             (  'duration', 201912),
#             (  'duration', 202001),
#             (  'duration', 202002),
#             (  'duration', 202003),
#             (  'duration', 202004),
#             (  'duration', 202005),
#             (  'duration', 202006),
#             (  'duration', 202007),
#             (  'duration', 202008)],
#            names=[None, 'year-month'])

# %%
pivot_voice_usage_info.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#             call_count                                                  \
# year-month      201908      201909      201910      201911      201912
# count       1197.00000  1197.00000  1197.00000  1197.00000  1197.00000
# mean           1.87719     1.73935     2.01671     1.45113     1.69089
# std            5.17963     4.42162     6.33840     4.19910     7.33752
# min            0.00000     0.00000     0.00000     0.00000     0.00000
# 25%            0.00000     0.00000     0.00000     0.00000     0.00000
# 50%            0.00000     0.00000     0.00000     0.00000     0.00000
# 75%            2.00000     1.00000     2.00000     1.00000     1.00000
# max           83.00000    51.00000   128.00000    64.00000   208.00000
#
#                                                                         ...  \
# year-month      202001      202002      202003      202004      202005  ...
# count       1197.00000  1197.00000  1197.00000  1197.00000  1197.00000  ...
# mean           1.97076     1.62657     1.34921     0.96491     1.03175  ...
# std            6.14158     4.80298     3.82323     3.10256     3.72091  ...
# min            0.00000     0.00000     0.00000     0.00000     0.00000  ...
# 25%            0.00000     0.00000     0.00000     0.00000     0.00000  ...
# 50%            0.00000     0.00000     0.00000     0.00000     0.00000  ...
# 75%            2.00000     1.00000     1.00000     1.00000     1.00000  ...
# max          127.00000    72.00000    50.00000    35.00000    61.00000  ...
#
#                duration                                                      \
# year-month       201911       201912       202001       202002       202003
# count        1197.00000   1197.00000   1197.00000   1197.00000   1197.00000
# mean          544.51295    509.99833    685.94653    598.19883    593.18296
# std          2251.37431   2049.41993   2440.66274   2201.45805   2286.65340
# min             0.00000      0.00000      0.00000      0.00000      0.00000
# 25%             0.00000      0.00000      0.00000      0.00000      0.00000
# 50%             0.00000      0.00000      0.00000      0.00000      0.00000
# 75%           126.00000    157.00000    295.00000    119.00000     93.00000
# max         38355.00000  41941.00000  32434.00000  29438.00000  36844.00000
#
#
# year-month       202004       202005       202006       202007       202008
# count        1197.00000   1197.00000   1197.00000   1197.00000   1197.00000
# mean          484.24060    481.32916    561.06767    496.22055    469.71763
# std          1872.40712   2081.08792   1947.68421   1894.46995   1689.92458
# min             0.00000      0.00000      0.00000      0.00000      0.00000
# 25%             0.00000      0.00000      0.00000      0.00000      0.00000
# 50%             0.00000      0.00000      0.00000      0.00000      0.00000
# 75%            13.00000     11.00000     71.00000     11.00000     62.00000
# max         30178.00000  36928.00000  25426.00000  24939.00000  22856.00000
#
# [8 rows x 26 columns]

# %%
voice_usage.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#           event_source  call_count     duration    year-month
# count       5131.00000  5131.00000   5131.00000    5131.00000
# mean   279186888.21243     4.69051   1725.30306  201963.81427
# std    208366727.01098     9.83080   3519.70864      46.75324
# min    112053643.00000     1.00000      1.00000  201908.00000
# 25%    112723052.00000     1.00000    127.00000  201910.00000
# 50%    112910219.00000     2.00000    525.00000  202001.00000
# 75%    382251458.00000     5.00000   1742.00000  202005.00000
# max    912286838.00000   314.00000  62113.00000  202008.00000

# %%
# binning call_count
count_bins = [0,3,6,100,314]
for col in pivot_voice_usage_info['call_count'].columns:
    pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
pivot_voice_usage_info['call_count']
# Out:
# <ipython-input-14-14283cecf24d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
# year-month    201908  201909  201910  201911  201912  202001  202002  202003  \
# event_source
# 112053643          0       1       0       0       0       0       0       0
# 112055691          1       1       3       2       3       2       3       2
# 112055692          0       0       1       0       0       0       1       0
# 112055693          1       0       0       0       0       1       1       0
# 112058059          0       1       0       0       0       0       0       0
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 912255127          0       0       0       0       1       0       0       0
# 912286091          1       0       0       0       0       0       0       0
# 912286158          0       0       0       1       0       0       0       0
# 912286560          1       1       1       0       0       1       0       0
# 912286838          0       0       0       0       0       0       1       0
#
# year-month    202004  202005  202006  202007  202008
# event_source
# 112053643          0       0       0       0       0
# 112055691          0       0       1       1       0
# 112055692          0       0       0       0       1
# 112055693          0       0       0       0       0
# 112058059          0       0       0       0       0
# ...              ...     ...     ...     ...     ...
# 912255127          0       0       0       0       0
# 912286091          0       0       0       0       0
# 912286158          0       0       0       1       0
# 912286560          1       0       0       0       0
# 912286838          0       0       0       0       0
#
# [1197 rows x 13 columns]

# %%
pivot_voice_usage_info['call_count'].describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       1197.000000  1197.000000  1197.000000  1197.000000  1197.000000
# mean           0.604845     0.593150     0.616541     0.507101     0.527987
# std            0.899690     0.909291     0.948063     0.830637     0.858906
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000     0.000000     0.000000
# 75%            1.000000     1.000000     1.000000     1.000000     1.000000
# max            3.000000     3.000000     4.000000     3.000000     4.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       1197.000000  1197.000000  1197.000000  1197.000000  1197.000000
# mean           0.618212     0.515455     0.474520     0.369256     0.367586
# std            0.918285     0.863107     0.819124     0.729679     0.721309
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000     0.000000     0.000000
# 75%            1.000000     1.000000     1.000000     1.000000     1.000000
# max            4.000000     3.000000     3.000000     3.000000     3.000000
#
# year-month       202006       202007       202008
# count       1197.000000  1197.000000  1197.000000
# mean           0.486216     0.399332     0.443609
# std            0.859252     0.779718     0.786298
# min            0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000
# 75%            1.000000     1.000000     1.000000
# max            4.000000     4.000000     4.000000

# %%
# binning duration
duration_bins = [0, 120, 600, 1800,62113]
for col in pivot_voice_usage_info['duration'].columns:
    pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
pivot_voice_usage_info['duration']
# Out:
# <ipython-input-16-cb880e52479f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
# year-month    201908  201909  201910  201911  201912  202001  202002  202003  \
# event_source
# 112053643          0       2       0       0       0       0       0       0
# 112055691          3       1       4       3       3       3       4       3
# 112055692          0       0       1       0       0       0       2       0
# 112055693          1       0       0       0       0       2       2       0
# 112058059          0       1       0       0       0       0       0       0
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 912255127          0       0       0       0       1       0       0       0
# 912286091          2       0       0       0       0       0       0       0
# 912286158          0       0       0       2       0       0       0       0
# 912286560          3       2       2       0       0       2       0       0
# 912286838          0       0       0       0       0       0       1       0
#
# year-month    202004  202005  202006  202007  202008
# event_source
# 112053643          0       0       0       0       0
# 112055691          0       0       1       2       0
# 112055692          0       0       0       0       2
# 112055693          0       0       0       0       0
# 112058059          0       0       0       0       0
# ...              ...     ...     ...     ...     ...
# 912255127          0       0       0       0       0
# 912286091          0       0       0       0       0
# 912286158          0       0       0       1       0
# 912286560          2       0       0       0       0
# 912286838          0       0       0       0       0
#
# [1197 rows x 13 columns]

# %%
pivot_voice_usage_info['duration'].describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       1197.000000  1197.000000  1197.000000  1197.000000  1197.000000
# mean           0.997494     0.932331     0.944862     0.812030     0.844612
# std            1.406802     1.369007     1.395873     1.289495     1.321642
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000     0.000000     0.000000
# 75%            2.000000     2.000000     2.000000     2.000000     2.000000
# max            4.000000     4.000000     4.000000     4.000000     4.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       1197.000000  1197.000000  1197.000000  1197.000000  1197.000000
# mean           0.979950     0.831245     0.792815     0.657477     0.640769
# std            1.379956     1.342610     1.327172     1.243567     1.225267
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000     0.000000     0.000000
# 75%            2.000000     1.000000     1.000000     1.000000     1.000000
# max            4.000000     4.000000     4.000000     4.000000     4.000000
#
# year-month       202006       202007       202008
# count       1197.000000  1197.000000  1197.000000
# mean           0.776107     0.641604     0.729323
# std            1.318126     1.228578     1.259181
# min            0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000
# 75%            1.000000     1.000000     1.000000
# max            4.000000     4.000000     4.000000

# %%
year_month_list = pivot_voice_usage_info['call_count'].columns

# %%
# multplying bins to get usage rating
for col in year_month_list:
    pivot_voice_usage_info[col] = pivot_voice_usage_info['call_count'][col]  * pivot_voice_usage_info['duration'][col]

# %% [markdown]
# ### Usage ratings for year-month

# %%
pivot_voice_usage_info = pivot_voice_usage_info.drop(['call_count','duration'], axis=1)
pivot_voice_usage_info
# Out:
#              201908 201909 201910 201911 201912 202001 202002 202003 202004  \
# year-month
# event_source
# 112053643         0      2      0      0      0      0      0      0      0
# 112055691         3      1     12      6      9      6     12      6      0
# 112055692         0      0      1      0      0      0      2      0      0
# 112055693         1      0      0      0      0      2      2      0      0
# 112058059         0      1      0      0      0      0      0      0      0
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 912255127         0      0      0      0      1      0      0      0      0
# 912286091         2      0      0      0      0      0      0      0      0
# 912286158         0      0      0      2      0      0      0      0      0
# 912286560         3      2      2      0      0      2      0      0      2
# 912286838         0      0      0      0      0      0      1      0      0
#
#              202005 202006 202007 202008
# year-month
# event_source
# 112053643         0      0      0      0
# 112055691         0      1      2      0
# 112055692         0      0      0      2
# 112055693         0      0      0      0
# 112058059         0      0      0      0
# ...             ...    ...    ...    ...
# 912255127         0      0      0      0
# 912286091         0      0      0      0
# 912286158         0      0      1      0
# 912286560         0      0      0      0
# 912286838         0      0      0      0
#
# [1197 rows x 13 columns]

# %%
pivot_voice_usage_info.T.reset_index(drop=True).T
pivot_voice_usage_info.columns=year_month_list

# %%
# scaling usage rating
scaler = MinMaxScaler()
for col in year_month_list:
    pivot_voice_usage_info[col] = scaler.fit_transform(pivot_voice_usage_info[col].values.reshape(-1,1))
pivot_voice_usage_info
# Out:
# year-month      201908    201909  201910    201911  201912  202001    202002  \
# event_source
# 112053643     0.000000  0.166667  0.0000  0.000000  0.0000   0.000  0.000000
# 112055691     0.250000  0.083333  0.7500  0.500000  0.5625   0.375  1.000000
# 112055692     0.000000  0.000000  0.0625  0.000000  0.0000   0.000  0.166667
# 112055693     0.083333  0.000000  0.0000  0.000000  0.0000   0.125  0.166667
# 112058059     0.000000  0.083333  0.0000  0.000000  0.0000   0.000  0.000000
# ...                ...       ...     ...       ...     ...     ...       ...
# 912255127     0.000000  0.000000  0.0000  0.000000  0.0625   0.000  0.000000
# 912286091     0.166667  0.000000  0.0000  0.000000  0.0000   0.000  0.000000
# 912286158     0.000000  0.000000  0.0000  0.166667  0.0000   0.000  0.000000
# 912286560     0.250000  0.166667  0.1250  0.000000  0.0000   0.125  0.000000
# 912286838     0.000000  0.000000  0.0000  0.000000  0.0000   0.000  0.083333
#
# year-month    202003    202004  202005  202006  202007  202008
# event_source
# 112053643        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112055691        0.5  0.000000     0.0  0.0625  0.1250   0.000
# 112055692        0.0  0.000000     0.0  0.0000  0.0000   0.125
# 112055693        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112058059        0.0  0.000000     0.0  0.0000  0.0000   0.000
# ...              ...       ...     ...     ...     ...     ...
# 912255127        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286091        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286158        0.0  0.000000     0.0  0.0000  0.0625   0.000
# 912286560        0.0  0.166667     0.0  0.0000  0.0000   0.000
# 912286838        0.0  0.000000     0.0  0.0000  0.0000   0.000
#
# [1197 rows x 13 columns]

# %%
sns.heatmap(pivot_voice_usage_info[year_month_list].head(), annot=True)
# Out:
# <AxesSubplot:xlabel='year-month', ylabel='event_source'>

# %%
pivot_voice_usage_info['Usage_Rating_Scaled'] = pivot_voice_usage_info[year_month_list].sum(axis=1)/len(year_month_list)
pivot_voice_usage_info
# Out:
# year-month      201908    201909  201910    201911  201912  202001    202002  \
# event_source
# 112053643     0.000000  0.166667  0.0000  0.000000  0.0000   0.000  0.000000
# 112055691     0.250000  0.083333  0.7500  0.500000  0.5625   0.375  1.000000
# 112055692     0.000000  0.000000  0.0625  0.000000  0.0000   0.000  0.166667
# 112055693     0.083333  0.000000  0.0000  0.000000  0.0000   0.125  0.166667
# 112058059     0.000000  0.083333  0.0000  0.000000  0.0000   0.000  0.000000
# ...                ...       ...     ...       ...     ...     ...       ...
# 912255127     0.000000  0.000000  0.0000  0.000000  0.0625   0.000  0.000000
# 912286091     0.166667  0.000000  0.0000  0.000000  0.0000   0.000  0.000000
# 912286158     0.000000  0.000000  0.0000  0.166667  0.0000   0.000  0.000000
# 912286560     0.250000  0.166667  0.1250  0.000000  0.0000   0.125  0.000000
# 912286838     0.000000  0.000000  0.0000  0.000000  0.0000   0.000  0.083333
#
# year-month    202003    202004  202005  202006  202007  202008  \
# event_source
# 112053643        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112055691        0.5  0.000000     0.0  0.0625  0.1250   0.000
# 112055692        0.0  0.000000     0.0  0.0000  0.0000   0.125
# 112055693        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112058059        0.0  0.000000     0.0  0.0000  0.0000   0.000
# ...              ...       ...     ...     ...     ...     ...
# 912255127        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286091        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286158        0.0  0.000000     0.0  0.0000  0.0625   0.000
# 912286560        0.0  0.166667     0.0  0.0000  0.0000   0.000
# 912286838        0.0  0.000000     0.0  0.0000  0.0000   0.000
#
# year-month    Usage_Rating_Scaled
# event_source
# 112053643                0.012821
# 112055691                0.323718
# 112055692                0.027244
# 112055693                0.028846
# 112058059                0.006410
# ...                           ...
# 912255127                0.004808
# 912286091                0.012821
# 912286158                0.017628
# 912286560                0.064103
# 912286838                0.006410
#
# [1197 rows x 14 columns]

# %% [markdown]
# ### Finding Outliers

# %%
pivot_voice_usage_info.plot.line(subplots=True, figsize=(16,8))
# Out:
# array([<AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>], dtype=object)

# %%
pivot_voice_usage_info.boxplot(column=[201908,201909,201910,201911,201912,202001,202002,202003,202004,202005,202006,202007,202008,])
# Out:
# <AxesSubplot:>

# %%
pivot_voice_usage_info.describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       1197.000000  1197.000000  1197.000000  1197.000000  1197.000000
# mean           0.142022     0.137079     0.109597     0.112434     0.090434
# std            0.259743     0.259102     0.204180     0.228523     0.182377
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000     0.000000     0.000000
# 75%            0.166667     0.166667     0.125000     0.166667     0.125000
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       1197.000000  1197.000000  1197.000000  1197.000000  1197.000000
# mean           0.108135     0.121345     0.112434     0.087719     0.084865
# std            0.198070     0.252461     0.238275     0.211414     0.204715
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000     0.000000     0.000000
# 50%            0.000000     0.000000     0.000000     0.000000     0.000000
# 75%            0.125000     0.166667     0.083333     0.083333     0.083333
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202006       202007       202008  Usage_Rating_Scaled
# count       1197.000000  1197.000000  1197.000000          1197.000000
# mean           0.085840     0.069288     0.074091             0.102714
# std            0.184055     0.167575     0.164596             0.164449
# min            0.000000     0.000000     0.000000             0.004808
# 25%            0.000000     0.000000     0.000000             0.012821
# 50%            0.000000     0.000000     0.000000             0.030449
# 75%            0.062500     0.062500     0.062500             0.108974
# max            1.000000     1.000000     1.000000             0.884615

# %%
# labling usage bins
bins = [0, 0.05, 0.3,1]
labels = ['LOW','MEDIUM','HIGH']
pivot_voice_usage_info['Usage_Rating_Categorical'] = pd.cut(pivot_voice_usage_info['Usage_Rating_Scaled'], bins=bins, labels=labels)
pivot_voice_usage_info
# Out:
# year-month      201908    201909  201910    201911  201912  202001    202002  \
# event_source
# 112053643     0.000000  0.166667  0.0000  0.000000  0.0000   0.000  0.000000
# 112055691     0.250000  0.083333  0.7500  0.500000  0.5625   0.375  1.000000
# 112055692     0.000000  0.000000  0.0625  0.000000  0.0000   0.000  0.166667
# 112055693     0.083333  0.000000  0.0000  0.000000  0.0000   0.125  0.166667
# 112058059     0.000000  0.083333  0.0000  0.000000  0.0000   0.000  0.000000
# ...                ...       ...     ...       ...     ...     ...       ...
# 912255127     0.000000  0.000000  0.0000  0.000000  0.0625   0.000  0.000000
# 912286091     0.166667  0.000000  0.0000  0.000000  0.0000   0.000  0.000000
# 912286158     0.000000  0.000000  0.0000  0.166667  0.0000   0.000  0.000000
# 912286560     0.250000  0.166667  0.1250  0.000000  0.0000   0.125  0.000000
# 912286838     0.000000  0.000000  0.0000  0.000000  0.0000   0.000  0.083333
#
# year-month    202003    202004  202005  202006  202007  202008  \
# event_source
# 112053643        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112055691        0.5  0.000000     0.0  0.0625  0.1250   0.000
# 112055692        0.0  0.000000     0.0  0.0000  0.0000   0.125
# 112055693        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112058059        0.0  0.000000     0.0  0.0000  0.0000   0.000
# ...              ...       ...     ...     ...     ...     ...
# 912255127        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286091        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286158        0.0  0.000000     0.0  0.0000  0.0625   0.000
# 912286560        0.0  0.166667     0.0  0.0000  0.0000   0.000
# 912286838        0.0  0.000000     0.0  0.0000  0.0000   0.000
#
# year-month    Usage_Rating_Scaled Usage_Rating_Categorical
# event_source
# 112053643                0.012821                      LOW
# 112055691                0.323718                     HIGH
# 112055692                0.027244                      LOW
# 112055693                0.028846                      LOW
# 112058059                0.006410                      LOW
# ...                           ...                      ...
# 912255127                0.004808                      LOW
# 912286091                0.012821                      LOW
# 912286158                0.017628                      LOW
# 912286560                0.064103                   MEDIUM
# 912286838                0.006410                      LOW
#
# [1197 rows x 15 columns]

# %%
# adding category "NO" 
pivot_voice_usage_info['Usage_Rating_Categorical'] = pivot_voice_usage_info['Usage_Rating_Categorical'].cat.add_categories("NO")
pivot_voice_usage_info.loc[pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0, 'Usage_Rating_Categorical'] = "NO"
pivot_voice_usage_info[(pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [201908, 201909, 201910, 201911, 201912, 202001, 202002, 202003, 202004, 202005, 202006, 202007, 202008, Usage_Rating_Scaled, Usage_Rating_Categorical]
# Index: []

# %% [markdown]
# ### Fina Result: Usage Ratings

# %%
pivot_voice_usage_info
# Out:
# year-month      201908    201909  201910    201911  201912  202001    202002  \
# event_source
# 112053643     0.000000  0.166667  0.0000  0.000000  0.0000   0.000  0.000000
# 112055691     0.250000  0.083333  0.7500  0.500000  0.5625   0.375  1.000000
# 112055692     0.000000  0.000000  0.0625  0.000000  0.0000   0.000  0.166667
# 112055693     0.083333  0.000000  0.0000  0.000000  0.0000   0.125  0.166667
# 112058059     0.000000  0.083333  0.0000  0.000000  0.0000   0.000  0.000000
# ...                ...       ...     ...       ...     ...     ...       ...
# 912255127     0.000000  0.000000  0.0000  0.000000  0.0625   0.000  0.000000
# 912286091     0.166667  0.000000  0.0000  0.000000  0.0000   0.000  0.000000
# 912286158     0.000000  0.000000  0.0000  0.166667  0.0000   0.000  0.000000
# 912286560     0.250000  0.166667  0.1250  0.000000  0.0000   0.125  0.000000
# 912286838     0.000000  0.000000  0.0000  0.000000  0.0000   0.000  0.083333
#
# year-month    202003    202004  202005  202006  202007  202008  \
# event_source
# 112053643        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112055691        0.5  0.000000     0.0  0.0625  0.1250   0.000
# 112055692        0.0  0.000000     0.0  0.0000  0.0000   0.125
# 112055693        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 112058059        0.0  0.000000     0.0  0.0000  0.0000   0.000
# ...              ...       ...     ...     ...     ...     ...
# 912255127        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286091        0.0  0.000000     0.0  0.0000  0.0000   0.000
# 912286158        0.0  0.000000     0.0  0.0000  0.0625   0.000
# 912286560        0.0  0.166667     0.0  0.0000  0.0000   0.000
# 912286838        0.0  0.000000     0.0  0.0000  0.0000   0.000
#
# year-month    Usage_Rating_Scaled Usage_Rating_Categorical
# event_source
# 112053643                0.012821                      LOW
# 112055691                0.323718                     HIGH
# 112055692                0.027244                      LOW
# 112055693                0.028846                      LOW
# 112058059                0.006410                      LOW
# ...                           ...                      ...
# 912255127                0.004808                      LOW
# 912286091                0.012821                      LOW
# 912286158                0.017628                      LOW
# 912286560                0.064103                   MEDIUM
# 912286838                0.006410                      LOW
#
# [1197 rows x 15 columns]

# %%
pivot_voice_usage_info.to_csv("data/user_profile/VOICE_IDD_Incoming_Usage_Categorical.csv")

# %% [markdown]
# # Phase 2

# %% [markdown]
# ## Binnig by Location
#
# - 1. group by location columns
# - 2. Bin by location and get counts

# %%
# bucketing by location
voice_location_info = voice_usage_info
voice_location_info['Location_Identifier'] = voice_location_info['msan'].astype(str)+ voice_location_info['location_code'].astype(str) +voice_location_info['equp_id'].astype(str) +voice_location_info['equp_index'].astype(str)
voice_location_info
# Out:
#       event_source  call_count  duration  year-month rtom_code location_code  \
# 0        672221677           2       458      202002      R-KL   KL-PRC-NODE
# 1        242228729           9      4440      201912      R-VA   VA-NKM-NODE
# 2        672221677           2        56      202005      R-KL   KL-PRC-NODE
# 3        242228729           2       736      201911      R-VA   VA-NKM-NODE
# 4        672221677           6      1001      201912      R-KL   KL-PRC-NODE
# ...            ...         ...       ...         ...       ...           ...
# 5126     112727670           5     11352      202001      R-RM   MV-GDM-NODE
# 5127     112727670           3      7142      202008      R-RM   MV-GDM-NODE
# 5128     112727670           6      7328      202002      R-RM   MV-GDM-NODE
# 5129     112727670           4     11493      202004      R-RM   MV-GDM-NODE
# 5130     112727670           2      8091      202007      R-RM   MV-GDM-NODE
#
#                 msan  equp_id  equp_index              Location_Identifier
# 0     ZXDSL9806H-ISL    48236           1  ZXDSL9806H-ISLKL-PRC-NODE482361
# 1       MSAG5200-ISL    48196           1    MSAG5200-ISLVA-NKM-NODE481961
# 2     ZXDSL9806H-ISL    48236           1  ZXDSL9806H-ISLKL-PRC-NODE482361
# 3       MSAG5200-ISL    48196           1    MSAG5200-ISLVA-NKM-NODE481961
# 4     ZXDSL9806H-ISL    48236           1  ZXDSL9806H-ISLKL-PRC-NODE482361
# ...              ...      ...         ...                              ...
# 5126    MSAG5200-ISL    48249           1    MSAG5200-ISLMV-GDM-NODE482491
# 5127    MSAG5200-ISL    48249           1    MSAG5200-ISLMV-GDM-NODE482491
# 5128    MSAG5200-ISL    48249           1    MSAG5200-ISLMV-GDM-NODE482491
# 5129    MSAG5200-ISL    48249           1    MSAG5200-ISLMV-GDM-NODE482491
# 5130    MSAG5200-ISL    48249           1    MSAG5200-ISLMV-GDM-NODE482491
#
# [5131 rows x 10 columns]

# %%
voice_location_info = voice_location_info.drop_duplicates("event_source", keep="last")
voice_location_info.shape
# Out:
# (1197, 10)

# %%
user_location = voice_location_info[['event_source','Location_Identifier']]
user_location
# Out:
#       event_source            Location_Identifier
# 34       112816655  MSAG5200-ISLND-PHG-NODE500241
# 40       382251123      MSAG5200PH-AKG-NODE431631
# 42       112818580  MSAG5200-ISLND-PHG-NODE500241
# 58       112911252           C300MKI-NODE10668164
# 63       112819016  MSAG5200-ISLND-PHG-NODE500241
# ...            ...                            ...
# 5112     112725772  MSAG5200-ISLMV-GDM-NODE482491
# 5119     112726979  MSAG5200-ISLMV-GDM-NODE482491
# 5124     112727488  MSAG5200-ISLMV-GDM-NODE482491
# 5125     112727579  MSAG5200-ISLMV-GDM-NODE482491
# 5130     112727670  MSAG5200-ISLMV-GDM-NODE482491
#
# [1197 rows x 2 columns]

# %%
user_location.to_csv("data/user_profile/VOICE_IDD_INCOMING_Locations_of_Users.csv")

# %%
voice_location_info["User_Count"] = 1
voice_gropued_by_locations = voice_location_info.groupby(['Location_Identifier'], axis=0,as_index=False).sum()
voice_gropued_by_locations = voice_gropued_by_locations[['Location_Identifier','User_Count']]
# Out:
# <ipython-input-34-46e54884d952>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voice_location_info["User_Count"] = 1

# %%
voice_gropued_by_locations
# Out:
#                 Location_Identifier  User_Count
# 0          C300MHE-DMD-NODE15221561           3
# 1            C300MHT-NE-NODE8152461           5
# 2         C300MIDH-IDJ-NODE11065541          32
# 3              C300MKI-NODE10668164          39
# 4          C300MNW-MEE-NODE18887751          34
# 5             C300MPDT-NODE13379431           1
# 6               C300MTP-NODE8700911           6
# 7               C300MVH-NODE9874041           2
# 8        MA5603TAD-SRV-NODE10224991           3
# 9         MSAG5200-ISLBZ-NODE435881          32
# 10       MSAG5200-ISLGE-NODE5577981           5
# 11    MSAG5200-ISLHC-NAP-NODE478721           2
# 12    MSAG5200-ISLHK-OCC-NODE506561           8
# 13       MSAG5200-ISLHNT-NODE423851           9
# 14        MSAG5200-ISLHO-NODE524692           3
# 15    MSAG5200-ISLHZ-BRL-NODE471911           6
# 16  MSAG5200-ISLIDH-KGW-NODE6194491          84
# 17    MSAG5200-ISLJA-PKV-NODE460421          12
# 18    MSAG5200-ISLMB-PSL-NODE482261           5
# 19    MSAG5200-ISLMH-POL-NODE491451          29
# 20  MSAG5200-ISLMLT-VMD-NODE4145091          16
# 21    MSAG5200-ISLMT-AVR-NODE467161          98
# 22    MSAG5200-ISLMV-GDM-NODE482491         221
# 23       MSAG5200-ISLMX-NODE5391821          11
# 24    MSAG5200-ISLND-PHG-NODE500241         183
# 25    MSAG5200-ISLNL-HGW-NODE491281           2
# 26    MSAG5200-ISLPC-AGT-NODE480031          31
# 27   MSAG5200-ISLPK-PNU-NODE6136021           1
# 28       MSAG5200-ISLPRN-NODE427901           4
# 29    MSAG5200-ISLSI-DWS-NODE520721          39
# 30      MSAG5200-ISLTBL-NODE5577771           4
# 31   MSAG5200-ISLTBT-TLJ-NODE487241           1
# 32    MSAG5200-ISLVA-NKM-NODE481961          14
# 33    MSAG5200-ISLWI-NWT-NODE485201           6
# 34   MSAG5200-ISLWKN-SWP-NODE473481           5
# 35    MSAG5200-ISLWY-MDB-NODE506221           5
# 36            MSAG5200BG-NODE431391          53
# 37           MSAG5200HPG-NODE432141           5
# 38           MSAG5200MGE-NODE428381           2
# 39        MSAG5200PH-AKG-NODE431631          85
# 40            MSAG5200PK-NODE438641           4
# 41        UA5000(IPMB)IM-NODE391531           4
# 42        UA5000(IPMB)SL-NODE385341          54
# 43  ZXDSL9806H-ISLAG-PNP-NODE529761           7
# 44  ZXDSL9806H-ISLKE-NRP-NODE495731           5
# 45  ZXDSL9806H-ISLKL-PRC-NODE482361          17

# %%
voice_gropued_by_locations.to_csv("data/user_profile/VOICE_IDD_Users_Count_by_Location.csv")
