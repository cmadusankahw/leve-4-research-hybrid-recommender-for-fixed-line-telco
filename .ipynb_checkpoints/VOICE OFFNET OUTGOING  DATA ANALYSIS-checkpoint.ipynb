# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
voice_usage_info = pd.read_csv("data/VOICE_OUTGOING_CALL_USAGE_OFFNET.csv")

voice_usage_info
# Out:
#        event_source                 event_source.hash  call_count  \
# 0         542240120  90feabe2f2846cbf4eb77db650c48a1b          14
# 1         542240244  4c31c59c555ac6f4fdba3cec18674004         186
# 2         542240244  4c31c59c555ac6f4fdba3cec18674004         162
# 3         542240244  4c31c59c555ac6f4fdba3cec18674004         187
# 4         542240244  4c31c59c555ac6f4fdba3cec18674004         116
# ...             ...                               ...         ...
# 33207     552273668  881083811a88758606701519d3f07faa          12
# 33208     552273669  ac8d17782113fb666dc8d8804f46ceaa           8
# 33209     552273669  ac8d17782113fb666dc8d8804f46ceaa           8
# 33210     552273669  ac8d17782113fb666dc8d8804f46ceaa          15
# 33211     552273669  ac8d17782113fb666dc8d8804f46ceaa           4
#
#        duration (seconds)  year month account_num  \
# 0                    1200      201912  0019467547
# 1                   29616      202001  0002769147
# 2                   28799      202002  0002769147
# 3                   34830      202003  0002769147
# 4                   27311      202005  0002769147
# ...                   ...         ...         ...
# 33207                 389      202006  0003944938
# 33208                1560      201908  000394494X
# 33209                2100      201909  000394494X
# 33210                4020      202001  000394494X
# 33211                 600      202002  000394494X
#
#                        account_num.hash rtom_code location_code          msan  \
# 0      9c926ad1c6705e1f46462dc5b59d8feb      R-GP       TP-NODE         C300M
# 1      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 2      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 3      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 4      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# ...                                 ...       ...           ...           ...
# 33207  c78977b555bf659a9586b15dd4f3b608     R-MRG       BZ-NODE  MSAG5200-ISL
# 33208  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33209  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33210  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33211  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
#
#        equp_id  equp_index
# 0       870091           1
# 1       870091           1
# 2       870091           1
# 3       870091           1
# 4       870091           1
# ...        ...         ...
# 33207    43588           1
# 33208    43588           1
# 33209    43588           1
# 33210    43588           1
# 33211    43588           1
#
# [33212 rows x 12 columns]

# %%
# Handle null values
# Drop unnecessary cols
# Pivot by monthYear
# Usage rating Upload/Downlad/Duration - bucketizing/ add rating cols
# location grouping/bucketizing (consider 4 location cols)
# User profile dim table
# visualize and analyze data

# %%
voice_usage_info = voice_usage_info.drop_duplicates(["event_source.hash","year month"], keep="last")

voice_usage_info.shape
# Out:
# (33200, 12)

# %%
voice_usage_info = voice_usage_info.drop(['event_source','account_num'], axis=1)
voice_usage_info.rename(columns={'duration (seconds)': 'duration','year month':'year-month'}, inplace=True)
voice_usage_info
# Out:
#                       event_source.hash  call_count  duration  year-month  \
# 0      90feabe2f2846cbf4eb77db650c48a1b          14      1200      201912
# 1      4c31c59c555ac6f4fdba3cec18674004         186     29616      202001
# 2      4c31c59c555ac6f4fdba3cec18674004         162     28799      202002
# 3      4c31c59c555ac6f4fdba3cec18674004         187     34830      202003
# 4      4c31c59c555ac6f4fdba3cec18674004         116     27311      202005
# ...                                 ...         ...       ...         ...
# 33207  881083811a88758606701519d3f07faa          12       389      202006
# 33208  ac8d17782113fb666dc8d8804f46ceaa           8      1560      201908
# 33209  ac8d17782113fb666dc8d8804f46ceaa           8      2100      201909
# 33210  ac8d17782113fb666dc8d8804f46ceaa          15      4020      202001
# 33211  ac8d17782113fb666dc8d8804f46ceaa           4       600      202002
#
#                        account_num.hash rtom_code location_code          msan  \
# 0      9c926ad1c6705e1f46462dc5b59d8feb      R-GP       TP-NODE         C300M
# 1      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 2      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 3      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 4      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# ...                                 ...       ...           ...           ...
# 33207  c78977b555bf659a9586b15dd4f3b608     R-MRG       BZ-NODE  MSAG5200-ISL
# 33208  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33209  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33210  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33211  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
#
#        equp_id  equp_index
# 0       870091           1
# 1       870091           1
# 2       870091           1
# 3       870091           1
# 4       870091           1
# ...        ...         ...
# 33207    43588           1
# 33208    43588           1
# 33209    43588           1
# 33210    43588           1
# 33211    43588           1
#
# [33200 rows x 10 columns]

# %%
voice_usage_info['duration'].fillna(0)
voice_usage_info['call_count'].fillna(0)
# Out:
# 0         14
# 1        186
# 2        162
# 3        187
# 4        116
#         ...
# 33207     12
# 33208      8
# 33209      8
# 33210     15
# 33211      4
# Name: call_count, Length: 33200, dtype: int64

# %%
voice_usage_info.isnull().sum(axis=0)
# Out:
# event_source.hash    0
# call_count           0
# duration             0
# year-month           0
# account_num.hash     0
# rtom_code            0
# location_code        0
# msan                 0
# equp_id              0
# equp_index           0
# dtype: int64

# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Usage Ranking
#
# - 1. Pivot by year-month
# - 2. Bin by Upload/Download/Duration
# - 3. Usage Rank
# - 4. Labling usage

# %%
voice_usage = voice_usage_info[['event_source.hash','account_num.hash','call_count','duration','year-month']]
voice_usage
# Out:
#                       event_source.hash                  account_num.hash  \
# 0      90feabe2f2846cbf4eb77db650c48a1b  9c926ad1c6705e1f46462dc5b59d8feb
# 1      4c31c59c555ac6f4fdba3cec18674004  b0c495cfe7a57adf77d0fdadecabe3e0
# 2      4c31c59c555ac6f4fdba3cec18674004  b0c495cfe7a57adf77d0fdadecabe3e0
# 3      4c31c59c555ac6f4fdba3cec18674004  b0c495cfe7a57adf77d0fdadecabe3e0
# 4      4c31c59c555ac6f4fdba3cec18674004  b0c495cfe7a57adf77d0fdadecabe3e0
# ...                                 ...                               ...
# 33207  881083811a88758606701519d3f07faa  c78977b555bf659a9586b15dd4f3b608
# 33208  ac8d17782113fb666dc8d8804f46ceaa  cfc0dd04946fe2779e63e51c7a3aa0c2
# 33209  ac8d17782113fb666dc8d8804f46ceaa  cfc0dd04946fe2779e63e51c7a3aa0c2
# 33210  ac8d17782113fb666dc8d8804f46ceaa  cfc0dd04946fe2779e63e51c7a3aa0c2
# 33211  ac8d17782113fb666dc8d8804f46ceaa  cfc0dd04946fe2779e63e51c7a3aa0c2
#
#        call_count  duration  year-month
# 0              14      1200      201912
# 1             186     29616      202001
# 2             162     28799      202002
# 3             187     34830      202003
# 4             116     27311      202005
# ...           ...       ...         ...
# 33207          12       389      202006
# 33208           8      1560      201908
# 33209           8      2100      201909
# 33210          15      4020      202001
# 33211           4       600      202002
#
# [33200 rows x 5 columns]

# %%
pivot_voice_usage_info = pd.pivot_table(voice_usage,index=['event_source.hash'],columns=['year-month'], aggfunc=np.sum, fill_value=0)
pivot_voice_usage_info
# Out:
#                                  call_count                              \
# year-month                           201908 201909 201910 201911 201912
# event_source.hash
# 00221451f705ebe26051158bb14f567a         43      6     24      7     22
# 002fb47f60400713c854b0f69ff78c0a         12      1      8      6     14
# 00567a4a3c474aca1ce5cd6570648932         10      0      0      0      2
# 00724ae2470df1ed0fe919800d02517d          0      0      0      0      0
# 007400db8afa996e788d23986739f3db         30     40     27     18     29
# ...                                     ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2          0     13     15     15      1
# ffb63ff99cf1354dff1da862f379da80         99    156    143    154     73
# ffd697d66cc01c8897ce3e37d693673a          1      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713         91     61     90     63     55
# ffee845c0caa320b55e31bb156827d16          0      2      8      0      0
#
#                                                                      ...  \
# year-month                       202001 202002 202003 202004 202005  ...
# event_source.hash                                                    ...
# 00221451f705ebe26051158bb14f567a      9      3      7      3      5  ...
# 002fb47f60400713c854b0f69ff78c0a      8     13      9     17     12  ...
# 00567a4a3c474aca1ce5cd6570648932      3      0      0      0      0  ...
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0  ...
# 007400db8afa996e788d23986739f3db      7     11      0      4     15  ...
# ...                                 ...    ...    ...    ...    ...  ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      0      0      1      4      0  ...
# ffb63ff99cf1354dff1da862f379da80    190    125    142     53     61  ...
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0      0  ...
# ffd96f173d6cd683bf3384bdc2f99713     56     65     59     23      3  ...
# ffee845c0caa320b55e31bb156827d16      0      1      6      3      0  ...
#
#                                  duration                                     \
# year-month                         201911 201912 202001 202002 202003 202004
# event_source.hash
# 00221451f705ebe26051158bb14f567a     1181   2263    547    386   2203   1638
# 002fb47f60400713c854b0f69ff78c0a      442   2861   4991   3903   3747   6419
# 00567a4a3c474aca1ce5cd6570648932        0    120    180      0      0      0
# 00724ae2470df1ed0fe919800d02517d        0      0      0      0      0      0
# 007400db8afa996e788d23986739f3db     1380   2400    540    840      0    240
# ...                                   ...    ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2     1836   2683      0      0    346    772
# ffb63ff99cf1354dff1da862f379da80    20460  12120  23220  15960  18000   5580
# ffd697d66cc01c8897ce3e37d693673a        0      0      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713    17210  11399  10759   9866   6796   3755
# ffee845c0caa320b55e31bb156827d16        0      0      0     60    840    300
#
#
# year-month                       202005 202006 202007 202008
# event_source.hash
# 00221451f705ebe26051158bb14f567a   1694   3140   2063   1550
# 002fb47f60400713c854b0f69ff78c0a  10999    477    226   2081
# 00567a4a3c474aca1ce5cd6570648932      0      0      0      0
# 00724ae2470df1ed0fe919800d02517d      0      0      0   1140
# 007400db8afa996e788d23986739f3db    960   1740      0      0
# ...                                 ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      0      0    303      0
# ffb63ff99cf1354dff1da862f379da80   9360  19200  38940  11580
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713    552  18668   8560  12825
# ffee845c0caa320b55e31bb156827d16      0   9060   2460   1680
#
# [3191 rows x 26 columns]

# %%
# check for all zero cols
pivot_voice_usage_info.loc[pivot_voice_usage_info.index == 0.0]
# Out:
# Empty DataFrame
# Columns: [(call_count, 201908), (call_count, 201909), (call_count, 201910), (call_count, 201911), (call_count, 201912), (call_count, 202001), (call_count, 202002), (call_count, 202003), (call_count, 202004), (call_count, 202005), (call_count, 202006), (call_count, 202007), (call_count, 202008), (duration, 201908), (duration, 201909), (duration, 201910), (duration, 201911), (duration, 201912), (duration, 202001), (duration, 202002), (duration, 202003), (duration, 202004), (duration, 202005), (duration, 202006), (duration, 202007), (duration, 202008)]
# Index: []
#
# [0 rows x 26 columns]

# %%
pivot_voice_usage_info.columns
# Out:
# MultiIndex([('call_count', 201908),
#             ('call_count', 201909),
#             ('call_count', 201910),
#             ('call_count', 201911),
#             ('call_count', 201912),
#             ('call_count', 202001),
#             ('call_count', 202002),
#             ('call_count', 202003),
#             ('call_count', 202004),
#             ('call_count', 202005),
#             ('call_count', 202006),
#             ('call_count', 202007),
#             ('call_count', 202008),
#             (  'duration', 201908),
#             (  'duration', 201909),
#             (  'duration', 201910),
#             (  'duration', 201911),
#             (  'duration', 201912),
#             (  'duration', 202001),
#             (  'duration', 202002),
#             (  'duration', 202003),
#             (  'duration', 202004),
#             (  'duration', 202005),
#             (  'duration', 202006),
#             (  'duration', 202007),
#             (  'duration', 202008)],
#            names=[None, 'year-month'])

# %%
voice_usage.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#         call_count      duration    year-month
# count  33200.00000   33200.00000   33200.00000
# mean      56.20889    7295.82563  201967.88563
# std      126.97360   15862.24739      46.07265
# min        1.00000       1.00000  201908.00000
# 25%        9.00000    1034.75000  201911.00000
# 50%       27.00000    3240.00000  202002.00000
# 75%       61.00000    7925.25000  202005.00000
# max     3627.00000  469620.00000  202008.00000

# %%
# binning call_count
count_bins = [0, 10, 30,60, 100,300,1000,2000,3627]
for col in pivot_voice_usage_info['call_count'].columns:
    pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
pivot_voice_usage_info['call_count']
# Out:
# <ipython-input-13-8ac00b71a459>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
# year-month                        201908  201909  201910  201911  201912  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       3       1       2       1       2
# 002fb47f60400713c854b0f69ff78c0a       2       1       1       1       2
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       1
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       2       3       2       2       2
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       0       2       2       2       1
# ffb63ff99cf1354dff1da862f379da80       4       5       5       5       4
# ffd697d66cc01c8897ce3e37d693673a       1       0       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       4       4       4       4       3
# ffee845c0caa320b55e31bb156827d16       0       1       1       0       0
#
# year-month                        202001  202002  202003  202004  202005  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       1       1       1       1       1
# 002fb47f60400713c854b0f69ff78c0a       1       2       1       2       2
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       1       2       0       1       2
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       0       0       1       1       0
# ffb63ff99cf1354dff1da862f379da80       5       5       5       3       4
# ffd697d66cc01c8897ce3e37d693673a       0       0       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       3       4       3       2       1
# ffee845c0caa320b55e31bb156827d16       0       1       1       1       0
#
# year-month                        202006  202007  202008
# event_source.hash
# 00221451f705ebe26051158bb14f567a       2       2       2
# 002fb47f60400713c854b0f69ff78c0a       1       1       1
# 00567a4a3c474aca1ce5cd6570648932       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       2
# 007400db8afa996e788d23986739f3db       2       0       0
# ...                                  ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       0       1       0
# ffb63ff99cf1354dff1da862f379da80       5       5       4
# ffd697d66cc01c8897ce3e37d693673a       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       3       3       3
# ffee845c0caa320b55e31bb156827d16       2       1       1
#
# [3191 rows x 13 columns]

# %%
# binning duration
duration_bins = [0, 1080, 3300, 8100,16200,32400,64800,240000,469620]
for col in pivot_voice_usage_info['duration'].columns:
    pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
pivot_voice_usage_info['duration']
# Out:
# <ipython-input-14-1abd4eb7bf03>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
# year-month                        201908  201909  201910  201911  201912  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       3       1       2       2       2
# 002fb47f60400713c854b0f69ff78c0a       2       1       2       1       2
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       1
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       2       2       2       2       2
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       0       1       2       2       2
# ffb63ff99cf1354dff1da862f379da80       4       5       5       5       4
# ffd697d66cc01c8897ce3e37d693673a       1       0       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       4       4       4       5       4
# ffee845c0caa320b55e31bb156827d16       0       1       2       0       0
#
# year-month                        202001  202002  202003  202004  202005  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       1       1       2       2       2
# 002fb47f60400713c854b0f69ff78c0a       3       3       3       3       4
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       1       1       0       1       1
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       0       0       1       1       0
# ffb63ff99cf1354dff1da862f379da80       5       4       5       3       4
# ffd697d66cc01c8897ce3e37d693673a       0       0       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       4       4       3       3       1
# ffee845c0caa320b55e31bb156827d16       0       1       1       1       0
#
# year-month                        202006  202007  202008
# event_source.hash
# 00221451f705ebe26051158bb14f567a       2       2       2
# 002fb47f60400713c854b0f69ff78c0a       1       1       2
# 00567a4a3c474aca1ce5cd6570648932       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       2
# 007400db8afa996e788d23986739f3db       2       0       0
# ...                                  ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       0       1       0
# ffb63ff99cf1354dff1da862f379da80       5       6       4
# ffd697d66cc01c8897ce3e37d693673a       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       5       4       4
# ffee845c0caa320b55e31bb156827d16       4       2       2
#
# [3191 rows x 13 columns]

# %%
year_month_list = pivot_voice_usage_info['call_count'].columns

# %%
# multplying bins to get usage rating
for col in year_month_list:
    pivot_voice_usage_info[col] = pivot_voice_usage_info['call_count'][col]  * pivot_voice_usage_info['duration'][col]

# %% [markdown]
# ## ToDO
# - find a different approach other than product

# %% [markdown]
# ### Justification
# - https://www.researchgate.net/post/Can-I-combine-2-independent-variable-as-one-variable-in-a-model-Can-I-still-include-the-individual-variable-in-the-same-model-after-combing-the-two
# - http://www.utstat.toronto.edu/~brunner/DataAnalysisText/Interactions.pdf
#
# ### More advanced methods
# - Dimension reduction approaches?

# %% [markdown]
# ### Usage ratings for year-month

# %%
pivot_voice_usage_info = pivot_voice_usage_info.drop(['call_count','duration'], axis=1)
pivot_voice_usage_info
# Out:
#                                  201908 201909 201910 201911 201912 202001  \
# year-month
# event_source.hash
# 00221451f705ebe26051158bb14f567a      9      1      4      2      4      1
# 002fb47f60400713c854b0f69ff78c0a      4      1      2      1      4      3
# 00567a4a3c474aca1ce5cd6570648932      1      0      0      0      1      1
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0      0
# 007400db8afa996e788d23986739f3db      4      6      4      4      4      1
# ...                                 ...    ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      0      2      4      4      2      0
# ffb63ff99cf1354dff1da862f379da80     16     25     25     25     16     25
# ffd697d66cc01c8897ce3e37d693673a      1      0      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713     16     16     16     20     12     12
# ffee845c0caa320b55e31bb156827d16      0      1      2      0      0      0
#
#                                  202002 202003 202004 202005 202006 202007  \
# year-month
# event_source.hash
# 00221451f705ebe26051158bb14f567a      1      2      2      2      4      4
# 002fb47f60400713c854b0f69ff78c0a      6      3      6      8      1      1
# 00567a4a3c474aca1ce5cd6570648932      0      0      0      0      0      0
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0      0
# 007400db8afa996e788d23986739f3db      2      0      1      2      4      0
# ...                                 ...    ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      0      1      1      0      0      1
# ffb63ff99cf1354dff1da862f379da80     20     25      9     16     25     30
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713     16      9      6      1     15     12
# ffee845c0caa320b55e31bb156827d16      1      1      1      0      8      2
#
#                                  202008
# year-month
# event_source.hash
# 00221451f705ebe26051158bb14f567a      4
# 002fb47f60400713c854b0f69ff78c0a      2
# 00567a4a3c474aca1ce5cd6570648932      0
# 00724ae2470df1ed0fe919800d02517d      4
# 007400db8afa996e788d23986739f3db      0
# ...                                 ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      0
# ffb63ff99cf1354dff1da862f379da80     16
# ffd697d66cc01c8897ce3e37d693673a      0
# ffd96f173d6cd683bf3384bdc2f99713     12
# ffee845c0caa320b55e31bb156827d16      2
#
# [3191 rows x 13 columns]

# %%
pivot_voice_usage_info.T.reset_index(drop=True).T
pivot_voice_usage_info.columns=year_month_list

# %%
# scaling usage rating
scaler = MinMaxScaler()
for col in year_month_list:
    pivot_voice_usage_info[col] = scaler.fit_transform(pivot_voice_usage_info[col].values.reshape(-1,1))

# %%
sns.heatmap(pivot_voice_usage_info[year_month_list].sample(n=10), annot=True)
# Out:
# <AxesSubplot:xlabel='year-month', ylabel='event_source.hash'>

# %%
pivot_voice_usage_info['Usage_Rating_Scaled'] = pivot_voice_usage_info[year_month_list].sum(axis=1)/len(year_month_list)
pivot_voice_usage_info
# Out:
# year-month                          201908    201909    201910    201911  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.140625  0.015625  0.062500  0.031250
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.015625  0.031250  0.015625
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.062500  0.093750  0.062500  0.062500
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.031250  0.062500  0.062500
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.390625  0.390625  0.390625
# ffd697d66cc01c8897ce3e37d693673a  0.015625  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.250000  0.250000  0.250000  0.312500
# ffee845c0caa320b55e31bb156827d16  0.000000  0.015625  0.031250  0.000000
#
# year-month                          201912    202001    202002    202003  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.062500  0.015625  0.015625  0.031250
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.046875  0.093750  0.046875
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.015625  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.062500  0.015625  0.031250  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.031250  0.000000  0.000000  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.390625  0.312500  0.390625
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.187500  0.250000  0.140625
# ffee845c0caa320b55e31bb156827d16  0.000000  0.000000  0.015625  0.015625
#
# year-month                          202004    202005    202006    202007  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.031250  0.040816  0.062500  0.062500
# 002fb47f60400713c854b0f69ff78c0a  0.093750  0.163265  0.015625  0.015625
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.015625  0.040816  0.062500  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.015625  0.000000  0.000000  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.140625  0.326531  0.390625  0.468750
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.093750  0.020408  0.234375  0.187500
# ffee845c0caa320b55e31bb156827d16  0.015625  0.000000  0.125000  0.031250
#
# year-month                         202008  Usage_Rating_Scaled
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.06250             0.048813
# 002fb47f60400713c854b0f69ff78c0a  0.03125             0.053424
# 00567a4a3c474aca1ce5cd6570648932  0.00000             0.003606
# 00724ae2470df1ed0fe919800d02517d  0.06250             0.004808
# 007400db8afa996e788d23986739f3db  0.00000             0.039197
# ...                                   ...                  ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.00000             0.018029
# ffb63ff99cf1354dff1da862f379da80  0.25000             0.334012
# ffd697d66cc01c8897ce3e37d693673a  0.00000             0.001202
# ffd96f173d6cd683bf3384bdc2f99713  0.18750             0.196281
# ffee845c0caa320b55e31bb156827d16  0.03125             0.021635
#
# [3191 rows x 14 columns]

# %% [markdown]
# ### Finding Outliers

# %%
pivot_voice_usage_info.boxplot(column=[int(x) for x in year_month_list])
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(data=pivot_voice_usage_info[[int(x) for x in year_month_list]], orient="h", palette="Set2")
ax
# Out:
# <AxesSubplot:ylabel='year-month'>

# %% [markdown]
# ## Three quantitative methods commonly used in statistics for the detection of univariate outliers:
# - Tukey’s box plot method
# - Internally studentized residuals (AKA z-score method)
# - Median Absolute Deviation method

# %% [markdown]
# ### 1) Tukey’s box plot method
# - Tukey distinguishes between possible and probable outliers. A possible outlier is located between the inner and the outer fence, whereas a probable outlier is located outside the outer fence.
#
# - IQR =Q3 - Q1, whereas q3 := 75th quartile and q1 := 25th quartile
# - Inner fence = [Q1-1.5*IQR, Q3+1.5*IQR]
# - Outer fence = [Q1–3*IQR, Q3+3*IQR]

# %%
#Tukey's method
def tukeys_method(df, variable):
    #Takes two parameters: dataframe & variable of interest as string
    q1 = df[variable].quantile(0.25)
    q3 = df[variable].quantile(0.75)
    iqr = q3-q1
    inner_fence = 1.5*iqr
    outer_fence = 3*iqr
    
    #inner fence lower and upper end
    inner_fence_le = q1-inner_fence
    inner_fence_ue = q3+inner_fence
    
    #outer fence lower and upper end
    outer_fence_le = q1-outer_fence
    outer_fence_ue = q3+outer_fence
    
    outliers_prob = []
    outliers_poss = []
    outliers_prob_indexes = []
    outliers_poss_indexes = []
    for index, x in enumerate(df[variable]):
        if x <= outer_fence_le or x >= outer_fence_ue:
            outliers_prob_indexes.append(index)
            outliers_prob.append(x)
    for index, x in enumerate(df[variable]):
        if x <= inner_fence_le or x >= inner_fence_ue:
            outliers_poss_indexes.append(index)
            outliers_poss.append(x)
    # returns indexes of the rows with outliers
    return outliers_prob, outliers_prob_indexes, outliers_poss, outliers_poss_indexes

# %%
pr_col_threshold = []
po_col_threshold = []
for col in year_month_list:
    pr_col, pr_col_indexes, po_col, po_col_indexes = tukeys_method(pivot_voice_usage_info, int(col))
    pr_col_threshold.append({col: {"threshold": min(pr_col), "count": len(pr_col)}})
    po_col_threshold.append({col: {"threshold": min(po_col), "count": len(po_col)}})
    print()
    print(f"Probable Outliers for {col}---->\n", pr_col)
    print(len(pr_col))
    print()
    print(f"Possible Outliers for {col}----->\n", po_col)
    print(len(po_col))
    print()
# Out:
# Probable Outliers for 201908---->
#  [0.765625, 0.765625, 0.765625, 0.765625, 0.765625, 1.0, 0.765625, 0.765625, 1.0, 1.0, 0.765625, 0.765625]
# 12
#
# Possible Outliers for 201908----->
#  [0.65625, 0.5625, 0.65625, 0.5625, 0.46875, 0.46875, 0.65625, 0.46875, 0.5625, 0.46875, 0.46875, 0.46875, 0.46875, 0.46875, 0.5625, 0.765625, 0.65625, 0.65625, 0.5625, 0.765625, 0.46875, 0.5625, 0.5625, 0.5625, 0.46875, 0.46875, 0.765625, 0.46875, 0.65625, 0.46875, 0.46875, 0.46875, 0.5625, 0.46875, 0.5625, 0.5625, 0.65625, 0.5625, 0.65625, 0.46875, 0.46875, 0.65625, 0.5625, 0.5625, 0.5625, 0.5625, 0.765625, 0.5625, 0.46875, 0.46875, 0.765625, 1.0, 0.765625, 0.546875, 0.46875, 0.5625, 0.46875, 0.765625, 0.65625, 0.5625, 0.65625, 0.65625, 0.46875, 0.5625, 0.46875, 0.46875, 0.5625, 0.5625, 0.46875, 0.5625, 0.546875, 0.46875, 0.46875, 0.65625, 0.65625, 0.46875, 1.0, 1.0, 0.765625, 0.5625, 0.5625, 0.5625, 0.46875, 0.5625, 0.5625, 0.46875, 0.46875, 0.5625, 0.46875, 0.5625, 0.65625, 0.65625, 0.46875, 0.65625, 0.65625, 0.765625, 0.46875, 0.46875, 0.65625, 0.5625, 0.65625, 0.46875, 0.46875, 0.46875, 0.5625]
# 105
#
#
# Probable Outliers for 201909---->
#  [0.5625, 0.5625, 0.5625, 0.5625, 0.5625, 0.546875, 0.5625, 0.5625, 0.5625, 0.546875, 0.65625, 0.5625, 0.5625, 0.5625, 0.65625, 0.5625, 0.5625, 0.5625, 0.5625, 0.5625, 0.5625, 0.65625, 1.0, 0.65625, 0.65625, 0.5625, 0.65625, 0.65625, 0.5625, 0.5625, 0.65625, 0.765625, 0.765625, 1.0, 0.5625, 0.5625, 0.5625, 0.65625, 0.5625, 0.5625, 0.65625, 0.5625, 0.5625, 0.5625]
# 44
#
# Possible Outliers for 201909----->
#  [0.5625, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.46875, 0.390625, 0.390625, 0.46875, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.375, 0.390625, 0.5625, 0.390625, 0.5625, 0.546875, 0.390625, 0.5625, 0.5625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.546875, 0.65625, 0.46875, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.46875, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.46875, 0.46875, 0.65625, 0.390625, 0.46875, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.46875, 0.5625, 0.5625, 0.5625, 0.5625, 0.390625, 0.65625, 1.0, 0.65625, 0.46875, 0.46875, 0.390625, 0.390625, 0.46875, 0.46875, 0.65625, 0.5625, 0.390625, 0.65625, 0.65625, 0.390625, 0.46875, 0.46875, 0.390625, 0.390625, 0.375, 0.46875, 0.5625, 0.5625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.65625, 0.390625, 0.390625, 0.765625, 0.765625, 1.0, 0.390625, 0.390625, 0.5625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.65625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.46875, 0.390625, 0.5625, 0.390625, 0.390625, 0.65625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.5625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390
#  {202001: {'threshold': 0.46875, 'count': 93}},
#  {202002: {'threshold': 0.375, 'count': 187}},
#  {202003: {'threshold': 0.375, 'count': 193}},
#  {202004: {'threshold': 0.375, 'count': 138}},
#  {202005: {'threshold': 0.32653061224489793, 'count': 228}},
#  {202006: {'threshold': 0.46875, 'count': 120}},
#  {202007: {'threshold': 0.375, 'count': 241}},
#  {202008: {'threshold': 0.375, 'count': 182}}]

# %% [markdown]
# ### 2) Median Absolute Deviation method
# - this method is highly limited as the distributions mean and standard deviation are sensitive to outliers. This means that finding one outlier is dependent on other outliers as every observation directly affects the mean.
# ![image.png](attachment:image.png)

# %%
from scipy import stats

# MAD method
def mad_method(df, variable_name):
    #Takes two parameters: dataframe & variable of interest as string
    columns = df.columns
    med = np.median(df, axis = 0)
    mad = np.abs(stats.median_absolute_deviation(df))
    threshold = 3
    outlier = []
    index=0
    for item in range(len(columns)):
        if columns[item] == variable_name:
            index == item
    for i, v in enumerate(df.loc[:,variable_name]):
        t = (v-med[index])/mad[index]
        if t > threshold:
            outlier.append(i)
        else:
            continue
    return outlier

# %%
col_threshold = []
for col in year_month_list:
    outliers = mad_method(pivot_voice_usage_info, int(col))
    outlier_cols = pivot_voice_usage_info[int(col)].iloc[outliers]
    col_threshold.append({col: {"threshold" :min(outlier_cols), "count":len(outliers)}})
    print()
    print(f"Outliers for {col}---->\n", outlier_cols)
    print(len(outliers))
# Out:
# Outliers for 201908---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.656250
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 011adeeaef79aeac706a2e7fc225e8f8    0.390625
# 01ce983dcf27d1231539e5827f8ad6af    0.390625
# 03d189e698bac53767b82645f582d574    0.656250
#                                       ...
# fb5b5d2333b68e9f1ff6c4bd6f208a81    0.390625
# fcb16a85d0044180bb747f0211f92990    0.468750
# fd81ffbb5f0c5adb57428d3ef126618a    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.562500
# ff1093d5ef61bf46f8c88e9b7614e311    0.390625
# Name: 201908, Length: 243, dtype: float64
# 243
#
# Outliers for 201909---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.562500
# 00d4474d7b8abcb71cc114a564769182    0.468750
# 011adeeaef79aeac706a2e7fc225e8f8    0.390625
# 03d189e698bac53767b82645f582d574    0.468750
# 0541411ea78d692ada524e8734da6bb2    0.390625
#                                       ...
# f852c66e165c8845bf24e759a33e0bfe    0.390625
# fcb16a85d0044180bb747f0211f92990    0.390625
# fcfae4ea0dc12d7a82da4c968df820e7    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# ffb63ff99cf1354dff1da862f379da80    0.390625
# Name: 201909, Length: 180, dtype: float64
# 180
#
# Outliers for 201910---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.562500
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 03d189e698bac53767b82645f582d574    0.468750
# 0541411ea78d692ada524e8734da6bb2    0.390625
# 0550aa60e5d21395371c54b785975cce    0.390625
#                                       ...
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.562500
# fe4e907a21bb03842eb88d0c0d633ca8    0.390625
# fe755bf21b5abbfa6cbe808e1f99d55a    0.390625
# ff1093d5ef61bf46f8c88e9b7614e311    0.390625
# ffb63ff99cf1354dff1da862f379da80    0.390625
# Name: 201910, Length: 283, dtype: float64
# 283
#
# Outliers for 201911---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.656250
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 03d189e698bac53767b82645f582d574    0.468750
# 0541411ea78d692ada524e8734da6bb2    0.390625
# 06b93cc32b6bfdbc24ab9c6df1da3d0b    0.562500
#                                       ...
# fcb16a85d0044180bb747f0211f92990    0.468750
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# fe4e907a21bb03842eb88d0c0d633ca8    0.390625
# ff1093d5ef61bf46f8c88e9b7614e311    0.390625
# ffb63ff99cf1354dff1da862f379da80    0.390625
# Name: 201911, Length: 195, dtype: float64
# 195
#
# Outliers for 201912---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.562500
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 01ce983dcf27d1231539e5827f8ad6af    0.390625
# 03d189e698bac53767b82645f582d574    0.562500
# 0541411ea78d692ada524e8734da6bb2    0.390625
#                                       ...
# fd5e924e4c60a31db58620fd58f3cdc8    0.390625
# fd81ffbb5f0c5adb57428d3ef126618a    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# fe755bf21b5abbfa6cbe808e1f99d55a    0.390625
# ff1093d5ef61bf46f8c88e9b7614e311    0.390625
# Name: 201912, Length: 213, dtype: float64
# 213
#
# Outliers for 202001---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.562500
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 03d189e698bac53767b82645f582d574    0.468750
# 0541411ea78d692ada524e8734da6bb2    0.390625
# 0550aa60e5d21395371c54b785975cce    0.468750
#                                       ...
# fcb16a85d0044180bb747f0211f92990    0.390625
# fd81ffbb5f0c5adb57428d3ef126618a    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# fe4e907a21bb03842eb88d0c0d633ca8    0.390625
# ffb63ff99cf1354dff1da862f379da80    0.390625
# Name: 202001, Length: 232, dtype: float64
# 232
#
# Outliers for 202002---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.390625
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 03d189e698bac53767b82645f582d574    0.468750
# 0541411ea78d692ada524e8734da6bb2    0.390625
# 0550aa60e5d21395371c54b785975cce    0.468750
#                                       ...
# f6f97a90a742d6f3ee157c9e519c7242    0.390625
# facfe99fff1a63941380ad952a055621    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# fe4e907a21bb03842eb88d0c0d633ca8    0.390625
# ff1093d5ef61bf46f8c88e9b7614e311    0.390625
# Name: 202002, Length: 187, dtype: float64
# 187
#
# Outliers for 202003---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.390625
# 00d4474d7b8abcb71cc114a564769182    0.468750
# 01ce983dcf27d1231539e5827f8ad6af    0.390625
# 03d189e698bac53767b82645f582d574    0.562500
# 0541411ea78d692ada524e8734da6bb2    0.390625
#                                       ...
# f6f97a90a742d6f3ee157c9e519c7242    0.390625
# f8ed2eeab5cb3467976dec49e5268293    0.390625
# fbfe5e170af1fae88a0bc64d5c6254dc    0.390625
# fe4e907a21bb03842eb88d0c0d633ca8    0.390625
# ffb63ff99cf1354dff1da862f379da80    0.390625
# Name: 202003, Length: 193, dtype: float64
# 193
#
# Outliers for 202004---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.390625
# 01ce983dcf27d1231539e5827f8ad6af    0.390625
# 03d189e698bac53767b82645f582d574    0.562500
# 0541411ea78d692ada524e8734da6bb2    0.468750
# 0550aa60e5d21395371c54b785975cce    0.656250
#                                       ...
# f5a97db046731b78334a7053fd33bb24    0.390625
# f6ec80f8701edf2f87c851996aa07ef1    0.390625
# f8ed2eeab5cb3467976dec49e5268293    0.390625
# fb5b5d2333b68e9f1ff6c4bd6f208a81    0.390625
# fe4e907a21bb03842eb88d0c0d633ca8    0.390625
# Name: 202004, Length: 138, dtype: float64
# 138
#
# Outliers for 202005---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.857143
# 00d4474d7b8abcb71cc114a564769182    0.510204
# 03d189e698bac53767b82645f582d574    0.612245
# 0541411ea78d692ada524e8734da6bb2    0.510204
# 0550aa60e5d21395371c54b785975cce    0.714286
#                                       ...
# f0c62743dc7cecdbe2ae6df8e92f6a13    0.510204
# f547fbc8c176e87102bcf736c5d1d6a0    0.489796
# f937cc06caf1660ee9ed382a510a6688    0.408163
# facfe99fff1a63941380ad952a055621    0.510204
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.408163
# Name: 202005, Length: 147, dtype: float64
# 147
#
# Outliers for 202006---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.765625
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 01ce983dcf27d1231539e5827f8ad6af    0.390625
# 03d189e698bac53767b82645f582d574    0.562500
# 0541411ea78d692ada524e8734da6bb2    0.468750
#                                       ...
# fcfae4ea0dc12d7a82da4c968df820e7    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# fe4e907a21bb03842eb88d0c0d633ca8    0.390625
# ff1093d5ef61bf46f8c88e9b7614e311    0.390625
# ffb63ff99cf1354dff1da862f379da80    0.390625
# Name: 202006, Length: 291, dtype: float64
# 291
#
# Outliers for 202007---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.656250
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 01ce983dcf27d1231539e5827f8ad6af    0.390625
# 03d189e698bac53767b82645f582d574    0.562500
# 0541411ea78d692ada524e8734da6bb2    0.390625
#                                       ...
# f8ed2eeab5cb3467976dec49e5268293    0.390625
# f937cc06caf1660ee9ed382a510a6688    0.375000
# facfe99fff1a63941380ad952a055621    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# ffb63ff99cf1354dff1da862f379da80    0.468750
# Name: 202007, Length: 241, dtype: float64
# 241
#
# Outliers for 202008---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.468750
# 00d4474d7b8abcb71cc114a564769182    0.562500
# 02d8213d352d3e2cc30fb98249cf5c89    0.390625
# 03d189e698bac53767b82645f582d574    0.562500
# 0541411ea78d692ada524e8734da6bb2    0.390625
#                                       ...
# f937cc06caf1660ee9ed382a510a6688    0.468750
# facfe99fff1a63941380ad952a055621    0.390625
# fcb16a85d0044180bb747f0211f92990    0.468750
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.468750
# ff1093d5ef61bf46f8c88e9b7614e311    0.390625
# Name: 202008, Length: 182, dtype: float64
# 182
# <ipython-input-28-ab658f4f8d27>:8: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# `scipy.stats.median_abs_deviation(..., scale=1/1.4826)`.
# The value 1.4826 is not numerically precise for scaling
# with a normal distribution. For a numerically precise value, use
# `scipy.stats.median_abs_deviation(..., scale='normal')`.
#
#   mad = np.abs(stats.median_absolute_deviation(df))

# %%
col_threshold
# Out:
# [{201908: {'threshold': 0.390625, 'count': 243}},
#  {201909: {'threshold': 0.375, 'count': 180}},
#  {201910: {'threshold': 0.375, 'count': 283}},
#  {201911: {'threshold': 0.390625, 'count': 195}},
#  {201912: {'threshold': 0.375, 'count': 213}},
#  {202001: {'threshold': 0.375, 'count': 232}},
#  {202002: {'threshold': 0.375, 'count': 187}},
#  {202003: {'threshold': 0.375, 'count': 193}},
#  {202004: {'threshold': 0.375, 'count': 138}},
#  {202005: {'threshold': 0.4081632653061224, 'count': 147}},
#  {202006: {'threshold': 0.375, 'count': 291}},
#  {202007: {'threshold': 0.375, 'count': 241}},
#  {202008: {'threshold': 0.375, 'count': 182}}]

# %%
sum_outlier = 0
for col in col_threshold:
    for key,val in col.items():
        sum_outlier += val["threshold"]
avg_outlier = sum_outlier / len(col_threshold)
pivot_voice_usage_info["Outlier"]=pivot_voice_usage_info.apply(lambda x : "YES" if x["Usage_Rating_Scaled"]> avg_outlier else "NO", axis=1)
print(avg_outlier)
# Out:
# 0.3799548665620094

# %%
pivot_voice_usage_info.describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       3191.000000  3191.000000  3191.000000  3191.000000  3191.000000
# mean           0.114908     0.097623     0.125436     0.106202     0.114463
# std            0.138763     0.122347     0.146255     0.130960     0.132240
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.015625     0.015625     0.015625     0.015625     0.015625
# 50%            0.062500     0.062500     0.062500     0.062500     0.062500
# 75%            0.187500     0.140625     0.187500     0.140625     0.187500
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       3191.000000  3191.000000  3191.000000  3191.000000  3191.000000
# mean           0.113948     0.103817     0.110119     0.085392     0.091258
# std            0.133495     0.126028     0.127201     0.114835     0.125925
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.015625     0.015625     0.015625     0.000000     0.000000
# 50%            0.062500     0.062500     0.062500     0.031250     0.040816
# 75%            0.187500     0.140625     0.140625     0.140625     0.122449
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202006       202007       202008  Usage_Rating_Scaled
# count       3191.000000  3191.000000  3191.000000          3191.000000
# mean           0.125064     0.112548     0.101286             0.107851
# std            0.141051     0.135715     0.124991             0.114321
# min            0.000000     0.000000     0.000000             0.001202
# 25%            0.015625     0.015625     0.015625             0.024038
# 50%            0.062500     0.062500     0.062500             0.073685
# 75%            0.187500     0.140625     0.140625             0.152914
# max            1.000000     1.000000     1.000000             1.000000

# %%
# labling usage bins
bins = [0, 0.08, 0.3,1]
labels = ['LOW','MEDIUM','HIGH']
pivot_voice_usage_info['Usage_Rating_Categorical'] = pd.cut(pivot_voice_usage_info['Usage_Rating_Scaled'], bins=bins, labels=labels)
pivot_voice_usage_info
# Out:
# year-month                          201908    201909    201910    201911  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.140625  0.015625  0.062500  0.031250
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.015625  0.031250  0.015625
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.062500  0.093750  0.062500  0.062500
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.031250  0.062500  0.062500
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.390625  0.390625  0.390625
# ffd697d66cc01c8897ce3e37d693673a  0.015625  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.250000  0.250000  0.250000  0.312500
# ffee845c0caa320b55e31bb156827d16  0.000000  0.015625  0.031250  0.000000
#
# year-month                          201912    202001    202002    202003  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.062500  0.015625  0.015625  0.031250
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.046875  0.093750  0.046875
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.015625  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.062500  0.015625  0.031250  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.031250  0.000000  0.000000  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.390625  0.312500  0.390625
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.187500  0.250000  0.140625
# ffee845c0caa320b55e31bb156827d16  0.000000  0.000000  0.015625  0.015625
#
# year-month                          202004    202005    202006    202007  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.031250  0.040816  0.062500  0.062500
# 002fb47f60400713c854b0f69ff78c0a  0.093750  0.163265  0.015625  0.015625
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.015625  0.040816  0.062500  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.015625  0.000000  0.000000  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.140625  0.326531  0.390625  0.468750
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.093750  0.020408  0.234375  0.187500
# ffee845c0caa320b55e31bb156827d16  0.015625  0.000000  0.125000  0.031250
#
# year-month                         202008  Usage_Rating_Scaled Outlier  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.06250             0.048813      NO
# 002fb47f60400713c854b0f69ff78c0a  0.03125             0.053424      NO
# 00567a4a3c474aca1ce5cd6570648932  0.00000             0.003606      NO
# 00724ae2470df1ed0fe919800d02517d  0.06250             0.004808      NO
# 007400db8afa996e788d23986739f3db  0.00000             0.039197      NO
# ...                                   ...                  ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.00000             0.018029      NO
# ffb63ff99cf1354dff1da862f379da80  0.25000             0.334012      NO
# ffd697d66cc01c8897ce3e37d693673a  0.00000             0.001202      NO
# ffd96f173d6cd683bf3384bdc2f99713  0.18750             0.196281      NO
# ffee845c0caa320b55e31bb156827d16  0.03125             0.021635      NO
#
# year-month                       Usage_Rating_Categorical
# event_source.hash
# 00221451f705ebe26051158bb14f567a                      LOW
# 002fb47f60400713c854b0f69ff78c0a                      LOW
# 00567a4a3c474aca1ce5cd6570648932                      LOW
# 00724ae2470df1ed0fe919800d02517d                      LOW
# 007400db8afa996e788d23986739f3db                      LOW
# ...                                                   ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# ffb63ff99cf1354dff1da862f379da80                     HIGH
# ffd697d66cc01c8897ce3e37d693673a                      LOW
# ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# ffee845c0caa320b55e31bb156827d16                      LOW
#
# [3191 rows x 16 columns]

# %%
# adding category "NO" 
pivot_voice_usage_info['Usage_Rating_Categorical'] = pivot_voice_usage_info['Usage_Rating_Categorical'].cat.add_categories("NO")
pivot_voice_usage_info.loc[pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0, 'Usage_Rating_Categorical'] = "NO"
pivot_voice_usage_info[(pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [201908, 201909, 201910, 201911, 201912, 202001, 202002, 202003, 202004, 202005, 202006, 202007, 202008, Usage_Rating_Scaled, Outlier, Usage_Rating_Categorical]
# Index: []

# %% [markdown]
# ### Fina Result: Usage Ratings

# %%
pivot_voice_usage_info
# Out:
# year-month                          201908    201909    201910    201911  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.140625  0.015625  0.062500  0.031250
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.015625  0.031250  0.015625
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.062500  0.093750  0.062500  0.062500
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.031250  0.062500  0.062500
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.390625  0.390625  0.390625
# ffd697d66cc01c8897ce3e37d693673a  0.015625  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.250000  0.250000  0.250000  0.312500
# ffee845c0caa320b55e31bb156827d16  0.000000  0.015625  0.031250  0.000000
#
# year-month                          201912    202001    202002    202003  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.062500  0.015625  0.015625  0.031250
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.046875  0.093750  0.046875
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.015625  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.062500  0.015625  0.031250  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.031250  0.000000  0.000000  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.390625  0.312500  0.390625
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.187500  0.250000  0.140625
# ffee845c0caa320b55e31bb156827d16  0.000000  0.000000  0.015625  0.015625
#
# year-month                          202004    202005    202006    202007  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.031250  0.040816  0.062500  0.062500
# 002fb47f60400713c854b0f69ff78c0a  0.093750  0.163265  0.015625  0.015625
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.015625  0.040816  0.062500  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.015625  0.000000  0.000000  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.140625  0.326531  0.390625  0.468750
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.093750  0.020408  0.234375  0.187500
# ffee845c0caa320b55e31bb156827d16  0.015625  0.000000  0.125000  0.031250
#
# year-month                         202008  Usage_Rating_Scaled Outlier  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.06250             0.048813      NO
# 002fb47f60400713c854b0f69ff78c0a  0.03125             0.053424      NO
# 00567a4a3c474aca1ce5cd6570648932  0.00000             0.003606      NO
# 00724ae2470df1ed0fe919800d02517d  0.06250             0.004808      NO
# 007400db8afa996e788d23986739f3db  0.00000             0.039197      NO
# ...                                   ...                  ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.00000             0.018029      NO
# ffb63ff99cf1354dff1da862f379da80  0.25000             0.334012      NO
# ffd697d66cc01c8897ce3e37d693673a  0.00000             0.001202      NO
# ffd96f173d6cd683bf3384bdc2f99713  0.18750             0.196281      NO
# ffee845c0caa320b55e31bb156827d16  0.03125             0.021635      NO
#
# year-month                       Usage_Rating_Categorical
# event_source.hash
# 00221451f705ebe26051158bb14f567a                      LOW
# 002fb47f60400713c854b0f69ff78c0a                      LOW
# 00567a4a3c474aca1ce5cd6570648932                      LOW
# 00724ae2470df1ed0fe919800d02517d                      LOW
# 007400db8afa996e788d23986739f3db                      LOW
# ...                                                   ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# ffb63ff99cf1354dff1da862f379da80                     HIGH
# ffd697d66cc01c8897ce3e37d693673a                      LOW
# ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# ffee845c0caa320b55e31bb156827d16                      LOW
#
# [3191 rows x 16 columns]

# %%
pivot_voice_usage_info.to_csv("data/user_profile/VOICE_OFFNET_OUTGOING_Usage_Categorical.csv")

# %% [markdown]
# # Phase 2

# %% [markdown]
# ## Binnig by Location
#
# - 1. group by location columns
# - 2. Bin by location and get counts

# %%
# bucketing by location
voice_location_info = voice_usage_info
voice_location_info['Location_Identifier'] = voice_location_info['msan'].astype(str)+ voice_location_info['location_code'].astype(str) +voice_location_info['equp_id'].astype(str) +voice_location_info['equp_index'].astype(str)
voice_location_info
# Out:
#                       event_source.hash  call_count  duration  year-month  \
# 0      90feabe2f2846cbf4eb77db650c48a1b          14      1200      201912
# 1      4c31c59c555ac6f4fdba3cec18674004         186     29616      202001
# 2      4c31c59c555ac6f4fdba3cec18674004         162     28799      202002
# 3      4c31c59c555ac6f4fdba3cec18674004         187     34830      202003
# 4      4c31c59c555ac6f4fdba3cec18674004         116     27311      202005
# ...                                 ...         ...       ...         ...
# 33207  881083811a88758606701519d3f07faa          12       389      202006
# 33208  ac8d17782113fb666dc8d8804f46ceaa           8      1560      201908
# 33209  ac8d17782113fb666dc8d8804f46ceaa           8      2100      201909
# 33210  ac8d17782113fb666dc8d8804f46ceaa          15      4020      202001
# 33211  ac8d17782113fb666dc8d8804f46ceaa           4       600      202002
#
#                        account_num.hash rtom_code location_code          msan  \
# 0      9c926ad1c6705e1f46462dc5b59d8feb      R-GP       TP-NODE         C300M
# 1      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 2      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 3      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# 4      b0c495cfe7a57adf77d0fdadecabe3e0      R-GP       TP-NODE         C300M
# ...                                 ...       ...           ...           ...
# 33207  c78977b555bf659a9586b15dd4f3b608     R-MRG       BZ-NODE  MSAG5200-ISL
# 33208  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33209  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33210  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
# 33211  cfc0dd04946fe2779e63e51c7a3aa0c2     R-MRG       BZ-NODE  MSAG5200-ISL
#
#        equp_id  equp_index        Location_Identifier
# 0       870091           1        C300MTP-NODE8700911
# 1       870091           1        C300MTP-NODE8700911
# 2       870091           1        C300MTP-NODE8700911
# 3       870091           1        C300MTP-NODE8700911
# 4       870091           1        C300MTP-NODE8700911
# ...        ...         ...                        ...
# 33207    43588           1  MSAG5200-ISLBZ-NODE435881
# 33208    43588           1  MSAG5200-ISLBZ-NODE435881
# 33209    43588           1  MSAG5200-ISLBZ-NODE435881
# 33210    43588           1  MSAG5200-ISLBZ-NODE435881
# 33211    43588           1  MSAG5200-ISLBZ-NODE435881
#
# [33200 rows x 11 columns]

# %%
voice_location_info = voice_location_info.drop_duplicates("event_source.hash", keep="last")
voice_location_info.shape
# Out:
# (3191, 11)

# %%
user_location = voice_location_info[['event_source.hash','Location_Identifier']]
user_location
# Out:
#                       event_source.hash            Location_Identifier
# 13     4c31c59c555ac6f4fdba3cec18674004            C300MTP-NODE8700911
# 26     73051c4485db78111612f2de609ef769            C300MTP-NODE8700911
# 39     2cacd49987694a9a2ee3b95301c47aa7            C300MTP-NODE8700911
# 50     b2098cfa4095b95c9bdf865a15cbf320            C300MTP-NODE8700911
# 60     921b3d510c7a37d94c57415b9f71a533  MSAG5200-ISLND-PHG-NODE500241
# ...                                 ...                            ...
# 33173  7c3ef713055f0d38a9ff266ce65e5e30      MSAG5200-ISLBZ-NODE435881
# 33185  7137d1cbc03fe72dd0a32dd430b49f78      MSAG5200-ISLBZ-NODE435881
# 33194  91ab83caaebbc937ca30f5306e80dbad      MSAG5200-ISLBZ-NODE435881
# 33207  881083811a88758606701519d3f07faa      MSAG5200-ISLBZ-NODE435881
# 33211  ac8d17782113fb666dc8d8804f46ceaa      MSAG5200-ISLBZ-NODE435881
#
# [3191 rows x 2 columns]

# %%
user_location.to_csv("data/user_profile/VOICE_OFFNET_OUTGOING_Locations_of_Users.csv")

# %%
voice_location_info["User_Count"] = 1
voice_gropued_by_locations = voice_location_info.groupby(['Location_Identifier'], axis=0,as_index=False).sum()
voice_gropued_by_locations = voice_gropued_by_locations[['Location_Identifier','User_Count']]
# Out:
# <ipython-input-42-46e54884d952>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voice_location_info["User_Count"] = 1

# %%
voice_gropued_by_locations
# Out:
#                 Location_Identifier  User_Count
# 0          C300MHE-DMD-NODE15221561          12
# 1            C300MHT-NE-NODE8152461          17
# 2         C300MIDH-IDJ-NODE11065541          60
# 3              C300MKI-NODE10668164          86
# 4          C300MNW-MEE-NODE18887751         179
# 5             C300MPDT-NODE13379431          12
# 6               C300MTP-NODE8700911          21
# 7               C300MVH-NODE9874041          16
# 8        MA5603TAD-SRV-NODE10224991           7
# 9         MSAG5200-ISLBZ-NODE435881         150
# 10       MSAG5200-ISLGE-NODE5577981          15
# 11    MSAG5200-ISLHC-NAP-NODE478721          17
# 12    MSAG5200-ISLHK-OCC-NODE506561          18
# 13       MSAG5200-ISLHNT-NODE423851          16
# 14        MSAG5200-ISLHO-NODE524692           4
# 15    MSAG5200-ISLHZ-BRL-NODE471911          16
# 16  MSAG5200-ISLIDH-KGW-NODE6194491         187
# 17    MSAG5200-ISLJA-PKV-NODE460421          18
# 18    MSAG5200-ISLKI-KRB-NODE479411           1
# 19    MSAG5200-ISLMB-PSL-NODE482261          18
# 20    MSAG5200-ISLMH-POL-NODE491451         107
# 21  MSAG5200-ISLMLT-VMD-NODE4145091          65
# 22    MSAG5200-ISLMT-AVR-NODE467161         306
# 23    MSAG5200-ISLMV-GDM-NODE482491         325
# 24       MSAG5200-ISLMX-NODE5391821          20
# 25    MSAG5200-ISLND-PHG-NODE500241         355
# 26    MSAG5200-ISLNL-HGW-NODE491281          15
# 27    MSAG5200-ISLPC-AGT-NODE480031         114
# 28   MSAG5200-ISLPK-PNU-NODE6136021           7
# 29       MSAG5200-ISLPRN-NODE427901          11
# 30    MSAG5200-ISLSI-DWS-NODE520721          89
# 31      MSAG5200-ISLTBL-NODE5577771          16
# 32   MSAG5200-ISLTBT-TLJ-NODE487241           9
# 33    MSAG5200-ISLVA-NKM-NODE481961          50
# 34    MSAG5200-ISLWI-NWT-NODE485201          20
# 35   MSAG5200-ISLWKN-SWP-NODE473481          33
# 36        MSAG5200-ISLWM-NODE432881           5
# 37    MSAG5200-ISLWY-MDB-NODE506221          16
# 38            MSAG5200BG-NODE431391         210
# 39           MSAG5200HPG-NODE432141          17
# 40           MSAG5200MGE-NODE428381          19
# 41        MSAG5200PH-AKG-NODE431631         266
# 42            MSAG5200PK-NODE438641          12
# 43           MSAG5200WLI-NODE422581           2
# 44        UA5000(IPMB)IM-NODE391531          17
# 45        UA5000(IPMB)SL-NODE385341         156
# 46  ZXDSL9806H-ISLAG-PNP-NODE529761          19
# 47  ZXDSL9806H-ISLKE-NRP-NODE495731          20
# 48  ZXDSL9806H-ISLKL-PRC-NODE482361          20

# %%
voice_gropued_by_locations.to_csv("data/user_profile/VOICE_OFFNET_OUTGOING_Users_by_location.csv")
