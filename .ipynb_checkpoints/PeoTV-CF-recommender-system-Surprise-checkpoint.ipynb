# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from surprise import *
from surprise import accuracy
from surprise.model_selection import GridSearchCV
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# %%
# import dataset
user_profile = pd.read_csv("data/user_profile/PEO_TV_Usage_Categorical_Non_Unique.csv")
user_profile
# Out:
#       Unnamed: 0                 Phone_Number.hash   Peo_TV_Package  \
# 0              0  46960b77dad950ddae76dd53bd7848cd      PEO_UTHAYAM
# 1              1  46960b77dad950ddae76dd53bd7848cd      PEO_UTHAYAM
# 2              2  71d08664b609dcaddf02d6ffc2532aa7       PEO_SILVER
# 3              3  71d08664b609dcaddf02d6ffc2532aa7       PEO_SILVER
# 4              4  f98bd7d6c96317fc2656bc43441df8bb       PEO_SILVER
# ...          ...                               ...              ...
# 2588        2588  5fc30724801d125e0048b486655723f6       PEO_SILVER
# 2589        2589  e034fe9b7cb567273a07edbad9946fde  PEO_SILVER_PLUS
# 2590        2590  e034fe9b7cb567273a07edbad9946fde  PEO_SILVER_PLUS
# 2591        2591  2ab8436cc34b4f16de3c452300f975c3       PEO_SILVER
# 2592        2592  2ab8436cc34b4f16de3c452300f975c3       PEO_SILVER
#
#       usage_08_20 (hh:mm)  usage_07_20 (hh:mm)  usage_06_20 (hh:mm)  \
# 0                    0.75                 1.00                 1.00
# 1                    0.75                 1.00                 1.00
# 2                    0.25                 0.25                 0.25
# 3                    0.25                 0.25                 0.25
# 4                    0.75                 0.75                 0.75
# ...                   ...                  ...                  ...
# 2588                 0.75                 0.75                 0.75
# 2589                 0.75                 0.75                 0.75
# 2590                 0.75                 0.75                 0.75
# 2591                 0.00                 0.00                 0.00
# 2592                 0.00                 0.00                 0.00
#
#       usage_05_20 (hh:mm)  usage04_20 (hh:mm)  usage_03_20 (hh:mm)  \
# 0                    1.00                1.00                 1.00
# 1                    1.00                1.00                 1.00
# 2                    0.50                0.75                 0.75
# 3                    0.50                0.75                 0.75
# 4                    0.75                0.75                 0.75
# ...                   ...                 ...                  ...
# 2588                 0.75                0.75                 0.75
# 2589                 0.75                1.00                 0.75
# 2590                 0.75                1.00                 0.75
# 2591                 0.00                0.00                 0.00
# 2592                 0.00                0.00                 0.00
#
#       usage_02_20 (hh:mm)  usage_01_20 (hh:mm)     Usage_Rating_Scaled  \
# 0                    0.75                 1.00                 0.93750
# 1                    0.75                 1.00                 0.93750
# 2                    0.25                 0.25                 0.40625
# 3                    0.25                 0.25                 0.40625
# 4                    0.75                 0.75                 0.75000
# ...                   ...                  ... ..                  ...
# 2588                 0.75                 0.75                 0.75000
# 2589                 0.75                 0.75                 0.78125
# 2590                 0.75                 0.75                 0.78125
# 2591                 0.50                 0.75                 0.15625
# 2592                 0.50                 0.75                 0.15625
#
#      Usage_Rating_Categorical
# 0                        HIGH
# 1                        HIGH
# 2                      MEDIUM
# 3                      MEDIUM
# 4                        HIGH
# ...                       ...
# 2588                     HIGH
# 2589                     HIGH
# 2590                     HIGH
# 2591                      LOW
# 2592                      LOW
#
# [2593 rows x 14 columns]

# %%
user_profile.columns
# Out:
# Index(['Unnamed: 0', 'Phone_Number.hash', 'Peo_TV_Package',
#        'usage_08_20 (hh:mm)', 'usage_07_20 (hh:mm)', 'usage_06_20 (hh:mm)',
#        'usage_05_20 (hh:mm)', 'usage04_20 (hh:mm)', 'usage_03_20 (hh:mm)',
#        'usage_02_20 (hh:mm)', 'usage_01_20 (hh:mm)', ' ',
#        'Usage_Rating_Scaled', 'Usage_Rating_Categorical'],
#       dtype='object')

# %%
data=user_profile.iloc[:,[1,2,12]]
data
# Out:
#                      Phone_Number.hash   Peo_TV_Package  Usage_Rating_Scaled
# 0     46960b77dad950ddae76dd53bd7848cd      PEO_UTHAYAM              0.93750
# 1     46960b77dad950ddae76dd53bd7848cd      PEO_UTHAYAM              0.93750
# 2     71d08664b609dcaddf02d6ffc2532aa7       PEO_SILVER              0.40625
# 3     71d08664b609dcaddf02d6ffc2532aa7       PEO_SILVER              0.40625
# 4     f98bd7d6c96317fc2656bc43441df8bb       PEO_SILVER              0.75000
# ...                                ...              ...                  ...
# 2588  5fc30724801d125e0048b486655723f6       PEO_SILVER              0.75000
# 2589  e034fe9b7cb567273a07edbad9946fde  PEO_SILVER_PLUS              0.78125
# 2590  e034fe9b7cb567273a07edbad9946fde  PEO_SILVER_PLUS              0.78125
# 2591  2ab8436cc34b4f16de3c452300f975c3       PEO_SILVER              0.15625
# 2592  2ab8436cc34b4f16de3c452300f975c3       PEO_SILVER              0.15625
#
# [2593 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2593 entries, 0 to 2592
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Phone_Number.hash    2593 non-null   object
#  1   Peo_TV_Package       2593 non-null   object
#  2   Usage_Rating_Scaled  2593 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 60.9+ KB

# %%
# total number of unique users
data['Phone_Number.hash'].nunique()
# Out:
# 1428

# %%
# total number of unique peo tv package
data['Peo_TV_Package'].nunique()
# Out:
# 22

# %% [markdown]
# ## Interaction Matrix

# %%
# create a histogram of all the interactions by all the users present in the dataset
interactions = data.groupby('Phone_Number.hash').count()['Peo_TV_Package']
plt.hist(interactions,bins=20)
plt.show()

# %%
# create the user item matrix using the ratings dataset - Hint: try using pivot function 
interactions_metrix = data.pivot_table(index="Phone_Number.hash", columns="Peo_TV_Package", values="Usage_Rating_Scaled")

# %%
interactions_metrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1428 entries, 00567a4a3c474aca1ce5cd6570648932 to fff2221d1365d22d2d08285f2b9fd303
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BOC                          5 non-null      float64
#  1   DOUBLEPROMO                  2 non-null      float64
#  2   LEISURE_SPORTS               1 non-null      float64
#  3   LOTUS                        2 non-null      float64
#  4   NEW_SLT_STAFF_PACKAGE        9 non-null      float64
#  5   NEW_YEAR_TREAT               6 non-null      float64
#  6   PEO_ENTERTAINMENT            18 non-null     float64
#  7   PEO_FAMILY                   1 non-null      float64
#  8   PEO_GOLD                     6 non-null      float64
#  9   PEO_PLATINUM                 4 non-null      float64
#  10  PEO_RELIGIOUS_PACKAGE        4 non-null      float64
#  11  PEO_SILVER                   995 non-null    float64
#  12  PEO_SILVER_FTTH              3 non-null      float64
#  13  PEO_SILVER_PLUS              57 non-null     float64
#  14  PEO_SILVER_PLUS_FTTH         2 non-null      float64
#  15  PEO_TITANIUM                 21 non-null     float64
#  16  PEO_UNNATHAM                 49 non-null     float64
#  17  PEO_UTHAYAM                  174 non-null    float64
#  18  PRANAMA                      61 non-null     float64
#  19  SLTStaff_PEO_SILVER          6 non-null      float64
#  20  SLT_STAFF_PEO_UNNATHAM_FTTH  1 non-null      float64
#  21  SLT_STAFF_TRIPLE_PLAY        1 non-null      float64
# dtypes: float64(22)
# memory usage: 256.6+ KB

# %%
# replace all the missing values with zero
interactions_metrix = interactions_metrix.fillna(0)

# %%
interactions_metrix.sample(n=10)
# Out:
# Peo_TV_Package                    BOC  DOUBLEPROMO  LEISURE_SPORTS  LOTUS  \
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13  0.0          0.0             0.0    0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13  0.0          0.0             0.0    0.0
# bf970282eba794f1fd3b59a5e281b1f6  0.0          0.0             0.0    0.0
# f39f7435a778b27d02b33993523a55b5  0.0          0.0             0.0    0.0
# c65ea87b700d2801e7adcfaea90cc228  0.0          0.0             0.0    0.0
# 6de165518de641dbd2036b88f62084c5  0.0          0.0             0.0    0.0
# b043714c955e2839cf3270f89ba82420  0.0          0.0             0.0    0.0
# 36adba3ab3196ff055dc0cb66d3fc03d  0.0          0.0             0.0    0.0
# 157d80966d29d5f94629843c64622c1b  0.0          0.0             0.0    0.0
# 81cdc716998cf7a22c87600415056adf  0.0          0.0             0.0    0.0
#
# Peo_TV_Package                    NEW_SLT_STAFF_PACKAGE  NEW_YEAR_TREAT  \
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13                    0.0             0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13                    0.0             0.0
# bf970282eba794f1fd3b59a5e281b1f6                    0.0             0.0
# f39f7435a778b27d02b33993523a55b5                    0.0             0.0
# c65ea87b700d2801e7adcfaea90cc228                    0.0             0.0
# 6de165518de641dbd2036b88f62084c5                    0.0             0.0
# b043714c955e2839cf3270f89ba82420                    0.0             0.0
# 36adba3ab3196ff055dc0cb66d3fc03d                    0.0             0.0
# 157d80966d29d5f94629843c64622c1b                    0.0             0.0
# 81cdc716998cf7a22c87600415056adf                    0.0             0.0
#
# Peo_TV_Package                    PEO_ENTERTAINMENT  PEO_FAMILY  PEO_GOLD  \
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13                0.0         0.0       0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13                0.0         0.0       0.0
# bf970282eba794f1fd3b59a5e281b1f6                0.0         0.0       0.0
# f39f7435a778b27d02b33993523a55b5                0.0         0.0       0.0
# c65ea87b700d2801e7adcfaea90cc228                0.0         0.0       0.0
# 6de165518de641dbd2036b88f62084c5                0.0         0.0       0.0
# b043714c955e2839cf3270f89ba82420                0.0         0.0       0.0
# 36adba3ab3196ff055dc0cb66d3fc03d                0.0         0.0       0.0
# 157d80966d29d5f94629843c64622c1b                0.0         0.0       0.0
# 81cdc716998cf7a22c87600415056adf                0.0         0.0       0.0
#
# Peo_TV_Package                    PEO_PLATINUM  ...  PEO_SILVER_FTTH  \
# Phone_Number.hash                               ...
# 38fa17c37f34b7c3cbab423c31f21c13           0.0  ...              0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13           0.0  ...              0.0
# bf970282eba794f1fd3b59a5e281b1f6           0.0  ...              0.0
# f39f7435a778b27d02b33993523a55b5           0.0  ...              0.0
# c65ea87b700d2801e7adcfaea90cc228           0.0  ...              0.0
# 6de165518de641dbd2036b88f62084c5           0.0  ...              0.0
# b043714c955e2839cf3270f89ba82420           0.0  ...              0.0
# 36adba3ab3196ff055dc0cb66d3fc03d           0.0  ...              0.0
# 157d80966d29d5f94629843c64622c1b           0.0  ...              0.0
# 81cdc716998cf7a22c87600415056adf           0.0  ...              0.0
#
# Peo_TV_Package                    PEO_SILVER_PLUS  PEO_SILVER_PLUS_FTTH  \
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13              0.0                   0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13              0.0                   0.0
# bf970282eba794f1fd3b59a5e281b1f6              0.0                   0.0
# f39f7435a778b27d02b33993523a55b5              0.0                   0.0
# c65ea87b700d2801e7adcfaea90cc228              0.0                   0.0
# 6de165518de641dbd2036b88f62084c5              0.0                   0.0
# b043714c955e2839cf3270f89ba82420              0.0                   0.0
# 36adba3ab3196ff055dc0cb66d3fc03d              0.0                   0.0
# 157d80966d29d5f94629843c64622c1b              0.0                   0.0
# 81cdc716998cf7a22c87600415056adf              0.0                   0.0
#
# Peo_TV_Package                    PEO_TITANIUM  PEO_UNNATHAM  PEO_UTHAYAM  \
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13           0.0           0.0      0.00000
# 1d6f0ffdce6d98064083dcd7b2d4db13           0.0           0.0      0.00000
# bf970282eba794f1fd3b59a5e281b1f6           0.0           0.0      0.00000
# f39f7435a778b27d02b33993523a55b5           0.0           0.0      0.00000
# c65ea87b700d2801e7adcfaea90cc228           0.0           0.0      0.00000
# 6de165518de641dbd2036b88f62084c5           0.0           0.0      0.00000
# b043714c955e2839cf3270f89ba82420           0.0           0.0      0.00000
# 36adba3ab3196ff055dc0cb66d3fc03d           0.0           0.0      0.00000
# 157d80966d29d5f94629843c64622c1b           0.0           0.0      0.00000
# 81cdc716998cf7a22c87600415056adf           0.0           0.0      0.71875
#
# Peo_TV_Package                    PRANAMA  SLTStaff_PEO_SILVER  \
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13   0.0000                  0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13   0.0000                  0.0
# bf970282eba794f1fd3b59a5e281b1f6   0.0000                  0.0
# f39f7435a778b27d02b33993523a55b5   0.1875                  0.0
# c65ea87b700d2801e7adcfaea90cc228   0.0000                  0.0
# 6de165518de641dbd2036b88f62084c5   0.0000                  0.0
# b043714c955e2839cf3270f89ba82420   0.0000                  0.0
# 36adba3ab3196ff055dc0cb66d3fc03d   0.0000                  0.0
# 157d80966d29d5f94629843c64622c1b   0.0000                  0.0
# 81cdc716998cf7a22c87600415056adf   0.0000                  0.0
#
# Peo_TV_Package                    SLT_STAFF_PEO_UNNATHAM_FTTH  \
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13                          0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13                          0.0
# bf970282eba794f1fd3b59a5e281b1f6                          0.0
# f39f7435a778b27d02b33993523a55b5                          0.0
# c65ea87b700d2801e7adcfaea90cc228                          0.0
# 6de165518de641dbd2036b88f62084c5                          0.0
# b043714c955e2839cf3270f89ba82420                          0.0
# 36adba3ab3196ff055dc0cb66d3fc03d                          0.0
# 157d80966d29d5f94629843c64622c1b                          0.0
# 81cdc716998cf7a22c87600415056adf                          0.0
#
# Peo_TV_Package                    SLT_STAFF_TRIPLE_PLAY
# Phone_Number.hash
# 38fa17c37f34b7c3cbab423c31f21c13                    0.0
# 1d6f0ffdce6d98064083dcd7b2d4db13                    0.0
# bf970282eba794f1fd3b59a5e281b1f6                    0.0
# f39f7435a778b27d02b33993523a55b5                    0.0
# c65ea87b700d2801e7adcfaea90cc228                    0.0
# 6de165518de641dbd2036b88f62084c5                    0.0
# b043714c955e2839cf3270f89ba82420                    0.0
# 36adba3ab3196ff055dc0cb66d3fc03d                    0.0
# 157d80966d29d5f94629843c64622c1b                    0.0
# 81cdc716998cf7a22c87600415056adf                    0.0
#
# [10 rows x 22 columns]

# %%
reader = Reader(rating_scale=(0, 1))
data_model = Dataset.load_from_df(data, reader)

# %%
trainset, testset = train_test_split(data_model, test_size=.20)

# %% [markdown]
# ## Collabarative Recoomenders with Suprise

# %%
def get_Iu(uid):
    """Return the number of items rated by given user
    
    Args:
        uid: The raw id of the user.
    Returns:
        The number of items rated by the user.
    """
    
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError:  # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """Return the number of users that have rated given item
    
    Args:
        iid: The raw id of the item.
    Returns:
        The number of users that have rated the item.
    """
    
    try:
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:  # item was not part of the trainset
        return 0

# %% [markdown]
# ### SVD recommender

# %%
# We'll use the famous SVD algorithm.
algo = SVD()

# Run 5-fold cross-validation and print results
validate = cross_validate(algo, data_model, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.3218  0.3302  0.3233  0.3248  0.3240  0.3248  0.0029
# MAE (testset)     0.2841  0.2911  0.2855  0.2850  0.2840  0.2860  0.0027
# Fit time          0.13    0.10    0.13    0.12    0.13    0.12    0.01
# Test time         0.01    0.00    0.00    0.01    0.00    0.00    0.00

# %%
# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# %%
# Let's build a pandas dataframe with all the predictions
df = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])    
df['Iu'] = df.uid.apply(get_Iu)
df['Ui'] = df.iid.apply(get_Ui)
df['err'] = abs(df.est - df.rui)

# %%
# 10 Best predictions
best_predictions = df.sort_values(by='err')[:10]
best_predictions
# Out:
#                                   uid                    iid      rui  \
# 383  fda179f74ebd420110e55ec547c039b7             PEO_SILVER  0.46875
# 330  bb6a044ecacc35c5af46e01536032364             PEO_SILVER  0.46875
# 18   fda179f74ebd420110e55ec547c039b7             PEO_SILVER  0.46875
# 47   9231c080ea1108c7eeede0f449becb59           PEO_UNNATHAM  0.71875
# 514  6953074125422a5fca58110a45dfd4e4        PEO_SILVER_PLUS  0.59375
# 5    3cc8e646c3053630a33f22f2ed11309d        PEO_SILVER_PLUS  0.65625
# 506  3cc8e646c3053630a33f22f2ed11309d        PEO_SILVER_PLUS  0.65625
# 92   793b67f4506d81e95404f44058bd9518  PEO_RELIGIOUS_PACKAGE  0.50000
# 160  a197b51cda9976cf80da4bb379027531                PRANAMA  0.46875
# 381  181e25f778e05ad6ddaa29d4df7af8d9             PEO_SILVER  0.46875
#
#           est                    details  Iu    Ui       err
# 383  0.467093  {'was_impossible': False}   0  1447  0.001657
# 330  0.467093  {'was_impossible': False}   0  1447  0.001657
# 18   0.467093  {'was_impossible': False}   0  1447  0.001657
# 47   0.720903  {'was_impossible': False}   1    71  0.002153
# 514  0.590117  {'was_impossible': False}   1    81  0.003633
# 5    0.649687  {'was_impossible': False}   0    81  0.006563
# 506  0.649687  {'was_impossible': False}   0    81  0.006563
# 92   0.491727  {'was_impossible': False}   1     7  0.008273
# 160  0.479229  {'was_impossible': False}   1    90  0.010479
# 381  0.479680  {'was_impossible': False}   1  1447  0.010930

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.3118
# 0.3118334067384793

# %%
# RMSE
fig,ax = plt.subplots(figsize=(10,7))
ax.plot(validate["test_rmse"])

# %% [markdown]
# ### SlopeOne recommender

# %%
# We'll use the SlopeOne algorithm.
algo = SlopeOne()

# Run 5-fold cross-validation and print results
validate =cross_validate(algo, data_model, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SlopeOne on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.2175  0.2199  0.2256  0.2176  0.2054  0.2172  0.0066
# MAE (testset)     0.1118  0.1110  0.1139  0.1105  0.0981  0.1091  0.0056
# Fit time          0.02    0.02    0.02    0.01    0.02    0.02    0.00
# Test time         0.01    0.01    0.01    0.00    0.01    0.01    0.00

# %%
# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# %%
# Let's build a pandas dataframe with all the predictions
df = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])    
df['Iu'] = df.uid.apply(get_Iu)
df['Ui'] = df.iid.apply(get_Ui)
df['err'] = abs(df.est - df.rui)

# %%
# 10 Best predictions
best_predictions = df.sort_values(by='err')[:10]
best_predictions
# Out:
#                                   uid           iid      rui      est  \
# 518  22cc771a7d6bca13485e3d12ffe31c30    PEO_SILVER  0.00000  0.00000
# 290  a26f6222a5641f631d210d3f20cf0545    PEO_SILVER  0.65625  0.65625
# 288  7030e30e6f4161e27a1965ec12d9ce6f  PEO_UNNATHAM  0.75000  0.75000
# 287  24c3c7ca6e772ca95aa25afe4eecb0bb    PEO_SILVER  0.59375  0.59375
# 286  3404ac8dc0a32ae3e9858b8d576e4c89    PEO_SILVER  0.12500  0.12500
# 285  189d153ed80d6ecdae7fde4fb540a4f3    PEO_SILVER  0.40625  0.40625
# 283  31110bf10f07e3d5e23da9680b1dd287    PEO_SILVER  0.93750  0.93750
# 282  f6a7b28f970d152c4af7109cb211cbef    PEO_SILVER  1.00000  1.00000
# 281  82dec366d337db00245e0e6963195fb6   PEO_UTHAYAM  0.00000  0.00000
# 476  df06f421bfe860cb3759946614d1b838    PEO_SILVER  0.84375  0.84375
#
#                        details  Iu    Ui  err
# 518  {'was_impossible': False}   1  1447  0.0
# 290  {'was_impossible': False}   1  1447  0.0
# 288  {'was_impossible': False}   1    71  0.0
# 287  {'was_impossible': False}   1  1447  0.0
# 286  {'was_impossible': False}   1  1447  0.0
# 285  {'was_impossible': False}   1  1447  0.0
# 283  {'was_impossible': False}   1  1447  0.0
# 282  {'was_impossible': False}   1  1447  0.0
# 281  {'was_impossible': False}   1   247  0.0
# 476  {'was_impossible': False}   1  1447  0.0

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.2021
# 0.20209516606888278

# %%
# RMSE
fig,ax = plt.subplots(figsize=(10,7))
ax.plot(validate["test_rmse"])

# %% [markdown]
# ### KNN with Means recommender

# %%
# We'll use the SlopeOne algorithm.
algo = KNNWithMeans()

# Run 5-fold cross-validation and print results
validate = cross_validate(algo, data_model, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.2342  0.1970  0.2103  0.2095  0.2151  0.2132  0.0121
# MAE (testset)     0.1199  0.0914  0.0988  0.0986  0.1057  0.1029  0.0096
# Fit time          0.13    0.13    0.15    0.20    0.09    0.14    0.04
# Test time         0.25    0.42    0.57    0.26    0.30    0.36    0.12

# %%
# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
# Let's build a pandas dataframe with all the predictions
df = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])    
df['Iu'] = df.uid.apply(get_Iu)
df['Ui'] = df.iid.apply(get_Ui)
df['err'] = abs(df.est - df.rui)

# %%
# 10 Best predictions
best_predictions = df.sort_values(by='err')[:10]
best_predictions
# Out:
#                                   uid           iid      rui      est  \
# 518  22cc771a7d6bca13485e3d12ffe31c30    PEO_SILVER  0.00000  0.00000
# 290  a26f6222a5641f631d210d3f20cf0545    PEO_SILVER  0.65625  0.65625
# 288  7030e30e6f4161e27a1965ec12d9ce6f  PEO_UNNATHAM  0.75000  0.75000
# 287  24c3c7ca6e772ca95aa25afe4eecb0bb    PEO_SILVER  0.59375  0.59375
# 286  3404ac8dc0a32ae3e9858b8d576e4c89    PEO_SILVER  0.12500  0.12500
# 285  189d153ed80d6ecdae7fde4fb540a4f3    PEO_SILVER  0.40625  0.40625
# 283  31110bf10f07e3d5e23da9680b1dd287    PEO_SILVER  0.93750  0.93750
# 282  f6a7b28f970d152c4af7109cb211cbef    PEO_SILVER  1.00000  1.00000
# 281  82dec366d337db00245e0e6963195fb6   PEO_UTHAYAM  0.00000  0.00000
# 476  df06f421bfe860cb3759946614d1b838    PEO_SILVER  0.84375  0.84375
#
#                                        details  Iu    Ui  err
# 518  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0
# 290  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0
# 288  {'actual_k': 40, 'was_impossible': False}   1    71  0.0
# 287  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0
# 286  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0
# 285  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0
# 283  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0
# 282  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0
# 281  {'actual_k': 40, 'was_impossible': False}   1   247  0.0
# 476  {'actual_k': 40, 'was_impossible': False}   1  1447  0.0

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.2021
# 0.20209516606888278

# %%
# RMSE
fig,ax = plt.subplots(figsize=(10,7))
ax.plot(validate["test_rmse"])

# %% [markdown]
# ### Benchmark algorithms

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SlopeOne(), KNNBaseline(), KNNWithMeans(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data_model, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
#               test_rmse  fit_time  test_time
# Algorithm
# KNNWithMeans   0.240019  0.083025   0.452025
# SlopeOne       0.245035  0.015551   0.006710
# KNNBaseline    0.252890  0.090200   0.442280
# SVD            0.328585  0.129221   0.040414
# BaselineOnly   0.348353  0.004862   0.005412
# CoClustering   0.519342  0.153761   0.006218
