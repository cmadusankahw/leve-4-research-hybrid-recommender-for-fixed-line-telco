# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
voice_usage_info = pd.read_csv("data/VOICE_OUTGOING_CALL_USAGE_ONNET.csv")

voice_usage_info
# Out:
#        event_source                 event_source.hash  call_count  \
# 0         112074655  ba2cd0a629f9bd5acc9d7fcd89971dad          17
# 1         332284364  f36049a029726b88e7ccc0ac53cd966c          48
# 2         112074723  d7b523c1eba8e755b5c8a149f6562348          30
# 3         332284364  f36049a029726b88e7ccc0ac53cd966c          37
# 4         332284364  f36049a029726b88e7ccc0ac53cd966c          94
# ...             ...                               ...         ...
# 32164     382247076  8bce192f1a4cf21bcd65958a32f537ed           1
# 32165     382247139  6d219e6c2e086d6959f4d90cad121009           6
# 32166     382247139  6d219e6c2e086d6959f4d90cad121009          14
# 32167     382247139  6d219e6c2e086d6959f4d90cad121009           4
# 32168     382247139  6d219e6c2e086d6959f4d90cad121009          10
#
#        duration (seconds)  year month account_num  \
# 0                  6240.0      201912  0033241719
# 1                 10260.0      202004  0029874823
# 2                  6474.0      202005  0033259838
# 3                 12060.0      202005  0029874823
# 4                 24720.0      202006  0029874823
# ...                   ...         ...         ...
# 32164               393.0      201911  0030285325
# 32165              1070.0      202001  0037371559
# 32166              1695.0      202002  0037371559
# 32167              2340.0      202003  0037371559
# 32168              2400.0      202004  0037371559
#
#                        account_num.hash rtom_code location_code          msan  \
# 0      1cca6a8545b413f559cb2150db1e60d4     R-KON   WI-NWT-NODE  MSAG5200-ISL
# 1      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# 2      6c9c219e7478591ee675017aba34b105     R-KON  IDH-KGW-NODE  MSAG5200-ISL
# 3      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# 4      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# ...                                 ...       ...           ...           ...
# 32164  adf3f539cdcfd24b33c8ad83631f825a      R-PH   PH-AKG-NODE      MSAG5200
# 32165  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32166  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32167  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32168  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
#
#        equp_id  equp_index
# 0        48520           1
# 1        48003           1
# 2       619449           1
# 3        48003           1
# 4        48003           1
# ...        ...         ...
# 32164    43163           1
# 32165    43163           1
# 32166    43163           1
# 32167    43163           1
# 32168    43163           1
#
# [32169 rows x 12 columns]

# %%
# Handle null values
# Drop unnecessary cols
# Pivot by monthYear
# Usage rating Upload/Downlad/Duration - bucketizing/ add rating cols
# location grouping/bucketizing (consider 4 location cols)
# User profile dim table
# visualize and analyze data

# %%
voice_usage_info = voice_usage_info.drop_duplicates(["event_source.hash","year month"], keep="last")

voice_usage_info.shape
# Out:
# (32140, 12)

# %%
voice_usage_info = voice_usage_info.drop(['event_source','account_num'], axis=1)
voice_usage_info.rename(columns={'duration (seconds)': 'duration','year month':'year-month'}, inplace=True)
voice_usage_info
# Out:
#                       event_source.hash  call_count  duration  year-month  \
# 0      ba2cd0a629f9bd5acc9d7fcd89971dad          17    6240.0      201912
# 1      f36049a029726b88e7ccc0ac53cd966c          48   10260.0      202004
# 2      d7b523c1eba8e755b5c8a149f6562348          30    6474.0      202005
# 3      f36049a029726b88e7ccc0ac53cd966c          37   12060.0      202005
# 4      f36049a029726b88e7ccc0ac53cd966c          94   24720.0      202006
# ...                                 ...         ...       ...         ...
# 32164  8bce192f1a4cf21bcd65958a32f537ed           1     393.0      201911
# 32165  6d219e6c2e086d6959f4d90cad121009           6    1070.0      202001
# 32166  6d219e6c2e086d6959f4d90cad121009          14    1695.0      202002
# 32167  6d219e6c2e086d6959f4d90cad121009           4    2340.0      202003
# 32168  6d219e6c2e086d6959f4d90cad121009          10    2400.0      202004
#
#                        account_num.hash rtom_code location_code          msan  \
# 0      1cca6a8545b413f559cb2150db1e60d4     R-KON   WI-NWT-NODE  MSAG5200-ISL
# 1      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# 2      6c9c219e7478591ee675017aba34b105     R-KON  IDH-KGW-NODE  MSAG5200-ISL
# 3      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# 4      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# ...                                 ...       ...           ...           ...
# 32164  adf3f539cdcfd24b33c8ad83631f825a      R-PH   PH-AKG-NODE      MSAG5200
# 32165  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32166  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32167  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32168  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
#
#        equp_id  equp_index
# 0        48520           1
# 1        48003           1
# 2       619449           1
# 3        48003           1
# 4        48003           1
# ...        ...         ...
# 32164    43163           1
# 32165    43163           1
# 32166    43163           1
# 32167    43163           1
# 32168    43163           1
#
# [32140 rows x 10 columns]

# %%
voice_usage_info['duration'].fillna(0)
voice_usage_info['call_count'].fillna(0)
# Out:
# 0        17
# 1        48
# 2        30
# 3        37
# 4        94
#          ..
# 32164     1
# 32165     6
# 32166    14
# 32167     4
# 32168    10
# Name: call_count, Length: 32140, dtype: int64

# %%
voice_usage_info.isnull().sum(axis=0)
# Out:
# event_source.hash     0
# call_count            0
# duration             31
# year-month            0
# account_num.hash      0
# rtom_code             0
# location_code         0
# msan                  0
# equp_id               0
# equp_index            0
# dtype: int64

# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Usage Ranking
#
# - 1. Pivot by year-month
# - 2. Bin by Upload/Download/Duration
# - 3. Usage Rank
# - 4. Labling usage

# %%
voice_usage = voice_usage_info[['event_source.hash','account_num.hash','call_count','duration','year-month']]
voice_usage
# Out:
#                       event_source.hash                  account_num.hash  \
# 0      ba2cd0a629f9bd5acc9d7fcd89971dad  1cca6a8545b413f559cb2150db1e60d4
# 1      f36049a029726b88e7ccc0ac53cd966c  9cce11d3fb4e2be8a4f836907220e850
# 2      d7b523c1eba8e755b5c8a149f6562348  6c9c219e7478591ee675017aba34b105
# 3      f36049a029726b88e7ccc0ac53cd966c  9cce11d3fb4e2be8a4f836907220e850
# 4      f36049a029726b88e7ccc0ac53cd966c  9cce11d3fb4e2be8a4f836907220e850
# ...                                 ...                               ...
# 32164  8bce192f1a4cf21bcd65958a32f537ed  adf3f539cdcfd24b33c8ad83631f825a
# 32165  6d219e6c2e086d6959f4d90cad121009  7aa8c0a144b14c0d37d9b50e420c4773
# 32166  6d219e6c2e086d6959f4d90cad121009  7aa8c0a144b14c0d37d9b50e420c4773
# 32167  6d219e6c2e086d6959f4d90cad121009  7aa8c0a144b14c0d37d9b50e420c4773
# 32168  6d219e6c2e086d6959f4d90cad121009  7aa8c0a144b14c0d37d9b50e420c4773
#
#        call_count  duration  year-month
# 0              17    6240.0      201912
# 1              48   10260.0      202004
# 2              30    6474.0      202005
# 3              37   12060.0      202005
# 4              94   24720.0      202006
# ...           ...       ...         ...
# 32164           1     393.0      201911
# 32165           6    1070.0      202001
# 32166          14    1695.0      202002
# 32167           4    2340.0      202003
# 32168          10    2400.0      202004
#
# [32140 rows x 5 columns]

# %%
pivot_voice_usage_info = pd.pivot_table(voice_usage,index=['event_source.hash'],columns=['year-month'], aggfunc=np.sum, fill_value=0)
pivot_voice_usage_info
# Out:
#                                  call_count                              \
# year-month                           201908 201909 201910 201911 201912
# event_source.hash
# 00221451f705ebe26051158bb14f567a          3      0      0      0      0
# 002fb47f60400713c854b0f69ff78c0a          3      4     13      6      8
# 00567a4a3c474aca1ce5cd6570648932          4      0      0      0      0
# 00724ae2470df1ed0fe919800d02517d          0      0      0      0      0
# 007400db8afa996e788d23986739f3db          2      8      9      2      0
# ...                                     ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2          3     19     14     25      0
# ffb63ff99cf1354dff1da862f379da80         72     83     55     57     37
# ffd697d66cc01c8897ce3e37d693673a          0      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713         29     16     26     20     23
# ffee845c0caa320b55e31bb156827d16          0      1      0      2      2
#
#                                                                      ...  \
# year-month                       202001 202002 202003 202004 202005  ...
# event_source.hash                                                    ...
# 00221451f705ebe26051158bb14f567a      0      1      1      4      1  ...
# 002fb47f60400713c854b0f69ff78c0a      6      2      5     11     12  ...
# 00567a4a3c474aca1ce5cd6570648932      1      0      0      0      0  ...
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0  ...
# 007400db8afa996e788d23986739f3db     13      1      0      2      1  ...
# ...                                 ...    ...    ...    ...    ...  ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      4      2      7      0      0  ...
# ffb63ff99cf1354dff1da862f379da80     83     33     39     10     20  ...
# ffd697d66cc01c8897ce3e37d693673a      0      3      0      1      0  ...
# ffd96f173d6cd683bf3384bdc2f99713     23     31     26     31     16  ...
# ffee845c0caa320b55e31bb156827d16      3      2      6      8      2  ...
#
#                                  duration                                     \
# year-month                         201911 201912 202001 202002 202003 202004
# event_source.hash
# 00221451f705ebe26051158bb14f567a        0      0      0     35     25    253
# 002fb47f60400713c854b0f69ff78c0a      902   1639   1057    426   1474   1766
# 00567a4a3c474aca1ce5cd6570648932        0      0     60      0      0      0
# 00724ae2470df1ed0fe919800d02517d        0      0      0      0      0      0
# 007400db8afa996e788d23986739f3db      180      0   2100     60      0    188
# ...                                   ...    ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2     6709      0   4069   2127   1017      0
# ffb63ff99cf1354dff1da862f379da80     6240   3540   8160   3300   5040   1380
# ffd697d66cc01c8897ce3e37d693673a        0      0      0    255      0     15
# ffd96f173d6cd683bf3384bdc2f99713     3999   5154   7804   4437   7647   6516
# ffee845c0caa320b55e31bb156827d16      840    208    180    180    420    480
#
#
# year-month                       202005 202006 202007 202008
# event_source.hash
# 00221451f705ebe26051158bb14f567a     29     46     99      0
# 002fb47f60400713c854b0f69ff78c0a   2720   1757    756   1518
# 00567a4a3c474aca1ce5cd6570648932      0      0      0      0
# 00724ae2470df1ed0fe919800d02517d      0      0      0    933
# 007400db8afa996e788d23986739f3db    660    200      0      0
# ...                                 ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      0    266    272      0
# ffb63ff99cf1354dff1da862f379da80   1920   5640   7680   3360
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713   2846  11012   6245  10811
# ffee845c0caa320b55e31bb156827d16    120  12660   3600   1560
#
# [3307 rows x 26 columns]

# %%
# check for all zero cols
pivot_voice_usage_info.loc[pivot_voice_usage_info.index == 0.0]
# Out:
# Empty DataFrame
# Columns: [(call_count, 201908), (call_count, 201909), (call_count, 201910), (call_count, 201911), (call_count, 201912), (call_count, 202001), (call_count, 202002), (call_count, 202003), (call_count, 202004), (call_count, 202005), (call_count, 202006), (call_count, 202007), (call_count, 202008), (duration, 201908), (duration, 201909), (duration, 201910), (duration, 201911), (duration, 201912), (duration, 202001), (duration, 202002), (duration, 202003), (duration, 202004), (duration, 202005), (duration, 202006), (duration, 202007), (duration, 202008)]
# Index: []
#
# [0 rows x 26 columns]

# %%
pivot_voice_usage_info.columns
# Out:
# MultiIndex([('call_count', 201908),
#             ('call_count', 201909),
#             ('call_count', 201910),
#             ('call_count', 201911),
#             ('call_count', 201912),
#             ('call_count', 202001),
#             ('call_count', 202002),
#             ('call_count', 202003),
#             ('call_count', 202004),
#             ('call_count', 202005),
#             ('call_count', 202006),
#             ('call_count', 202007),
#             ('call_count', 202008),
#             (  'duration', 201908),
#             (  'duration', 201909),
#             (  'duration', 201910),
#             (  'duration', 201911),
#             (  'duration', 201912),
#             (  'duration', 202001),
#             (  'duration', 202002),
#             (  'duration', 202003),
#             (  'duration', 202004),
#             (  'duration', 202005),
#             (  'duration', 202006),
#             (  'duration', 202007),
#             (  'duration', 202008)],
#            names=[None, 'year-month'])

# %%
pivot_voice_usage_info.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#             call_count                                                  \
# year-month      201908      201909      201910      201911      201912
# count       3307.00000  3307.00000  3307.00000  3307.00000  3307.00000
# mean          33.82552    25.52404    40.33353    29.84971    32.82310
# std          208.94356   140.21727   226.50099   148.98619   219.34391
# min            0.00000     0.00000     0.00000     0.00000     0.00000
# 25%            1.00000     0.00000     1.00000     1.00000     1.00000
# 50%            7.00000     5.00000     8.00000     7.00000     7.00000
# 75%           23.00000    19.00000    26.00000    20.50000    23.00000
# max         8128.00000  4602.00000  6921.00000  5327.00000  9471.00000
#
#                                                                         ...  \
# year-month      202001      202002      202003      202004      202005  ...
# count       3307.00000  3307.00000  3307.00000  3307.00000  3307.00000  ...
# mean          31.85878    25.72725    26.82280    20.56456    16.33021  ...
# std          177.49614   131.21731   136.38522    95.03928    82.97547  ...
# min            0.00000     0.00000     0.00000     0.00000     0.00000  ...
# 25%            1.00000     1.00000     1.00000     0.00000     0.00000  ...
# 50%            7.00000     5.00000     7.00000     5.00000     4.00000  ...
# 75%           23.00000    19.00000    24.00000    19.00000    14.00000  ...
# max         7127.00000  4960.00000  5287.00000  3851.00000  3520.00000  ...
#
#                 duration                                             \
# year-month        201911         201912        202001        202002
# count         3307.00000     3307.00000    3307.00000    3307.00000
# mean          3846.05866     4180.64258    4272.88902    3486.17508
# std          17307.53612    25611.23849   21567.77370   15497.86124
# min              0.00000        0.00000       0.00000       0.00000
# 25%             10.50000       24.00000      22.50000       1.00000
# 50%            835.00000      900.00000     889.00000     667.00000
# 75%           3000.00000     3353.50000    3589.50000    2947.00000
# max         719717.00000  1218097.00000  968220.00000  641871.00000
#
#                                                                     \
# year-month        202003        202004        202005        202006
# count         3307.00000    3307.00000    3307.00000    3307.00000
# mean          4082.56486    3613.82280    2608.12186    4900.24856
# std          17433.74260   12170.65369    9868.54314   18555.28767
# min              0.00000       0.00000       0.00000       0.00000
# 25%             22.00000       0.00000       0.00000      60.00000
# 50%           1020.00000     720.00000     541.00000    1312.00000
# 75%           3869.50000    3610.00000    2520.00000    4728.00000
# max         742911.00000  477380.00000  409974.00000  783780.00000
#
#
# year-month        202007        202008
# count         3307.00000    3307.00000
# mean          4238.55579    3595.93045
# std          17479.33107   14462.33634
# min              0.00000       0.00000
# 25%              1.00000       9.00000
# 50%            900.00000     780.00000
# 75%           3718.00000    3084.50000
# max         736025.00000  559092.00000
#
# [8 rows x 26 columns]

# %%
voice_usage.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#         call_count       duration    year-month
# count  32140.00000    32109.00000   32140.00000
# mean      38.36139     5331.98633  201967.80884
# std      182.97132    21800.56032      46.09250
# min        1.00000        1.00000  201908.00000
# 25%        4.00000      540.00000  201911.00000
# 50%       12.00000     1776.00000  202002.00000
# 75%       29.00000     4740.00000  202005.00000
# max     9471.00000  1218097.00000  202008.00000

# %%
# binning call_count
count_bins = [0, 6,15, 30, 100,1200,2400,4800,9471]
for col in pivot_voice_usage_info['call_count'].columns:
    pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
pivot_voice_usage_info['call_count']
# Out:
# <ipython-input-14-5d85ff993919>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
# year-month                        201908  201909  201910  201911  201912  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       1       0       0       0       0
# 002fb47f60400713c854b0f69ff78c0a       1       1       2       1       2
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       1       2       2       1       0
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       1       3       2       3       0
# ffb63ff99cf1354dff1da862f379da80       4       4       4       4       4
# ffd697d66cc01c8897ce3e37d693673a       0       0       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       3       3       3       3       3
# ffee845c0caa320b55e31bb156827d16       0       1       0       1       1
#
# year-month                        202001  202002  202003  202004  202005  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       0       1       1       1       1
# 002fb47f60400713c854b0f69ff78c0a       1       1       1       2       2
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       2       1       0       1       1
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       1       1       2       0       0
# ffb63ff99cf1354dff1da862f379da80       4       4       4       2       3
# ffd697d66cc01c8897ce3e37d693673a       0       1       0       1       0
# ffd96f173d6cd683bf3384bdc2f99713       3       4       3       4       3
# ffee845c0caa320b55e31bb156827d16       1       1       1       2       1
#
# year-month                        202006  202007  202008
# event_source.hash
# 00221451f705ebe26051158bb14f567a       1       1       0
# 002fb47f60400713c854b0f69ff78c0a       2       1       1
# 00567a4a3c474aca1ce5cd6570648932       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       1
# 007400db8afa996e788d23986739f3db       1       0       0
# ...                                  ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       1       1       0
# ffb63ff99cf1354dff1da862f379da80       4       4       3
# ffd697d66cc01c8897ce3e37d693673a       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       4       3       4
# ffee845c0caa320b55e31bb156827d16       4       1       2
#
# [3307 rows x 13 columns]

# %%
# binning duration
duration_bins = [0, 600, 1800, 4800,16200,64800,240000,720000,1218097]
for col in pivot_voice_usage_info['duration'].columns:
    pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
pivot_voice_usage_info['duration']
# Out:
# <ipython-input-15-2693a7c15b15>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
# year-month                        201908  201909  201910  201911  201912  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       1       0       0       0       0
# 002fb47f60400713c854b0f69ff78c0a       3       2       2       2       2
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       1       2       1       1       0
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       1       3       3       4       0
# ffb63ff99cf1354dff1da862f379da80       4       4       4       4       3
# ffd697d66cc01c8897ce3e37d693673a       0       0       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       4       3       4       3       4
# ffee845c0caa320b55e31bb156827d16       0       1       0       2       1
#
# year-month                        202001  202002  202003  202004  202005  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a       0       1       1       1       1
# 002fb47f60400713c854b0f69ff78c0a       2       1       2       2       3
# 00567a4a3c474aca1ce5cd6570648932       1       0       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       0       0       0
# 007400db8afa996e788d23986739f3db       3       1       0       1       2
# ...                                  ...     ...     ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       3       3       2       0       0
# ffb63ff99cf1354dff1da862f379da80       4       3       4       2       3
# ffd697d66cc01c8897ce3e37d693673a       0       1       0       1       0
# ffd96f173d6cd683bf3384bdc2f99713       4       3       4       4       3
# ffee845c0caa320b55e31bb156827d16       1       1       1       1       1
#
# year-month                        202006  202007  202008
# event_source.hash
# 00221451f705ebe26051158bb14f567a       1       1       0
# 002fb47f60400713c854b0f69ff78c0a       2       2       2
# 00567a4a3c474aca1ce5cd6570648932       0       0       0
# 00724ae2470df1ed0fe919800d02517d       0       0       2
# 007400db8afa996e788d23986739f3db       1       0       0
# ...                                  ...     ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2       1       1       0
# ffb63ff99cf1354dff1da862f379da80       4       4       3
# ffd697d66cc01c8897ce3e37d693673a       0       0       0
# ffd96f173d6cd683bf3384bdc2f99713       4       4       4
# ffee845c0caa320b55e31bb156827d16       4       3       2
#
# [3307 rows x 13 columns]

# %%
year_month_list = pivot_voice_usage_info['call_count'].columns

# %%
# multplying bins to get usage rating
for col in year_month_list:
    pivot_voice_usage_info[col] = pivot_voice_usage_info['call_count'][col]  * pivot_voice_usage_info['duration'][col]

# %% [markdown]
# ## ToDO
# - find a different approach other than product

# %% [markdown]
# ### Justification
# - https://www.researchgate.net/post/Can-I-combine-2-independent-variable-as-one-variable-in-a-model-Can-I-still-include-the-individual-variable-in-the-same-model-after-combing-the-two
# - http://www.utstat.toronto.edu/~brunner/DataAnalysisText/Interactions.pdf
#
# ### More advanced methods
# - Dimension reduction approaches?

# %% [markdown]
# ### Usage ratings for year-month

# %%
pivot_voice_usage_info = pivot_voice_usage_info.drop(['call_count','duration'], axis=1)
pivot_voice_usage_info
# Out:
#                                  201908 201909 201910 201911 201912 202001  \
# year-month
# event_source.hash
# 00221451f705ebe26051158bb14f567a      1      0      0      0      0      0
# 002fb47f60400713c854b0f69ff78c0a      3      2      4      2      4      2
# 00567a4a3c474aca1ce5cd6570648932      1      0      0      0      0      1
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0      0
# 007400db8afa996e788d23986739f3db      1      4      2      1      0      6
# ...                                 ...    ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      1      9      6     12      0      3
# ffb63ff99cf1354dff1da862f379da80     16     16     16     16     12     16
# ffd697d66cc01c8897ce3e37d693673a      0      0      0      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713     12      9     12      9     12     12
# ffee845c0caa320b55e31bb156827d16      0      1      0      2      1      1
#
#                                  202002 202003 202004 202005 202006 202007  \
# year-month
# event_source.hash
# 00221451f705ebe26051158bb14f567a      1      1      1      1      1      1
# 002fb47f60400713c854b0f69ff78c0a      1      2      4      6      4      2
# 00567a4a3c474aca1ce5cd6570648932      0      0      0      0      0      0
# 00724ae2470df1ed0fe919800d02517d      0      0      0      0      0      0
# 007400db8afa996e788d23986739f3db      1      0      1      2      1      0
# ...                                 ...    ...    ...    ...    ...    ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      3      4      0      0      1      1
# ffb63ff99cf1354dff1da862f379da80     12     16      4      9     16     16
# ffd697d66cc01c8897ce3e37d693673a      1      0      1      0      0      0
# ffd96f173d6cd683bf3384bdc2f99713     12     12     16      9     16     12
# ffee845c0caa320b55e31bb156827d16      1      1      2      1     16      3
#
#                                  202008
# year-month
# event_source.hash
# 00221451f705ebe26051158bb14f567a      0
# 002fb47f60400713c854b0f69ff78c0a      2
# 00567a4a3c474aca1ce5cd6570648932      0
# 00724ae2470df1ed0fe919800d02517d      2
# 007400db8afa996e788d23986739f3db      0
# ...                                 ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2      0
# ffb63ff99cf1354dff1da862f379da80      9
# ffd697d66cc01c8897ce3e37d693673a      0
# ffd96f173d6cd683bf3384bdc2f99713     16
# ffee845c0caa320b55e31bb156827d16      4
#
# [3307 rows x 13 columns]

# %%
pivot_voice_usage_info.T.reset_index(drop=True).T
pivot_voice_usage_info.columns=year_month_list

# %%
# scaling usage rating
scaler = MinMaxScaler()
for col in year_month_list:
    pivot_voice_usage_info[col] = scaler.fit_transform(pivot_voice_usage_info[col].values.reshape(-1,1))

# %%
sns.heatmap(pivot_voice_usage_info[year_month_list].sample(n=10), annot=True)
# Out:
# <AxesSubplot:xlabel='year-month', ylabel='event_source.hash'>

# %%
pivot_voice_usage_info['Usage_Rating_Scaled'] = pivot_voice_usage_info[year_month_list].sum(axis=1)/len(year_month_list)
pivot_voice_usage_info
# Out:
# year-month                          201908    201909   201910    201911  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.015625  0.000000  0.00000  0.000000
# 002fb47f60400713c854b0f69ff78c0a  0.046875  0.040816  0.06250  0.035714
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.000000  0.00000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.00000  0.000000
# 007400db8afa996e788d23986739f3db  0.015625  0.081633  0.03125  0.017857
# ...                                    ...       ...      ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.015625  0.183673  0.09375  0.214286
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.326531  0.25000  0.285714
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.00000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.183673  0.18750  0.160714
# ffee845c0caa320b55e31bb156827d16  0.000000  0.020408  0.00000  0.035714
#
# year-month                          201912    202001    202002    202003  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.000000  0.000000  0.017857  0.015625
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.031250  0.017857  0.031250
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.015625  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.000000  0.093750  0.017857  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.046875  0.053571  0.062500
# ffb63ff99cf1354dff1da862f379da80  0.187500  0.250000  0.214286  0.250000
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.017857  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.187500  0.214286  0.187500
# ffee845c0caa320b55e31bb156827d16  0.015625  0.015625  0.017857  0.015625
#
# year-month                          202004    202005    202006    202007  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.020408  0.020408  0.015625  0.015625
# 002fb47f60400713c854b0f69ff78c0a  0.081633  0.122449  0.062500  0.031250
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.020408  0.040816  0.015625  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.000000  0.015625  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.081633  0.183673  0.250000  0.250000
# ffd697d66cc01c8897ce3e37d693673a  0.020408  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.326531  0.183673  0.250000  0.187500
# ffee845c0caa320b55e31bb156827d16  0.040816  0.020408  0.250000  0.046875
#
# year-month                          202008  Usage_Rating_Scaled
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.000000             0.009321
# 002fb47f60400713c854b0f69ff78c0a  0.040816             0.051339
# 00567a4a3c474aca1ce5cd6570648932  0.000000             0.002404
# 00724ae2470df1ed0fe919800d02517d  0.040816             0.003140
# 007400db8afa996e788d23986739f3db  0.000000             0.025755
# ...                                    ...                  ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000             0.053964
# ffb63ff99cf1354dff1da862f379da80  0.183673             0.227924
# ffd697d66cc01c8897ce3e37d693673a  0.000000             0.002943
# ffd96f173d6cd683bf3384bdc2f99713  0.326531             0.213108
# ffee845c0caa320b55e31bb156827d16  0.081633             0.043122
#
# [3307 rows x 14 columns]

# %% [markdown]
# ### Finding Outliers

# %%
pivot_voice_usage_info.boxplot(column=[int(x) for x in year_month_list], rot=90)
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(data=pivot_voice_usage_info[[int(x) for x in year_month_list]], orient="h", palette="Set2")
ax
# Out:
# <AxesSubplot:ylabel='year-month'>

# %% [markdown]
# ## Three quantitative methods commonly used in statistics for the detection of univariate outliers:
# - Tukey’s box plot method
# - Internally studentized residuals (AKA z-score method)
# - Median Absolute Deviation method

# %% [markdown]
# ### 1) Tukey’s box plot method
# - Tukey distinguishes between possible and probable outliers. A possible outlier is located between the inner and the outer fence, whereas a probable outlier is located outside the outer fence.
#
# - IQR =Q3 - Q1, whereas q3 := 75th quartile and q1 := 25th quartile
# - Inner fence = [Q1-1.5*IQR, Q3+1.5*IQR]
# - Outer fence = [Q1–3*IQR, Q3+3*IQR]

# %%
#Tukey's method
def tukeys_method(df, variable):
    #Takes two parameters: dataframe & variable of interest as string
    q1 = df[variable].quantile(0.25)
    q3 = df[variable].quantile(0.75)
    iqr = q3-q1
    inner_fence = 1.5*iqr
    outer_fence = 3*iqr
    
    #inner fence lower and upper end
    inner_fence_le = q1-inner_fence
    inner_fence_ue = q3+inner_fence
    
    #outer fence lower and upper end
    outer_fence_le = q1-outer_fence
    outer_fence_ue = q3+outer_fence
    
    outliers_prob = []
    outliers_poss = []
    outliers_prob_indexes = []
    outliers_poss_indexes = []
    for index, x in enumerate(df[variable]):
        if x <= outer_fence_le or x >= outer_fence_ue:
            outliers_prob_indexes.append(index)
            outliers_prob.append(x)
    for index, x in enumerate(df[variable]):
        if x <= inner_fence_le or x >= inner_fence_ue:
            outliers_poss_indexes.append(index)
            outliers_poss.append(x)
    # returns indexes of the rows with outliers
    return outliers_prob, outliers_prob_indexes, outliers_poss, outliers_poss_indexes

# %%
pr_col_threshold = []
po_col_threshold = []
for col in year_month_list:
    pr_col, pr_col_indexes, po_col, po_col_indexes = tukeys_method(pivot_voice_usage_info, int(col))
    pr_col_threshold.append({col: {"threshold": min(pr_col), "count": len(pr_col)}})
    po_col_threshold.append({col: {"threshold": min(po_col), "count": len(po_col)}})
    print()
    print(f"Probable Outliers for {col}---->\n", pr_col)
    print(len(pr_col))
    print()
    print(f"Possible Outliers for {col}----->\n", po_col)
    print(len(po_col))
    print()
# Out:
# Probable Outliers for 201908---->
#  [0.765625, 0.5625, 0.5625, 0.5625, 1.0, 0.875, 0.765625, 0.5625]
# 8
#
# Possible Outliers for 201908----->
#  [0.765625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.46875, 0.46875, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 1.0, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.375, 0.46875, 0.46875, 0.390625, 0.390625, 0.875, 0.46875, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.765625, 0.5625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625]
# 102
#
#
# Probable Outliers for 201909---->
#  [0.9999999999999999, 0.7346938775510203, 0.7346938775510203, 0.9999999999999999, 0.9999999999999999, 0.7346938775510203, 0.9999999999999999]
# 7
#
# Possible Outliers for 201909----->
#  [0.9999999999999999, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.9999999999999999, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.9999999999999999, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.7346938775510203, 0.9999999999999999, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531]
# 81
#
#
# Probable Outliers for 201910---->
#  [0.765625, 0.65625, 0.5625, 0.765625, 0.65625, 0.5625, 1.0, 0.65625, 0.765625, 0.5625, 0.875]
# 11
#
# Possible Outliers for 201910----->
#  [0.765625, 0.390625, 0.65625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.765625, 0.390625, 0.46875, 0.390625, 0.390625, 0.65625, 0.390625, 0.5625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 1.0, 0.390625, 0.65625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.765625, 0.46875, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.46875, 0.46875, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.5625, 0.875, 0.390625, 0.390625, 0.46875, 0.390625, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625]
# 120
#
#
# Probable Outliers for 201911---->
#  [0.875, 0.6428571428571428, 0.75, 0.6428571428571428, 0.6428571428571428, 1.0, 0.875, 0.6428571428571428]
# 8
#
# Possible Outliers for 201911----->
#  [0.4464285714285714, 0.875, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.6428571428571428, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.75, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.6428571428571428, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.6428571428571428, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 1.0, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.875, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.6428571428571428, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714]
# 92
#
#
# Probable Outliers for 201912---->
#  [0.765625, 0.5625, 0.765625, 1.0, 0.765625, 0.765625, 0.5625]
# 7
#
# Possible Outliers for 201912----->
#  [0.765625, 0.46875, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.765625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 1.0, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.46875, 0.390625, 0.765625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.765625, 0.390625, 0.390625, 0.5625, 0.46875, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625]
# 95
#
#
# Probable Outliers for 202001---->
#  [0.765625, 0.5625, 0.5625, 0.5625, 0.765625, 1.0, 0.765625, 0.5625]
# 8
#
# Possible Outliers for 202001----->
#  [0.390625, 0.765625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.765625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 1.0, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.375, 0.390625, 0.390625, 0.765625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.5625, 0.390625, 0.390625, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625]
# 97
#
#
# Probable Outliers for 202002---->
#  [0.6428571428571428, 0.6428571428571428, 0.6428571428571428, 1.0, 0.875, 0.6428571428571428]
# 6
#
# Possible Outliers for 202002----->
#  [0.6428571428571428, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.6428571428571428, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.6428571428571428, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 1.0, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.875, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.6428571428571428, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.5357142857142857, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714, 0.4464285714285714]
# 86
#
#
# Probable Outliers for 202003---->
#  [0.765625, 0.5625, 0.5625, 1.0, 0.765625, 0.5625, 0.5625]
# 7
#
# Possible Outliers for 202003----->
#  [0.765625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 1.0, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.765625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625]
# 84
#
#
# Probable Outliers for 202004---->
#  [0.7346938775510203, 0.7346938775510203, 0.9999999999999999, 0.7346938775510203]
# 4
#
# Possible Outliers for 202004----->
#  [0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.7346938775510203, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.9999999999999999, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.4897959183673469]
# 62
#
#
# Probable Outliers for 202005---->
#  [0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.6122448979591836, 0.5102040816326531, 0.9999999999999999, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531]
# 37
#
# Possible Outliers for 202005----->
#  [0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.7346938775510203, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.4081632653061224, 0.4081632653061224, 0.32653061224489793, 0.4081632653061224, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.6122448979591836, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.4081632653061224, 0.32653061224489793, 0.4081632653061224, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.4081632653061224, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.5102040816326531, 0.32653061224489793, 0.6122448979591836, 0.4081632653061224, 0.32653061224489793, 0.6122448979591836, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.9999999999999999, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.32653061224489793, 0.4081632653061224, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.5102040816326531, 0.32653061224489793, 0.4081632653061224, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.6122448979591836, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.5102040816326531, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.5102040816326531, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.5102040816326531, 0.4081632653061224, 0.32653061224489793, 0.6122448979591836, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.5102040816326531, 0.32653061224489793, 0.6122448979591836, 0.4081632653061224, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.32653061224489793, 0.4081632653061224, 0.4081632653061224, 0.4081632653061224, 0.32653061224489793, 0.5102040816326531, 0.4081632653061 ...
# 263
#
#
# Probable Outliers for 202006---->
#  [0.765625, 1.0, 0.765625]
# 3
#
# Possible Outliers for 202006----->
#  [0.765625, 0.5625, 0.46875, 0.46875, 0.65625, 0.46875, 0.46875, 1.0, 0.46875, 0.46875, 0.46875, 0.765625, 0.46875, 0.46875, 0.5625, 0.46875, 0.46875, 0.46875, 0.46875]
# 19
#
#
# Probable Outliers for 202007---->
#  [0.765625, 0.5625, 0.5625, 0.5625, 0.5625, 1.0, 0.65625, 0.5625]
# 8
#
# Possible Outliers for 202007----->
#  [0.765625, 0.46875, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.390625, 0.390625, 0.390625, 1.0, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.375, 0.390625, 0.390625, 0.65625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.5625, 0.46875, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.46875, 0.390625, 0.390625, 0.390625, 0.390625, 0.390625]
# 95
#
#
# Probable Outliers for 202008---->
#  [0.9999999999999999, 0.7346938775510203, 0.7346938775510203, 0.9999999999999999, 0.7346938775510203]
# 5
#
# Possible Outliers for 202008----->
#  [0.5102040816326531, 0.9999999999999999, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.9999999999999999, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.4897959183673469, 0.5102040816326531, 0.7346938775510203, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531, 0.6122448979591836, 0.6122448979591836, 0.5102040816326531, 0.5102040816326531, 0.5102040816326531]
# 85

# %%
pr_col_threshold
# Out:
# [{201908: {'threshold': 0.5625, 'count': 8}},
#  {201909: {'threshold': 0.7346938775510203, 'count': 7}},
#  {201910: {'threshold': 0.5625, 'count': 11}},
#  {201911: {'threshold': 0.6428571428571428, 'count': 8}},
#  {201912: {'threshold': 0.5625, 'count': 7}},
#  {202001: {'threshold': 0.5625, 'count': 8}},
#  {202002: {'threshold': 0.6428571428571428, 'count': 6}},
#  {202003: {'threshold': 0.5625, 'count': 7}},
#  {202004: {'threshold': 0.7346938775510203, 'count': 4}},
#  {202005: {'threshold': 0.5102040816326531, 'count': 37}},
#  {202006: {'threshold': 0.765625, 'count': 3}},
#  {202007: {'threshold': 0.5625, 'count': 8}},
#  {202008: {'threshold': 0.7346938775510203, 'count': 5}}]

# %%
po_col_threshold
# Out:
# [{201908: {'threshold': 0.375, 'count': 102}},
#  {201909: {'threshold': 0.5102040816326531, 'count': 81}},
#  {201910: {'threshold': 0.390625, 'count': 120}},
#  {201911: {'threshold': 0.4464285714285714, 'count': 92}},
#  {201912: {'threshold': 0.390625, 'count': 95}},
#  {202001: {'threshold': 0.375, 'count': 97}},
#  {202002: {'threshold': 0.4464285714285714, 'count': 86}},
#  {202003: {'threshold': 0.390625, 'count': 84}},
#  {202004: {'threshold': 0.4897959183673469, 'count': 62}},
#  {202005: {'threshold': 0.32653061224489793, 'count': 263}},
#  {202006: {'threshold': 0.46875, 'count': 19}},
#  {202007: {'threshold': 0.375, 'count': 95}},
#  {202008: {'threshold': 0.4897959183673469, 'count': 85}}]

# %% [markdown]
# ### 2) Median Absolute Deviation method
# - this method is highly limited as the distributions mean and standard deviation are sensitive to outliers. This means that finding one outlier is dependent on other outliers as every observation directly affects the mean.
# ![image.png](attachment:image.png)

# %%
from scipy import stats

# MAD method
def mad_method(df, variable_name):
    #Takes two parameters: dataframe & variable of interest as string
    columns = df.columns
    med = np.median(df, axis = 0)
    mad = np.abs(stats.median_absolute_deviation(df))
    threshold = 3
    outlier = []
    index=0
    for item in range(len(columns)):
        if columns[item] == variable_name:
            index == item
    for i, v in enumerate(df.loc[:,variable_name]):
        t = (v-med[index])/mad[index]
        if t > threshold:
            outlier.append(i)
        else:
            continue
    return outlier

# %%
col_threshold = []
for col in year_month_list:
    outliers = mad_method(pivot_voice_usage_info, int(col))
    outlier_cols = pivot_voice_usage_info[int(col)].iloc[outliers]
    col_threshold.append({col: {"threshold" :min(outlier_cols), "count":len(outliers)}})
    print()
    print(f"Outliers for {col}---->\n", outlier_cols)
    print(len(outliers))
# Out:
# Outliers for 201908---->
#  event_source.hash
# 00d4474d7b8abcb71cc114a564769182    0.312500
# 029b57551e576f248ff07c849db52fd6    0.312500
# 03d189e698bac53767b82645f582d574    0.765625
# 048f304256dc532c9aa79b434ab5ee2e    0.390625
# 06b3c8e2e60e881a571273d35220b8a5    0.312500
#                                       ...
# f937cc06caf1660ee9ed382a510a6688    0.312500
# fa7e0de5a952b8d187a904649eafcc76    0.390625
# facfe99fff1a63941380ad952a055621    0.390625
# fc9f73eca9b4fdcfd714154b613b5917    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.390625
# Name: 201908, Length: 196, dtype: float64
# 196
#
# Outliers for 201909---->
#  event_source.hash
# 0074ca4eb00b4faae08701181b27895b    0.326531
# 009f305bf85a71012c0e343233e611ba    0.326531
# 00d4474d7b8abcb71cc114a564769182    0.408163
# 03c567a2c97746f2545c0f9b8285827c    0.326531
# 03d189e698bac53767b82645f582d574    1.000000
#                                       ...
# fd5e924e4c60a31db58620fd58f3cdc8    0.326531
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.408163
# ff445f580f7525bd9f1455d6b09704cd    0.326531
# ff7e0f4edb7b39b683b9134af37fc4d3    0.326531
# ffb63ff99cf1354dff1da862f379da80    0.326531
# Name: 201909, Length: 365, dtype: float64
# 365
#
# Outliers for 201910---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.312500
# 00d4474d7b8abcb71cc114a564769182    0.312500
# 03d189e698bac53767b82645f582d574    0.765625
# 0480fbc41f1ab2d73ea50c0dda53b89e    0.312500
# 048f304256dc532c9aa79b434ab5ee2e    0.390625
#                                       ...
# fc9f73eca9b4fdcfd714154b613b5917    0.390625
# fd4d35bafb701dad8d3418e8c56d548b    0.312500
# fd5e924e4c60a31db58620fd58f3cdc8    0.312500
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.390625
# ff7e0f4edb7b39b683b9134af37fc4d3    0.312500
# Name: 201910, Length: 226, dtype: float64
# 226
#
# Outliers for 201911---->
#  event_source.hash
# 0074ca4eb00b4faae08701181b27895b    0.285714
# 009f305bf85a71012c0e343233e611ba    0.446429
# 00a8c3e3baed0557c31ab9b68a086ed2    0.285714
# 00d4474d7b8abcb71cc114a564769182    0.357143
# 029c7817843470cd12b4b673d95ef6e3    0.285714
#                                       ...
# fc9f73eca9b4fdcfd714154b613b5917    0.357143
# fd4d35bafb701dad8d3418e8c56d548b    0.285714
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.357143
# ff7e0f4edb7b39b683b9134af37fc4d3    0.285714
# ffb63ff99cf1354dff1da862f379da80    0.285714
# Name: 201911, Length: 416, dtype: float64
# 416
#
# Outliers for 201912---->
#  event_source.hash
# 00d4474d7b8abcb71cc114a564769182    0.312500
# 03d189e698bac53767b82645f582d574    0.765625
# 0480fbc41f1ab2d73ea50c0dda53b89e    0.312500
# 04ec40da46c6ca65064a371a0a695f74    0.312500
# 06b3c8e2e60e881a571273d35220b8a5    0.312500
#                                       ...
# f937cc06caf1660ee9ed382a510a6688    0.312500
# fa7e0de5a952b8d187a904649eafcc76    0.390625
# fc9f73eca9b4fdcfd714154b613b5917    0.390625
# fd4d35bafb701dad8d3418e8c56d548b    0.312500
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.390625
# Name: 201912, Length: 182, dtype: float64
# 182
#
# Outliers for 202001---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.390625
# 00d4474d7b8abcb71cc114a564769182    0.312500
# 03d189e698bac53767b82645f582d574    0.765625
# 048f304256dc532c9aa79b434ab5ee2e    0.390625
# 04ec40da46c6ca65064a371a0a695f74    0.312500
#                                       ...
# f937cc06caf1660ee9ed382a510a6688    0.312500
# f96b3eb3b3ab32ffea88ce41c87ec0b0    0.312500
# fa7e0de5a952b8d187a904649eafcc76    0.390625
# fc9f73eca9b4fdcfd714154b613b5917    0.312500
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.390625
# Name: 202001, Length: 185, dtype: float64
# 185
#
# Outliers for 202002---->
#  event_source.hash
# 0074ca4eb00b4faae08701181b27895b    0.285714
# 009f305bf85a71012c0e343233e611ba    0.285714
# 00d4474d7b8abcb71cc114a564769182    0.357143
# 029c7817843470cd12b4b673d95ef6e3    0.285714
# 03bb72cb05e85b1d3f1d62291ad5804c    0.285714
#                                       ...
# fc9f73eca9b4fdcfd714154b613b5917    0.357143
# fd5e924e4c60a31db58620fd58f3cdc8    0.285714
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.357143
# fe0bea5ee8cbf5765fb5d29e0423fdcc    0.285714
# ff7e0f4edb7b39b683b9134af37fc4d3    0.285714
# Name: 202002, Length: 386, dtype: float64
# 386
#
# Outliers for 202003---->
#  event_source.hash
# 00d4474d7b8abcb71cc114a564769182    0.312500
# 03d189e698bac53767b82645f582d574    0.765625
# 06b3c8e2e60e881a571273d35220b8a5    0.312500
# 06b93cc32b6bfdbc24ab9c6df1da3d0b    0.390625
# 07a45a5c0b544c8f79f659c2c00c4c26    0.390625
#                                       ...
# f937cc06caf1660ee9ed382a510a6688    0.312500
# fa7e0de5a952b8d187a904649eafcc76    0.390625
# fbfe5e170af1fae88a0bc64d5c6254dc    0.312500
# fc9f73eca9b4fdcfd714154b613b5917    0.312500
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.312500
# Name: 202003, Length: 193, dtype: float64
# 193
#
# Outliers for 202004---->
#  event_source.hash
# 00d4474d7b8abcb71cc114a564769182    0.326531
# 029c7817843470cd12b4b673d95ef6e3    0.326531
# 036693531286a8e2ce75dff2e49b144c    0.510204
# 03bb72cb05e85b1d3f1d62291ad5804c    0.326531
# 03c567a2c97746f2545c0f9b8285827c    0.326531
#                                       ...
# fd8f915fb9e178a110b7b179aac85b08    0.326531
# ff1093d5ef61bf46f8c88e9b7614e311    0.326531
# ff68d8c56f7fe78efb4d01ccb40c8ff3    0.408163
# ff7e0f4edb7b39b683b9134af37fc4d3    0.326531
# ffd96f173d6cd683bf3384bdc2f99713    0.326531
# Name: 202004, Length: 438, dtype: float64
# 438
#
# Outliers for 202005---->
#  event_source.hash
# 00d4474d7b8abcb71cc114a564769182    0.326531
# 029c7817843470cd12b4b673d95ef6e3    0.326531
# 036693531286a8e2ce75dff2e49b144c    0.510204
# 03d189e698bac53767b82645f582d574    0.734694
# 0480fbc41f1ab2d73ea50c0dda53b89e    0.326531
#                                       ...
# facfe99fff1a63941380ad952a055621    0.326531
# fb5b5d2333b68e9f1ff6c4bd6f208a81    0.326531
# fe755bf21b5abbfa6cbe808e1f99d55a    0.326531
# ff1093d5ef61bf46f8c88e9b7614e311    0.326531
# ff7e0f4edb7b39b683b9134af37fc4d3    0.408163
# Name: 202005, Length: 272, dtype: float64
# 272
#
# Outliers for 202006---->
#  event_source.hash
# 00d4474d7b8abcb71cc114a564769182    0.312500
# 03d189e698bac53767b82645f582d574    0.765625
# 04c1837672928bdbbf936eac43f5aeac    0.312500
# 05be9be55a8a24c5ee0a7004f04e53f3    0.312500
# 063f3be0a6af9f777434429112257c03    0.312500
#                                       ...
# facfe99fff1a63941380ad952a055621    0.390625
# fbfe5e170af1fae88a0bc64d5c6254dc    0.312500
# fc9f73eca9b4fdcfd714154b613b5917    0.390625
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.390625
# ff68d8c56f7fe78efb4d01ccb40c8ff3    0.312500
# Name: 202006, Length: 250, dtype: float64
# 250
#
# Outliers for 202007---->
#  event_source.hash
# 03d189e698bac53767b82645f582d574    0.765625
# 04ec40da46c6ca65064a371a0a695f74    0.312500
# 05be9be55a8a24c5ee0a7004f04e53f3    0.312500
# 06b93cc32b6bfdbc24ab9c6df1da3d0b    0.468750
# 07a45a5c0b544c8f79f659c2c00c4c26    0.312500
#                                       ...
# fa7e0de5a952b8d187a904649eafcc76    0.390625
# facfe99fff1a63941380ad952a055621    0.312500
# fb5b5d2333b68e9f1ff6c4bd6f208a81    0.312500
# fc9f73eca9b4fdcfd714154b613b5917    0.312500
# fdf1cca1f96ccf2fdf7426b6bd74309e    0.312500
# Name: 202007, Length: 197, dtype: float64
# 197
#
# Outliers for 202008---->
#  event_source.hash
# 009f305bf85a71012c0e343233e611ba    0.326531
# 00a8c3e3baed0557c31ab9b68a086ed2    0.326531
# 00d4474d7b8abcb71cc114a564769182    0.326531
# 029c7817843470cd12b4b673d95ef6e3    0.326531
# 02d8213d352d3e2cc30fb98249cf5c89    0.510204
#                                       ...
# fe755bf21b5abbfa6cbe808e1f99d55a    0.326531
# ff1093d5ef61bf46f8c88e9b7614e311    0.408163
# ff68d8c56f7fe78efb4d01ccb40c8ff3    0.326531
# ff7e0f4edb7b39b683b9134af37fc4d3    0.326531
# ffd96f173d6cd683bf3384bdc2f99713    0.326531
# Name: 202008, Length: 395, dtype: float64
# 395
# <ipython-input-29-ab658f4f8d27>:8: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# `scipy.stats.median_abs_deviation(..., scale=1/1.4826)`.
# The value 1.4826 is not numerically precise for scaling
# with a normal distribution. For a numerically precise value, use
# `scipy.stats.median_abs_deviation(..., scale='normal')`.
#
#   mad = np.abs(stats.median_absolute_deviation(df))

# %%
col_threshold
# Out:
# [{201908: {'threshold': 0.3125, 'count': 196}},
#  {201909: {'threshold': 0.3061224489795918, 'count': 365}},
#  {201910: {'threshold': 0.3125, 'count': 226}},
#  {201911: {'threshold': 0.26785714285714285, 'count': 416}},
#  {201912: {'threshold': 0.3125, 'count': 182}},
#  {202001: {'threshold': 0.3125, 'count': 185}},
#  {202002: {'threshold': 0.26785714285714285, 'count': 386}},
#  {202003: {'threshold': 0.3125, 'count': 193}},
#  {202004: {'threshold': 0.3061224489795918, 'count': 438}},
#  {202005: {'threshold': 0.3061224489795918, 'count': 272}},
#  {202006: {'threshold': 0.3125, 'count': 250}},
#  {202007: {'threshold': 0.3125, 'count': 197}},
#  {202008: {'threshold': 0.3061224489795918, 'count': 395}}]

# %%
sum_outlier = 0
for col in col_threshold:
    for key,val in col.items():
        sum_outlier += val["threshold"]
avg_outlier = sum_outlier / len(col_threshold)
pivot_voice_usage_info["Outlier"]=pivot_voice_usage_info.apply(lambda x : "YES" if x["Usage_Rating_Scaled"]> avg_outlier else "NO", axis=1)
print(avg_outlier)
# Out:
# 0.30366954474097335

# %%
pivot_voice_usage_info.describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       3307.000000  3307.000000  3307.000000  3307.000000  3307.000000
# mean           0.089228     0.101529     0.097138     0.096565     0.089531
# std            0.107860     0.129516     0.113206     0.118155     0.106134
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.015625     0.000000     0.015625     0.017857     0.015625
# 50%            0.046875     0.040816     0.062500     0.035714     0.046875
# 75%            0.140625     0.183673     0.140625     0.160714     0.140625
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       3307.000000  3307.000000  3307.000000  3307.000000  3307.000000
# mean           0.089937     0.091597     0.092824     0.106120     0.086064
# std            0.106908     0.115365     0.106590     0.131524     0.113485
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.015625     0.017857     0.015625     0.000000     0.000000
# 50%            0.046875     0.035714     0.062500     0.040816     0.040816
# 75%            0.140625     0.160714     0.140625     0.183673     0.122449
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202006       202007       202008  Usage_Rating_Scaled
# count       3307.000000  3307.000000  3307.000000          3307.000000
# mean           0.103667     0.090239     0.106243             0.095437
# std            0.113178     0.107246     0.131478             0.102268
# min            0.000000     0.000000     0.000000             0.001202
# 25%            0.015625     0.015625     0.020408             0.017624
# 50%            0.062500     0.031250     0.040816             0.056907
# 75%            0.187500     0.140625     0.183673             0.147321
# max            1.000000     1.000000     1.000000             1.000000

# %%
# labling usage bins
bins = [0, 0.08, 0.3,1]
labels = ['LOW','MEDIUM','HIGH']
pivot_voice_usage_info['Usage_Rating_Categorical'] = pd.cut(pivot_voice_usage_info['Usage_Rating_Scaled'], bins=bins, labels=labels)
pivot_voice_usage_info
# Out:
# year-month                          201908    201909   201910    201911  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.015625  0.000000  0.00000  0.000000
# 002fb47f60400713c854b0f69ff78c0a  0.046875  0.040816  0.06250  0.035714
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.000000  0.00000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.00000  0.000000
# 007400db8afa996e788d23986739f3db  0.015625  0.081633  0.03125  0.017857
# ...                                    ...       ...      ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.015625  0.183673  0.09375  0.214286
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.326531  0.25000  0.285714
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.00000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.183673  0.18750  0.160714
# ffee845c0caa320b55e31bb156827d16  0.000000  0.020408  0.00000  0.035714
#
# year-month                          201912    202001    202002    202003  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.000000  0.000000  0.017857  0.015625
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.031250  0.017857  0.031250
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.015625  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.000000  0.093750  0.017857  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.046875  0.053571  0.062500
# ffb63ff99cf1354dff1da862f379da80  0.187500  0.250000  0.214286  0.250000
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.017857  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.187500  0.214286  0.187500
# ffee845c0caa320b55e31bb156827d16  0.015625  0.015625  0.017857  0.015625
#
# year-month                          202004    202005    202006    202007  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.020408  0.020408  0.015625  0.015625
# 002fb47f60400713c854b0f69ff78c0a  0.081633  0.122449  0.062500  0.031250
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.020408  0.040816  0.015625  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.000000  0.015625  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.081633  0.183673  0.250000  0.250000
# ffd697d66cc01c8897ce3e37d693673a  0.020408  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.326531  0.183673  0.250000  0.187500
# ffee845c0caa320b55e31bb156827d16  0.040816  0.020408  0.250000  0.046875
#
# year-month                          202008  Usage_Rating_Scaled Outlier  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.000000             0.009321      NO
# 002fb47f60400713c854b0f69ff78c0a  0.040816             0.051339      NO
# 00567a4a3c474aca1ce5cd6570648932  0.000000             0.002404      NO
# 00724ae2470df1ed0fe919800d02517d  0.040816             0.003140      NO
# 007400db8afa996e788d23986739f3db  0.000000             0.025755      NO
# ...                                    ...                  ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000             0.053964      NO
# ffb63ff99cf1354dff1da862f379da80  0.183673             0.227924      NO
# ffd697d66cc01c8897ce3e37d693673a  0.000000             0.002943      NO
# ffd96f173d6cd683bf3384bdc2f99713  0.326531             0.213108      NO
# ffee845c0caa320b55e31bb156827d16  0.081633             0.043122      NO
#
# year-month                       Usage_Rating_Categorical
# event_source.hash
# 00221451f705ebe26051158bb14f567a                      LOW
# 002fb47f60400713c854b0f69ff78c0a                      LOW
# 00567a4a3c474aca1ce5cd6570648932                      LOW
# 00724ae2470df1ed0fe919800d02517d                      LOW
# 007400db8afa996e788d23986739f3db                      LOW
# ...                                                   ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# ffb63ff99cf1354dff1da862f379da80                   MEDIUM
# ffd697d66cc01c8897ce3e37d693673a                      LOW
# ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# ffee845c0caa320b55e31bb156827d16                      LOW
#
# [3307 rows x 16 columns]

# %%
# adding category "NO" 
pivot_voice_usage_info['Usage_Rating_Categorical'] = pivot_voice_usage_info['Usage_Rating_Categorical'].cat.add_categories("NO")
pivot_voice_usage_info.loc[pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0, 'Usage_Rating_Categorical'] = "NO"
pivot_voice_usage_info[(pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [201908, 201909, 201910, 201911, 201912, 202001, 202002, 202003, 202004, 202005, 202006, 202007, 202008, Usage_Rating_Scaled, Outlier, Usage_Rating_Categorical]
# Index: []

# %% [markdown]
# ### Fina Result: Usage Ratings

# %%
pivot_voice_usage_info
# Out:
# year-month                          201908    201909   201910    201911  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.015625  0.000000  0.00000  0.000000
# 002fb47f60400713c854b0f69ff78c0a  0.046875  0.040816  0.06250  0.035714
# 00567a4a3c474aca1ce5cd6570648932  0.015625  0.000000  0.00000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.00000  0.000000
# 007400db8afa996e788d23986739f3db  0.015625  0.081633  0.03125  0.017857
# ...                                    ...       ...      ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.015625  0.183673  0.09375  0.214286
# ffb63ff99cf1354dff1da862f379da80  0.250000  0.326531  0.25000  0.285714
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.00000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.183673  0.18750  0.160714
# ffee845c0caa320b55e31bb156827d16  0.000000  0.020408  0.00000  0.035714
#
# year-month                          201912    202001    202002    202003  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.000000  0.000000  0.017857  0.015625
# 002fb47f60400713c854b0f69ff78c0a  0.062500  0.031250  0.017857  0.031250
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.015625  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.000000  0.093750  0.017857  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.046875  0.053571  0.062500
# ffb63ff99cf1354dff1da862f379da80  0.187500  0.250000  0.214286  0.250000
# ffd697d66cc01c8897ce3e37d693673a  0.000000  0.000000  0.017857  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.187500  0.187500  0.214286  0.187500
# ffee845c0caa320b55e31bb156827d16  0.015625  0.015625  0.017857  0.015625
#
# year-month                          202004    202005    202006    202007  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.020408  0.020408  0.015625  0.015625
# 002fb47f60400713c854b0f69ff78c0a  0.081633  0.122449  0.062500  0.031250
# 00567a4a3c474aca1ce5cd6570648932  0.000000  0.000000  0.000000  0.000000
# 00724ae2470df1ed0fe919800d02517d  0.000000  0.000000  0.000000  0.000000
# 007400db8afa996e788d23986739f3db  0.020408  0.040816  0.015625  0.000000
# ...                                    ...       ...       ...       ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000  0.000000  0.015625  0.015625
# ffb63ff99cf1354dff1da862f379da80  0.081633  0.183673  0.250000  0.250000
# ffd697d66cc01c8897ce3e37d693673a  0.020408  0.000000  0.000000  0.000000
# ffd96f173d6cd683bf3384bdc2f99713  0.326531  0.183673  0.250000  0.187500
# ffee845c0caa320b55e31bb156827d16  0.040816  0.020408  0.250000  0.046875
#
# year-month                          202008  Usage_Rating_Scaled Outlier  \
# event_source.hash
# 00221451f705ebe26051158bb14f567a  0.000000             0.009321      NO
# 002fb47f60400713c854b0f69ff78c0a  0.040816             0.051339      NO
# 00567a4a3c474aca1ce5cd6570648932  0.000000             0.002404      NO
# 00724ae2470df1ed0fe919800d02517d  0.040816             0.003140      NO
# 007400db8afa996e788d23986739f3db  0.000000             0.025755      NO
# ...                                    ...                  ...     ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2  0.000000             0.053964      NO
# ffb63ff99cf1354dff1da862f379da80  0.183673             0.227924      NO
# ffd697d66cc01c8897ce3e37d693673a  0.000000             0.002943      NO
# ffd96f173d6cd683bf3384bdc2f99713  0.326531             0.213108      NO
# ffee845c0caa320b55e31bb156827d16  0.081633             0.043122      NO
#
# year-month                       Usage_Rating_Categorical
# event_source.hash
# 00221451f705ebe26051158bb14f567a                      LOW
# 002fb47f60400713c854b0f69ff78c0a                      LOW
# 00567a4a3c474aca1ce5cd6570648932                      LOW
# 00724ae2470df1ed0fe919800d02517d                      LOW
# 007400db8afa996e788d23986739f3db                      LOW
# ...                                                   ...
# ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# ffb63ff99cf1354dff1da862f379da80                   MEDIUM
# ffd697d66cc01c8897ce3e37d693673a                      LOW
# ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# ffee845c0caa320b55e31bb156827d16                      LOW
#
# [3307 rows x 16 columns]

# %%
pivot_voice_usage_info.to_csv("data/user_profile/VOICE_ONNET_OUTGOING_Usage_Categorical.csv")

# %% [markdown]
# # Phase 2

# %% [markdown]
# ## Binnig by Location
#
# - 1. group by location columns
# - 2. Bin by location and get counts

# %%
# bucketing by location
voice_location_info = voice_usage_info
voice_location_info['Location_Identifier'] = voice_location_info['msan'].astype(str)+ voice_location_info['location_code'].astype(str) +voice_location_info['equp_id'].astype(str) +voice_location_info['equp_index'].astype(str)
voice_location_info
# Out:
#                       event_source.hash  call_count  duration  year-month  \
# 0      ba2cd0a629f9bd5acc9d7fcd89971dad          17    6240.0      201912
# 1      f36049a029726b88e7ccc0ac53cd966c          48   10260.0      202004
# 2      d7b523c1eba8e755b5c8a149f6562348          30    6474.0      202005
# 3      f36049a029726b88e7ccc0ac53cd966c          37   12060.0      202005
# 4      f36049a029726b88e7ccc0ac53cd966c          94   24720.0      202006
# ...                                 ...         ...       ...         ...
# 32164  8bce192f1a4cf21bcd65958a32f537ed           1     393.0      201911
# 32165  6d219e6c2e086d6959f4d90cad121009           6    1070.0      202001
# 32166  6d219e6c2e086d6959f4d90cad121009          14    1695.0      202002
# 32167  6d219e6c2e086d6959f4d90cad121009           4    2340.0      202003
# 32168  6d219e6c2e086d6959f4d90cad121009          10    2400.0      202004
#
#                        account_num.hash rtom_code location_code          msan  \
# 0      1cca6a8545b413f559cb2150db1e60d4     R-KON   WI-NWT-NODE  MSAG5200-ISL
# 1      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# 2      6c9c219e7478591ee675017aba34b105     R-KON  IDH-KGW-NODE  MSAG5200-ISL
# 3      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# 4      9cce11d3fb4e2be8a4f836907220e850     R-NTB   PC-AGT-NODE  MSAG5200-ISL
# ...                                 ...       ...           ...           ...
# 32164  adf3f539cdcfd24b33c8ad83631f825a      R-PH   PH-AKG-NODE      MSAG5200
# 32165  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32166  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32167  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
# 32168  7aa8c0a144b14c0d37d9b50e420c4773      R-PH   PH-AKG-NODE      MSAG5200
#
#        equp_id  equp_index              Location_Identifier
# 0        48520           1    MSAG5200-ISLWI-NWT-NODE485201
# 1        48003           1    MSAG5200-ISLPC-AGT-NODE480031
# 2       619449           1  MSAG5200-ISLIDH-KGW-NODE6194491
# 3        48003           1    MSAG5200-ISLPC-AGT-NODE480031
# 4        48003           1    MSAG5200-ISLPC-AGT-NODE480031
# ...        ...         ...                              ...
# 32164    43163           1        MSAG5200PH-AKG-NODE431631
# 32165    43163           1        MSAG5200PH-AKG-NODE431631
# 32166    43163           1        MSAG5200PH-AKG-NODE431631
# 32167    43163           1        MSAG5200PH-AKG-NODE431631
# 32168    43163           1        MSAG5200PH-AKG-NODE431631
#
# [32140 rows x 11 columns]

# %%
voice_location_info = voice_location_info.drop_duplicates("event_source.hash", keep="last")
voice_location_info.shape
# Out:
# (3307, 11)

# %%
user_location = voice_location_info[['event_source.hash','Location_Identifier']]
user_location
# Out:
#                       event_source.hash              Location_Identifier
# 7      d7b523c1eba8e755b5c8a149f6562348  MSAG5200-ISLIDH-KGW-NODE6194491
# 35     e66925d5277dac781824d054f75998d7  MSAG5200-ISLIDH-KGW-NODE6194491
# 39     f7508647677b63cfa0f63fe548f3236b  MSAG5200-ISLIDH-KGW-NODE6194491
# 58     4c01c7a8616e48c2b2dc8c56bb09b605    MSAG5200-ISLPC-AGT-NODE480031
# 71     27e3e9cde496878b297d35ee9ef8406a         C300MNW-MEE-NODE18887751
# ...                                 ...                              ...
# 32156  59ce55487af1cbf6855b860ab5455019    MSAG5200-ISLVA-NKM-NODE481961
# 32158  15d5e1896fc1afc13074efcd398edf8e    MSAG5200-ISLND-PHG-NODE500241
# 32159  ef1e2374e34fa4f73b6b4ae1e640d318    MSAG5200-ISLND-PHG-NODE500241
# 32164  8bce192f1a4cf21bcd65958a32f537ed        MSAG5200PH-AKG-NODE431631
# 32168  6d219e6c2e086d6959f4d90cad121009        MSAG5200PH-AKG-NODE431631
#
# [3307 rows x 2 columns]

# %%
user_location.to_csv("data/user_profile/VOICE_ONNET_OUTGOING_Locations_of_Users.csv")

# %%
voice_location_info["User_Count"] = 1
voice_gropued_by_locations = voice_location_info.groupby(['Location_Identifier'], axis=0,as_index=False).sum()
voice_gropued_by_locations = voice_gropued_by_locations[['Location_Identifier','User_Count']]
# Out:
# <ipython-input-43-46e54884d952>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voice_location_info["User_Count"] = 1

# %%
voice_gropued_by_locations
# Out:
#                 Location_Identifier  User_Count
# 0          C300MHE-DMD-NODE15221561          12
# 1            C300MHT-NE-NODE8152461          20
# 2         C300MIDH-IDJ-NODE11065541          61
# 3              C300MKI-NODE10668164          87
# 4          C300MNW-MEE-NODE18887751         183
# 5             C300MPDT-NODE13379431          12
# 6               C300MTP-NODE8700911          21
# 7               C300MVH-NODE9874041          17
# 8        MA5603TAD-SRV-NODE10224991           7
# 9         MSAG5200-ISLBZ-NODE435881         157
# 10       MSAG5200-ISLGE-NODE5577981          17
# 11    MSAG5200-ISLHC-NAP-NODE478721          16
# 12    MSAG5200-ISLHK-OCC-NODE506561          17
# 13       MSAG5200-ISLHNT-NODE423851          17
# 14        MSAG5200-ISLHO-NODE524692           5
# 15    MSAG5200-ISLHZ-BRL-NODE471911          18
# 16  MSAG5200-ISLIDH-KGW-NODE6194491         186
# 17    MSAG5200-ISLJA-PKV-NODE460421          19
# 18    MSAG5200-ISLKI-KRB-NODE479411           1
# 19    MSAG5200-ISLMB-PSL-NODE482261          19
# 20    MSAG5200-ISLMH-POL-NODE491451         107
# 21  MSAG5200-ISLMLT-VMD-NODE4145091          69
# 22    MSAG5200-ISLMT-AVR-NODE467161         323
# 23    MSAG5200-ISLMV-GDM-NODE482491         329
# 24       MSAG5200-ISLMX-NODE5391821          20
# 25    MSAG5200-ISLND-PHG-NODE500241         362
# 26    MSAG5200-ISLNL-HGW-NODE491281          16
# 27    MSAG5200-ISLPC-AGT-NODE480031         116
# 28   MSAG5200-ISLPK-PNU-NODE6136021           7
# 29       MSAG5200-ISLPRN-NODE427901          10
# 30    MSAG5200-ISLSI-DWS-NODE520721         107
# 31      MSAG5200-ISLTBL-NODE5577771          15
# 32   MSAG5200-ISLTBT-TLJ-NODE487241          10
# 33    MSAG5200-ISLVA-NKM-NODE481961          54
# 34    MSAG5200-ISLWI-NWT-NODE485201          21
# 35   MSAG5200-ISLWKN-SWP-NODE473481          33
# 36        MSAG5200-ISLWM-NODE432881           5
# 37    MSAG5200-ISLWY-MDB-NODE506221          16
# 38            MSAG5200BG-NODE431391         219
# 39           MSAG5200HPG-NODE432141          19
# 40           MSAG5200MGE-NODE428381          20
# 41        MSAG5200PH-AKG-NODE431631         271
# 42            MSAG5200PK-NODE438641          12
# 43           MSAG5200WLI-NODE422581           1
# 44        UA5000(IPMB)IM-NODE391531          17
# 45        UA5000(IPMB)SL-NODE385341         177
# 46  ZXDSL9806H-ISLAG-PNP-NODE529761          19
# 47  ZXDSL9806H-ISLKE-NRP-NODE495731          20
# 48  ZXDSL9806H-ISLKL-PRC-NODE482361          20

# %%
voice_gropued_by_locations.to_csv("data/user_profile/VOICE_ONNET_OUTGOING_Users_by_location.csv")
