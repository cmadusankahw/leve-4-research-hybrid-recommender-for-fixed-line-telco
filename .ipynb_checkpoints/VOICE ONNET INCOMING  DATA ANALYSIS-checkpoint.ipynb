# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
voice_usage_info = pd.read_csv("data/VOICE_INCOMING_CALL_USAGE_ONNET.csv")

voice_usage_info.shape
# Out:
# (32798, 10)

# %%
voice_usage_info
# Out:
#        event_source                 event_source.hash  call_count  \
# 0         112818394  c028faa94551392bb5820d9355b986a5          26
# 1         372050595  235cbed1e48fc9f24b4714801fd35849          50
# 2         452287101  502dc489645005511c55b1d0eea775bb           2
# 3         112818394  c028faa94551392bb5820d9355b986a5           9
# 4         112769822  4b2e63f3edcb9ee2633d32edf895d787          27
# ...             ...                               ...         ...
# 32793     372050561  9c5b33b9d53d8f84a2ee95e4a2b63457           4
# 32794     112725329  167671a939e03e258ca9cd94a3349a25          41
# 32795     112769007  9bab394af0f213327f3b26885b43e77b           4
# 32796     112714199  9fb8b46719fb977ff1d99a786ba3937f           7
# 32797     372050561  9c5b33b9d53d8f84a2ee95e4a2b63457           2
#
#        duration (seconds)      ym rtom_code location_code          msan  \
# 0                   561.0  201908      R-ND   ND-PHG-NODE  MSAG5200-ISL
# 1                  4847.0  201908     R-KLY   HZ-BRL-NODE  MSAG5200-ISL
# 2                   243.0  201912      R-RN       BG-NODE      MSAG5200
# 3                   142.0  201909      R-ND   ND-PHG-NODE  MSAG5200-ISL
# 4                  4331.0  202006      R-ND   ND-PHG-NODE  MSAG5200-ISL
# ...                   ...     ...       ...           ...           ...
# 32793               480.0  202007     R-KLY   HZ-BRL-NODE  MSAG5200-ISL
# 32794              3516.0  202008      R-RM   MV-GDM-NODE  MSAG5200-ISL
# 32795               360.0  201911      R-ND   ND-PHG-NODE  MSAG5200-ISL
# 32796               763.0  202007      R-RM   MV-GDM-NODE  MSAG5200-ISL
# 32797               300.0  202008     R-KLY   HZ-BRL-NODE  MSAG5200-ISL
#
#        equp_id  equp_index
# 0        50024           1
# 1        47191           1
# 2        43139           1
# 3        50024           1
# 4        50024           1
# ...        ...         ...
# 32793    47191           1
# 32794    48249           1
# 32795    50024           1
# 32796    48249           1
# 32797    47191           1
#
# [32798 rows x 10 columns]

# %%
# ToDo 
# Handle null values
# Drop unnecessary cols
# Pivot by monthYear
# Usage rating Upload/Downlad/Duration - bucketizing/ add rating cols
# location grouping/bucketizing (consider 4 location cols)
# User profile dim table
# visualize and analyze data

# %%
voice_usage_info = voice_usage_info.drop_duplicates(["event_source","ym"], keep="last")

voice_usage_info.shape
# Out:
# (32427, 10)

# %%
voice_usage_info = voice_usage_info.drop(['event_source.hash'], axis=1)
voice_usage_info.rename(columns={'duration (seconds)': 'duration','ym':'year-month'}, inplace=True)
voice_usage_info
# Out:
#        event_source  call_count  duration  year-month rtom_code location_code  \
# 0         112818394          26     561.0      201908      R-ND   ND-PHG-NODE
# 1         372050595          50    4847.0      201908     R-KLY   HZ-BRL-NODE
# 2         452287101           2     243.0      201912      R-RN       BG-NODE
# 3         112818394           9     142.0      201909      R-ND   ND-PHG-NODE
# 4         112769822          27    4331.0      202006      R-ND   ND-PHG-NODE
# ...             ...         ...       ...         ...       ...           ...
# 32793     372050561           4     480.0      202007     R-KLY   HZ-BRL-NODE
# 32794     112725329          41    3516.0      202008      R-RM   MV-GDM-NODE
# 32795     112769007           4     360.0      201911      R-ND   ND-PHG-NODE
# 32796     112714199           7     763.0      202007      R-RM   MV-GDM-NODE
# 32797     372050561           2     300.0      202008     R-KLY   HZ-BRL-NODE
#
#                msan  equp_id  equp_index
# 0      MSAG5200-ISL    50024           1
# 1      MSAG5200-ISL    47191           1
# 2          MSAG5200    43139           1
# 3      MSAG5200-ISL    50024           1
# 4      MSAG5200-ISL    50024           1
# ...             ...      ...         ...
# 32793  MSAG5200-ISL    47191           1
# 32794  MSAG5200-ISL    48249           1
# 32795  MSAG5200-ISL    50024           1
# 32796  MSAG5200-ISL    48249           1
# 32797  MSAG5200-ISL    47191           1
#
# [32427 rows x 9 columns]

# %%
voice_usage_info['duration'].fillna(0)
voice_usage_info['call_count'].fillna(0)
# Out:
# 0        26
# 1        50
# 2         2
# 3         9
# 4        27
#          ..
# 32793     4
# 32794    41
# 32795     4
# 32796     7
# 32797     2
# Name: call_count, Length: 32427, dtype: int64

# %%
voice_usage_info.isnull().sum(axis=0)
# Out:
# event_source     0
# call_count       0
# duration         0
# year-month       0
# rtom_code        0
# location_code    0
# msan             0
# equp_id          0
# equp_index       0
# dtype: int64

# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Usage Ranking
#
# - 1. Pivot by year-month
# - 2. Bin by Upload/Download/Duration
# - 3. Usage Rank
# - 4. Labling usage

# %%
voice_usage = voice_usage_info[['event_source','call_count','duration','year-month']]
voice_usage
# Out:
#        event_source  call_count  duration  year-month
# 0         112818394          26     561.0      201908
# 1         372050595          50    4847.0      201908
# 2         452287101           2     243.0      201912
# 3         112818394           9     142.0      201909
# 4         112769822          27    4331.0      202006
# ...             ...         ...       ...         ...
# 32793     372050561           4     480.0      202007
# 32794     112725329          41    3516.0      202008
# 32795     112769007           4     360.0      201911
# 32796     112714199           7     763.0      202007
# 32797     372050561           2     300.0      202008
#
# [32427 rows x 4 columns]

# %%
pivot_voice_usage_info = pd.pivot_table(voice_usage,index=['event_source'],columns=['year-month'], aggfunc=np.sum, fill_value=0)
pivot_voice_usage_info
# Out:
#              call_count                                                   \
# year-month       201908 201909 201910 201911 201912 202001 202002 202003
# event_source
# 112053582            12      3      3      6      3      4      2      0
# 112053623             5      6     21     14      9      4      6      9
# 112053643            10      6      8      7      4      3      1     11
# 112054356            15     10     16      1      0      0      0      0
# 112055452             3      9      9      5      9      6      3      7
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# 912286838             3      0      2      1      0      5      1      0
# 912286932            20     11     18     13     16     11      4      5
# 912286996             2      0      0      2      0      0      1      3
# 912287030             5      1      2      0      0      3      3      8
# 912287049             0      0      1      2      2      0      0      1
#
#                             ... duration                                     \
# year-month   202004 202005  ...   201911 201912 202001 202002 202003 202004
# event_source                ...
# 112053582         0      0  ...     1200   1200    600    240      0      0
# 112053623         6      0  ...     2176   2658    938   2043   2413   1980
# 112053643         4      6  ...      660    240    180     60   2160   1200
# 112054356         0      0  ...       60      0      0      0      0      0
# 112055452        11     15  ...      352   1130    590    336    600   1069
# ...             ...    ...  ...      ...    ...    ...    ...    ...    ...
# 912286838         0      1  ...       60      0    248     60      0      0
# 912286932         2      2  ...     1250   2051   2049   1175    389     48
# 912286996         1      0  ...      127      0      0    240   1260    600
# 912287030        17     15  ...        0      0    180    129   1380   1980
# 912287049         0      0  ...      180    360      0      0     60      0
#
#
# year-month   202005 202006 202007 202008
# event_source
# 112053582         0      0      0      0
# 112053623         0   2228   2248   1956
# 112053643      1419   3195   2100    360
# 112054356         0      0    199   1421
# 112055452      1222   1455   1504    787
# ...             ...    ...    ...    ...
# 912286838       240     60    230   2520
# 912286932        97   1507    902      0
# 912286996         0    120      0      0
# 912287030      1860   6180   1440   3480
# 912287049         0      0      0      0
#
# [3236 rows x 26 columns]

# %%
# check for all zero cols
pivot_voice_usage_info.loc[pivot_voice_usage_info.index == 0.0]
# Out:
# Empty DataFrame
# Columns: [(call_count, 201908), (call_count, 201909), (call_count, 201910), (call_count, 201911), (call_count, 201912), (call_count, 202001), (call_count, 202002), (call_count, 202003), (call_count, 202004), (call_count, 202005), (call_count, 202006), (call_count, 202007), (call_count, 202008), (duration, 201908), (duration, 201909), (duration, 201910), (duration, 201911), (duration, 201912), (duration, 202001), (duration, 202002), (duration, 202003), (duration, 202004), (duration, 202005), (duration, 202006), (duration, 202007), (duration, 202008)]
# Index: []
#
# [0 rows x 26 columns]

# %%
pivot_voice_usage_info.columns
# Out:
# MultiIndex([('call_count', 201908),
#             ('call_count', 201909),
#             ('call_count', 201910),
#             ('call_count', 201911),
#             ('call_count', 201912),
#             ('call_count', 202001),
#             ('call_count', 202002),
#             ('call_count', 202003),
#             ('call_count', 202004),
#             ('call_count', 202005),
#             ('call_count', 202006),
#             ('call_count', 202007),
#             ('call_count', 202008),
#             (  'duration', 201908),
#             (  'duration', 201909),
#             (  'duration', 201910),
#             (  'duration', 201911),
#             (  'duration', 201912),
#             (  'duration', 202001),
#             (  'duration', 202002),
#             (  'duration', 202003),
#             (  'duration', 202004),
#             (  'duration', 202005),
#             (  'duration', 202006),
#             (  'duration', 202007),
#             (  'duration', 202008)],
#            names=[None, 'year-month'])

# %%
pivot_voice_usage_info.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#             call_count                                                  \
# year-month      201908      201909      201910      201911      201912
# count       3236.00000  3236.00000  3236.00000  3236.00000  3236.00000
# mean          26.59302    21.24506    30.35692    22.70828    27.54017
# std          144.13418   103.77830   140.42679   102.92508   181.46798
# min            0.00000     0.00000     0.00000     0.00000     0.00000
# 25%            1.00000     1.00000     1.00000     1.00000     1.00000
# 50%            6.00000     5.00000     8.00000     6.00000     6.00000
# 75%           22.00000    17.00000    24.00000    19.00000    21.00000
# max         4057.00000  2708.00000  3405.00000  3092.00000  6890.00000
#
#                                                                         ...  \
# year-month      202001      202002      202003      202004      202005  ...
# count       3236.00000  3236.00000  3236.00000  3236.00000  3236.00000  ...
# mean          27.39030    21.67583    24.14864    19.12577    14.94963  ...
# std          140.15233   103.13182   130.08750   107.14657    85.90419  ...
# min            0.00000     0.00000     0.00000     0.00000     0.00000  ...
# 25%            1.00000     1.00000     1.00000     0.00000     0.00000  ...
# 50%            6.00000     5.00000     7.00000     5.00000     3.00000  ...
# 75%           22.00000    18.00000    21.00000    17.00000    12.00000  ...
# max         4590.00000  3122.00000  4855.00000  4123.00000  3405.00000  ...
#
#                 duration                                            \
# year-month        201911        201912        202001        202002
# count         3236.00000    3236.00000    3236.00000    3236.00000
# mean          3169.92120    3778.27905    3922.46539    3173.56706
# std          10998.66523   19337.30759   15794.30440   12134.18894
# min              0.00000       0.00000       0.00000       0.00000
# 25%             60.00000      60.00000      60.00000      33.75000
# 50%            705.00000     773.00000     809.50000     660.00000
# 75%           2989.50000    3180.50000    3410.50000    2790.25000
# max         305339.00000  700042.00000  475362.00000  333383.00000
#
#                                                                     \
# year-month        202003        202004        202005        202006
# count         3236.00000    3236.00000    3236.00000    3236.00000
# mean          3848.11187    3513.24135    2520.18356    4533.51761
# std          14446.04011   12458.62488    9739.81387   17454.85254
# min              0.00000       0.00000       0.00000       0.00000
# 25%             60.00000       0.00000       0.00000      60.00000
# 50%            953.50000     646.00000     420.00000     943.50000
# 75%           3584.25000    3354.00000    2332.50000    4267.75000
# max         488677.00000  416370.00000  346065.00000  597087.00000
#
#
# year-month        202007        202008
# count         3236.00000    3236.00000
# mean          3935.10939    3503.96539
# std          15027.40866   12752.15430
# min              0.00000       0.00000
# 25%             60.00000      60.00000
# 50%            854.50000     720.00000
# 75%           3655.00000    2966.25000
# max         546068.00000  369813.00000
#
# [8 rows x 26 columns]

# %%
voice_usage.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#           event_source   call_count      duration    year-month
# count      32427.00000  32427.00000   32427.00000   32427.00000
# mean   329127027.34909     31.43439    4689.88938  201967.73874
# std    206043224.02867    144.07306   16137.82189      46.11390
# min    112053582.00000      1.00000       1.00000  201908.00000
# 25%    112761690.00000      4.00000     388.00000  201911.00000
# 50%    332284356.00000     10.00000    1542.00000  202002.00000
# 75%    472232506.50000     26.00000    4500.00000  202005.00000
# max    912287049.00000   6890.00000  700042.00000  202008.00000

# %%
# binning call_count
count_bins = [0, 6,15, 30, 100,1200,2400,4800,6890]
for col in pivot_voice_usage_info['call_count'].columns:
    pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
pivot_voice_usage_info['call_count']
# Out:
# <ipython-input-105-1a3cb312abcd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['call_count'][col] = np.searchsorted(count_bins, pivot_voice_usage_info['call_count'][col].values)
# year-month    201908  201909  201910  201911  201912  202001  202002  202003  \
# event_source
# 112053582          2       1       1       1       1       1       1       0
# 112053623          1       1       3       2       2       1       1       2
# 112053643          2       1       2       2       1       1       1       2
# 112054356          2       2       3       1       0       0       0       0
# 112055452          1       2       2       1       2       1       1       2
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 912286838          1       0       1       1       0       1       1       0
# 912286932          3       2       3       2       3       2       1       1
# 912286996          1       0       0       1       0       0       1       1
# 912287030          1       1       1       0       0       1       1       2
# 912287049          0       0       1       1       1       0       0       1
#
# year-month    202004  202005  202006  202007  202008
# event_source
# 112053582          0       0       0       0       0
# 112053623          1       0       2       1       2
# 112053643          1       1       3       2       1
# 112054356          0       0       0       1       3
# 112055452          2       2       2       2       2
# ...              ...     ...     ...     ...     ...
# 912286838          0       1       1       1       2
# 912286932          1       1       1       1       0
# 912286996          1       0       1       0       0
# 912287030          3       2       4       2       3
# 912287049          0       0       0       0       0
#
# [3236 rows x 13 columns]

# %%
pivot_voice_usage_info['call_count'].describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       3236.000000  3236.000000  3236.000000  3236.000000  3236.000000
# mean           1.803461     1.643696     1.927379     1.754635     1.814895
# std            1.481572     1.416854     1.513457     1.430425     1.472270
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            1.000000     1.000000     1.000000     1.000000     1.000000
# 50%            1.000000     1.000000     2.000000     1.000000     1.000000
# 75%            3.000000     3.000000     3.000000     3.000000     3.000000
# max            7.000000     7.000000     7.000000     7.000000     8.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       3236.000000  3236.000000  3236.000000  3236.000000  3236.000000
# mean           1.819530     1.692213     1.813659     1.592707     1.394005
# std            1.481948     1.421565     1.463269     1.436894     1.320466
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            1.000000     1.000000     1.000000     0.000000     0.000000
# 50%            1.000000     1.000000     2.000000     1.000000     1.000000
# 75%            3.000000     3.000000     3.000000     3.000000     2.000000
# max            7.000000     7.000000     8.000000     7.000000     7.000000
#
# year-month       202006       202007       202008
# count       3236.000000  3236.000000  3236.000000
# mean           1.920272     1.825093     1.732077
# std            1.517892     1.476137     1.442640
# min            0.000000     0.000000     0.000000
# 25%            1.000000     1.000000     1.000000
# 50%            2.000000     1.000000     1.000000
# 75%            3.000000     3.000000     3.000000
# max            8.000000     7.000000     7.000000

# %%
# binning duration
duration_bins = [0, 300, 1500, 4200,16800,33600,66000,240000,700042]
for col in pivot_voice_usage_info['duration'].columns:
    pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
pivot_voice_usage_info['duration']
# Out:
# <ipython-input-107-205fd79ce0cb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_voice_usage_info['duration'][col] = np.searchsorted(duration_bins, pivot_voice_usage_info['duration'][col].values)
# year-month    201908  201909  201910  201911  201912  202001  202002  202003  \
# event_source
# 112053582          3       2       2       2       2       2       1       0
# 112053623          3       3       4       3       3       2       3       3
# 112053643          2       2       2       2       1       1       1       3
# 112054356          2       2       3       1       0       0       0       0
# 112055452          2       2       3       2       2       2       2       2
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 912286838          1       0       2       1       0       1       1       0
# 912286932          3       2       3       2       3       3       2       2
# 912286996          2       0       0       1       0       0       1       2
# 912287030          2       1       1       0       0       1       1       2
# 912287049          0       0       1       1       2       0       0       1
#
# year-month    202004  202005  202006  202007  202008
# event_source
# 112053582          0       0       0       0       0
# 112053623          3       0       3       3       3
# 112053643          2       2       3       3       2
# 112054356          0       0       0       1       2
# 112055452          2       2       2       3       2
# ...              ...     ...     ...     ...     ...
# 912286838          0       1       1       1       3
# 912286932          1       1       3       2       0
# 912286996          2       0       1       0       0
# 912287030          3       3       4       2       3
# 912287049          0       0       0       0       0
#
# [3236 rows x 13 columns]

# %%
pivot_voice_usage_info['duration'].describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       3236.000000  3236.000000  3236.000000  3236.000000  3236.000000
# mean           2.044499     1.916564     2.145859     1.989493     2.051607
# std            1.553337     1.513818     1.572676     1.493690     1.520024
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            1.000000     1.000000     1.000000     1.000000     1.000000
# 50%            2.000000     2.000000     2.000000     2.000000     2.000000
# 75%            3.000000     3.000000     3.000000     3.000000     3.000000
# max            8.000000     8.000000     8.000000     8.000000     8.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       3236.000000  3236.000000  3236.000000  3236.000000  3236.000000
# mean           2.061496     1.945303     2.102596     1.943140     1.738566
# std            1.547073     1.499440     1.551978     1.610585     1.502890
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            1.000000     1.000000     1.000000     0.000000     0.000000
# 50%            2.000000     2.000000     2.000000     2.000000     2.000000
# 75%            3.000000     3.000000     3.000000     3.000000     3.000000
# max            8.000000     8.000000     8.000000     8.000000     8.000000
#
# year-month       202006       202007       202008
# count       3236.000000  3236.000000  3236.000000
# mean           2.197466     2.099197     2.010198
# std            1.596830     1.567360     1.533214
# min            0.000000     0.000000     0.000000
# 25%            1.000000     1.000000     1.000000
# 50%            2.000000     2.000000     2.000000
# 75%            4.000000     3.000000     3.000000
# max            8.000000     8.000000     8.000000

# %%
year_month_list = pivot_voice_usage_info['call_count'].columns

# %%
# multplying bins to get usage rating
for col in year_month_list:
    pivot_voice_usage_info[col] = pivot_voice_usage_info['call_count'][col]  * pivot_voice_usage_info['duration'][col]

# %% [markdown]
# ### Usage ratings for year-month

# %%
pivot_voice_usage_info = pivot_voice_usage_info.drop(['call_count','duration'], axis=1)
pivot_voice_usage_info
# Out:
#              201908 201909 201910 201911 201912 202001 202002 202003 202004  \
# year-month
# event_source
# 112053582         6      2      2      2      2      2      1      0      0
# 112053623         3      3     12      6      6      2      3      6      3
# 112053643         4      2      4      4      1      1      1      6      2
# 112054356         4      4      9      1      0      0      0      0      0
# 112055452         2      4      6      2      4      2      2      4      4
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 912286838         1      0      2      1      0      1      1      0      0
# 912286932         9      4      9      4      9      6      2      2      1
# 912286996         2      0      0      1      0      0      1      2      2
# 912287030         2      1      1      0      0      1      1      4      9
# 912287049         0      0      1      1      2      0      0      1      0
#
#              202005 202006 202007 202008
# year-month
# event_source
# 112053582         0      0      0      0
# 112053623         0      6      3      6
# 112053643         2      9      6      2
# 112054356         0      0      1      6
# 112055452         4      4      6      4
# ...             ...    ...    ...    ...
# 912286838         1      1      1      6
# 912286932         1      3      2      0
# 912286996         0      1      0      0
# 912287030         6     16      4      9
# 912287049         0      0      0      0
#
# [3236 rows x 13 columns]

# %%
pivot_voice_usage_info.T.reset_index(drop=True).T
pivot_voice_usage_info.columns=year_month_list

# %%
# scaling usage rating
scaler = MinMaxScaler()
for col in year_month_list:
    pivot_voice_usage_info[col] = scaler.fit_transform(pivot_voice_usage_info[col].values.reshape(-1,1))
pivot_voice_usage_info
# Out:
# year-month      201908    201909    201910    201911    201912    202001  \
# event_source
# 112053582     0.107143  0.035714  0.035714  0.035714  0.031250  0.035714
# 112053623     0.053571  0.053571  0.214286  0.107143  0.093750  0.035714
# 112053643     0.071429  0.035714  0.071429  0.071429  0.015625  0.017857
# 112054356     0.071429  0.071429  0.160714  0.017857  0.000000  0.000000
# 112055452     0.035714  0.071429  0.107143  0.035714  0.062500  0.035714
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.035714  0.017857  0.000000  0.017857
# 912286932     0.160714  0.071429  0.160714  0.071429  0.140625  0.107143
# 912286996     0.035714  0.000000  0.000000  0.017857  0.000000  0.000000
# 912287030     0.035714  0.017857  0.017857  0.000000  0.000000  0.017857
# 912287049     0.000000  0.000000  0.017857  0.017857  0.031250  0.000000
#
# year-month      202002    202003    202004    202005    202006    202007  \
# event_source
# 112053582     0.017857  0.000000  0.000000  0.000000  0.000000  0.000000
# 112053623     0.053571  0.093750  0.053571  0.000000  0.093750  0.053571
# 112053643     0.017857  0.093750  0.035714  0.035714  0.140625  0.107143
# 112054356     0.000000  0.000000  0.000000  0.000000  0.000000  0.017857
# 112055452     0.035714  0.062500  0.071429  0.071429  0.062500  0.107143
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.000000  0.017857  0.015625  0.017857
# 912286932     0.035714  0.031250  0.017857  0.017857  0.046875  0.035714
# 912286996     0.017857  0.031250  0.035714  0.000000  0.015625  0.000000
# 912287030     0.017857  0.062500  0.160714  0.107143  0.250000  0.071429
# 912287049     0.000000  0.015625  0.000000  0.000000  0.000000  0.000000
#
# year-month      202008
# event_source
# 112053582     0.000000
# 112053623     0.107143
# 112053643     0.035714
# 112054356     0.107143
# 112055452     0.071429
# ...                ...
# 912286838     0.107143
# 912286932     0.000000
# 912286996     0.000000
# 912287030     0.160714
# 912287049     0.000000
#
# [3236 rows x 13 columns]

# %%
sns.heatmap(pivot_voice_usage_info[year_month_list].head(), annot=True)
# Out:
# <AxesSubplot:xlabel='year-month', ylabel='event_source'>

# %%
pivot_voice_usage_info['Usage_Rating_Scaled'] = pivot_voice_usage_info[year_month_list].sum(axis=1)/len(year_month_list)
pivot_voice_usage_info
# Out:
# year-month      201908    201909    201910    201911    201912    202001  \
# event_source
# 112053582     0.107143  0.035714  0.035714  0.035714  0.031250  0.035714
# 112053623     0.053571  0.053571  0.214286  0.107143  0.093750  0.035714
# 112053643     0.071429  0.035714  0.071429  0.071429  0.015625  0.017857
# 112054356     0.071429  0.071429  0.160714  0.017857  0.000000  0.000000
# 112055452     0.035714  0.071429  0.107143  0.035714  0.062500  0.035714
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.035714  0.017857  0.000000  0.017857
# 912286932     0.160714  0.071429  0.160714  0.071429  0.140625  0.107143
# 912286996     0.035714  0.000000  0.000000  0.017857  0.000000  0.000000
# 912287030     0.035714  0.017857  0.017857  0.000000  0.000000  0.017857
# 912287049     0.000000  0.000000  0.017857  0.017857  0.031250  0.000000
#
# year-month      202002    202003    202004    202005    202006    202007  \
# event_source
# 112053582     0.017857  0.000000  0.000000  0.000000  0.000000  0.000000
# 112053623     0.053571  0.093750  0.053571  0.000000  0.093750  0.053571
# 112053643     0.017857  0.093750  0.035714  0.035714  0.140625  0.107143
# 112054356     0.000000  0.000000  0.000000  0.000000  0.000000  0.017857
# 112055452     0.035714  0.062500  0.071429  0.071429  0.062500  0.107143
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.000000  0.017857  0.015625  0.017857
# 912286932     0.035714  0.031250  0.017857  0.017857  0.046875  0.035714
# 912286996     0.017857  0.031250  0.035714  0.000000  0.015625  0.000000
# 912287030     0.017857  0.062500  0.160714  0.107143  0.250000  0.071429
# 912287049     0.000000  0.015625  0.000000  0.000000  0.000000  0.000000
#
# year-month      202008  Usage_Rating_Scaled
# event_source
# 112053582     0.000000             0.023008
# 112053623     0.107143             0.077953
# 112053643     0.035714             0.057692
# 112054356     0.107143             0.034341
# 112055452     0.071429             0.063874
# ...                ...                  ...
# 912286838     0.107143             0.020433
# 912286932     0.000000             0.069025
# 912286996     0.000000             0.011848
# 912287030     0.160714             0.070742
# 912287049     0.000000             0.006353
#
# [3236 rows x 14 columns]

# %% [markdown]
# ### Finding Outliers

# %%
pivot_voice_usage_info.plot.line(subplots=True, figsize=(16,8))
# Out:
# array([<AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>,
#        <AxesSubplot:xlabel='event_source'>], dtype=object)

# %%
pivot_voice_usage_info.boxplot(column=[201908,201909,201910,201911,201912,202001,202002,202003,202004,202005,202006,202007,202008,])
# Out:
# <AxesSubplot:>

# %%
pivot_voice_usage_info.describe()
# Out:
# year-month       201908       201909       201910       201911       201912  \
# count       3236.000000  3236.000000  3236.000000  3236.000000  3236.000000
# mean           0.102977     0.090704     0.112562     0.096702     0.089786
# std            0.121590     0.112768     0.128305     0.115184     0.106136
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.017857     0.017857     0.017857     0.017857     0.015625
# 50%            0.053571     0.035714     0.071429     0.035714     0.046875
# 75%            0.160714     0.160714     0.214286     0.160714     0.140625
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202001       202002       202003       202004       202005  \
# count       3236.000000  3236.000000  3236.000000  3236.000000  3236.000000
# mean           0.103826     0.092944     0.091592     0.092657     0.074635
# std            0.122238     0.113709     0.104709     0.115430     0.100173
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.017857     0.017857     0.015625     0.000000     0.000000
# 50%            0.053571     0.035714     0.062500     0.035714     0.035714
# 75%            0.160714     0.160714     0.140625     0.160714     0.107143
# max            1.000000     1.000000     1.000000     1.000000     1.000000
#
# year-month       202006       202007       202008  Usage_Rating_Scaled
# count       3236.000000  3236.000000  3236.000000          3236.000000
# mean           0.100051     0.105802     0.097563             0.096292
# std            0.113033     0.123355     0.118075             0.103855
# min            0.000000     0.000000     0.000000             0.001202
# 25%            0.015625     0.017857     0.017857             0.017170
# 50%            0.062500     0.053571     0.035714             0.058036
# 75%            0.187500     0.160714     0.160714             0.147708
# max            1.000000     1.000000     1.000000             1.000000

# %%
# labling usage bins
bins = [0, 0.08, 0.3,1]
labels = ['LOW','MEDIUM','HIGH']
pivot_voice_usage_info['Usage_Rating_Categorical'] = pd.cut(pivot_voice_usage_info['Usage_Rating_Scaled'], bins=bins, labels=labels)
pivot_voice_usage_info
# Out:
# year-month      201908    201909    201910    201911    201912    202001  \
# event_source
# 112053582     0.107143  0.035714  0.035714  0.035714  0.031250  0.035714
# 112053623     0.053571  0.053571  0.214286  0.107143  0.093750  0.035714
# 112053643     0.071429  0.035714  0.071429  0.071429  0.015625  0.017857
# 112054356     0.071429  0.071429  0.160714  0.017857  0.000000  0.000000
# 112055452     0.035714  0.071429  0.107143  0.035714  0.062500  0.035714
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.035714  0.017857  0.000000  0.017857
# 912286932     0.160714  0.071429  0.160714  0.071429  0.140625  0.107143
# 912286996     0.035714  0.000000  0.000000  0.017857  0.000000  0.000000
# 912287030     0.035714  0.017857  0.017857  0.000000  0.000000  0.017857
# 912287049     0.000000  0.000000  0.017857  0.017857  0.031250  0.000000
#
# year-month      202002    202003    202004    202005    202006    202007  \
# event_source
# 112053582     0.017857  0.000000  0.000000  0.000000  0.000000  0.000000
# 112053623     0.053571  0.093750  0.053571  0.000000  0.093750  0.053571
# 112053643     0.017857  0.093750  0.035714  0.035714  0.140625  0.107143
# 112054356     0.000000  0.000000  0.000000  0.000000  0.000000  0.017857
# 112055452     0.035714  0.062500  0.071429  0.071429  0.062500  0.107143
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.000000  0.017857  0.015625  0.017857
# 912286932     0.035714  0.031250  0.017857  0.017857  0.046875  0.035714
# 912286996     0.017857  0.031250  0.035714  0.000000  0.015625  0.000000
# 912287030     0.017857  0.062500  0.160714  0.107143  0.250000  0.071429
# 912287049     0.000000  0.015625  0.000000  0.000000  0.000000  0.000000
#
# year-month      202008  Usage_Rating_Scaled Usage_Rating_Categorical
# event_source
# 112053582     0.000000             0.023008                      LOW
# 112053623     0.107143             0.077953                      LOW
# 112053643     0.035714             0.057692                      LOW
# 112054356     0.107143             0.034341                      LOW
# 112055452     0.071429             0.063874                      LOW
# ...                ...                  ...                      ...
# 912286838     0.107143             0.020433                      LOW
# 912286932     0.000000             0.069025                      LOW
# 912286996     0.000000             0.011848                      LOW
# 912287030     0.160714             0.070742                      LOW
# 912287049     0.000000             0.006353                      LOW
#
# [3236 rows x 15 columns]

# %%
# adding category "NO" 
pivot_voice_usage_info['Usage_Rating_Categorical'] = pivot_voice_usage_info['Usage_Rating_Categorical'].cat.add_categories("NO")
pivot_voice_usage_info.loc[pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0, 'Usage_Rating_Categorical'] = "NO"
pivot_voice_usage_info[(pivot_voice_usage_info['Usage_Rating_Scaled'] == 0.0)]
# Out:
# Empty DataFrame
# Columns: [201908, 201909, 201910, 201911, 201912, 202001, 202002, 202003, 202004, 202005, 202006, 202007, 202008, Usage_Rating_Scaled, Usage_Rating_Categorical]
# Index: []

# %% [markdown]
# ### Fina Result: Usage Ratings

# %%
pivot_voice_usage_info
# Out:
# year-month      201908    201909    201910    201911    201912    202001  \
# event_source
# 112053582     0.107143  0.035714  0.035714  0.035714  0.031250  0.035714
# 112053623     0.053571  0.053571  0.214286  0.107143  0.093750  0.035714
# 112053643     0.071429  0.035714  0.071429  0.071429  0.015625  0.017857
# 112054356     0.071429  0.071429  0.160714  0.017857  0.000000  0.000000
# 112055452     0.035714  0.071429  0.107143  0.035714  0.062500  0.035714
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.035714  0.017857  0.000000  0.017857
# 912286932     0.160714  0.071429  0.160714  0.071429  0.140625  0.107143
# 912286996     0.035714  0.000000  0.000000  0.017857  0.000000  0.000000
# 912287030     0.035714  0.017857  0.017857  0.000000  0.000000  0.017857
# 912287049     0.000000  0.000000  0.017857  0.017857  0.031250  0.000000
#
# year-month      202002    202003    202004    202005    202006    202007  \
# event_source
# 112053582     0.017857  0.000000  0.000000  0.000000  0.000000  0.000000
# 112053623     0.053571  0.093750  0.053571  0.000000  0.093750  0.053571
# 112053643     0.017857  0.093750  0.035714  0.035714  0.140625  0.107143
# 112054356     0.000000  0.000000  0.000000  0.000000  0.000000  0.017857
# 112055452     0.035714  0.062500  0.071429  0.071429  0.062500  0.107143
# ...                ...       ...       ...       ...       ...       ...
# 912286838     0.017857  0.000000  0.000000  0.017857  0.015625  0.017857
# 912286932     0.035714  0.031250  0.017857  0.017857  0.046875  0.035714
# 912286996     0.017857  0.031250  0.035714  0.000000  0.015625  0.000000
# 912287030     0.017857  0.062500  0.160714  0.107143  0.250000  0.071429
# 912287049     0.000000  0.015625  0.000000  0.000000  0.000000  0.000000
#
# year-month      202008  Usage_Rating_Scaled Usage_Rating_Categorical
# event_source
# 112053582     0.000000             0.023008                      LOW
# 112053623     0.107143             0.077953                      LOW
# 112053643     0.035714             0.057692                      LOW
# 112054356     0.107143             0.034341                      LOW
# 112055452     0.071429             0.063874                      LOW
# ...                ...                  ...                      ...
# 912286838     0.107143             0.020433                      LOW
# 912286932     0.000000             0.069025                      LOW
# 912286996     0.000000             0.011848                      LOW
# 912287030     0.160714             0.070742                      LOW
# 912287049     0.000000             0.006353                      LOW
#
# [3236 rows x 15 columns]

# %% [markdown]
# # Phase 2

# %% [markdown]
# ## Binnig by Location
#
# - 1. group by location columns
# - 2. Bin by location and get counts

# %%
# bucketing by location
voice_location_info = voice_usage_info
voice_location_info['Location_Identifier'] = voice_location_info['msan'].astype(str)+ voice_location_info['location_code'].astype(str) +voice_location_info['equp_id'].astype(str) +voice_location_info['equp_index'].astype(str)
voice_location_info
# Out:
#        event_source  call_count  duration  year-month rtom_code location_code  \
# 0         112818394          26     561.0      201908      R-ND   ND-PHG-NODE
# 1         372050595          50    4847.0      201908     R-KLY   HZ-BRL-NODE
# 2         452287101           2     243.0      201912      R-RN       BG-NODE
# 3         112818394           9     142.0      201909      R-ND   ND-PHG-NODE
# 4         112769822          27    4331.0      202006      R-ND   ND-PHG-NODE
# ...             ...         ...       ...         ...       ...           ...
# 32793     372050561           4     480.0      202007     R-KLY   HZ-BRL-NODE
# 32794     112725329          41    3516.0      202008      R-RM   MV-GDM-NODE
# 32795     112769007           4     360.0      201911      R-ND   ND-PHG-NODE
# 32796     112714199           7     763.0      202007      R-RM   MV-GDM-NODE
# 32797     372050561           2     300.0      202008     R-KLY   HZ-BRL-NODE
#
#                msan  equp_id  equp_index            Location_Identifier
# 0      MSAG5200-ISL    50024           1  MSAG5200-ISLND-PHG-NODE500241
# 1      MSAG5200-ISL    47191           1  MSAG5200-ISLHZ-BRL-NODE471911
# 2          MSAG5200    43139           1          MSAG5200BG-NODE431391
# 3      MSAG5200-ISL    50024           1  MSAG5200-ISLND-PHG-NODE500241
# 4      MSAG5200-ISL    50024           1  MSAG5200-ISLND-PHG-NODE500241
# ...             ...      ...         ...                            ...
# 32793  MSAG5200-ISL    47191           1  MSAG5200-ISLHZ-BRL-NODE471911
# 32794  MSAG5200-ISL    48249           1  MSAG5200-ISLMV-GDM-NODE482491
# 32795  MSAG5200-ISL    50024           1  MSAG5200-ISLND-PHG-NODE500241
# 32796  MSAG5200-ISL    48249           1  MSAG5200-ISLMV-GDM-NODE482491
# 32797  MSAG5200-ISL    47191           1  MSAG5200-ISLHZ-BRL-NODE471911
#
# [32427 rows x 10 columns]

# %%
voice_location_info = voice_location_info.drop_duplicates("event_source", keep="last")
voice_location_info.shape
# Out:
# (3236, 10)

# %%
voice_location_info["User_Count"] = 1
voice_gropued_by_locations = voice_location_info.groupby(['Location_Identifier'], axis=0,as_index=False).sum()
voice_gropued_by_locations = voice_gropued_by_locations[['Location_Identifier','User_Count']]
# Out:
# <ipython-input-89-46e54884d952>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voice_location_info["User_Count"] = 1

# %%
voice_gropued_by_locations
# Out:
#                 Location_Identifier  User_Count
# 0          C300MHE-DMD-NODE15221561          14
# 1            C300MHT-NE-NODE8152461          16
# 2         C300MIDH-IDJ-NODE11065541          59
# 3              C300MKI-NODE10668164          90
# 4          C300MNW-MEE-NODE18887751         183
# 5             C300MPDT-NODE13379431          12
# 6               C300MTP-NODE8700911          21
# 7               C300MVH-NODE9874041          16
# 8        MA5603TAD-SRV-NODE10224991           7
# 9         MSAG5200-ISLBZ-NODE435881         158
# 10       MSAG5200-ISLGE-NODE5577981          16
# 11    MSAG5200-ISLHC-NAP-NODE478721          18
# 12    MSAG5200-ISLHK-OCC-NODE506561          19
# 13       MSAG5200-ISLHNT-NODE423851          17
# 14        MSAG5200-ISLHO-NODE524692           3
# 15    MSAG5200-ISLHZ-BRL-NODE471911          16
# 16  MSAG5200-ISLIDH-KGW-NODE6194491         188
# 17    MSAG5200-ISLJA-PKV-NODE460421          18
# 18    MSAG5200-ISLKI-KRB-NODE479411           1
# 19    MSAG5200-ISLMB-PSL-NODE482261          18
# 20    MSAG5200-ISLMH-POL-NODE491451         109
# 21  MSAG5200-ISLMLT-VMD-NODE4145091          59
# 22    MSAG5200-ISLMT-AVR-NODE467161         301
# 23    MSAG5200-ISLMV-GDM-NODE482491         330
# 24       MSAG5200-ISLMX-NODE5391821          20
# 25    MSAG5200-ISLND-PHG-NODE500241         362
# 26    MSAG5200-ISLNL-HGW-NODE491281          15
# 27    MSAG5200-ISLPC-AGT-NODE480031         110
# 28   MSAG5200-ISLPK-PNU-NODE6136021           7
# 29       MSAG5200-ISLPRN-NODE427901          11
# 30    MSAG5200-ISLSI-DWS-NODE520721         103
# 31      MSAG5200-ISLTBL-NODE5577771          15
# 32   MSAG5200-ISLTBT-TLJ-NODE487241           9
# 33    MSAG5200-ISLVA-NKM-NODE481961          50
# 34    MSAG5200-ISLWI-NWT-NODE485201          21
# 35   MSAG5200-ISLWKN-SWP-NODE473481          33
# 36        MSAG5200-ISLWM-NODE432881           5
# 37    MSAG5200-ISLWY-MDB-NODE506221          16
# 38            MSAG5200BG-NODE431391         219
# 39           MSAG5200HPG-NODE432141          17
# 40           MSAG5200MGE-NODE428381          19
# 41        MSAG5200PH-AKG-NODE431631         264
# 42            MSAG5200PK-NODE438641          12
# 43           MSAG5200WLI-NODE422581           2
# 44        UA5000(IPMB)IM-NODE391531          17
# 45        UA5000(IPMB)SL-NODE385341         161
# 46  ZXDSL9806H-ISLAG-PNP-NODE529761          19
# 47  ZXDSL9806H-ISLKE-NRP-NODE495731          20
# 48  ZXDSL9806H-ISLKL-PRC-NODE482361          20
