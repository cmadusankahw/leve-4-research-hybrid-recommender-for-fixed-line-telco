# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from collections import Counter
from ast import literal_eval

# %%
# reading datasets
bb_usage = pd.read_csv("data/user_profile/BB_Usage_Categorical.csv")
voice_onnet_incoming_usage = pd.read_csv("data/user_profile/VOICE_ONNET_INCOMING_Usage_Categorical.csv")
voice_onnet_outgoing_usage = pd.read_csv("data/user_profile/VOICE_ONNET_OUTGOING_Usage_Categorical.csv")
voice_offnet_incoming_usage = pd.read_csv("data/user_profile/VOICE_OFFNET_INCOMING_Usage_Categorical.csv")
voice_offnet_outgoing_usage = pd.read_csv("data/user_profile/VOICE_OFFNET_OUTGOING_Usage_Categorical.csv")
voice_IDD_incoming_usage = pd.read_csv("data/user_profile/VOICE_IDD_Incoming_Usage_Categorical.csv")
voice_IDD_outgoing_usage = pd.read_csv("data/user_profile/VOICE_IDD_Outgoing_Usage_Categorical.csv")
peo_tv_usage = pd.read_csv("data/user_profile/PEO_TV_Usage_Categorical.csv")

# product details
phone_num_products = pd.read_csv("data/user_profile/Products_Associated_to_Phone_No.csv")

# %%
# locations
bb_location = pd.read_csv("data/user_profile/BB_USAGE_Locations_of_Users.csv")
voice_onnet_incoming_location = pd.read_csv("data/user_profile/VOICE_ONNET_INCOMING_Locations_of_Users.csv")
voice_onnet_outgoing_location = pd.read_csv("data/user_profile/VOICE_ONNET_OUTGOING_Locations_of_Users.csv")
voice_offnet_incoming_location = pd.read_csv("data/user_profile/VOICE_OFFNET_INCOMING_Locations_of_Users.csv")
voice_offnet_outgoing_location = pd.read_csv("data/user_profile/VOICE_OFFNET_OUTGOING_Locations_of_Users.csv")
voice_IDD_incoming_location = pd.read_csv("data/user_profile/VOICE_IDD_INCOMING_Locations_of_Users.csv")
peo_tv_location = pd.read_csv("data/user_profile/PEO_TV_Locations_of_Users.csv")

# %% [markdown]
# # Data perapration

# %%
bb_usage.rename(columns={'Unnamed: 0':'event_source.hash'}, inplace="True")
bb_usage = bb_usage[['event_source.hash','Usage_Rating_Categorical','Usage_Rating_Scaled']]
bb_usage.drop_duplicates("event_source.hash", inplace=True)
bb_usage.drop([0,1], axis=0, inplace=True)
bb_usage
# Out:
#                      event_source.hash Usage_Rating_Categorical  \
# 2     00567a4a3c474aca1ce5cd6570648932                   MEDIUM
# 3     00724ae2470df1ed0fe919800d02517d                      LOW
# 4     00a8c3e3baed0557c31ab9b68a086ed2                      LOW
# 5     00cc5a820586ce291c0fa4c2a99a4816                      LOW
# 6     00d1f690ec4af27702febbd0db6942c2                      LOW
# ...                                ...                      ...
# 1303  feca6cdb74a4a95dec4fe88f3fb2f938                      LOW
# 1304  ff1093d5ef61bf46f8c88e9b7614e311                      LOW
# 1305  ff45fdfb4b6dac191aba17a281181d39                   MEDIUM
# 1306  ffb2ec238eba276f65157693ed329c7f                   MEDIUM
# 1307  ffd697d66cc01c8897ce3e37d693673a                      LOW
#
#       Usage_Rating_Scaled
# 2                0.619792
# 3                0.031250
# 4                0.175347
# 5                0.072917
# 6                0.128472
# ...                   ...
# 1303             0.041667
# 1304             0.326389
# 1305             0.625000
# 1306             0.567708
# 1307             0.013889
#
# [1306 rows x 3 columns]

# %%
voice_onnet_incoming_usage = voice_onnet_incoming_usage[['event_source.hash','Usage_Rating_Categorical','Usage_Rating_Scaled','Outlier']]
voice_onnet_incoming_usage.drop_duplicates("event_source.hash", inplace=True)
voice_onnet_incoming_usage
# Out:
#                      event_source.hash Usage_Rating_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                      LOW
# 1     002fb47f60400713c854b0f69ff78c0a                      LOW
# 2     00567a4a3c474aca1ce5cd6570648932                      LOW
# 3     006be321aad541ff1d6c32a43dd7cdde                   MEDIUM
# 4     00724ae2470df1ed0fe919800d02517d                      LOW
# ...                                ...                      ...
# 3231  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                   MEDIUM
# 3232  ffb63ff99cf1354dff1da862f379da80                   MEDIUM
# 3233  ffd697d66cc01c8897ce3e37d693673a                      LOW
# 3234  ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# 3235  ffee845c0caa320b55e31bb156827d16                   MEDIUM
#
#       Usage_Rating_Scaled Outlier
# 0                0.017514      NO
# 1                0.056319      NO
# 2                0.001374      NO
# 3                0.108688      NO
# 4                0.002747      NO
# ...                   ...     ...
# 3231             0.080529      NO
# 3232             0.173935      NO
# 3233             0.005495      NO
# 3234             0.203984      NO
# 3235             0.112466      NO
#
# [3236 rows x 4 columns]

# %%
voice_onnet_outgoing_usage = voice_onnet_outgoing_usage[['event_source.hash','Usage_Rating_Categorical','Usage_Rating_Scaled','Outlier']]
voice_onnet_outgoing_usage.drop_duplicates("event_source.hash", inplace=True)
voice_onnet_outgoing_usage
# Out:
#                      event_source.hash Usage_Rating_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                      LOW
# 1     002fb47f60400713c854b0f69ff78c0a                      LOW
# 2     00567a4a3c474aca1ce5cd6570648932                      LOW
# 3     00724ae2470df1ed0fe919800d02517d                      LOW
# 4     007400db8afa996e788d23986739f3db                      LOW
# ...                                ...                      ...
# 3302  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# 3303  ffb63ff99cf1354dff1da862f379da80                   MEDIUM
# 3304  ffd697d66cc01c8897ce3e37d693673a                      LOW
# 3305  ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# 3306  ffee845c0caa320b55e31bb156827d16                      LOW
#
#       Usage_Rating_Scaled Outlier
# 0                0.009321      NO
# 1                0.051339      NO
# 2                0.002404      NO
# 3                0.003140      NO
# 4                0.025755      NO
# ...                   ...     ...
# 3302             0.053964      NO
# 3303             0.227924      NO
# 3304             0.002943      NO
# 3305             0.213108      NO
# 3306             0.043122      NO
#
# [3307 rows x 4 columns]

# %%
voice_offnet_incoming_usage = voice_offnet_incoming_usage[['event_source.hash','Usage_Rating_Categorical','Usage_Rating_Scaled','Outlier']]
voice_offnet_incoming_usage.drop_duplicates("event_source.hash", inplace=True)
voice_offnet_incoming_usage
# Out:
#                      event_source.hash Usage_Rating_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                      LOW
# 1     002fb47f60400713c854b0f69ff78c0a                      LOW
# 2     00567a4a3c474aca1ce5cd6570648932                      LOW
# 3     006be321aad541ff1d6c32a43dd7cdde                   MEDIUM
# 4     00724ae2470df1ed0fe919800d02517d                      LOW
# ...                                ...                      ...
# 3324  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# 3325  ffb63ff99cf1354dff1da862f379da80                   MEDIUM
# 3326  ffd697d66cc01c8897ce3e37d693673a                      LOW
# 3327  ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# 3328  ffee845c0caa320b55e31bb156827d16                      LOW
#
#       Usage_Rating_Scaled Outlier
# 0                0.085835      NO
# 1                0.079989      NO
# 2                0.002404      NO
# 3                0.227801      NO
# 4                0.010817      NO
# ...                   ...     ...
# 3324             0.011332      NO
# 3325             0.147142      NO
# 3326             0.012019      NO
# 3327             0.135744      NO
# 3328             0.035878      NO
#
# [3329 rows x 4 columns]

# %%
voice_offnet_outgoing_usage = voice_offnet_outgoing_usage[['event_source.hash','Usage_Rating_Categorical','Usage_Rating_Scaled','Outlier']]
voice_offnet_outgoing_usage.drop_duplicates("event_source.hash", inplace=True)
voice_offnet_outgoing_usage
# Out:
#                      event_source.hash Usage_Rating_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                      LOW
# 1     002fb47f60400713c854b0f69ff78c0a                      LOW
# 2     00567a4a3c474aca1ce5cd6570648932                      LOW
# 3     00724ae2470df1ed0fe919800d02517d                      LOW
# 4     007400db8afa996e788d23986739f3db                      LOW
# ...                                ...                      ...
# 3186  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# 3187  ffb63ff99cf1354dff1da862f379da80                     HIGH
# 3188  ffd697d66cc01c8897ce3e37d693673a                      LOW
# 3189  ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
# 3190  ffee845c0caa320b55e31bb156827d16                      LOW
#
#       Usage_Rating_Scaled Outlier
# 0                0.048813      NO
# 1                0.053424      NO
# 2                0.003606      NO
# 3                0.004808      NO
# 4                0.039197      NO
# ...                   ...     ...
# 3186             0.018029      NO
# 3187             0.334012      NO
# 3188             0.001202      NO
# 3189             0.196281      NO
# 3190             0.021635      NO
#
# [3191 rows x 4 columns]

# %%
voice_IDD_incoming_usage = voice_IDD_incoming_usage[['event_source.hash','Usage_Rating_Categorical','Usage_Rating_Scaled','Outlier']]
voice_IDD_incoming_usage.drop_duplicates("event_source.hash", inplace=True)
voice_IDD_incoming_usage
# Out:
#                      event_source.hash Usage_Rating_Categorical  \
# 0     002fb47f60400713c854b0f69ff78c0a                      LOW
# 1     007400db8afa996e788d23986739f3db                      LOW
# 2     009f305bf85a71012c0e343233e611ba                     HIGH
# 3     011adeeaef79aeac706a2e7fc225e8f8                      LOW
# 4     013736757d2ddad83cdfaa418921605c                      LOW
# ...                                ...                      ...
# 1192  fefee9a8aed82517d62c14ea4793bf0a                      LOW
# 1193  ff445f580f7525bd9f1455d6b09704cd                      LOW
# 1194  ff7e0f4edb7b39b683b9134af37fc4d3                     HIGH
# 1195  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                      LOW
# 1196  ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
#
#       Usage_Rating_Scaled Outlier
# 0                0.014423      NO
# 1                0.043269      NO
# 2                0.679487     YES
# 3                0.032051      NO
# 4                0.006410      NO
# ...                   ...     ...
# 1192             0.052885      NO
# 1193             0.028846      NO
# 1194             0.673077     YES
# 1195             0.006410      NO
# 1196             0.110577     YES
#
# [1197 rows x 4 columns]

# %%
voice_IDD_outgoing_usage = voice_IDD_outgoing_usage[['event_source.hash','Usage_Rating_Categorical','Usage_Rating_Scaled','Outlier']]
voice_IDD_outgoing_usage.drop_duplicates("event_source.hash", inplace=True)
voice_IDD_outgoing_usage
# Out:
#                     event_source.hash Usage_Rating_Categorical  \
# 0    007400db8afa996e788d23986739f3db                      LOW
# 1    009f305bf85a71012c0e343233e611ba                      LOW
# 2    00cc5a820586ce291c0fa4c2a99a4816                      LOW
# 3    011adeeaef79aeac706a2e7fc225e8f8                      LOW
# 4    0201ee9b60de662cdd16c885f178feea                      LOW
# ..                                ...                      ...
# 512  fe20b17a9573e4b7e765cc3098728f3d                      LOW
# 513  fe4e907a21bb03842eb88d0c0d633ca8                     HIGH
# 514  ff445f580f7525bd9f1455d6b09704cd                      LOW
# 515  ff7e0f4edb7b39b683b9134af37fc4d3                     HIGH
# 516  ffd96f173d6cd683bf3384bdc2f99713                   MEDIUM
#
#      Usage_Rating_Scaled Outlier
# 0               0.004808      NO
# 1               0.014423      NO
# 2               0.032051      NO
# 3               0.006410      NO
# 4               0.030449      NO
# ..                   ...     ...
# 512             0.057692      NO
# 513             0.375000     YES
# 514             0.004808      NO
# 515             0.826923     YES
# 516             0.272436     YES
#
# [517 rows x 4 columns]

# %%
peo_tv_usage = peo_tv_usage[['Phone_Number.hash','Peo_TV_Package','Usage_Rating_Categorical','Usage_Rating_Scaled']]
peo_tv_usage.drop_duplicates("Phone_Number.hash", inplace=True)
peo_tv_usage
# Out:
#                      Phone_Number.hash   Peo_TV_Package  \
# 0     46960b77dad950ddae76dd53bd7848cd      PEO_UTHAYAM
# 1     71d08664b609dcaddf02d6ffc2532aa7       PEO_SILVER
# 2     f98bd7d6c96317fc2656bc43441df8bb       PEO_SILVER
# 3     a41d8c2af7a4d478417f2368ee852296      PEO_UTHAYAM
# 4     09e7342066a13ca589d4a58ea0c685ae       PEO_SILVER
# ...                                ...              ...
# 1423  3ec6441eb5df6ef9ba2bdd63f919ce8b       PEO_SILVER
# 1424  013736757d2ddad83cdfaa418921605c       PEO_SILVER
# 1425  5fc30724801d125e0048b486655723f6       PEO_SILVER
# 1426  e034fe9b7cb567273a07edbad9946fde  PEO_SILVER_PLUS
# 1427  2ab8436cc34b4f16de3c452300f975c3       PEO_SILVER
#
#      Usage_Rating_Categorical  Usage_Rating_Scaled
# 0                        HIGH              0.93750
# 1                      MEDIUM              0.40625
# 2                        HIGH              0.75000
# 3                          NO              0.00000
# 4                        HIGH              0.90625
# ...                       ...                  ...
# 1423                     HIGH              1.00000
# 1424                       NO              0.00000
# 1425                     HIGH              0.75000
# 1426                     HIGH              0.78125
# 1427                      LOW              0.15625
#
# [1428 rows x 4 columns]

# %%
# user location 
print(bb_location.shape)
print(voice_onnet_incoming_location.shape)
print(voice_onnet_outgoing_location.shape)
print(voice_offnet_incoming_location.shape)
print(voice_offnet_outgoing_location.shape)
print(voice_IDD_incoming_location.shape)
print(peo_tv_location.shape)
# Out:
# (1306, 3)
# (3236, 3)
# (3307, 3)
# (3329, 3)
# (3191, 3)
# (1197, 3)
# (1428, 4)

# %%
# location from voice onnet outgoing
# justification: this has the max no of subscribers
voice_onnet_outgoing_location = voice_onnet_outgoing_location[['event_source.hash','Location_Identifier']]
voice_onnet_outgoing_location.drop_duplicates("event_source.hash", inplace=True)
voice_onnet_outgoing_location
# Out:
#                      event_source.hash              Location_Identifier
# 0     d7b523c1eba8e755b5c8a149f6562348  MSAG5200-ISLIDH-KGW-NODE6194491
# 1     e66925d5277dac781824d054f75998d7  MSAG5200-ISLIDH-KGW-NODE6194491
# 2     f7508647677b63cfa0f63fe548f3236b  MSAG5200-ISLIDH-KGW-NODE6194491
# 3     4c01c7a8616e48c2b2dc8c56bb09b605    MSAG5200-ISLPC-AGT-NODE480031
# 4     27e3e9cde496878b297d35ee9ef8406a         C300MNW-MEE-NODE18887751
# ...                                ...                              ...
# 3302  59ce55487af1cbf6855b860ab5455019    MSAG5200-ISLVA-NKM-NODE481961
# 3303  15d5e1896fc1afc13074efcd398edf8e    MSAG5200-ISLND-PHG-NODE500241
# 3304  ef1e2374e34fa4f73b6b4ae1e640d318    MSAG5200-ISLND-PHG-NODE500241
# 3305  8bce192f1a4cf21bcd65958a32f537ed        MSAG5200PH-AKG-NODE431631
# 3306  6d219e6c2e086d6959f4d90cad121009        MSAG5200PH-AKG-NODE431631
#
# [3307 rows x 2 columns]

# %%
phone_num_products
# Out:
#      Unnamed: 0                 Phone_Number.hash  \
# 0             0  009f305bf85a71012c0e343233e611ba
# 1             1  01cdd813d9a8bea5d70455a917c91e63
# 2             2  028c5d688b270307aea69a8dcb74bee2
# 3             3  05cfe8f4323299542b61cfdb60232095
# 4             4  06c40958738d7ff752abdd8973327e84
# ..          ...                               ...
# 436         436  fc49108a316204817f42189f9f6e6a70
# 437         437  fc77db5a9efeccfaace51889f68e3f22
# 438         438  fd62e39a7c82e9e9a066aee4307fdf87
# 439         439  feebdc83f80ba16208b54c2902471410
# 440         440  ffb9cb2e838925de5a75764fd59c6ea1
#
#                                           PRODUCT_NAME  Product_Count  \
# 0    ['V_Abbreviated Dialing', 'V_Call Transfer Thr...             13
# 1    ['V_Call Waiting', 'V_Call Forwarding-Immediat...              8
# 2                      ['E_TSTV', 'E_Video on Demand']              2
# 3    ['E_PeoTV Initiation', 'E_TSTV', 'E_Video on D...              3
# 4    ['V_DQ Contact Details', 'V_IDD', 'AB_Copper A...              5
# ..                                                 ...            ...
# 436  ['V_Referral offer Discount', 'AB_Referral off...              2
# 437                    ['E_Video on Demand', 'E_TSTV']              2
# 438         ['V_Call Forwarding', 'V_Hotline Service']              2
# 439                    ['E_Video on Demand', 'E_TSTV']              2
# 440  ['AB_Megaline', 'V_SLT CLI', 'V_IDD', 'AB_Mega...              5
#
#                                           Product_Dict
# 0    {'009f305bf85a71012c0e343233e611ba': ['V_Abbre...
# 1    {'01cdd813d9a8bea5d70455a917c91e63': ['V_Call ...
# 2    {'028c5d688b270307aea69a8dcb74bee2': ['E_TSTV'...
# 3    {'05cfe8f4323299542b61cfdb60232095': ['E_PeoTV...
# 4    {'06c40958738d7ff752abdd8973327e84': ['V_DQ Co...
# ..                                                 ...
# 436  {'fc49108a316204817f42189f9f6e6a70': ['V_Refer...
# 437  {'fc77db5a9efeccfaace51889f68e3f22': ['E_Video...
# 438  {'fd62e39a7c82e9e9a066aee4307fdf87': ['V_Call ...
# 439  {'feebdc83f80ba16208b54c2902471410': ['E_Video...
# 440  {'ffb9cb2e838925de5a75764fd59c6ea1': ['AB_Mega...
#
# [441 rows x 5 columns]

# %% [markdown]
# # User Profile : Usage

# %%
usage_df = voice_onnet_outgoing_usage.merge(voice_onnet_incoming_usage,how='left', on='event_source.hash')
usage_df.rename(columns={'Usage_Rating_Categorical_x':'ONNET_OUTGOING_Categorical', 'Usage_Rating_Categorical_y':'ONNET_INCOMING_Categorical',
                         'Usage_Rating_Scaled_x':'ONNET_OUTGOING_Scaled','Usage_Rating_Scaled_y':'ONNET_INCOMING_Scaled',
                         'Outlier_x':'ONNET_OUTGOING_Outlier','Outlier_y':'ONNET_INCOMING_Outlier'}, inplace="True")

usage_df = usage_df.merge(voice_offnet_outgoing_usage,how='left', on='event_source.hash')
usage_df.rename(columns={'Usage_Rating_Categorical':'OFFNET_OUTGOING_Categorical','Usage_Rating_Scaled':'OFFNET_OUTGOING_Scaled', 'Outlier':'OFFNET_OUTGOING_Outlier'}, inplace="True")

usage_df = usage_df.merge(voice_offnet_incoming_usage,how='left', on='event_source.hash')
usage_df.rename(columns={'Usage_Rating_Categorical':'OFFNET_INCOMING_Categorical','Usage_Rating_Scaled':'OFFNET_INCOMING_Scaled','Outlier':'OFFNET_INCOMING_Outlier'}, inplace="True")

usage_df = usage_df.merge(voice_IDD_incoming_usage,how='left', on='event_source.hash')
usage_df.rename(columns={'Usage_Rating_Categorical':'IDD_INCOMING_Categorical','Usage_Rating_Scaled':'IDD_INCOMING_Scaled','Outlier':'IDD_INCOMING_Outlier'}, inplace="True")

usage_df = usage_df.merge(voice_IDD_outgoing_usage,how='left', on='event_source.hash')
usage_df.rename(columns={'Usage_Rating_Categorical':'IDD_OUTGOING_Categorical','Usage_Rating_Scaled':'IDD_OUTGOING_Scaled','Outlier':'IDD_OUTGOING_Outlier'}, inplace="True")

usage_df = usage_df.merge(peo_tv_usage,how='left', left_on='event_source.hash', right_on='Phone_Number.hash')
usage_df.rename(columns={'Usage_Rating_Categorical':'PEO_TV_Categorical','Usage_Rating_Scaled':'PEO_TV_Scaled'}, inplace="True")
usage_df.drop('Phone_Number.hash', axis=1, inplace=True)

# merege BB usage
usage_df = usage_df.merge(bb_usage,how='left', on='event_source.hash')
usage_df.rename(columns={'Usage_Rating_Categorical':'BB_Categorical','Usage_Rating_Scaled':'BB_Scaled'}, inplace="True")

# merge user location identifier
usage_df = usage_df.merge(voice_onnet_outgoing_location,how='left', on='event_source.hash')

# merge Product packages map
usage_df = usage_df.merge(phone_num_products[['Phone_Number.hash','PRODUCT_NAME']],how='left', left_on='event_source.hash', right_on='Phone_Number.hash')
usage_df.rename(columns={'PRODUCT_NAME':'Other_Product_Packages'}, inplace="True")
usage_df.drop('Phone_Number.hash', axis=1, inplace=True)

cat_cols = ['ONNET_OUTGOING_Categorical', 'ONNET_INCOMING_Categorical', 'OFFNET_OUTGOING_Categorical', 'OFFNET_INCOMING_Categorical',
            'IDD_INCOMING_Categorical','IDD_OUTGOING_Categorical','Peo_TV_Package', 'PEO_TV_Categorical','BB_Categorical','Other_Product_Packages'
           ,'IDD_OUTGOING_Outlier','OFFNET_OUTGOING_Outlier','ONNET_OUTGOING_Outlier','ONNET_INCOMING_Outlier','ONNET_INCOMING_Outlier'
           ,'IDD_INCOMING_Outlier']

scaled_cols = ['ONNET_OUTGOING_Scaled', 'ONNET_INCOMING_Scaled', 'OFFNET_OUTGOING_Scaled', 'OFFNET_INCOMING_Scaled','IDD_INCOMING_Scaled'
        ,'IDD_OUTGOING_Scaled','PEO_TV_Scaled','BB_Scaled']

usage_df[cat_cols] = usage_df[cat_cols].fillna("NO")

usage_df[scaled_cols] = usage_df[scaled_cols].fillna(0)
usage_df
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                        LOW
# 1     002fb47f60400713c854b0f69ff78c0a                        LOW
# 2     00567a4a3c474aca1ce5cd6570648932                        LOW
# 3     00724ae2470df1ed0fe919800d02517d                        LOW
# 4     007400db8afa996e788d23986739f3db                        LOW
# ...                                ...                        ...
# 3302  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                        LOW
# 3303  ffb63ff99cf1354dff1da862f379da80                     MEDIUM
# 3304  ffd697d66cc01c8897ce3e37d693673a                        LOW
# 3305  ffd96f173d6cd683bf3384bdc2f99713                     MEDIUM
# 3306  ffee845c0caa320b55e31bb156827d16                        LOW
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 0                  0.009321                     NO                        LOW
# 1                  0.051339                     NO                        LOW
# 2                  0.002404                     NO                        LOW
# 3                  0.003140                     NO                        LOW
# 4                  0.025755                     NO                        LOW
# ...                     ...                    ...                        ...
# 3302               0.053964                     NO                     MEDIUM
# 3303               0.227924                     NO                     MEDIUM
# 3304               0.002943                     NO                        LOW
# 3305               0.213108                     NO                     MEDIUM
# 3306               0.043122                     NO                     MEDIUM
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 0                  0.017514                     NO
# 1                  0.056319                     NO
# 2                  0.001374                     NO
# 3                  0.002747                     NO
# 4                  0.017857                     NO
# ...                     ...                    ...
# 3302               0.080529                     NO
# 3303               0.173935                     NO
# 3304               0.005495                     NO
# 3305               0.203984                     NO
# 3306               0.112466                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 0                            LOW                0.048813
# 1                            LOW                0.053424
# 2                            LOW                0.003606
# 3                            LOW                0.004808
# 4                            LOW                0.039197
# ...                          ...                     ...
# 3302                         LOW                0.018029
# 3303                        HIGH                0.334012
# 3304                         LOW                0.001202
# 3305                      MEDIUM                0.196281
# 3306                         LOW                0.021635
#
#      OFFNET_OUTGOING_Outlier  ... IDD_OUTGOING_Categorical  \
# 0                         NO  ...                       NO
# 1                         NO  ...                       NO
# 2                         NO  ...                       NO
# 3                         NO  ...                       NO
# 4                         NO  ...                      LOW
# ...                      ...  ...                      ...
# 3302                      NO  ...                       NO
# 3303                      NO  ...                       NO
# 3304                      NO  ...                       NO
# 3305                      NO  ...                   MEDIUM
# 3306                      NO  ...                       NO
#
#       IDD_OUTGOING_Scaled IDD_OUTGOING_Outlier     Peo_TV_Package  \
# 0                0.000000                   NO                 NO
# 1                0.000000                   NO                 NO
# 2                0.000000                   NO  PEO_ENTERTAINMENT
# 3                0.000000                   NO                 NO
# 4                0.004808                   NO                 NO
# ...                   ...                  ...                ...
# 3302             0.000000                   NO                 NO
# 3303             0.000000                   NO                 NO
# 3304             0.000000                   NO         PEO_SILVER
# 3305             0.272436                  YES                 NO
# 3306             0.000000                   NO         PEO_SILVER
#
#       PEO_TV_Categorical PEO_TV_Scaled BB_Categorical  BB_Scaled  \
# 0                     NO         0.000             NO   0.000000
# 1                     NO         0.000             NO   0.000000
# 2                 MEDIUM         0.625         MEDIUM   0.619792
# 3                     NO         0.000            LOW   0.031250
# 4                     NO         0.000             NO   0.000000
# ...                  ...           ...            ...        ...
# 3302                  NO         0.000             NO   0.000000
# 3303                  NO         0.000             NO   0.000000
# 3304                  NO         0.000            LOW   0.013889
# 3305                  NO         0.000             NO   0.000000
# 3306                HIGH         0.750             NO   0.000000
#
#                   Location_Identifier Other_Product_Packages
# 0          MSAG5200-ISLMX-NODE5391821                     NO
# 1       MSAG5200-ISLND-PHG-NODE500241                     NO
# 2     MSAG5200-ISLIDH-KGW-NODE6194491                     NO
# 3       MSAG5200-ISLMT-AVR-NODE467161                     NO
# 4     ZXDSL9806H-ISLKL-PRC-NODE482361                     NO
# ...                               ...                    ...
# 3302    MSAG5200-ISLMV-GDM-NODE482491                     NO
# 3303   MSAG5200-ISLWKN-SWP-NODE473481                     NO
# 3304              C300MTP-NODE8700911                     NO
# 3305    MSAG5200-ISLMV-GDM-NODE482491                     NO
# 3306  MSAG5200-ISLIDH-KGW-NODE6194491                     NO
#
# [3307 rows x 26 columns]

# %%
 len(usage_df[usage_df['Other_Product_Packages'] == 'NO'])
# Out:
# 2907

# %%
3307- 2907
# Out:
# 400

# %%
usage_with_other_packages = usage_df[usage_df['Other_Product_Packages'] != 'NO']
usage_with_other_packages
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 7     009f305bf85a71012c0e343233e611ba                     MEDIUM
# 24    01cdd813d9a8bea5d70455a917c91e63                        LOW
# 71    05cfe8f4323299542b61cfdb60232095                        LOW
# 79    06c40958738d7ff752abdd8973327e84                     MEDIUM
# 100   08c38286f1a189b638e60f800de4cf98                        LOW
# ...                                ...                        ...
# 3239  f987efdcbfcdc0f3f78d4ee6ed37b88a                        LOW
# 3261  fc49108a316204817f42189f9f6e6a70                        LOW
# 3263  fc77db5a9efeccfaace51889f68e3f22                     MEDIUM
# 3275  fd62e39a7c82e9e9a066aee4307fdf87                        LOW
# 3293  feebdc83f80ba16208b54c2902471410                        LOW
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 7                  0.249951                     NO                       HIGH
# 24                 0.031324                     NO                        LOW
# 71                 0.022248                     NO                        LOW
# 79                 0.193755                     NO                     MEDIUM
# 100                0.001202                     NO                         NO
# ...                     ...                    ...                        ...
# 3239               0.006917                     NO                        LOW
# 3261               0.046041                     NO                        LOW
# 3263               0.088525                     NO                        LOW
# 3275               0.058109                     NO                        LOW
# 3293               0.007947                     NO                        LOW
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 7                  0.593407                    YES
# 24                 0.002747                     NO
# 71                 0.009272                     NO
# 79                 0.172047                     NO
# 100                0.000000                     NO
# ...                     ...                    ...
# 3239               0.008929                     NO
# 3261               0.017170                     NO
# 3263               0.045330                     NO
# 3275               0.039148                     NO
# 3293               0.034684                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 7                           HIGH                0.575549
# 24                           LOW                0.019599
# 71                           LOW                0.068779
# 79                        MEDIUM                0.103635
# 100                          LOW                0.002404
# ...                          ...                     ...
# 3239                         LOW                0.010817
# 3261                      MEDIUM                0.086342
# 3263                         LOW                0.035224
# 3275                         LOW                0.040031
# 3293                         LOW                0.008413
#
#      OFFNET_OUTGOING_Outlier  ... IDD_OUTGOING_Categorical  \
# 7                        YES  ...                      LOW
# 24                        NO  ...                       NO
# 71                        NO  ...                       NO
# 79                        NO  ...                       NO
# 100                       NO  ...                       NO
# ...                      ...  ...                      ...
# 3239                      NO  ...                       NO
# 3261                      NO  ...                       NO
# 3263                      NO  ...                       NO
# 3275                      NO  ...                       NO
# 3293                      NO  ...                       NO
#
#       IDD_OUTGOING_Scaled IDD_OUTGOING_Outlier         Peo_TV_Package  \
# 7                0.014423                   NO                     NO
# 24               0.000000                   NO             PEO_SILVER
# 71               0.000000                   NO  PEO_RELIGIOUS_PACKAGE
# 79               0.000000                   NO            PEO_UTHAYAM
# 100              0.000000                   NO                     NO
# ...                   ...                  ...                    ...
# 3239             0.000000                   NO             PEO_SILVER
# 3261             0.000000                   NO                     NO
# 3263             0.000000                   NO        PEO_SILVER_PLUS
# 3275             0.000000                   NO             PEO_SILVER
# 3293             0.000000                   NO                     NO
#
#       PEO_TV_Categorical PEO_TV_Scaled BB_Categorical  BB_Scaled  \
# 7                     NO        0.0000             NO   0.000000
# 24                  HIGH        0.8125            LOW   0.236111
# 71                    NO        0.0000             NO   0.000000
# 79                    NO        0.0000             NO   0.000000
# 100                   NO        0.0000             NO   0.000000
# ...                  ...           ...            ...        ...
# 3239              MEDIUM        0.5625             NO   0.000000
# 3261                  NO        0.0000            LOW   0.052083
# 3263                  NO        0.0000         MEDIUM   0.531250
# 3275                HIGH        1.0000         MEDIUM   0.338542
# 3293                  NO        0.0000             NO   0.000000
#
#                   Location_Identifier  \
# 7       MSAG5200-ISLND-PHG-NODE500241
# 24    ZXDSL9806H-ISLAG-PNP-NODE529761
# 71               C300MKI-NODE10668164
# 79      MSAG5200-ISLPC-AGT-NODE480031
# 100     MSAG5200-ISLMV-GDM-NODE482491
# ...                               ...
# 3239            MSAG5200BG-NODE431391
# 3261        MSAG5200PH-AKG-NODE431631
# 3263    MSAG5200-ISLMT-AVR-NODE467161
# 3275    MSAG5200-ISLMT-AVR-NODE467161
# 3293    MSAG5200-ISLMV-GDM-NODE482491
#
#                                  Other_Product_Packages
# 7     ['V_Abbreviated Dialing', 'V_Call Transfer Thr...
# 24    ['V_Call Waiting', 'V_Call Forwarding-Immediat...
# 71    ['E_PeoTV Initiation', 'E_TSTV', 'E_Video on D...
# 79    ['V_DQ Contact Details', 'V_IDD', 'AB_Copper A...
# 100   ['V_Call Forwarding-Immediate', 'V_Call Forwar...
# ...                                                 ...
# 3239  ['V_Call Forwarding-On Busy', 'V_Absentee serv...
# 3261  ['V_Referral offer Discount', 'AB_Referral off...
# 3263                    ['E_Video on Demand', 'E_TSTV']
# 3275         ['V_Call Forwarding', 'V_Hotline Service']
# 3293                    ['E_Video on Demand', 'E_TSTV']
#
# [400 rows x 26 columns]

# %% [markdown]
# ## Note:
# - product pacakges merged using the available phone number(as **PRODUCT LABEL**) has only 400 matches.
# - Reason: Even "Prodduct state Changes df" has **3000+** , when grouped by **Account No** there are only **441 unque phone numbers**(event sources) associated with services.

# %% [markdown]
# ## Voice Usage Bins

# %%
def voice_bin(incoming,outgoing):
    if incoming=="LOW" and outgoing=="LOW":
        return "LOW"
    if incoming=="HIGH" and outgoing=="HIGH":
        return "HIGH"
    if (incoming=="HIGH" and outgoing=="MEDIUM") or (incoming=="MEDIUM" and outgoing=="HIGH"):
        return "HIGH"
    if incoming=="MEDIUM" and outgoing=="MEDIUM":
        return "MEDIUM"
    if (incoming=="MEDIUM" and outgoing=="LOW") or (incoming=="LOW" and outgoing=="MEDIUM"):
        return "LOW"
    if (incoming=="LOW" and outgoing=="HIGH") or (incoming=="HIGH" and outgoing=="LOW"):
        return "MEDIUM"
    if (incoming=="NO" and outgoing!="NO") or (incoming!="NO" and outgoing=="NO"):
        return "LOW"
    if incoming=="NO" and outgoing=="NO":
        return "NO"

# %%
# test
voice_bin("LOW","HIGH")
# Out:
# 'MEDIUM'

# %%
usage_df["ONNET_Overall_Categorical"] = usage_df.apply(lambda x: voice_bin(x["ONNET_INCOMING_Categorical"], x["ONNET_OUTGOING_Categorical"]), axis=1)

# %%
usage_df["OFFNET_Overall_Categorical"] = usage_df.apply(lambda x: voice_bin(x["OFFNET_INCOMING_Categorical"], x["OFFNET_OUTGOING_Categorical"]), axis=1)

# %%
usage_df["IDD_Overall_Categorical"] = usage_df.apply(lambda x: voice_bin(x["IDD_INCOMING_Categorical"], x["IDD_OUTGOING_Categorical"]), axis=1)

# %%
def voice_overall_bin(call_usage):
    counts = Counter(call_usage)
    if counts["LOW"] > 1:
        return "LOW"
    if counts["HIGH"] > 1:
        return "HIGH"
    if counts["MEDIUM"] > 1:
        return "MEDIUM"
    if counts["NO"] == 2:
        return "LOW"
    if counts["NO"] == 3:
        return "NO"
    if counts["LOW"] == 1 and counts["MEDIUM"] == 1 and counts["HIGH"] == 1:
        return "MEDIUM"
    else:
        return "MEDIUM"

# %%
# test
voice_overall_bin(["HIGH","HIGH","NO"])
# Out:
# 'HIGH'

# %%
usage_df["VOICE_Categorical"] = usage_df.apply(lambda x: voice_overall_bin([x["ONNET_Overall_Categorical"], x["OFFNET_Overall_Categorical"], x["IDD_Overall_Categorical"]]), axis=1)

# %%
usage_df
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                        LOW
# 1     002fb47f60400713c854b0f69ff78c0a                        LOW
# 2     00567a4a3c474aca1ce5cd6570648932                        LOW
# 3     00724ae2470df1ed0fe919800d02517d                        LOW
# 4     007400db8afa996e788d23986739f3db                        LOW
# ...                                ...                        ...
# 3302  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                        LOW
# 3303  ffb63ff99cf1354dff1da862f379da80                     MEDIUM
# 3304  ffd697d66cc01c8897ce3e37d693673a                        LOW
# 3305  ffd96f173d6cd683bf3384bdc2f99713                     MEDIUM
# 3306  ffee845c0caa320b55e31bb156827d16                        LOW
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 0                  0.009321                     NO                        LOW
# 1                  0.051339                     NO                        LOW
# 2                  0.002404                     NO                        LOW
# 3                  0.003140                     NO                        LOW
# 4                  0.025755                     NO                        LOW
# ...                     ...                    ...                        ...
# 3302               0.053964                     NO                     MEDIUM
# 3303               0.227924                     NO                     MEDIUM
# 3304               0.002943                     NO                        LOW
# 3305               0.213108                     NO                     MEDIUM
# 3306               0.043122                     NO                     MEDIUM
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 0                  0.017514                     NO
# 1                  0.056319                     NO
# 2                  0.001374                     NO
# 3                  0.002747                     NO
# 4                  0.017857                     NO
# ...                     ...                    ...
# 3302               0.080529                     NO
# 3303               0.173935                     NO
# 3304               0.005495                     NO
# 3305               0.203984                     NO
# 3306               0.112466                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 0                            LOW                0.048813
# 1                            LOW                0.053424
# 2                            LOW                0.003606
# 3                            LOW                0.004808
# 4                            LOW                0.039197
# ...                          ...                     ...
# 3302                         LOW                0.018029
# 3303                        HIGH                0.334012
# 3304                         LOW                0.001202
# 3305                      MEDIUM                0.196281
# 3306                         LOW                0.021635
#
#      OFFNET_OUTGOING_Outlier  ... PEO_TV_Categorical  PEO_TV_Scaled  \
# 0                         NO  ...                 NO          0.000
# 1                         NO  ...                 NO          0.000
# 2                         NO  ...             MEDIUM          0.625
# 3                         NO  ...                 NO          0.000
# 4                         NO  ...                 NO          0.000
# ...                      ...  ...                ...            ...
# 3302                      NO  ...                 NO          0.000
# 3303                      NO  ...                 NO          0.000
# 3304                      NO  ...                 NO          0.000
# 3305                      NO  ...                 NO          0.000
# 3306                      NO  ...               HIGH          0.750
#
#      BB_Categorical BB_Scaled              Location_Identifier  \
# 0                NO  0.000000       MSAG5200-ISLMX-NODE5391821
# 1                NO  0.000000    MSAG5200-ISLND-PHG-NODE500241
# 2            MEDIUM  0.619792  MSAG5200-ISLIDH-KGW-NODE6194491
# 3               LOW  0.031250    MSAG5200-ISLMT-AVR-NODE467161
# 4                NO  0.000000  ZXDSL9806H-ISLKL-PRC-NODE482361
# ...             ...       ...                              ...
# 3302             NO  0.000000    MSAG5200-ISLMV-GDM-NODE482491
# 3303             NO  0.000000   MSAG5200-ISLWKN-SWP-NODE473481
# 3304            LOW  0.013889              C300MTP-NODE8700911
# 3305             NO  0.000000    MSAG5200-ISLMV-GDM-NODE482491
# 3306             NO  0.000000  MSAG5200-ISLIDH-KGW-NODE6194491
#
#      Other_Product_Packages ONNET_Overall_Categorical  \
# 0                        NO                       LOW
# 1                        NO                       LOW
# 2                        NO                       LOW
# 3                        NO                       LOW
# 4                        NO                       LOW
# ...                     ...                       ...
# 3302                     NO                       LOW
# 3303                     NO                    MEDIUM
# 3304                     NO                       LOW
# 3305                     NO                    MEDIUM
# 3306                     NO                       LOW
#
#       OFFNET_Overall_Categorical IDD_Overall_Categorical VOICE_Categorical
# 0                            LOW                      NO               LOW
# 1                            LOW                     LOW               LOW
# 2                            LOW                      NO               LOW
# 3                            LOW                      NO               LOW
# 4                            LOW                     LOW               LOW
# ...                          ...                     ...               ...
# 3302                         LOW                     LOW               LOW
# 3303                        HIGH                      NO            MEDIUM
# 3304                         LOW                      NO               LOW
# 3305                      MEDIUM                  MEDIUM            MEDIUM
# 3306                         LOW                      NO               LOW
#
# [3307 rows x 30 columns]

# %% [markdown]
# ## Play Types and Usage

# %%
def check_product_level(voice,bb,tv):
    all_voice = False
    for el in voice:
        if el != "NO":
            all_voice=True
    if all_voice and bb=="NO" and tv=="NO":
        return "SINGLE_PLAY"
    elif all_voice and (bb != "NO" and tv == "NO") or (bb == "NO" and tv != "NO"):
        return "DOUBLE_PLAY"
    elif all_voice and bb != "NO" and tv != "NO":
        return "TRIPLE_PLAY"

# %%
# test
check_product_level(["NO","LOW","LOW","NO","HIGH"],"HIGH","LOW")
# Out:
# 'TRIPLE_PLAY'

# %%
usage_df["Play_Type"] = usage_df.apply(lambda x: check_product_level([x["ONNET_OUTGOING_Categorical"], x["ONNET_INCOMING_Categorical"], x["OFFNET_OUTGOING_Categorical"], x["OFFNET_INCOMING_Categorical"], x["IDD_INCOMING_Categorical"], x["IDD_OUTGOING_Categorical"]], x["BB_Categorical"], x["PEO_TV_Categorical"]), axis=1)

# %%
# play usage
def play_usage(usage):
    if len(usage)>2:
        return [f"VOICE_{usage[0]}", f"BB_{usage[1]}", f"TV_{usage[2]}"]
    else:
        return "ERR"

# %%
# test
play_usage(["LOW","HIGH","LOW"])
# Out:
# ['VOICE_LOW', 'BB_HIGH', 'TV_LOW']

# %%
usage_df["Play_Usage"] = usage_df.apply(lambda x: play_usage([x["VOICE_Categorical"], x["BB_Categorical"], x["PEO_TV_Categorical"]]), axis=1)

# %%
usage_df
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                        LOW
# 1     002fb47f60400713c854b0f69ff78c0a                        LOW
# 2     00567a4a3c474aca1ce5cd6570648932                        LOW
# 3     00724ae2470df1ed0fe919800d02517d                        LOW
# 4     007400db8afa996e788d23986739f3db                        LOW
# ...                                ...                        ...
# 3302  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                        LOW
# 3303  ffb63ff99cf1354dff1da862f379da80                     MEDIUM
# 3304  ffd697d66cc01c8897ce3e37d693673a                        LOW
# 3305  ffd96f173d6cd683bf3384bdc2f99713                     MEDIUM
# 3306  ffee845c0caa320b55e31bb156827d16                        LOW
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 0                  0.009321                     NO                        LOW
# 1                  0.051339                     NO                        LOW
# 2                  0.002404                     NO                        LOW
# 3                  0.003140                     NO                        LOW
# 4                  0.025755                     NO                        LOW
# ...                     ...                    ...                        ...
# 3302               0.053964                     NO                     MEDIUM
# 3303               0.227924                     NO                     MEDIUM
# 3304               0.002943                     NO                        LOW
# 3305               0.213108                     NO                     MEDIUM
# 3306               0.043122                     NO                     MEDIUM
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 0                  0.017514                     NO
# 1                  0.056319                     NO
# 2                  0.001374                     NO
# 3                  0.002747                     NO
# 4                  0.017857                     NO
# ...                     ...                    ...
# 3302               0.080529                     NO
# 3303               0.173935                     NO
# 3304               0.005495                     NO
# 3305               0.203984                     NO
# 3306               0.112466                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 0                            LOW                0.048813
# 1                            LOW                0.053424
# 2                            LOW                0.003606
# 3                            LOW                0.004808
# 4                            LOW                0.039197
# ...                          ...                     ...
# 3302                         LOW                0.018029
# 3303                        HIGH                0.334012
# 3304                         LOW                0.001202
# 3305                      MEDIUM                0.196281
# 3306                         LOW                0.021635
#
#      OFFNET_OUTGOING_Outlier  ... BB_Categorical  BB_Scaled  \
# 0                         NO  ...             NO   0.000000
# 1                         NO  ...             NO   0.000000
# 2                         NO  ...         MEDIUM   0.619792
# 3                         NO  ...            LOW   0.031250
# 4                         NO  ...             NO   0.000000
# ...                      ...  ...            ...        ...
# 3302                      NO  ...             NO   0.000000
# 3303                      NO  ...             NO   0.000000
# 3304                      NO  ...            LOW   0.013889
# 3305                      NO  ...             NO   0.000000
# 3306                      NO  ...             NO   0.000000
#
#                   Location_Identifier Other_Product_Packages  \
# 0          MSAG5200-ISLMX-NODE5391821                     NO
# 1       MSAG5200-ISLND-PHG-NODE500241                     NO
# 2     MSAG5200-ISLIDH-KGW-NODE6194491                     NO
# 3       MSAG5200-ISLMT-AVR-NODE467161                     NO
# 4     ZXDSL9806H-ISLKL-PRC-NODE482361                     NO
# ...                               ...                    ...
# 3302    MSAG5200-ISLMV-GDM-NODE482491                     NO
# 3303   MSAG5200-ISLWKN-SWP-NODE473481                     NO
# 3304              C300MTP-NODE8700911                     NO
# 3305    MSAG5200-ISLMV-GDM-NODE482491                     NO
# 3306  MSAG5200-ISLIDH-KGW-NODE6194491                     NO
#
#       ONNET_Overall_Categorical OFFNET_Overall_Categorical  \
# 0                           LOW                        LOW
# 1                           LOW                        LOW
# 2                           LOW                        LOW
# 3                           LOW                        LOW
# 4                           LOW                        LOW
# ...                         ...                        ...
# 3302                        LOW                        LOW
# 3303                     MEDIUM                       HIGH
# 3304                        LOW                        LOW
# 3305                     MEDIUM                     MEDIUM
# 3306                        LOW                        LOW
#
#      IDD_Overall_Categorical  VOICE_Categorical    Play_Type  \
# 0                         NO                LOW  SINGLE_PLAY
# 1                        LOW                LOW  SINGLE_PLAY
# 2                         NO                LOW  TRIPLE_PLAY
# 3                         NO                LOW  DOUBLE_PLAY
# 4                        LOW                LOW  SINGLE_PLAY
# ...                      ...                ...          ...
# 3302                     LOW                LOW  SINGLE_PLAY
# 3303                      NO             MEDIUM  SINGLE_PLAY
# 3304                      NO                LOW  DOUBLE_PLAY
# 3305                  MEDIUM             MEDIUM  SINGLE_PLAY
# 3306                      NO                LOW  DOUBLE_PLAY
#
#                              Play_Usage
# 0             [VOICE_LOW, BB_NO, TV_NO]
# 1             [VOICE_LOW, BB_NO, TV_NO]
# 2     [VOICE_LOW, BB_MEDIUM, TV_MEDIUM]
# 3            [VOICE_LOW, BB_LOW, TV_NO]
# 4             [VOICE_LOW, BB_NO, TV_NO]
# ...                                 ...
# 3302          [VOICE_LOW, BB_NO, TV_NO]
# 3303       [VOICE_MEDIUM, BB_NO, TV_NO]
# 3304         [VOICE_LOW, BB_LOW, TV_NO]
# 3305       [VOICE_MEDIUM, BB_NO, TV_NO]
# 3306        [VOICE_LOW, BB_NO, TV_HIGH]
#
# [3307 rows x 32 columns]

# %% [markdown]
# # Product Categories
# - categories derived from "Product State Changes" dataset

# %%
voice_products = ['V_Single VAS Bundle', 'V_Absentee service', 'V_Hotline Service',
       'V_Caller Line Identification', 'V_Call Forwarding Offline',
       'V_Abbreviated Dialing', 'V_Call Transfer Three way',
       'V_Call Forwarding', 'V_Call Waiting',
       'V_Call Forwarding-Immediate', 'V_Outgoing Call Memory',
       'V_Call Forwarding-On Busy', 'V_Call Forwarding-No Answer',
       'V_Cordeless Phone - Installment', 'V_Selective call acceptance',
       'V_Hotline-Immediate', 'V_Call holding', 'V_Hotline-Time Delayed',
       'V_Call Forwarding by time', 'V_Incoming Call Memory',
       'V_Short Message Service', 'V_Secretary service', 'V_Call park',
       'V_Selective call rejection', 'V_Call back on busy',
       'V_Call Forwarding - Immediate', 'V_Anonymous call barring',
       'V_Call Forwarding - On Busy', 'V_Incoming Call Transfer',
       'V_CLI presentation in call waiting', 'V_SLT CLI',
       'V_Sisu Connect', 'V_DQ Contact Details', 'V_IDD',
       'V_SLT Voice Service', 'V_Selective call waiting',
       'V_Do not disturb service', 'V_Complete call on no response',
       'V_Call forwarding selective',
       'V_Password call barring (secret code)', 'V_Detailed Bill',
       'V_Triple VAS Bundle', 'V_Caller name identificationPresentation',
       'V_Caller name sending', 'V_Installment',
       'V_Call Barring - Outgoing', 'V_Call Barring',
       'V_Call Forwarding - No Answer', 'V_Basic Phone Installment',
       'V_Double VAS Bundle', 'V_E-channeling Registration',
       'V_Voice Startup Fee', 'V_Referral offer Discount',
       'V_Miscellaneous Service', 'E_PeoTV_Package Transfer',
       'V_Telehealth', 'V_One-Time Detailed Bill',
       'V_Railway Registration', 'V_Basic Phone','V-Plus1_TeleLife']

# %%
other_products=['E_Referral offer Discount', 'E_PeoTV Initiation',
       'M_Activation Charge', 'E_Video on Demand', 'AB_Megaline',
       'E_TSTV', 'AB_Service Vacation', 'AB_Rental Free',
    'E_SLT PeoTV Service', 'AB_Megaline Startup',
       'AB_Relocation', 'P_IDD',
       'P_Additional features -Double VAS Bundle', 'P_SLT CLI',
       'P_Megaline', 'DQ_Contact Details', 'P_Megaline New Connection',
       'P_Incoming Call Transfer', 'P_Call Transfer Three way',
       'P_Call holding', 'P_Call Forwarding Offline',
       'P_Outgoing Call Memory', 'P_Call back on busy',
       'AB_Citylink Loyalty Rewards', 'AB_Copper Access Bearer',
       'P_One-Time Detailed Bill', 'AB_Referral offer Discount',
       'P_Removal of Int & Parallel Ext', 'AB_Parallel line Installation',
       'OTT_SLT PeoTV Go', 'AB_Additional Distance',
       'P_CLI presentation in call waiting', 'P_Call Forwarding by time',
       'P_Incoming Call Memory', 'P_Anonymous call barring',
       'P_Call park']

# %%
peo_tv_products=['PEO_UTHAYAM', 'PEO_SILVER', 'PRANAMA', 'DOUBLEPROMO',
       'PEO_ENTERTAINMENT', 'PEO_SILVER_PLUS', 'PEO_UNNATHAM',
       'PEO_SILVER_FTTH', 'NEW_SLT_STAFF_PACKAGE', 'BOC', 'PEO_TITANIUM',
       'PEO_GOLD', 'SLT_STAFF_TRIPLE_PLAY', 'NEW_YEAR_TREAT',
       'SLT_STAFF_PEO_UNNATHAM_FTTH', 'SLTStaff_PEO_SILVER',
       'PEO_RELIGIOUS_PACKAGE', 'PEO_PLATINUM', 'LOTUS', 'LEISURE_SPORTS',
       'PEO_FAMILY', 'PEO_SILVER_PLUS_FTTH']

# %%
def select_products(col_list, all_list):
    if col_list == "NO":
        return "NO"
    else:
        products=[]
        for col in literal_eval(col_list):
            for all_val in all_list:
                if col == all_val:
                    products.append(col)
        if len(products)>0:
            return products
        else:
            return "NO"

# %%
# test
select_products("[]",voice_products)
# Out:
# 'NO'

# %%
usage_df["Voice_Packages"] = usage_df.apply(lambda x: select_products(x["Other_Product_Packages"],voice_products), axis=1)

# %%
usage_df["Other_Packages"] = usage_df.apply(lambda x: select_products(x["Other_Product_Packages"],other_products), axis=1)

# %%
usage_df.drop(["Other_Product_Packages"],axis=1, inplace=True)

# %%
usage_df[usage_df['Voice_Packages'] != 'NO']
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 7     009f305bf85a71012c0e343233e611ba                     MEDIUM
# 24    01cdd813d9a8bea5d70455a917c91e63                        LOW
# 79    06c40958738d7ff752abdd8973327e84                     MEDIUM
# 100   08c38286f1a189b638e60f800de4cf98                        LOW
# 102   08eb64b67829f5df06e65577c25d2a53                        LOW
# ...                                ...                        ...
# 3231  f8e6676be134123306b135068462ae31                        LOW
# 3232  f8ed2eeab5cb3467976dec49e5268293                        LOW
# 3239  f987efdcbfcdc0f3f78d4ee6ed37b88a                        LOW
# 3261  fc49108a316204817f42189f9f6e6a70                        LOW
# 3275  fd62e39a7c82e9e9a066aee4307fdf87                        LOW
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 7                  0.249951                     NO                       HIGH
# 24                 0.031324                     NO                        LOW
# 79                 0.193755                     NO                     MEDIUM
# 100                0.001202                     NO                         NO
# 102                0.037995                     NO                        LOW
# ...                     ...                    ...                        ...
# 3231               0.003606                     NO                        LOW
# 3232               0.078616                     NO                        LOW
# 3239               0.006917                     NO                        LOW
# 3261               0.046041                     NO                        LOW
# 3275               0.058109                     NO                        LOW
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 7                  0.593407                    YES
# 24                 0.002747                     NO
# 79                 0.172047                     NO
# 100                0.000000                     NO
# 102                0.030048                     NO
# ...                     ...                    ...
# 3231               0.001374                     NO
# 3232               0.077095                     NO
# 3239               0.008929                     NO
# 3261               0.017170                     NO
# 3275               0.039148                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 7                           HIGH                0.575549
# 24                           LOW                0.019599
# 79                        MEDIUM                0.103635
# 100                          LOW                0.002404
# 102                          LOW                0.043269
# ...                          ...                     ...
# 3231                         LOW                0.001202
# 3232                      MEDIUM                0.221031
# 3239                         LOW                0.010817
# 3261                      MEDIUM                0.086342
# 3275                         LOW                0.040031
#
#      OFFNET_OUTGOING_Outlier  ... BB_Scaled              Location_Identifier  \
# 7                        YES  ...  0.000000    MSAG5200-ISLND-PHG-NODE500241
# 24                        NO  ...  0.236111  ZXDSL9806H-ISLAG-PNP-NODE529761
# 79                        NO  ...  0.000000    MSAG5200-ISLPC-AGT-NODE480031
# 100                       NO  ...  0.000000    MSAG5200-ISLMV-GDM-NODE482491
# 102                       NO  ...  0.000000    MSAG5200-ISLPC-AGT-NODE480031
# ...                      ...  ...       ...                              ...
# 3231                      NO  ...  0.000000        UA5000(IPMB)SL-NODE385341
# 3232                      NO  ...  0.010417  MSAG5200-ISLIDH-KGW-NODE6194491
# 3239                      NO  ...  0.000000            MSAG5200BG-NODE431391
# 3261                      NO  ...  0.052083        MSAG5200PH-AKG-NODE431631
# 3275                      NO  ...  0.338542    MSAG5200-ISLMT-AVR-NODE467161
#
#      ONNET_Overall_Categorical OFFNET_Overall_Categorical  \
# 7                         HIGH                       HIGH
# 24                         LOW                        LOW
# 79                      MEDIUM                     MEDIUM
# 100                        LOW                        LOW
# 102                        LOW                        LOW
# ...                        ...                        ...
# 3231                       LOW                        LOW
# 3232                       LOW                     MEDIUM
# 3239                       LOW                        LOW
# 3261                       LOW                        LOW
# 3275                       LOW                        LOW
#
#       IDD_Overall_Categorical VOICE_Categorical    Play_Type  \
# 7                      MEDIUM              HIGH  SINGLE_PLAY
# 24                         NO               LOW  TRIPLE_PLAY
# 79                         NO            MEDIUM  SINGLE_PLAY
# 100                        NO               LOW  SINGLE_PLAY
# 102                        NO               LOW  SINGLE_PLAY
# ...                       ...               ...          ...
# 3231                       NO               LOW  SINGLE_PLAY
# 3232                       NO            MEDIUM  TRIPLE_PLAY
# 3239                       NO               LOW  DOUBLE_PLAY
# 3261                      LOW               LOW  DOUBLE_PLAY
# 3275                       NO               LOW  TRIPLE_PLAY
#
#                              Play_Usage  \
# 7            [VOICE_HIGH, BB_NO, TV_NO]
# 24         [VOICE_LOW, BB_LOW, TV_HIGH]
# 79         [VOICE_MEDIUM, BB_NO, TV_NO]
# 100           [VOICE_LOW, BB_NO, TV_NO]
# 102           [VOICE_LOW, BB_NO, TV_NO]
# ...                                 ...
# 3231          [VOICE_LOW, BB_NO, TV_NO]
# 3232  [VOICE_MEDIUM, BB_LOW, TV_MEDIUM]
# 3239      [VOICE_LOW, BB_NO, TV_MEDIUM]
# 3261         [VOICE_LOW, BB_LOW, TV_NO]
# 3275    [VOICE_LOW, BB_MEDIUM, TV_HIGH]
#
#                                          Voice_Packages  \
# 7     [V_Abbreviated Dialing, V_Call Transfer Three ...
# 24    [V_Call Waiting, V_Call Forwarding-Immediate, ...
# 79    [V_DQ Contact Details, V_IDD, V_SLT Voice Serv...
# 100   [V_Call Forwarding-Immediate, V_Call Forwardin...
# 102                         [V_Call Barring - Outgoing]
# ...                                                 ...
# 3231  [V_Call Transfer Three way, V_Absentee service...
# 3232  [V_Abbreviated Dialing, V_Call Transfer Three ...
# 3239  [V_Call Forwarding-On Busy, V_Absentee service...
# 3261                        [V_Referral offer Discount]
# 3275             [V_Call Forwarding, V_Hotline Service]
#
#                               Other_Packages
# 7                                         NO
# 24                                        NO
# 79    [AB_Copper Access Bearer, AB_Megaline]
# 100              [E_Video on Demand, E_TSTV]
# 102                                       NO
# ...                                      ...
# 3231                                      NO
# 3232                                      NO
# 3239                                      NO
# 3261            [AB_Referral offer Discount]
# 3275                                      NO
#
# [300 rows x 33 columns]

# %%
usage_df[usage_df['Other_Packages'] != 'NO']
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 71    05cfe8f4323299542b61cfdb60232095                        LOW
# 79    06c40958738d7ff752abdd8973327e84                     MEDIUM
# 100   08c38286f1a189b638e60f800de4cf98                        LOW
# 109   09c78989d21febb16d71f52534dbedcd                        LOW
# 145   0d4860557d1bd99dac04acfa0e42daad                        LOW
# ...                                ...                        ...
# 3189  f676a68c466387d834fece11b5891c86                       HIGH
# 3205  f7508647677b63cfa0f63fe548f3236b                        LOW
# 3261  fc49108a316204817f42189f9f6e6a70                        LOW
# 3263  fc77db5a9efeccfaace51889f68e3f22                     MEDIUM
# 3293  feebdc83f80ba16208b54c2902471410                        LOW
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 71                 0.022248                     NO                        LOW
# 79                 0.193755                     NO                     MEDIUM
# 100                0.001202                     NO                         NO
# 109                0.013589                     NO                        LOW
# 145                0.026025                     NO                        LOW
# ...                     ...                    ...                        ...
# 3189               0.362662                    YES                     MEDIUM
# 3205               0.002404                     NO                        LOW
# 3261               0.046041                     NO                        LOW
# 3263               0.088525                     NO                        LOW
# 3293               0.007947                     NO                        LOW
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 71                 0.009272                     NO
# 79                 0.172047                     NO
# 100                0.000000                     NO
# 109                0.014080                     NO
# 145                0.035371                     NO
# ...                     ...                    ...
# 3189               0.292239                     NO
# 3205               0.002747                     NO
# 3261               0.017170                     NO
# 3263               0.045330                     NO
# 3293               0.034684                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 71                           LOW                0.068779
# 79                        MEDIUM                0.103635
# 100                          LOW                0.002404
# 109                          LOW                0.011185
# 145                       MEDIUM                0.227703
# ...                          ...                     ...
# 3189                      MEDIUM                0.225765
# 3205                         LOW                0.001202
# 3261                      MEDIUM                0.086342
# 3263                         LOW                0.035224
# 3293                         LOW                0.008413
#
#      OFFNET_OUTGOING_Outlier  ... BB_Scaled              Location_Identifier  \
# 71                        NO  ...  0.000000             C300MKI-NODE10668164
# 79                        NO  ...  0.000000    MSAG5200-ISLPC-AGT-NODE480031
# 100                       NO  ...  0.000000    MSAG5200-ISLMV-GDM-NODE482491
# 109                       NO  ...  0.067708    MSAG5200-ISLMT-AVR-NODE467161
# 145                       NO  ...  0.000000        MSAG5200-ISLBZ-NODE435881
# ...                      ...  ...       ...                              ...
# 3189                      NO  ...  0.000000    MSAG5200-ISLMV-GDM-NODE482491
# 3205                      NO  ...  0.000000  MSAG5200-ISLIDH-KGW-NODE6194491
# 3261                      NO  ...  0.052083        MSAG5200PH-AKG-NODE431631
# 3263                      NO  ...  0.531250    MSAG5200-ISLMT-AVR-NODE467161
# 3293                      NO  ...  0.000000    MSAG5200-ISLMV-GDM-NODE482491
#
#      ONNET_Overall_Categorical OFFNET_Overall_Categorical  \
# 71                         LOW                        LOW
# 79                      MEDIUM                     MEDIUM
# 100                        LOW                        LOW
# 109                        LOW                        LOW
# 145                        LOW                        LOW
# ...                        ...                        ...
# 3189                      HIGH                     MEDIUM
# 3205                       LOW                        LOW
# 3261                       LOW                        LOW
# 3263                       LOW                        LOW
# 3293                       LOW                        LOW
#
#       IDD_Overall_Categorical VOICE_Categorical    Play_Type  \
# 71                         NO               LOW  SINGLE_PLAY
# 79                         NO            MEDIUM  SINGLE_PLAY
# 100                        NO               LOW  SINGLE_PLAY
# 109                        NO               LOW  TRIPLE_PLAY
# 145                        NO               LOW  SINGLE_PLAY
# ...                       ...               ...          ...
# 3189                      LOW            MEDIUM  SINGLE_PLAY
# 3205                       NO               LOW  SINGLE_PLAY
# 3261                      LOW               LOW  DOUBLE_PLAY
# 3263                      LOW               LOW  DOUBLE_PLAY
# 3293                      LOW               LOW  SINGLE_PLAY
#
#                          Play_Usage  \
# 71        [VOICE_LOW, BB_NO, TV_NO]
# 79     [VOICE_MEDIUM, BB_NO, TV_NO]
# 100       [VOICE_LOW, BB_NO, TV_NO]
# 109    [VOICE_LOW, BB_LOW, TV_HIGH]
# 145       [VOICE_LOW, BB_NO, TV_NO]
# ...                             ...
# 3189   [VOICE_MEDIUM, BB_NO, TV_NO]
# 3205      [VOICE_LOW, BB_NO, TV_NO]
# 3261     [VOICE_LOW, BB_LOW, TV_NO]
# 3263  [VOICE_LOW, BB_MEDIUM, TV_NO]
# 3293      [VOICE_LOW, BB_NO, TV_NO]
#
#                                          Voice_Packages  \
# 71                                                   NO
# 79    [V_DQ Contact Details, V_IDD, V_SLT Voice Serv...
# 100   [V_Call Forwarding-Immediate, V_Call Forwardin...
# 109                                                  NO
# 145                                                  NO
# ...                                                 ...
# 3189                                                 NO
# 3205                                                 NO
# 3261                        [V_Referral offer Discount]
# 3263                                                 NO
# 3293                                                 NO
#
#                                          Other_Packages
# 71      [E_PeoTV Initiation, E_TSTV, E_Video on Demand]
# 79               [AB_Copper Access Bearer, AB_Megaline]
# 100                         [E_Video on Demand, E_TSTV]
# 109   [E_Referral offer Discount, AB_Referral offer ...
# 145                         [E_Video on Demand, E_TSTV]
# ...                                                 ...
# 3189                        [E_TSTV, E_Video on Demand]
# 3205                              [AB_Service Vacation]
# 3261                       [AB_Referral offer Discount]
# 3263                        [E_Video on Demand, E_TSTV]
# 3293                        [E_Video on Demand, E_TSTV]
#
# [186 rows x 33 columns]

# %% [markdown]
# # Socio-Economic features

# %% [markdown]
# ### Household types
# - Senior Citizen (VOICE_HIGH and TV_HIGH)
# - Kids (TV_HIGH)
# - Working Professional or Student (BB_HIGH)
# - Family Member Abroad (IDD_HIGH)

# %%
def household_types(idd,usage):
    household=[]
    if ("VOICE_HIGH" in usage) and ("TV_HIGH" in usage):
        household.append("Senior_Citizen")
    if "TV_HIGH" in usage:
        household.append("Kids")
    if "BB_HIGH" in usage:
        household.append("Professional_or_Student")
    if idd == "HIGH":
        household.append("Family_Member_Abroad")
    if len(household)>0:
        return household
    else:
        return "NO"

# %%
# test
household_types("HIGH",'["VOICE_HIGH","BB_NO","TV_HIGH"]')
# Out:
# ['Senior_Citizen', 'Kids', 'Family_Member_Abroad']

# %%
usage_df["Household_Types"] = usage_df.apply(lambda x: household_types(x["IDD_Overall_Categorical"],x["Play_Usage"]), axis=1)

# %% [markdown]
# ### Having an Insurance?

# %%
def having_insurance(voice,other, peo):
    having_insurance = "NO"
    insurrence_VAS = ["V_Telehealth", "V-Plus1_TeleLife"]
    for vas in insurrence_VAS:
        if (vas in voice) or (vas in other) or (vas in peo):
            having_insurance = "YES"
    return having_insurance

# %%
usage_df["Having_Insurance"] = usage_df.apply(lambda x: having_insurance(x["Voice_Packages"],x["Other_Packages"],x["Peo_TV_Package"]), axis=1)

# %%
usage_df[usage_df['Having_Insurance'] == 'YES']
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 515   29126104c89f72a50253c47ca6de2c29                        LOW
# 2253  ae96c23b4702df9ff2d918e3b332407a                     MEDIUM
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 515                0.048298                     NO                        LOW
# 2253               0.204670                     NO                     MEDIUM
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 515                0.078640                     NO
# 2253               0.161058                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 515                       MEDIUM                0.266434
# 2253                      MEDIUM                0.216052
#
#      OFFNET_OUTGOING_Outlier  ... ONNET_Overall_Categorical  \
# 515                       NO  ...                       LOW
# 2253                      NO  ...                    MEDIUM
#
#       OFFNET_Overall_Categorical IDD_Overall_Categorical VOICE_Categorical  \
# 515                       MEDIUM                      NO            MEDIUM
# 2253                      MEDIUM                      NO            MEDIUM
#
#         Play_Type                      Play_Usage      Voice_Packages  \
# 515   SINGLE_PLAY    [VOICE_MEDIUM, BB_NO, TV_NO]  [V-Plus1_TeleLife]
# 2253  DOUBLE_PLAY  [VOICE_MEDIUM, BB_NO, TV_HIGH]      [V_Telehealth]
#
#       Other_Packages Household_Types Having_Insurance
# 515               NO              NO              YES
# 2253              NO          [Kids]              YES
#
# [2 rows x 35 columns]

# %%
usage_df
# Out:
#                      event_source.hash ONNET_OUTGOING_Categorical  \
# 0     00221451f705ebe26051158bb14f567a                        LOW
# 1     002fb47f60400713c854b0f69ff78c0a                        LOW
# 2     00567a4a3c474aca1ce5cd6570648932                        LOW
# 3     00724ae2470df1ed0fe919800d02517d                        LOW
# 4     007400db8afa996e788d23986739f3db                        LOW
# ...                                ...                        ...
# 3302  ffb4fa6778bc5b3d9c858f5f4fa1e0c2                        LOW
# 3303  ffb63ff99cf1354dff1da862f379da80                     MEDIUM
# 3304  ffd697d66cc01c8897ce3e37d693673a                        LOW
# 3305  ffd96f173d6cd683bf3384bdc2f99713                     MEDIUM
# 3306  ffee845c0caa320b55e31bb156827d16                        LOW
#
#       ONNET_OUTGOING_Scaled ONNET_OUTGOING_Outlier ONNET_INCOMING_Categorical  \
# 0                  0.009321                     NO                        LOW
# 1                  0.051339                     NO                        LOW
# 2                  0.002404                     NO                        LOW
# 3                  0.003140                     NO                        LOW
# 4                  0.025755                     NO                        LOW
# ...                     ...                    ...                        ...
# 3302               0.053964                     NO                     MEDIUM
# 3303               0.227924                     NO                     MEDIUM
# 3304               0.002943                     NO                        LOW
# 3305               0.213108                     NO                     MEDIUM
# 3306               0.043122                     NO                     MEDIUM
#
#       ONNET_INCOMING_Scaled ONNET_INCOMING_Outlier  \
# 0                  0.017514                     NO
# 1                  0.056319                     NO
# 2                  0.001374                     NO
# 3                  0.002747                     NO
# 4                  0.017857                     NO
# ...                     ...                    ...
# 3302               0.080529                     NO
# 3303               0.173935                     NO
# 3304               0.005495                     NO
# 3305               0.203984                     NO
# 3306               0.112466                     NO
#
#      OFFNET_OUTGOING_Categorical  OFFNET_OUTGOING_Scaled  \
# 0                            LOW                0.048813
# 1                            LOW                0.053424
# 2                            LOW                0.003606
# 3                            LOW                0.004808
# 4                            LOW                0.039197
# ...                          ...                     ...
# 3302                         LOW                0.018029
# 3303                        HIGH                0.334012
# 3304                         LOW                0.001202
# 3305                      MEDIUM                0.196281
# 3306                         LOW                0.021635
#
#      OFFNET_OUTGOING_Outlier  ... ONNET_Overall_Categorical  \
# 0                         NO  ...                       LOW
# 1                         NO  ...                       LOW
# 2                         NO  ...                       LOW
# 3                         NO  ...                       LOW
# 4                         NO  ...                       LOW
# ...                      ...  ...                       ...
# 3302                      NO  ...                       LOW
# 3303                      NO  ...                    MEDIUM
# 3304                      NO  ...                       LOW
# 3305                      NO  ...                    MEDIUM
# 3306                      NO  ...                       LOW
#
#       OFFNET_Overall_Categorical IDD_Overall_Categorical VOICE_Categorical  \
# 0                            LOW                      NO               LOW
# 1                            LOW                     LOW               LOW
# 2                            LOW                      NO               LOW
# 3                            LOW                      NO               LOW
# 4                            LOW                     LOW               LOW
# ...                          ...                     ...               ...
# 3302                         LOW                     LOW               LOW
# 3303                        HIGH                      NO            MEDIUM
# 3304                         LOW                      NO               LOW
# 3305                      MEDIUM                  MEDIUM            MEDIUM
# 3306                         LOW                      NO               LOW
#
#         Play_Type                         Play_Usage Voice_Packages  \
# 0     SINGLE_PLAY          [VOICE_LOW, BB_NO, TV_NO]             NO
# 1     SINGLE_PLAY          [VOICE_LOW, BB_NO, TV_NO]             NO
# 2     TRIPLE_PLAY  [VOICE_LOW, BB_MEDIUM, TV_MEDIUM]             NO
# 3     DOUBLE_PLAY         [VOICE_LOW, BB_LOW, TV_NO]             NO
# 4     SINGLE_PLAY          [VOICE_LOW, BB_NO, TV_NO]             NO
# ...           ...                                ...            ...
# 3302  SINGLE_PLAY          [VOICE_LOW, BB_NO, TV_NO]             NO
# 3303  SINGLE_PLAY       [VOICE_MEDIUM, BB_NO, TV_NO]             NO
# 3304  DOUBLE_PLAY         [VOICE_LOW, BB_LOW, TV_NO]             NO
# 3305  SINGLE_PLAY       [VOICE_MEDIUM, BB_NO, TV_NO]             NO
# 3306  DOUBLE_PLAY        [VOICE_LOW, BB_NO, TV_HIGH]             NO
#
#       Other_Packages Household_Types Having_Insurance
# 0                 NO              NO               NO
# 1                 NO              NO               NO
# 2                 NO              NO               NO
# 3                 NO              NO               NO
# 4                 NO              NO               NO
# ...              ...             ...              ...
# 3302              NO              NO               NO
# 3303              NO              NO               NO
# 3304              NO              NO               NO
# 3305              NO              NO               NO
# 3306              NO          [Kids]               NO
#
# [3307 rows x 35 columns]

# %%
usage_df.to_csv("data/user_profile/prepared/User_Profile.csv")

# %% [markdown]
# ## ToDo
# - enrich user profile with more features (VAS or NOT, Extra GB usage, extra Peo TV Channels, watchTime, Internet usage time, pyment and billing, complaints and inqueries etc.)
