# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly import tools
from plotly.subplots import make_subplots
import plotly.offline as py
import seaborn as sns
from ast import literal_eval
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

# %%
plt.rcParams.update({
    "lines.color": "white",
    "patch.edgecolor": "white",
    "xtick.color": "white",
    "ytick.color": "white",})

# %%
user_profile = pd.read_csv("data/user_profile/prepared/User_Profile_with_clusters.csv")
# Out:
# /home/chiran/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning:
#
# Columns (4,6,7,9,10,12,13,15,16,18,19,20,22,24,25,26,28,30,34,35,36,37,75,76) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
user_profile.drop(["Unnamed: 0"],axis=1,inplace=True)

# %% [markdown]
# ### Cluster Counts

# %%
user_profile["Cluster"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Cluster'>

# %% [markdown]
# # Cluster analysis - Cluster 0

# %%
cluster_0 = user_profile[(user_profile["Cluster"]==0)]

# %%
cluster_0.describe()
# Out:
#        ONNET_OUTGOING_Scaled  ONNET_INCOMING_Scaled  OFFNET_OUTGOING_Scaled  \
# count             264.000000             259.000000              258.000000
# mean                0.109809               0.111656                0.118555
# std                 0.110562               0.107715                0.111667
# min                 0.001202               0.001374                0.001202
# 25%                 0.026761               0.027301                0.037836
# 50%                 0.071159               0.073489                0.089212
# 75%                 0.162554               0.173935                0.161812
# max                 0.482266               0.508242                0.668294
#
#        OFFNET_INCOMING_Scaled  IDD_INCOMING_Scaled  IDD_OUTGOING_Scaled  \
# count              262.000000           140.000000            28.000000
# mean                 0.126485             0.072592             0.071200
# std                  0.100208             0.135285             0.106919
# min                  0.001202             0.002500             0.004808
# 25%                  0.051296             0.005167             0.014022
# 50%                  0.110283             0.016750             0.043269
# 75%                  0.173629             0.065375             0.068910
# max                  0.640453             0.882000             0.480769
#
#        IDD_outgoing_Cumulative_Revenue  PEO_TV_Scaled  BB_Scaled   BIRTH_YEAR  \
# count                     2.800000e+01     125.000000  99.000000   290.000000
# mean                      6.266846e+05       0.504900   0.408986  1964.531034
# std                       1.597776e+06       0.355347   0.269107    11.175886
# min                       1.800000e+03       0.000000   0.005208  1943.000000
# 25%                       2.049975e+04       0.000000   0.192708  1957.000000
# 50%                       1.551245e+05       0.612500   0.343750  1963.500000
# 75%                       3.509250e+05       0.793750   0.579861  1970.750000
# max                       6.679200e+06       0.950000   1.000000  1998.000000
#
#               AGE  BB_Extra_GB_Purchased_Times  BB_Extra_GB_Purchased_Scaled  \
# count  290.000000                  3132.000000                   3132.000000
# mean    56.468966                    43.974138                      0.740984
# std     11.175886                    17.555614                      0.302559
# min     23.000000                     1.000000                      0.010000
# 25%     50.250000                    23.000000                      0.379310
# 50%     57.500000                    58.000000                      0.982759
# 75%     64.000000                    58.000000                      0.982759
# max     78.000000                    58.000000                      0.982759
#
#        Having_Senior_Citizen_Scaled  Having_Kids_at_Home_Scaled  \
# count                    3365.00000                 3365.000000
# mean                        0.51786                    0.763536
# std                         0.07383                    0.278935
# min                         0.50000                    0.000000
# 25%                         0.50000                    0.500000
# 50%                         0.50000                    1.000000
# 75%                         0.50000                    1.000000
# max                         1.10000                    1.100000
#
#        Having_Teenagers_Students_Scaled  Having_Working_Professionals_Scaled  \
# count                       3365.000000                          3365.000000
# mean                           0.582080                             0.662273
# std                            0.174427                             0.191063
# min                            0.000000                             0.000000
# 25%                            0.500000                             0.550000
# 50%                            0.700000                             0.800000
# 75%                            0.700000                             0.800000
# max                            1.300000                             1.250000
#
#        Having_Family_Member_Abroad_Scaled  Cluster
# count                         3365.000000   3365.0
# mean                             0.028158      0.0
# std                              0.167773      0.0
# min                              0.000000      0.0
# 25%                              0.000000      0.0
# 50%                              0.000000      0.0
# 75%                              0.000000      0.0
# max                              2.600000      0.0

# %%
cluster_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3365 entries, 0 to 27232
# Data columns (total 77 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   event_source.hash                    3365 non-null   object
#  1   ACCOUNT_NUM.hash                     3365 non-null   object
#  2   CUSTOMER_REF.hash                    3365 non-null   object
#  3   ONNET_OUTGOING_Categorical           264 non-null    object
#  4   ONNET_OUTGOING_Scaled                264 non-null    float64
#  5   ONNET_OUTGOING_Outlier               264 non-null    object
#  6   ONNET_INCOMING_Categorical           259 non-null    object
#  7   ONNET_INCOMING_Scaled                259 non-null    float64
#  8   ONNET_INCOMING_Outlier               259 non-null    object
#  9   OFFNET_OUTGOING_Categorical          258 non-null    object
#  10  OFFNET_OUTGOING_Scaled               258 non-null    float64
#  11  OFFNET_OUTGOING_Outlier              258 non-null    object
#  12  OFFNET_INCOMING_Categorical          262 non-null    object
#  13  OFFNET_INCOMING_Scaled               262 non-null    float64
#  14  OFFNET_INCOMING_Outlier              262 non-null    object
#  15  IDD_INCOMING_Categorical             140 non-null    object
#  16  IDD_INCOMING_Scaled                  140 non-null    float64
#  17  IDD_INCOMING_Outlier                 140 non-null    object
#  18  IDD_incoming_country                 140 non-null    object
#  19  IDD_OUTGOING_Categorical             28 non-null     object
#  20  IDD_OUTGOING_Scaled                  28 non-null     float64
#  21  IDD_OUTGOING_Outlier                 28 non-null     object
#  22  IDD_outgoing_Cumulative_Revenue      28 non-null     float64
#  23  IDD_outgoing_country                 28 non-null     object
#  24  Peo_TV_Package                       125 non-null    object
#  25  PEO_TV_Categorical                   125 non-null    object
#  26  PEO_TV_Scaled                        125 non-null    float64
#  27  BB_Categorical                       99 non-null     object
#  28  BB_Scaled                            99 non-null     float64
#  29  Location_Identifier                  264 non-null    object
#  30  GENDER                               290 non-null    object
#  31  BIRTH_YEAR                           290 non-null    float64
#  32  AGE                                  290 non-null    float64
#  33  ONNET_Overall_Categorical            266 non-null    object
#  34  OFFNET_Overall_Categorical           262 non-null    object
#  35  IDD_Overall_Categorical              141 non-null    object
#  36  VOICE_Categorical                    262 non-null    object
#  37  Subscription                         3151 non-null   object
#  38  Sub_Type                             3365 non-null   object
#  39  Sub_Usage                            3365 non-null   object
#  40  Sub_Type_State                       3365 non-null   object
#  41  Voice_VAS_Package                    3365 non-null   object
#  42  Voice_VAS_Month_Subscribed           3365 non-null   object
#  43  Voice_VAS_Rental                     3365 non-null   object
#  44  Voice_VAS_One_Time_Charge            3365 non-null   object
#  45  BB_VAS_Package                       3109 non-null   object
#  46  BB_VAS_Month_Subscribed              3109 non-null   object
#  47  BB_VAS_Rental                        3109 non-null   object
#  48  BB_VAS_One_Time_Charge               3109 non-null   object
#  49  Peo_VAS_Package                      608 non-null    object
#  50  Peo_VAS_Month_Subscribed             608 non-null    object
#  51  Peo_VAS_Rental                       608 non-null    object
#  52  Peo_VAS_One_Time_Charge              608 non-null    object
#  53  Other_VAS_Package                    3365 non-null   object
#  54  Other_VAS_Month_Subscribed           3365 non-null   object
#  55  Other_VAS_Rental                     3365 non-null   object
#  56  Other_VAS_One_Time_Charge            3365 non-null   object
#  57  Sub_Update_Date                      3151 non-null   object
#  58  Sub_Update_Status                    3151 non-null   object
#  59  Sub_Update                           3151 non-null   object
#  60  BB_Extra_GB_Purchased_Times          3132 non-null   float64
#  61  BB_Extra_GB_Month_vs_Rental          3132 non-null   object
#  62  BB_Extra_GB_Purchased_Scaled         3132 non-null   float64
#  63  BB_Extra_GB_Purchase_Categorical     3132 non-null   object
#  64  Having_Insurance                     3365 non-null   object
#  65  Having_Senior_Citizen_Scaled         3365 non-null   float64
#  66  Having_Senior_Citizen                3365 non-null   object
#  67  Having_Kids_at_Home_Scaled           3365 non-null   float64
#  68  Having_Kids_at_Home                  3110 non-null   object
#  69  Having_Teenagers_Students_Scaled     3365 non-null   float64
#  70  Having_Teenagers_Students            3099 non-null   object
#  71  Having_Working_Professionals_Scaled  3365 non-null   float64
#  72  Having_Working_Professionals         3110 non-null   object
#  73  Having_Family_Member_Abroad_Scaled   3365 non-null   float64
#  74  Having_Family_Member_Abroad          79 non-null     object
#  75  Tamil_Customer                       25 non-null     object
#  76  Cluster                              3365 non-null   int64
# dtypes: float64(18), int64(1), object(58)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Distribution: Usage

# %%
cluster_0.iloc[:,[4,7,10,13,16,20,26,28,62]].boxplot(figsize=(10,7),rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Usage of randomly selected users

# %%
cluster_0.iloc[:,[4,7,10,13,16,20,26,28,62]].sample(n=10).plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
cluster_0.iloc[:,[4,7,10,13,16,20,26,28,62]].plot.kde(figsize=(20,30),subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>], dtype=object)

# %%
cluster_0.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'ONNET_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'ONNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'OFFNET_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'OFFNET_INCOMING_Scaled'}>],
#        [<AxesSubplot:title={'center':'IDD_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_outgoing_Cumulative_Revenue'}>,
#         <AxesSubplot:title={'center':'PEO_TV_Scaled'}>],
#        [<AxesSubplot:title={'center':'BB_Scaled'}>,
#         <AxesSubplot:title={'center':'BIRTH_YEAR'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'BB_Extra_GB_Purchased_Times'}>],
#        [<AxesSubplot:title={'center':'BB_Extra_GB_Purchased_Scaled'}>,
#         <AxesSubplot:title={'center':'Having_Senior_Citizen_Scaled'}>,
#         <AxesSubplot:title={'center':'Having_Kids_at_Home_Scaled'}>,
#         <AxesSubplot:title={'center':'Having_Teenagers_Students_Scaled'}>],
#        [<AxesSubplot:title={'center':'Having_Working_Professionals_Scaled'}>,
#         <AxesSubplot:title={'center':'Having_Family_Member_Abroad_Scaled'}>,
#         <AxesSubplot:title={'center':'Cluster'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### Subscription Type and Usage

# %%
cluster_0["Sub_Type"].value_counts()
# Out:
# DOUBLE_PLAY_BV    1937
# DOUBLE_PLAY_PV    1192
# TRIPLE_PLAY        214
# SINGLE_PLAY         22
# Name: Sub_Type, dtype: int64

# %%
cluster_0["Sub_Usage"].value_counts()
# Out:
# ['VOICE_NO_INFO', 'BB_NO_INFO', 'TV_NO_INFO']    3100
# ['VOICE_LOW', 'BB_NO_INFO', 'TV_NO_INFO']          77
# ['VOICE_MEDIUM', 'BB_NO_INFO', 'TV_NO_INFO']       24
# ['VOICE_LOW', 'BB_NO_INFO', 'TV_HIGH']             16
# ['VOICE_LOW', 'BB_NO_INFO', 'TV_NO']               16
# ['VOICE_LOW', 'BB_NO_INFO', 'TV_MEDIUM']           13
# ['VOICE_LOW', 'BB_LOW', 'TV_NO_INFO']              12
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_HIGH']              11
# ['VOICE_LOW', 'BB_LOW', 'TV_HIGH']                 10
# ['VOICE_LOW', 'BB_HIGH', 'TV_HIGH']                 8
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_NO_INFO']            7
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_NO_INFO']            7
# ['VOICE_LOW', 'BB_LOW', 'TV_NO']                    6
# ['VOICE_LOW', 'BB_HIGH', 'TV_NO_INFO']              4
# ['VOICE_MEDIUM', 'BB_NO_INFO', 'TV_MEDIUM']         4
# ['VOICE_HIGH', 'BB_NO_INFO', 'TV_NO_INFO']          4
# ['VOICE_LOW', 'BB_HIGH', 'TV_NO']                   4
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_HIGH']            4
# ['VOICE_LOW', 'BB_HIGH', 'TV_MEDIUM']               3
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_NO']                 3
# ['VOICE_LOW', 'BB_LOW', 'TV_MEDIUM']                3
# ['VOICE_LOW', 'BB_NO_INFO', 'TV_LOW']               3
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_MEDIUM']             2
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_MEDIUM']             2
# ['VOICE_MEDIUM', 'BB_NO_INFO', 'TV_HIGH']           2
# ['VOICE_NO_INFO', 'BB_NO_INFO', 'TV_NO']            2
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_HIGH']               2
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_MEDIUM']          2
# ['VOICE_HIGH', 'BB_LOW', 'TV_NO_INFO']              2
# ['VOICE_NO_INFO', 'BB_NO_INFO', 'TV_HIGH']          1
# ['VOICE_HIGH', 'BB_NO_INFO', 'TV_NO']               1
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_NO_INFO']         1
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_MEDIUM']            1
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_NO_INFO']           1
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_NO']              1
# ['VOICE_HIGH', 'BB_MEDIUM', 'TV_NO_INFO']           1
# ['VOICE_HIGH', 'BB_NO_INFO', 'TV_HIGH']             1
# ['VOICE_MEDIUM', 'BB_NO_INFO', 'TV_LOW']            1
# ['VOICE_HIGH', 'BB_LOW', 'TV_HIGH']                 1
# ['VOICE_MEDIUM', 'BB_NO_INFO', 'TV_NO']             1
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_NO']                1
# Name: Sub_Usage, dtype: int64

# %%
len(cluster_0[(cluster_0["Sub_Usage"] != "['VOICE_NO_INFO', 'BB_NO_INFO', 'TV_NO_INFO']")]["Sub_Usage"])
# Out:
# 265

# %%
ax =cluster_0[(cluster_0["Sub_Usage"] != "['VOICE_NO_INFO', 'BB_NO_INFO', 'TV_NO_INFO']")]["Sub_Usage"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Voice Calls Usage

# %%
cluster_0["VOICE_Categorical"].value_counts()
# Out:
# LOW       198
# MEDIUM     54
# HIGH       10
# Name: VOICE_Categorical, dtype: int64

# %%
Voice_map = {"all":len(cluster_0["VOICE_Categorical"]),"notnull":len(cluster_0[(cluster_0["VOICE_Categorical"].notna())]["IDD_Overall_Categorical"])}

# %%
Voice_map
# Out:
# {'all': 3365, 'notnull': 262}

# %%
pd.DataFrame(Voice_map.items(),columns=["all","notnull"])["notnull"].plot(kind='pie', figsize=(6,6), autopct='%1.1f%%',colors = ['red','yellow'])
# Out:
# <AxesSubplot:ylabel='notnull'>

# %%
cluster_0["VOICE_Categorical"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%',colors = ['pink', 'yellow','green'] )
# Out:
# <AxesSubplot:ylabel='VOICE_Categorical'>

# %% [markdown]
# ### VOICE VAS Packages

# %%
count_dict = dict(cluster_0["Voice_VAS_Package"].value_counts())
all_products = []
for x,y in count_dict.items():
    if not isinstance(x, float):
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
all_voice_products_dict = Counter(all_products)

# %%
all_voice_products_dict.pop('V_SLT Voice Service')
# Out:
# 3121

# %%
avp_without_no = all_voice_products_dict
#avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(20,14))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### IDD Usage

# %%
cluster_0["IDD_Overall_Categorical"].value_counts()
# Out:
# LOW       139
# MEDIUM      2
# Name: IDD_Overall_Categorical, dtype: int64

# %%
IDD_map = {"all":len(cluster_0["IDD_Overall_Categorical"]),"notnull":len(cluster_0[(cluster_0["IDD_Overall_Categorical"].notna())]["IDD_Overall_Categorical"])}

# %%
IDD_map
# Out:
# {'all': 3365, 'notnull': 141}

# %%
pd.DataFrame(IDD_map.items(),columns=["all","notnull"])["notnull"].plot(kind='pie', figsize=(6,6), autopct='%1.1f%%',colors = ['red','yellow'])
# Out:
# <AxesSubplot:ylabel='notnull'>

# %%
cluster_0["IDD_Overall_Categorical"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%',colors = ['pink','yellow','green'] )
# Out:
# <AxesSubplot:ylabel='IDD_Overall_Categorical'>

# %% [markdown]
# ### PeoTV Usage

# %%
cluster_0["PEO_TV_Categorical"].value_counts()
# Out:
# HIGH      56
# NO        35
# MEDIUM    30
# LOW        4
# Name: PEO_TV_Categorical, dtype: int64

# %%
Peo_map = {"all":len(cluster_0["PEO_TV_Categorical"]),"notnull":len(cluster_0[(cluster_0["PEO_TV_Categorical"].notna())]["IDD_Overall_Categorical"])}

# %%
Peo_map
# Out:
# {'all': 3365, 'notnull': 125}

# %%
pd.DataFrame(Peo_map.items(),columns=["all","notnull"])["notnull"].plot(kind='pie', figsize=(6,6), autopct='%1.1f%%',colors = ['red','yellow'])
# Out:
# <AxesSubplot:ylabel='notnull'>

# %% [markdown]
# #### PeoTV Usage among Triple Play users in Cluster 0

# %%
cluster_0_peo = cluster_0[(cluster_0["Sub_Type"] == "TRIPLE_PLAY")]
cluster_0_peo["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%',colors = ['pink','yellow','green','red'])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %%
ax =cluster_0_peo["Peo_TV_Package"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# #### PeoTV Usage among Double Play PV users in Cluster 0

# %%
cluster_0_peo_pv = cluster_0[(cluster_0["Sub_Type"] == "DOUBLE_PLAY_PV")]
cluster_0_peo_pv["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(9,9), autopct='%1.1f%%',colors = ['green','yellow','red','pink'])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %%
ax =cluster_0_peo_pv["Peo_TV_Package"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### PEO TV VAS Packages

# %%
count_dict = dict(cluster_0["Peo_VAS_Package"].value_counts())
all_products = []
for x,y in count_dict.items():
    if not isinstance(x, float):
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
all_peo_products_dict = Counter(all_products)

# %%
avp_without_no = all_peo_products_dict
#avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(8,10))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## ToDo
# - Peo Monthly rental/ One time charge/ subscribed timeframes analysis

# %% [markdown]
# ### BroadBand Internet Usage

# %%
cluster_0["BB_Categorical"].value_counts()
# Out:
# LOW       45
# MEDIUM    32
# HIGH      22
# Name: BB_Categorical, dtype: int64

# %%
BB_map = {"all":len(cluster_0["BB_Categorical"]),"notnull":len(cluster_0[(cluster_0["BB_Categorical"].notna())]["IDD_Overall_Categorical"])}

# %%
BB_map
# Out:
# {'all': 3365, 'notnull': 99}

# %%
pd.DataFrame(BB_map.items(),columns=["all","notnull"])["notnull"].plot(kind='pie', figsize=(6,6), autopct='%1.1f%%',colors = ['red','yellow'])
# Out:
# <AxesSubplot:ylabel='notnull'>

# %% [markdown]
# #### BB Usage for triple Play users in Cluster 0

# %%
cluster_0_bb = cluster_0[(cluster_0["Sub_Type"] == "TRIPLE_PLAY")]
cluster_0_bb["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%',colors = ['pink','yellow','green'])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# #### BB Usage for Double Play BV Customers in Cluster 0

# %%
cluster_0_bb_dp = cluster_0[(cluster_0["Sub_Type"] == "DOUBLE_PLAY_BV")]
cluster_0_bb_dp["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%',colors = ['pink','yellow','green'])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# ### BB VAS Package

# %%
count_dict = dict(cluster_0["BB_VAS_Package"].value_counts())
all_products = []
for x,y in count_dict.items():
    if not isinstance(x, float):
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
all_bb_products_dict = Counter(all_products)

# %%
avp_without_no = all_bb_products_dict
#avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(8,10))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## ToDo
# - Extra GB Usage analysis
# - BB Monthly rental/ One time charge/ subscribed timeframes analysis

# %% [markdown]
# ## User Location

# %%
ax =cluster_0["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# #### User locations of Triply play customers

# %%
ax =cluster_0_peo["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# #### User locations of double play PV customers

# %%
ax =cluster_0_peo_pv["Location_Identifier"].value_counts().plot(kind='bar', figsize=(15,7))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# #### User locations of double play BV customers

# %%
ax =cluster_0_bb_dp["Location_Identifier"].value_counts().plot(kind='bar', figsize=(15,7))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Socio-economic factors

# %% [markdown]
# ## ToDo
# - Analyze Socio Economic factors

# %%
cluster_0["Having_Insurance"].value_counts()
# Out:
# YES    3365
# Name: Having_Insurance, dtype: int64

# %% [markdown]
# ## Cluster 0 - Findings

# %% [markdown]
# - Subscription: Signle Play (But having 60 Triple Play customers as well?)
# - Subscription Usage:
#   - Voice: low Usage | **68% L** | **28% M* | **4% H**
#   - BB (Overall): Very low usage | **3% Low** | **97% NO**
#   - BB (Usage among Triple Play cusomers): Very Low | **95% L** | **5% M**
#   - PeoTV (Overall): Very low usage | **3% L** | **97% NO**
#   - PeoTV (Usage among Triple Play cusomers): Very Low | **96.7% L** | **3.3% M**
#   - Triple Play Users have **very low** use of BB and PeoTV (Maybe thats why they are in this cluster?)
# - IDD Usage: Low | **61% NO** | **34% LOW**
# - Mostly Used Voice package - V_Call Forwarding (4%)
# - Mostly used PeoTV package (among Triple Play users) - Peo Silver (83%)
# - Locations - **MSAG5200** | MSAG5200-ISLND-PHG-NODE500241 (14%), MSAG5200-ISLMV-GDM-NODE482491(12%),
# - Household : Mostly No information found **97%** |  some households have family members abroad **2%**
# - Only 1 User having Insurrance Coverage. This cannot be commented as we only have 2 users for whole dataset having an insurrance

# %% [markdown]
# # Cluster analysis - Cluster 1

# %%
cluster_1 = user_profile[(user_profile["Cluster"]==1)]

# %%
cluster_1.describe()
# Out:
#        ONNET_OUTGOING_Scaled  ONNET_INCOMING_Scaled  OFFNET_OUTGOING_Scaled  \
# count             561.000000             561.000000              561.000000
# mean                0.101772               0.098437                0.106371
# std                 0.091440               0.093265                0.101327
# min                 0.001202               0.000000                0.000000
# 25%                 0.027522               0.020948                0.026810
# 50%                 0.079548               0.063874                0.078493
# 75%                 0.152914               0.157795                0.157452
# max                 0.521929               0.540865                0.667092
#
#        OFFNET_INCOMING_Scaled  IDD_INCOMING_Scaled  IDD_OUTGOING_Scaled  \
# count              561.000000           561.000000           561.000000
# mean                 0.114133             0.037010             0.017400
# std                  0.093224             0.111117             0.080858
# min                  0.000000             0.000000             0.000000
# 25%                  0.036270             0.000000             0.000000
# 50%                  0.101526             0.000000             0.000000
# 75%                  0.166331             0.012821             0.000000
# max                  0.712569             0.807692             0.833333
#
#        PEO_TV_Scaled   BB_Scaled  Cluster
# count     561.000000  561.000000    561.0
# mean        0.747861    0.406445      1.0
# std         0.188249    0.251168      0.0
# min         0.093750    0.005208      1.0
# 25%         0.618750    0.201389      1.0
# 50%         0.775000    0.364583      1.0
# 75%         0.918750    0.578125      1.0
# max         0.975000    1.000000      1.0

# %%
cluster_1.iloc[:,:34].boxplot(figsize=(10,7),rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Usage among selected sample of users

# %%
cluster_1.iloc[:,[2,5,8,11,14,17,21,23]].sample(n=10).plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
cluster_1.iloc[:,[2,5,8,11,14,17,21,23]].plot.kde(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cluster_1.iloc[:,:34].hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'ONNET_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'ONNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'OFFNET_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'OFFNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'PEO_TV_Scaled'}>,
#         <AxesSubplot:title={'center':'BB_Scaled'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### Subscription Type and Usage

# %%
cluster_1["Play_Type"].value_counts()
# Out:
# TRIPLE_PLAY    561
# Name: Play_Type, dtype: int64

# %%
cluster_1["Play_Usage"].value_counts()
# Out:
# ['VOICE_LOW', 'BB_LOW', 'TV_HIGH']            95
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_HIGH']         81
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_HIGH']      70
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_HIGH']         63
# ['VOICE_LOW', 'BB_LOW', 'TV_MEDIUM']          60
# ['VOICE_LOW', 'BB_HIGH', 'TV_HIGH']           38
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_MEDIUM']       30
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_HIGH']        27
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_MEDIUM']       24
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_MEDIUM']    18
# ['VOICE_LOW', 'BB_HIGH', 'TV_MEDIUM']         17
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_MEDIUM']      10
# ['VOICE_HIGH', 'BB_LOW', 'TV_HIGH']            6
# ['VOICE_LOW', 'BB_HIGH', 'TV_LOW']             5
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_LOW']           3
# ['VOICE_HIGH', 'BB_MEDIUM', 'TV_HIGH']         3
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_LOW']        3
# ['VOICE_HIGH', 'BB_HIGH', 'TV_LOW']            2
# ['VOICE_HIGH', 'BB_HIGH', 'TV_HIGH']           2
# ['VOICE_HIGH', 'BB_LOW', 'TV_MEDIUM']          2
# ['VOICE_LOW', 'BB_LOW', 'TV_LOW']              1
# ['VOICE_HIGH', 'BB_MEDIUM', 'TV_MEDIUM']       1
# Name: Play_Usage, dtype: int64

# %%
ax =cluster_1["Play_Usage"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Voice Calls Usage

# %%
cluster_1["VOICE_Categorical"].value_counts()
# Out:
# LOW       324
# MEDIUM    221
# HIGH       16
# Name: VOICE_Categorical, dtype: int64

# %%
cluster_1["VOICE_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='VOICE_Categorical'>

# %%
count_dict = dict(cluster_1["Voice_Packages"].value_counts())
all_products = []
for x,y in count_dict.items():
    if x != "NO":
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
    else:
        for i in range(y):
            all_products.append(x)
all_voice_products_dict = Counter(all_products)

# %%
avp_without_no = all_voice_products_dict
avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(20,10))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### IDD Usage

# %%
cluster_1["IDD_Overall_Categorical"].value_counts()
# Out:
# NO        333
# LOW       204
# HIGH       15
# MEDIUM      9
# Name: IDD_Overall_Categorical, dtype: int64

# %%
cluster_1["IDD_Overall_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='IDD_Overall_Categorical'>

# %% [markdown]
# ### PeoTV Usage

# %%
cluster_1["PEO_TV_Categorical"].value_counts()
# Out:
# HIGH      385
# MEDIUM    162
# LOW        14
# Name: PEO_TV_Categorical, dtype: int64

# %%
cluster_1["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["green","yellow","pink"])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %%
ax =cluster_1["Peo_TV_Package"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### BroadBand Internet Usage

# %%
cluster_1["BB_Categorical"].value_counts()
# Out:
# LOW       257
# MEDIUM    203
# HIGH      101
# Name: BB_Categorical, dtype: int64

# %%
cluster_1["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# ### User Location

# %%
ax =cluster_1["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Socio-economic factors

# %%
cluster_1["Household_Types"].value_counts()
# Out:
# ['Kids']                                                       301
# NO                                                             140
# ['Kids', 'Professional_or_Student']                             62
# ['Professional_or_Student']                                     33
# ['Kids', 'Family_Member_Abroad']                                 8
# ['Senior_Citizen', 'Kids']                                       8
# ['Kids', 'Professional_or_Student', 'Family_Member_Abroad']      3
# ['Family_Member_Abroad']                                         2
# ['Senior_Citizen', 'Kids', 'Professional_or_Student']            2
# ['Senior_Citizen', 'Kids', 'Family_Member_Abroad']               1
# ['Professional_or_Student', 'Family_Member_Abroad']              1
# Name: Household_Types, dtype: int64

# %%
ax = cluster_1["Household_Types"].value_counts().plot(kind='bar', figsize=(10,6))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()
    
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %%
cluster_1["Having_Insurance"].value_counts()
# Out:
# NO    561
# Name: Having_Insurance, dtype: int64

# %% [markdown]
# ## Cluster 1 - Findings

# %% [markdown]
# - Subscription: Triple Play
# - Subscription Usage:
#   - Peo TV **High** usage | **H 67%** | **M 28%** | **L 5%**
#   - BB **Medium** usage | **H 18%** | **M 36%** | **L 45%**
#   - VOICE **Low** usage | **H 3%** | **M 39%** | **L 57%**
# - IDD Usage: Very low  | **No usage 59%** | **Low Usage 36%**
# - Mostly used Voice package - **V_Call Transfer Three way** and **V_Call Forwarding** (4%)
# - Mostly used PeoTV package - Peo_Silver (68%)
# - Household : Mostly Kids and senior citizens(55%), Some probability of having Working Professional or Students (17%)
# - Location : Mostly in MSAN: MSAG5200 - 65%
# - No Insurrance Coverage

# %% [markdown]
# # Cluster analysis - Cluster 2

# %%
cluster_2 = user_profile[(user_profile["Cluster"]==2)]

# %%
cluster_2.describe()
# Out:
#        ONNET_OUTGOING_Scaled  ONNET_INCOMING_Scaled  OFFNET_OUTGOING_Scaled  \
# count            1025.000000            1025.000000             1025.000000
# mean                0.100434               0.098378                0.104891
# std                 0.104874               0.106129                0.113736
# min                 0.001202               0.000000                0.000000
# 25%                 0.019304               0.015968                0.020801
# 50%                 0.063825               0.061985                0.068779
# 75%                 0.156937               0.151957                0.147346
# max                 0.795894               0.742788                0.705357
#
#        OFFNET_INCOMING_Scaled  IDD_INCOMING_Scaled  IDD_OUTGOING_Scaled  \
# count             1025.000000          1025.000000          1025.000000
# mean                 0.102195             0.036332             0.013907
# std                  0.094631             0.104220             0.061302
# min                  0.000000             0.000000             0.000000
# 25%                  0.026213             0.000000             0.000000
# 50%                  0.081019             0.000000             0.000000
# 75%                  0.149088             0.014423             0.000000
# max                  0.640453             0.884615             0.785256
#
#        PEO_TV_Scaled    BB_Scaled  Cluster
# count    1025.000000  1025.000000   1025.0
# mean        0.245049     0.197636      2.0
# std         0.338322     0.260511      0.0
# min         0.000000     0.000000      2.0
# 25%         0.000000     0.000000      2.0
# 50%         0.000000     0.081597      2.0
# 75%         0.575000     0.307292      2.0
# max         0.950000     1.000000      2.0

# %%
cluster_2.iloc[:,:34].boxplot(figsize=(10,7),rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Usage among sample of users

# %%
cluster_2.iloc[:,[2,5,8,11,14,17,21,23]].sample(n=10).plot.bar(stacked=True, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
cluster_2.iloc[:,[2,5,8,11,14,17,21,23]].plot.kde(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cluster_2.iloc[:,:34].hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'ONNET_OUTGOING_Scaled'}>,
#         <AxesSubplot:title={'center':'ONNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'OFFNET_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'OFFNET_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_INCOMING_Scaled'}>,
#         <AxesSubplot:title={'center':'IDD_OUTGOING_Scaled'}>],
#        [<AxesSubplot:title={'center':'PEO_TV_Scaled'}>,
#         <AxesSubplot:title={'center':'BB_Scaled'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### Subscription Type and Usage

# %%
cluster_2["Play_Type"].value_counts()
# Out:
# DOUBLE_PLAY    1025
# Name: Play_Type, dtype: int64

# %%
cluster_2["Play_Usage"].value_counts()
# Out:
# ['VOICE_LOW', 'BB_LOW', 'TV_NO']          242
# ['VOICE_LOW', 'BB_NO', 'TV_HIGH']         131
# ['VOICE_MEDIUM', 'BB_LOW', 'TV_NO']       122
# ['VOICE_LOW', 'BB_MEDIUM', 'TV_NO']       101
# ['VOICE_LOW', 'BB_NO', 'TV_MEDIUM']        80
# ['VOICE_MEDIUM', 'BB_NO', 'TV_HIGH']       76
# ['VOICE_LOW', 'BB_HIGH', 'TV_NO']          66
# ['VOICE_MEDIUM', 'BB_NO', 'TV_MEDIUM']     52
# ['VOICE_LOW', 'BB_NO', 'TV_LOW']           42
# ['VOICE_MEDIUM', 'BB_MEDIUM', 'TV_NO']     38
# ['VOICE_MEDIUM', 'BB_HIGH', 'TV_NO']       25
# ['VOICE_HIGH', 'BB_LOW', 'TV_NO']          16
# ['VOICE_MEDIUM', 'BB_NO', 'TV_LOW']        13
# ['VOICE_HIGH', 'BB_MEDIUM', 'TV_NO']        7
# ['VOICE_HIGH', 'BB_HIGH', 'TV_NO']          4
# ['VOICE_HIGH', 'BB_NO', 'TV_HIGH']          4
# ['VOICE_HIGH', 'BB_NO', 'TV_MEDIUM']        3
# ['VOICE_HIGH', 'BB_NO', 'TV_LOW']           3
# Name: Play_Usage, dtype: int64

# %%
ax =cluster_2["Play_Usage"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Double Play categories

# %%
tv_users = cluster_2[(cluster_2["BB_Categorical"] == "NO") & (cluster_2["PEO_TV_Categorical"] != "NO")]["event_source.hash"].count()
bb_users = cluster_2[(cluster_2["BB_Categorical"] != "NO") & (cluster_2["PEO_TV_Categorical"] == "NO")]["event_source.hash"].count()
new_dict= {"Double Play(Voice+BB)": bb_users, "Double Play(Voice+|PeoTV)": tv_users}
print(new_dict)

colors=["pink","gray"]
fig,ax = plt.subplots(figsize=(5,5))
ax.bar(*zip(*new_dict.items()), color=colors)
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/1025:.0%}', (x + width/2, y + height*1.02), ha='center')
plt.show()
# Out:
# {'Double Play(Voice+BB)': 621, 'Double Play(Voice+|PeoTV)': 404}

# %% [markdown]
# ### Voice Calls Usage

# %%
cluster_2["VOICE_Categorical"].value_counts()
# Out:
# LOW       662
# MEDIUM    326
# HIGH       37
# Name: VOICE_Categorical, dtype: int64

# %%
cluster_2["VOICE_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='VOICE_Categorical'>

# %%
count_dict = dict(cluster_2["Voice_Packages"].value_counts())
all_products = []
for x,y in count_dict.items():
    if x != "NO":
        for item in literal_eval(x):
            for i in range(y):
                all_products.append(item)
    else:
        for i in range(y):
            all_products.append(x)
all_voice_products_dict = Counter(all_products)

# %%
avp_without_no = all_voice_products_dict
avp_without_no.pop("NO")
fig,ax = plt.subplots(figsize=(20,10))
ax.bar(*zip(*avp_without_no.items()))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### IDD Usage

# %%
cluster_2["IDD_Overall_Categorical"].value_counts()
# Out:
# NO        625
# LOW       352
# MEDIUM     35
# HIGH       13
# Name: IDD_Overall_Categorical, dtype: int64

# %%
cluster_2["IDD_Overall_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='IDD_Overall_Categorical'>

# %% [markdown]
# ### PeoTV Usage

# %%
cluster_2["PEO_TV_Categorical"].value_counts()
# Out:
# NO        621
# HIGH      211
# MEDIUM    135
# LOW        58
# Name: PEO_TV_Categorical, dtype: int64

# %% [markdown]
# #### Usage among All users in cluster

# %%
cluster_2["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","green","yellow","pink"])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %% [markdown]
# #### Usage among VOICE + PeoTV Users

# %%
cluster_2_peo = cluster_2[(cluster_2["BB_Categorical"] == "NO") & (cluster_2["PEO_TV_Categorical"] != "NO")]
cluster_2_peo["PEO_TV_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["green","yellow","pink"])
# Out:
# <AxesSubplot:ylabel='PEO_TV_Categorical'>

# %%
ax =cluster_2_peo["Peo_TV_Package"].value_counts().plot(kind='bar', figsize=(10,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### BroadBand Internet Usage

# %%
cluster_2["BB_Categorical"].value_counts()
# Out:
# NO        404
# LOW       380
# MEDIUM    146
# HIGH       95
# Name: BB_Categorical, dtype: int64

# %% [markdown]
# #### Usage among All users in cluster

# %%
cluster_2["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["red","pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# #### Usage among Voice + BB Users

# %%
cluster_2_bb = cluster_2[(cluster_2["BB_Categorical"] != "NO") & (cluster_2["PEO_TV_Categorical"] == "NO")]
cluster_2_bb["BB_Categorical"].value_counts().plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', colors=["pink","yellow","green"])
# Out:
# <AxesSubplot:ylabel='BB_Categorical'>

# %% [markdown]
# ### User Location

# %%
ax =cluster_2["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# #### User locations of Voice + BB customers

# %%
ax =cluster_2_bb["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# #### User locations of Voice + peoTV customers

# %%
ax =cluster_2_peo["Location_Identifier"].value_counts().plot(kind='bar', figsize=(20,10))

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()

for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ### Socio-economic factors

# %%
cluster_2["Household_Types"].value_counts()
# Out:
# NO                                                     709
# ['Kids']                                               205
# ['Professional_or_Student']                             94
# ['Family_Member_Abroad']                                10
# ['Senior_Citizen', 'Kids']                               4
# ['Kids', 'Family_Member_Abroad']                         2
# ['Professional_or_Student', 'Family_Member_Abroad']      1
# Name: Household_Types, dtype: int64

# %%
ax = cluster_2["Household_Types"].value_counts().plot(kind='bar', figsize=(10,6),color=["red","green","green","green","green","green","green","green"])

total_height = 0
for p in ax.patches:
    total_height = total_height + p.get_height()
    
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height/total_height:.0%}', (x + width/2, y + height*1.02), ha='center')

# %%
cluster_2["Having_Insurance"].value_counts()
# Out:
# NO     1024
# YES       1
# Name: Having_Insurance, dtype: int64

# %% [markdown]
# ## Cluster 2 - Findings

# %% [markdown]
# - Subscription: Double Play (Voice + BB, Voice + PeoTV)
# - Subscripotion Types:
#   - Voice + BB Highest | **61%**
#   - Voice + PeoTV Lowest | **39%**
# - Subscription Usage:
#   - Voice: **Low** | **64% L** | **31% M** | **3.6% H**
#   - BB (Among Voice+BB Users): Low usage | **61% L** | **23% M** | **15% H**
#   - PeoTV (Among Voice+peoTV Users): High usage | **52% H** | **33% M** | **14% L**
# - IDD Usage: Very Low | **61% NO** | **34% LOW**
# - Mostly Used Voice package - V_Call Forwarding (4%)
# - Mostly used PeoTV Package (Among Voice + PeoTV Subscribers) - Peo_Sliver (64%)
# - Household : Mostly No information found **69%** | some have kids **20%** | some have professions or students **9**
# - Location: Motly in MSAN : MSAG5200 (67%)
#   - All Users - MSAG5200PH-AKG-NODE431631 (9%)
#   - Voice + BB Users - MSAG5200PH-AKG-NODE431631 (8%)
#   - Voice + PeoTV Users - MSAG5200-ISLMT-AVR-NODE467161 (11%)
# - Only 1 User having Insurrance Coverage. This cannot be commented as we only have 2 users for whole dataset having an insurrance

# %% [markdown]
# # Inter-clusters Analysis

# %% [markdown]
# ## Voice Usage

# %%
voice_usage = user_profile[["Cluster","VOICE_Categorical"]].value_counts().sort_index()
voice_usage
# Out:
# Cluster  VOICE_Categorical
# 0        HIGH                   66
#          LOW                  1170
#          MEDIUM                485
# 1        HIGH                   16
#          LOW                   324
#          MEDIUM                221
# 2        HIGH                   37
#          LOW                   662
#          MEDIUM                326
# dtype: int64

# %%
voice_usage.plot(kind='pie', figsize=(15,15), autopct='%1.1f%%',colors=["#4d9900","#99ff33","#85e085","#990099","#ff66ff","#df80ff","#004d80","#0099ff","#66c2ff"])
# Out:
# <AxesSubplot:ylabel='None'>

# %%
colors = ['#4D3425','#4D3425','#4D3425','#E4512B','#E4512B','#E4512B',"#C12345","#C12345","#C12345"]
voice_usage.plot(stacked=True, kind="bar", figsize=(10,10),color=colors)
# Out:
# <AxesSubplot:xlabel='Cluster,VOICE_Categorical'>

# %%
ax = voice_usage[:3].plot(stacked=True, kind="bar", figsize=(10,10), color="green")
voice_usage[6:9].plot(stacked=True, kind="bar",ax=ax, figsize=(10,10), color="red")
voice_usage[3:6].plot(stacked=True, kind="bar",ax=ax, figsize=(10,10), color="blue")
# Green - 0
# Red - 1
# Blue - 2
# Out:
# <AxesSubplot:xlabel='Cluster,VOICE_Categorical'>

# %% [markdown]
# ## IDD Usage

# %%
idd_usage = user_profile[["Cluster","IDD_Overall_Categorical"]].value_counts().sort_index()
idd_usage
# Out:
# Cluster  IDD_Overall_Categorical
# 0        HIGH                         37
#          LOW                         592
#          MEDIUM                       38
#          NO                         1054
# 1        HIGH                         15
#          LOW                         204
#          MEDIUM                        9
#          NO                          333
# 2        HIGH                         13
#          LOW                         352
#          MEDIUM                       35
#          NO                          625
# dtype: int64

# %%
idd_usage.plot(kind='pie', figsize=(15,15), autopct='%1.1f%%',colors=["#4d9900","#85e085","#99ff33","#b3ffb3","#990099","#df80ff","#ff66ff","#ffe6ff","#004d80","#66c2ff","#0099ff","#99ffff"])
# Out:
# <AxesSubplot:ylabel='None'>

# %%
colors = ['#4D3425','#4D3425','#4D3425','#4D3425','#E4512B','#E4512B','#E4512B','#E4512B',"#C12345","#C12345","#C12345","#C12345"]
idd_usage.plot(stacked=True, kind="bar", figsize=(10,10),color=colors)
# Out:
# <AxesSubplot:xlabel='Cluster,IDD_Overall_Categorical'>

# %%
ax = idd_usage[:4].plot(stacked=True, kind="bar", figsize=(10,10), color="green")
idd_usage[8:12].plot(stacked=True, kind="bar",ax=ax, figsize=(10,10), color="red")
idd_usage[4:8].plot(stacked=True, kind="bar",ax=ax, figsize=(10,10), color="blue")
#  0 - Blue , 1 - Red , 2- Green
# Out:
# <AxesSubplot:xlabel='Cluster,IDD_Overall_Categorical'>

# %% [markdown]
# ## BraodBand Usage analysis

# %%
bb_usage = user_profile[["Cluster","BB_Categorical"]].value_counts().sort_index()
bb_usage
# Out:
# Cluster  BB_Categorical
# 0        LOW                 55
#          MEDIUM               3
#          NO                1663
# 1        HIGH               101
#          LOW                257
#          MEDIUM             203
# 2        HIGH                95
#          LOW                380
#          MEDIUM             146
#          NO                 404
# dtype: int64

# %%
bb_usage.plot(kind='pie', figsize=(15,15), autopct='%1.1f%%',colors=["#85e085","#4d9900","#b3ffb3","#990099","#df80ff","#ff66ff","#004d80","#66c2ff","#0099ff","#99ffff"])
# Out:
# <AxesSubplot:ylabel='None'>

# %%
colors = ['#4D3425','#4D3425','#4D3425','#E4512B','#E4512B','#E4512B',"#C12345","#C12345","#C12345","#C12345"]
bb_usage.plot(stacked=True, kind="bar", figsize=(10,10), color=colors)
# Out:
# <AxesSubplot:xlabel='Cluster,BB_Categorical'>

# %% [markdown]
# ### Identifying factors for recommending Broadband for Cluster 0

# %%
# Cluster 2 --> 61% Broadband Users, first I'll Identify thier features and then compare with cluster 0

# %%
scaler = MinMaxScaler()
cluster_0["Location_Identifier"] = cluster_0["Location_Identifier"].astype("category")
cluster_0["Location_Identifier_Scaled"] = cluster_0["Location_Identifier"].cat.codes
cluster_0["Location_Identifier_Scaled"] = scaler.fit_transform(cluster_0["Location_Identifier_Scaled"].values.reshape(-1,1))
# Out:
# <ipython-input-99-4c4db900b709>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-99-4c4db900b709>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-99-4c4db900b709>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(15,8))
cluster_0.corr()['Location_Identifier_Scaled'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
cluster_0_loc = cluster_0.groupby('Location_Identifier').count()["event_source.hash"]

# %% [markdown]
# #### Feasible locations to offer BroadBand Internet compared to Double Play Users

# %%
cluster_2_bb_loc = cluster_2_bb.groupby('Location_Identifier').count()["event_source.hash"]

# %%
ax = cluster_0_loc.plot(stacked=True, kind="bar", figsize=(18,10), color="green")
cluster_2_bb_loc.plot(stacked=True, kind="bar",ax=ax, figsize=(18,10), color="blue")
# green cluser 0
# blue Cluster 1 BB
# Out:
# <AxesSubplot:xlabel='Location_Identifier'>

# %%
loc_precentage=(cluster_2_bb_loc/cluster_0_loc)*100

# %%
loc_precentage[(loc_precentage > 60)]
# Out:
# Location_Identifier
# MSAG5200-ISLGE-NODE5577981          62.500000
# MSAG5200-ISLHO-NODE524692          100.000000
# MSAG5200-ISLJA-PKV-NODE460421      200.000000
# MSAG5200-ISLMLT-VMD-NODE4145091    408.333333
# MSAG5200-ISLNL-HGW-NODE491281       71.428571
# MSAG5200-ISLPC-AGT-NODE480031       69.565217
# MSAG5200-ISLPRN-NODE427901         400.000000
# MSAG5200-ISLTBT-TLJ-NODE487241      80.000000
# MSAG5200-ISLVA-NKM-NODE481961      177.777778
# MSAG5200-ISLWI-NWT-NODE485201      100.000000
# UA5000(IPMB)SL-NODE385341           61.038961
# ZXDSL9806H-ISLAG-PNP-NODE529761     66.666667
# ZXDSL9806H-ISLKE-NRP-NODE495731    120.000000
# Name: event_source.hash, dtype: float64

# %%
# Relationship with Socio economic Factors

# %% [markdown]
# ## PeoTV Usage analysis

# %%
peo_usage = user_profile[["Cluster","PEO_TV_Categorical"]].value_counts().sort_index()
peo_usage
# Out:
# Cluster  PEO_TV_Categorical
# 0        LOW                     54
#          MEDIUM                   4
#          NO                    1663
# 1        HIGH                   385
#          LOW                     14
#          MEDIUM                 162
# 2        HIGH                   211
#          LOW                     58
#          MEDIUM                 135
#          NO                     621
# dtype: int64

# %%
peo_usage.plot(kind='pie', figsize=(15,15), autopct='%1.1f%%',colors=["#85e085","#4d9900","#b3ffb3","#990099","#df80ff","#ff66ff","#004d80","#66c2ff","#0099ff","#99ffff"])
# Out:
# <AxesSubplot:ylabel='None'>

# %%
colors = ['#4D3425','#4D3425','#4D3425','#E4512B','#E4512B','#E4512B',"#C12345","#C12345","#C12345","#C12345"]
peo_usage.plot(stacked=True, kind="bar", figsize=(10,10),color=colors)
# Out:
# <AxesSubplot:xlabel='Cluster,PEO_TV_Categorical'>

# %% [markdown]
# ### Identifying factors for recommending PeoTV for Cluster 0

# %%
# Cluster 2 --> 39% PeoTV Users, first I'll Identify thier features and then compare with cluster 0

# %% [markdown]
# #### Feasible locations to offer PeoTV compared to Double Play Users

# %%
cluster_2_peo_loc = cluster_2_peo.groupby('Location_Identifier').count()["event_source.hash"]

# %%
ax = cluster_0_loc.plot(stacked=True, kind="bar", figsize=(18,10), color="green")
cluster_2_peo_loc.plot(stacked=True, kind="bar",ax=ax, figsize=(18,10), color="blue")
# green cluser 0
# blue Cluster 1 BB
# Out:
# <AxesSubplot:xlabel='Location_Identifier'>

# %%
loc_precentage=(cluster_2_peo_loc/cluster_0_loc)*100

# %%
loc_precentage[(loc_precentage > 60)]
# Out:
# Location_Identifier
# C300MPDT-NODE13379431               80.000000
# MSAG5200-ISLHNT-NODE423851          75.000000
# MSAG5200-ISLTBL-NODE5577771         66.666667
# MSAG5200-ISLWI-NWT-NODE485201       83.333333
# MSAG5200-ISLWM-NODE432881           66.666667
# MSAG5200HPG-NODE432141             100.000000
# ZXDSL9806H-ISLKE-NRP-NODE495731     80.000000
# Name: event_source.hash, dtype: float64

# %% [markdown]
# ### Feasible locations to offer peoTV and Broadband compared to Triple Play Users

# %%
cluster_1_peo_loc = cluster_1.groupby('Location_Identifier').count()["event_source.hash"]

# %%
ax = cluster_0_loc.plot(stacked=True, kind="bar", figsize=(18,10), color="pink")
cluster_1_peo_loc.plot(stacked=True, kind="bar",ax=ax, figsize=(18,10), color="red")
# pink cluser 0
# red Cluster 1 PeoTV
# Out:
# <AxesSubplot:xlabel='Location_Identifier'>

# %%
loc_precentage=(cluster_1_peo_loc/cluster_0_loc)*100

# %%
loc_precentage[(loc_precentage > 60)]
# Out:
# Location_Identifier
# C300MHT-NE-NODE8152461              62.500000
# C300MIDH-IDJ-NODE11065541           61.290323
# MSAG5200-ISLHC-NAP-NODE478721       71.428571
# MSAG5200-ISLHK-OCC-NODE506561       71.428571
# MSAG5200-ISLHNT-NODE423851         200.000000
# MSAG5200-ISLMH-POL-NODE491451       62.222222
# MSAG5200-ISLPK-PNU-NODE6136021     100.000000
# MSAG5200-ISLWI-NWT-NODE485201       66.666667
# MSAG5200HPG-NODE432141             140.000000
# MSAG5200PK-NODE438641               80.000000
# ZXDSL9806H-ISLKE-NRP-NODE495731    100.000000
# Name: event_source.hash, dtype: float64
